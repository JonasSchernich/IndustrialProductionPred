# %%
# --- Setup & Imports ---
import os, sys
from pathlib import Path
import pandas as pd
import numpy as np

# --- 1. Pfad-Setup ---
def _locate_repo_root(start: Path) -> Path:
    cur = start.resolve()
    for _ in range(5):
        if (cur / 'src').exists():
            return cur
        if cur.parent == cur:
            break
        cur = cur.parent
    return start.resolve()

NOTEBOOK_DIR = Path.cwd()
PROJECT_ROOT = _locate_repo_root(NOTEBOOK_DIR)
os.environ['PROJECT_ROOT'] = str(PROJECT_ROOT)
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from src.config import GlobalConfig, DEFAULT_CORR_SPEC, EWMA_CORR_SPEC, outputs_for_model
from src.tuning import run_stageA, run_stageB
from src.io_timesplits import (
    load_target, load_ifo_features,
    load_full_lagged_features, load_rolling_importance # NEUE IMPORTE
)
# --- MODELL-IMPORT ---
from src.models.ET import ForecastModel # Nutzt ExtraTreesRegressor

print('PROJECT_ROOT =', PROJECT_ROOT)
# --- NEU: Pfad zur Feature-Importance-Output-Ordner ---
FI_PATH = PROJECT_ROOT / "outputs" / "feature_importance" /"outputs_no_missing"

# --- NEUER MASTER-SCHALTER ---
# Setze auf False, um die originale "Gleis 1/2" Pipeline (volles FE-Tuning) zu fahren
# Setze auf True, um die "Gleis 3" Pipeline (dynamische FI-Features) zu fahren
USE_DYNAMIC_FI_PIPELINE = True
# -----------------------------

# --- MODELLNAME ---
if USE_DYNAMIC_FI_PIPELINE:
    MODEL_NAME = "extra_trees_dynamic_fi" # Separater Output-Ordner
else:
    MODEL_NAME = "extra_trees" # Originaler Ordner

outputs_for_model(MODEL_NAME)
print(f'Modell {MODEL_NAME} wird getunt.')

# --- 2. Daten laden ---
y = load_target()  # ΔIP with DatetimeIndex
X_ifo = load_ifo_features() # ifo features (nur für Gleis 1/2)

# Lade die Daten für Gleis 3 (optional)
if USE_DYNAMIC_FI_PIPELINE:
    try:
        X_full_lagged = load_full_lagged_features(base_dir=FI_PATH)
        rolling_imp = load_rolling_importance(base_dir=FI_PATH)
        # Datenabgleich
        idx_fi = y.index.intersection(X_full_lagged.index).intersection(rolling_imp.index)
        y_fi, X_full_lagged, rolling_imp = y.loc[idx_fi], X_full_lagged.loc[idx_fi], rolling_imp.loc[idx_fi]
        print('Gleis 3-Daten geladen. Shapes:', X_full_lagged.shape, rolling_imp.shape)
    except FileNotFoundError as e:
        print(f"FEHLER: {e}")
        print("Stelle sicher, dass `feature_importance.ipynb` (Jobs 1 & 3) erfolgreich durchgelaufen ist.")
        # Beende das Skript, wenn die Daten fehlen
        raise
else:
    X_full_lagged, rolling_imp = None, None
    idx = y.index.intersection(X_ifo.index)
    y, X_ifo = y.loc[idx], X_ifo.loc[idx]
    print('Gleis 1/2-Daten geladen. Shapes:', X_ifo.shape, y.shape)


# --- 3. Base config (splits & policy as in thesis) ---
def base_cfg() -> GlobalConfig:
    cfg = GlobalConfig(preset="thesis") # Lädt Thesis-Splits (180, 240, etc.)
    # Policy Parameter
    cfg.policy_window   = 24
    cfg.policy_decay    = 0.95
    cfg.policy_gain_min = 0.03
    cfg.policy_cooldown = 3
    return cfg

cfg0 = base_cfg()

# --- 4. Helper für Korrelations-Spezifikation (bleibt gleich) ---
def make_corr_spec(kind: str) -> dict:
    if kind == 'expanding':
        return dict(DEFAULT_CORR_SPEC)
    elif kind == 'ewm':
        return dict(EWMA_CORR_SPEC)
    else:
        raise ValueError("kind must be 'expanding' or 'ewm'")

# --- 5. TUNING-GRID (Logik-Switch) ---

if USE_DYNAMIC_FI_PIPELINE:
    # --- GRID FÜR GLEIS 3 (Nur Modell-HPs) ---
    print("Erstelle HP-Grid für 'Dynamic FI' (Gleis 3)...")
    N_FEATURES_TO_USE = 20 # Anzahl der Top-Features, die wir auswählen

    n_estimators_list = [100, 300, 500]
    max_features_list = ['sqrt', 0.2, 0.4]
    min_samples_leaf_list = [5, 15, 30]
    weighting_options = [
        {"sample_weight_decay": None},
        {"sample_weight_decay": 0.98}
    ]

    def build_model_grid_dynamic_fi():
        hp_grid = []
        for n_est in n_estimators_list:
            for max_feat in max_features_list:
                for min_leaf in min_samples_leaf_list:
                    for weight_hp in weighting_options:
                        hp = {
                            'n_features_to_use': N_FEATURES_TO_USE,
                            'n_estimators': n_est,
                            'max_features': max_feat,
                            'min_samples_leaf': min_leaf,
                            **weight_hp,
                        }
                        hp_grid.append(hp)
        return hp_grid

    model_grid = build_model_grid_dynamic_fi()

else:
    # --- GRID FÜR GLEIS 1/2 (Original-Grid) ---
    print("Erstelle HP-Grid für 'Full FE' (Gleis 1/2)...")

    # A) Feature Engineering Parameter Listen
    corr_options = [
        ("expanding", make_corr_spec("expanding")),
        ("ewm", make_corr_spec("ewm"))
    ]
    lag_candidates_list = [(1, 2, 3, 6, 12)]
    top_k_lags_list = [1] # Reduziert
    use_rm3_list = [True] # Reduziert
    k1_topk_list = [100, 300]
    redundancy_param_list = [0.90] # Reduziert
    dr_options_list = [
        {'dr_method': 'none'},
        {'dr_method': 'pca', 'pca_var_target': 0.95, 'pca_kmax': 50},
        {'dr_method': 'pls', 'pls_components': 8}
    ]

    # B) Extra Trees Hyperparameter Listen
    n_estimators_list = [300]
    max_features_list = ['sqrt', 0.3] # Reduziert
    min_samples_leaf_list = [5, 15] # Reduziert (von [5] im alten Code, um mehr zu testen)

    # C) Target Blocks & Weighting Listen
    target_block_options = [ None, ["AR1"], ["Chronos"], ["TSFresh"] ]
    weighting_options = [ {"sample_weight_decay": None} ] # Reduziert

    # D) Grid zusammensetzen
    def build_model_grid_optimized():
        hp_grid = []
        for corr_tag, corr_spec in corr_options: # 2
            for lags in lag_candidates_list: # 1
                for k_lags in top_k_lags_list: # 1
                    for rm3 in use_rm3_list: # 1
                        for k1 in k1_topk_list: # 2
                            for red in redundancy_param_list: # 1
                                for dr_opt in dr_options_list: # 3
                                    # Einschränkung
                                    if k1 == 100 and dr_opt['dr_method'] != 'none': continue
                                    # Total FE/DR = (100,none) + (300,none) + (300,pca) + (300,pls) = 4

                                    for n_est in n_estimators_list: # 1
                                        for max_feat in max_features_list: # 2
                                            for min_leaf in min_samples_leaf_list: # 2
                                                for block_set in target_block_options: # 4
                                                    for weight_hp in weighting_options: # 1
                                                        hp = {
                                                            # FE Params
                                                            'lag_candidates': lags,
                                                            'top_k_lags_per_feature': k_lags,
                                                            'use_rm3': rm3,
                                                            'k1_topk': k1,
                                                            'redundancy_param': red,
                                                            **dr_opt,
                                                            # ET Params
                                                            'n_estimators': n_est,
                                                            'max_features': max_feat,
                                                            'min_samples_leaf': min_leaf,
                                                            # Other Params
                                                            **weight_hp,
                                                            'corr_tag': corr_tag,
                                                            'corr_spec': corr_spec,
                                                            'target_block_set': block_set
                                                        }
                                                        hp_grid.append(hp)
        return hp_grid

    model_grid = build_model_grid_optimized()

print("Optimierte HP-Kombinationen:", len(model_grid))
print("Erstes HP-Set:", model_grid[0] if model_grid else "Grid ist leer")


# --- 6. Stage A/B Lauf (Logik-Switch) ---
if model_grid:
    if USE_DYNAMIC_FI_PIPELINE:
        # --- LAUF FÜR GLEIS 3 ---
        shortlist = run_stageA(
            model_name=MODEL_NAME,
            model_ctor=lambda hp: ForecastModel(hp),
            model_grid=model_grid,
            X=X_ifo, # Platzhalter, wird nicht verwendet
            y=y_fi,
            cfg=cfg0,
            keep_top_k_final=min(5, len(model_grid)),
            min_survivors_per_block=max(1, len(model_grid)//4),
            # NEUE ARGUMENTE
            X_full_lagged=X_full_lagged,
            rolling_imp=rolling_imp
        )

        run_stageB(
            model_name=MODEL_NAME,
            model_ctor=lambda hp: ForecastModel(hp),
            shortlist=shortlist,
            X=X_ifo, # Platzhalter, wird nicht verwendet
            y=y_fi,
            cfg=cfg0,
            # NEUE ARGUMENTE
            X_full_lagged=X_full_lagged,
            rolling_imp=rolling_imp
        )
    else:
        # --- LAUF FÜR GLEIS 1/2 (Original) ---
        shortlist = run_stageA(
            model_name=MODEL_NAME,
            model_ctor=lambda hp: ForecastModel(hp),
            model_grid=model_grid,
            X=X_ifo,
            y=y,
            cfg=cfg0,
            keep_top_k_final=min(5, len(model_grid)),
            min_survivors_per_block=max(1, len(model_grid)//4),
            # (Keine extra Argumente)
        )

        run_stageB(
            model_name=MODEL_NAME,
            model_ctor=lambda hp: ForecastModel(hp),
            shortlist=shortlist,
            X=X_ifo,
            y=y,
            cfg=cfg0,
            # (Keine extra Argumente)
        )
else:
    print("Keine gültigen HP-Kombinationen gefunden, Stages übersprungen.")

print(f"\nDone. Check outputs/stageA|stageB/{MODEL_NAME} for results.")
# Out:
# PROJECT_ROOT = /Users/jonasschernich/Documents/Masterarbeit/Code
# Modell extra_trees_dynamic_fi wird getunt.
# INFO in load_ifo_features: Renaming columns to ensure validity.
# Gleis 3-Daten geladen. Shapes: (407, 2160) (407, 2160)
# Erstelle HP-Grid für 'Dynamic FI' (Gleis 3)...
# Optimierte HP-Kombinationen: 54
# Erstes HP-Set: {'n_features_to_use': 20, 'n_estimators': 100, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'sample_weight_decay': None}
# [Stage A] Using DYNAMIC FI pipeline (Gleis 3).
# [Stage A][Block 1] train_end=180, OOS=181-200 | configs=54
#   - Config 1/54
#     · Month 5/20 processed | running...RMSE=1.7381
#     · Month 10/20 processed | running...RMSE=1.4005
#     · Month 15/20 processed | running...RMSE=1.3165
#     · Month 20/20 processed | running...RMSE=1.2315
#   - Config 2/54
#     · Month 5/20 processed | running...RMSE=1.7815
#     · Month 10/20 processed | running...RMSE=1.4469
#     · Month 15/20 processed | running...RMSE=1.3498
#     · Month 20/20 processed | running...RMSE=1.2461
#   - Config 3/54
#     · Month 5/20 processed | running...RMSE=1.6565
#     · Month 10/20 processed | running...RMSE=1.3258
#     · Month 15/20 processed | running...RMSE=1.2472
#     · Month 20/20 processed | running...RMSE=1.1437
#   - Config 4/54
#     · Month 5/20 processed | running...RMSE=1.6751
#     · Month 10/20 processed | running...RMSE=1.3431
#     · Month 15/20 processed | running...RMSE=1.2632
#     · Month 20/20 processed | running...RMSE=1.1469
#   - Config 5/54
#     · Month 5/20 processed | running...RMSE=1.6372
#     · Month 10/20 processed | running...RMSE=1.3087
#     · Month 15/20 processed | running...RMSE=1.2292
#     · Month 20/20 processed | running...RMSE=1.1093
#   - Config 6/54
#     · Month 5/20 processed | running...RMSE=1.6503
#     · Month 10/20 processed | running...RMSE=1.3138
#     · Month 15/20 processed | running...RMSE=1.2288
#     · Month 20/20 processed | running...RMSE=1.1005
#   - Config 7/54
#     · Month 5/20 processed | running...RMSE=1.7381
#     · Month 10/20 processed | running...RMSE=1.4005
#     · Month 15/20 processed | running...RMSE=1.3165
#     · Month 20/20 processed | running...RMSE=1.2315
#   - Config 8/54
#     · Month 5/20 processed | running...RMSE=1.7815
#     · Month 10/20 processed | running...RMSE=1.4469
#     · Month 15/20 processed | running...RMSE=1.3498
#     · Month 20/20 processed | running...RMSE=1.2461
#   - Config 9/54
#     · Month 5/20 processed | running...RMSE=1.6565
#     · Month 10/20 processed | running...RMSE=1.3258
#     · Month 15/20 processed | running...RMSE=1.2472
#     · Month 20/20 processed | running...RMSE=1.1437
#   - Config 10/54
#     · Month 5/20 processed | running...RMSE=1.6751
#     · Month 10/20 processed | running...RMSE=1.3431
#     · Month 15/20 processed | running...RMSE=1.2632
#     · Month 20/20 processed | running...RMSE=1.1469
#   - Config 11/54
#     · Month 5/20 processed | running...RMSE=1.6372
#     · Month 10/20 processed | running...RMSE=1.3087
#     · Month 15/20 processed | running...RMSE=1.2292
#     · Month 20/20 processed | running...RMSE=1.1093
#   - Config 12/54
#     · Month 5/20 processed | running...RMSE=1.6503
#     · Month 10/20 processed | running...RMSE=1.3138
#     · Month 15/20 processed | running...RMSE=1.2288
#     · Month 20/20 processed | running...RMSE=1.1005
#   - Config 13/54
#     · Month 5/20 processed | running...RMSE=1.6109
#     · Month 10/20 processed | running...RMSE=1.2973
#     · Month 15/20 processed | running...RMSE=1.2497
#     · Month 20/20 processed | running...RMSE=1.2185
#   - Config 14/54
#     · Month 5/20 processed | running...RMSE=1.7373
#     · Month 10/20 processed | running...RMSE=1.4104
#     · Month 15/20 processed | running...RMSE=1.3498
#     · Month 20/20 processed | running...RMSE=1.2681
#   - Config 15/54
#     · Month 5/20 processed | running...RMSE=1.6533
#     · Month 10/20 processed | running...RMSE=1.3225
#     · Month 15/20 processed | running...RMSE=1.2377
#     · Month 20/20 processed | running...RMSE=1.1476
#   - Config 16/54
#     · Month 5/20 processed | running...RMSE=1.7069
#     · Month 10/20 processed | running...RMSE=1.3693
#     · Month 15/20 processed | running...RMSE=1.2885
#     · Month 20/20 processed | running...RMSE=1.1817
#   - Config 17/54
#     · Month 5/20 processed | running...RMSE=1.6333
#     · Month 10/20 processed | running...RMSE=1.3058
#     · Month 15/20 processed | running...RMSE=1.2249
#     · Month 20/20 processed | running...RMSE=1.1165
#   - Config 18/54
#     · Month 5/20 processed | running...RMSE=1.6569
#     · Month 10/20 processed | running...RMSE=1.3212
#     · Month 15/20 processed | running...RMSE=1.2327
#     · Month 20/20 processed | running...RMSE=1.1093
#   - Config 19/54
#     · Month 5/20 processed | running...RMSE=1.6881
#     · Month 10/20 processed | running...RMSE=1.3644
#     · Month 15/20 processed | running...RMSE=1.2887
#     · Month 20/20 processed | running...RMSE=1.2061
#   - Config 20/54
#     · Month 5/20 processed | running...RMSE=1.7639
#     · Month 10/20 processed | running...RMSE=1.4323
#     · Month 15/20 processed | running...RMSE=1.3397
#     · Month 20/20 processed | running...RMSE=1.2409
#   - Config 21/54
#     · Month 5/20 processed | running...RMSE=1.6516
#     · Month 10/20 processed | running...RMSE=1.3229
#     · Month 15/20 processed | running...RMSE=1.2439
#     · Month 20/20 processed | running...RMSE=1.1352
#   - Config 22/54
#     · Month 5/20 processed | running...RMSE=1.6767
#     · Month 10/20 processed | running...RMSE=1.3420
#     · Month 15/20 processed | running...RMSE=1.2600
#     · Month 20/20 processed | running...RMSE=1.1425
#   - Config 23/54
#     · Month 5/20 processed | running...RMSE=1.6459
#     · Month 10/20 processed | running...RMSE=1.3157
#     · Month 15/20 processed | running...RMSE=1.2334
#     · Month 20/20 processed | running...RMSE=1.1118
#   - Config 24/54
#     · Month 5/20 processed | running...RMSE=1.6471
#     · Month 10/20 processed | running...RMSE=1.3097
#     · Month 15/20 processed | running...RMSE=1.2263
#     · Month 20/20 processed | running...RMSE=1.0985
#   - Config 25/54
#     · Month 5/20 processed | running...RMSE=1.6881
#     · Month 10/20 processed | running...RMSE=1.3644
#     · Month 15/20 processed | running...RMSE=1.2887
#     · Month 20/20 processed | running...RMSE=1.2061
#   - Config 26/54
#     · Month 5/20 processed | running...RMSE=1.7639
#     · Month 10/20 processed | running...RMSE=1.4323
#     · Month 15/20 processed | running...RMSE=1.3397
#     · Month 20/20 processed | running...RMSE=1.2409
#   - Config 27/54
#     · Month 5/20 processed | running...RMSE=1.6516
#     · Month 10/20 processed | running...RMSE=1.3229
#     · Month 15/20 processed | running...RMSE=1.2439
#     · Month 20/20 processed | running...RMSE=1.1352
#   - Config 28/54
#     · Month 5/20 processed | running...RMSE=1.6767
#     · Month 10/20 processed | running...RMSE=1.3420
#     · Month 15/20 processed | running...RMSE=1.2600
#     · Month 20/20 processed | running...RMSE=1.1425
#   - Config 29/54
#     · Month 5/20 processed | running...RMSE=1.6459
#     · Month 10/20 processed | running...RMSE=1.3157
#     · Month 15/20 processed | running...RMSE=1.2334
#     · Month 20/20 processed | running...RMSE=1.1118
#   - Config 30/54
#     · Month 5/20 processed | running...RMSE=1.6471
#     · Month 10/20 processed | running...RMSE=1.3097
#     · Month 15/20 processed | running...RMSE=1.2263
#     · Month 20/20 processed | running...RMSE=1.0985
#   - Config 31/54
#     · Month 5/20 processed | running...RMSE=1.6427
#     · Month 10/20 processed | running...RMSE=1.3335
#     · Month 15/20 processed | running...RMSE=1.2709
#     · Month 20/20 processed | running...RMSE=1.2273
#   - Config 32/54
#     · Month 5/20 processed | running...RMSE=1.8190
#     · Month 10/20 processed | running...RMSE=1.4680
#     · Month 15/20 processed | running...RMSE=1.3837
#     · Month 20/20 processed | running...RMSE=1.3011
#   - Config 33/54
#     · Month 5/20 processed | running...RMSE=1.6591
#     · Month 10/20 processed | running...RMSE=1.3279
#     · Month 15/20 processed | running...RMSE=1.2503
#     · Month 20/20 processed | running...RMSE=1.1562
#   - Config 34/54
#     · Month 5/20 processed | running...RMSE=1.7009
#     · Month 10/20 processed | running...RMSE=1.3572
#     · Month 15/20 processed | running...RMSE=1.2755
#     · Month 20/20 processed | running...RMSE=1.1672
#   - Config 35/54
#     · Month 5/20 processed | running...RMSE=1.6493
#     · Month 10/20 processed | running...RMSE=1.3203
#     · Month 15/20 processed | running...RMSE=1.2376
#     · Month 20/20 processed | running...RMSE=1.1246
#   - Config 36/54
#     · Month 5/20 processed | running...RMSE=1.6675
#     · Month 10/20 processed | running...RMSE=1.3271
#     · Month 15/20 processed | running...RMSE=1.2395
#     · Month 20/20 processed | running...RMSE=1.1146
#   - Config 37/54
#     · Month 5/20 processed | running...RMSE=1.6802
#     · Month 10/20 processed | running...RMSE=1.3572
#     · Month 15/20 processed | running...RMSE=1.2832
#     · Month 20/20 processed | running...RMSE=1.1975
#   - Config 38/54
#     · Month 5/20 processed | running...RMSE=1.7513
#     · Month 10/20 processed | running...RMSE=1.4131
#     · Month 15/20 processed | running...RMSE=1.3254
#     · Month 20/20 processed | running...RMSE=1.2263
#   - Config 39/54
#     · Month 5/20 processed | running...RMSE=1.6453
#     · Month 10/20 processed | running...RMSE=1.3181
#     · Month 15/20 processed | running...RMSE=1.2413
#     · Month 20/20 processed | running...RMSE=1.1316
#   - Config 40/54
#     · Month 5/20 processed | running...RMSE=1.6728
#     · Month 10/20 processed | running...RMSE=1.3371
#     · Month 15/20 processed | running...RMSE=1.2555
#     · Month 20/20 processed | running...RMSE=1.1379
#   - Config 41/54
#     · Month 5/20 processed | running...RMSE=1.6449
#     · Month 10/20 processed | running...RMSE=1.3163
#     · Month 15/20 processed | running...RMSE=1.2350
#     · Month 20/20 processed | running...RMSE=1.1128
#   - Config 42/54
#     · Month 5/20 processed | running...RMSE=1.6491
#     · Month 10/20 processed | running...RMSE=1.3119
#     · Month 15/20 processed | running...RMSE=1.2293
#     · Month 20/20 processed | running...RMSE=1.1016
#   - Config 43/54
#     · Month 5/20 processed | running...RMSE=1.6802
#     · Month 10/20 processed | running...RMSE=1.3572
#     · Month 15/20 processed | running...RMSE=1.2832
#     · Month 20/20 processed | running...RMSE=1.1975
#   - Config 44/54
#     · Month 5/20 processed | running...RMSE=1.7513
#     · Month 10/20 processed | running...RMSE=1.4131
#     · Month 15/20 processed | running...RMSE=1.3254
#     · Month 20/20 processed | running...RMSE=1.2263
#   - Config 45/54
#     · Month 5/20 processed | running...RMSE=1.6453
#     · Month 10/20 processed | running...RMSE=1.3181
#     · Month 15/20 processed | running...RMSE=1.2413
#     · Month 20/20 processed | running...RMSE=1.1316
#   - Config 46/54
#     · Month 5/20 processed | running...RMSE=1.6728
#     · Month 10/20 processed | running...RMSE=1.3371
#     · Month 15/20 processed | running...RMSE=1.2555
#     · Month 20/20 processed | running...RMSE=1.1379
#   - Config 47/54
#     · Month 5/20 processed | running...RMSE=1.6449
#     · Month 10/20 processed | running...RMSE=1.3163
#     · Month 15/20 processed | running...RMSE=1.2350
#     · Month 20/20 processed | running...RMSE=1.1128
#   - Config 48/54
#     · Month 5/20 processed | running...RMSE=1.6491
#     · Month 10/20 processed | running...RMSE=1.3119
#     · Month 15/20 processed | running...RMSE=1.2293
#     · Month 20/20 processed | running...RMSE=1.1016
#   - Config 49/54
#     · Month 5/20 processed | running...RMSE=1.6727
#     · Month 10/20 processed | running...RMSE=1.3501
#     · Month 15/20 processed | running...RMSE=1.2843
#     · Month 20/20 processed | running...RMSE=1.2356
#   - Config 50/54
#     · Month 5/20 processed | running...RMSE=1.8318
#     · Month 10/20 processed | running...RMSE=1.4816
#     · Month 15/20 processed | running...RMSE=1.3927
#     · Month 20/20 processed | running...RMSE=1.3095
#   - Config 51/54
#     · Month 5/20 processed | running...RMSE=1.6560
#     · Month 10/20 processed | running...RMSE=1.3272
#     · Month 15/20 processed | running...RMSE=1.2513
#     · Month 20/20 processed | running...RMSE=1.1564
#   - Config 52/54
#     · Month 5/20 processed | running...RMSE=1.6978
#     · Month 10/20 processed | running...RMSE=1.3533
#     · Month 15/20 processed | running...RMSE=1.2750
#     · Month 20/20 processed | running...RMSE=1.1673
#   - Config 53/54
#     · Month 5/20 processed | running...RMSE=1.6432
#     · Month 10/20 processed | running...RMSE=1.3159
#     · Month 15/20 processed | running...RMSE=1.2344
#     · Month 20/20 processed | running...RMSE=1.1208
#   - Config 54/54
#     · Month 5/20 processed | running...RMSE=1.6688
#     · Month 10/20 processed | running...RMSE=1.3276
#     · Month 15/20 processed | running...RMSE=1.2409
#     · Month 20/20 processed | running...RMSE=1.1166
# [Stage A][Block 1] kept 27 configs (floor=13).
# [Stage A][Block 2] train_end=200, OOS=201-220 | configs=27
#   - Config 1/27
#     · Month 5/20 processed | running...RMSE=0.8896
#     · Month 10/20 processed | running...RMSE=1.2097
#     · Month 15/20 processed | running...RMSE=2.5434
#     · Month 20/20 processed | running...RMSE=2.5597
#   - Config 2/27
#     · Month 5/20 processed | running...RMSE=0.8993
#     · Month 10/20 processed | running...RMSE=1.2351
#     · Month 15/20 processed | running...RMSE=2.6511
#     · Month 20/20 processed | running...RMSE=2.6484
#   - Config 3/27
#     · Month 5/20 processed | running...RMSE=0.9032
#     · Month 10/20 processed | running...RMSE=1.2253
#     · Month 15/20 processed | running...RMSE=2.5023
#     · Month 20/20 processed | running...RMSE=2.5276
#   - Config 4/27
#     · Month 5/20 processed | running...RMSE=0.8896
#     · Month 10/20 processed | running...RMSE=1.2097
#     · Month 15/20 processed | running...RMSE=2.5434
#     · Month 20/20 processed | running...RMSE=2.5597
#   - Config 5/27
#     · Month 5/20 processed | running...RMSE=0.8993
#     · Month 10/20 processed | running...RMSE=1.2351
#     · Month 15/20 processed | running...RMSE=2.6511
#     · Month 20/20 processed | running...RMSE=2.6484
#   - Config 6/27
#     · Month 5/20 processed | running...RMSE=0.9026
#     · Month 10/20 processed | running...RMSE=1.2138
#     · Month 15/20 processed | running...RMSE=2.5164
#     · Month 20/20 processed | running...RMSE=2.5439
#   - Config 7/27
#     · Month 5/20 processed | running...RMSE=0.8924
#     · Month 10/20 processed | running...RMSE=1.2335
#     · Month 15/20 processed | running...RMSE=2.6255
#     · Month 20/20 processed | running...RMSE=2.6344
#   - Config 8/27
#     · Month 5/20 processed | running...RMSE=0.8820
#     · Month 10/20 processed | running...RMSE=1.2114
#     · Month 15/20 processed | running...RMSE=2.5092
#     · Month 20/20 processed | running...RMSE=2.5351
#   - Config 9/27
#     · Month 5/20 processed | running...RMSE=0.8830
#     · Month 10/20 processed | running...RMSE=1.2407
#     · Month 15/20 processed | running...RMSE=2.6085
#     · Month 20/20 processed | running...RMSE=2.6180
#   - Config 10/27
#     · Month 5/20 processed | running...RMSE=0.8917
#     · Month 10/20 processed | running...RMSE=1.2110
#     · Month 15/20 processed | running...RMSE=2.5480
#     · Month 20/20 processed | running...RMSE=2.5629
#   - Config 11/27
#     · Month 5/20 processed | running...RMSE=0.8920
#     · Month 10/20 processed | running...RMSE=1.2305
#     · Month 15/20 processed | running...RMSE=2.6472
#     · Month 20/20 processed | running...RMSE=2.6429
#   - Config 12/27
#     · Month 5/20 processed | running...RMSE=0.8820
#     · Month 10/20 processed | running...RMSE=1.2114
#     · Month 15/20 processed | running...RMSE=2.5092
#     · Month 20/20 processed | running...RMSE=2.5351
#   - Config 13/27
#     · Month 5/20 processed | running...RMSE=0.8830
#     · Month 10/20 processed | running...RMSE=1.2407
#     · Month 15/20 processed | running...RMSE=2.6085
#     · Month 20/20 processed | running...RMSE=2.6180
#   - Config 14/27
#     · Month 5/20 processed | running...RMSE=0.8917
#     · Month 10/20 processed | running...RMSE=1.2110
#     · Month 15/20 processed | running...RMSE=2.5480
#     · Month 20/20 processed | running...RMSE=2.5629
#   - Config 15/27
#     · Month 5/20 processed | running...RMSE=0.8920
#     · Month 10/20 processed | running...RMSE=1.2305
#     · Month 15/20 processed | running...RMSE=2.6472
#     · Month 20/20 processed | running...RMSE=2.6429
#   - Config 16/27
#     · Month 5/20 processed | running...RMSE=0.8985
#     · Month 10/20 processed | running...RMSE=1.2116
#     · Month 15/20 processed | running...RMSE=2.5100
#     · Month 20/20 processed | running...RMSE=2.5391
#   - Config 17/27
#     · Month 5/20 processed | running...RMSE=0.8911
#     · Month 10/20 processed | running...RMSE=1.2335
#     · Month 15/20 processed | running...RMSE=2.6155
#     · Month 20/20 processed | running...RMSE=2.6257
#   - Config 18/27
#     · Month 5/20 processed | running...RMSE=0.8876
#     · Month 10/20 processed | running...RMSE=1.2128
#     · Month 15/20 processed | running...RMSE=2.5031
#     · Month 20/20 processed | running...RMSE=2.5302
#   - Config 19/27
#     · Month 5/20 processed | running...RMSE=0.8884
#     · Month 10/20 processed | running...RMSE=1.2388
#     · Month 15/20 processed | running...RMSE=2.6031
#     · Month 20/20 processed | running...RMSE=2.6130
#   - Config 20/27
#     · Month 5/20 processed | running...RMSE=0.8924
#     · Month 10/20 processed | running...RMSE=1.2132
#     · Month 15/20 processed | running...RMSE=2.5451
#     · Month 20/20 processed | running...RMSE=2.5603
#   - Config 21/27
#     · Month 5/20 processed | running...RMSE=0.8933
#     · Month 10/20 processed | running...RMSE=1.2326
#     · Month 15/20 processed | running...RMSE=2.6368
#     · Month 20/20 processed | running...RMSE=2.6342
#   - Config 22/27
#     · Month 5/20 processed | running...RMSE=0.8876
#     · Month 10/20 processed | running...RMSE=1.2128
#     · Month 15/20 processed | running...RMSE=2.5031
#     · Month 20/20 processed | running...RMSE=2.5302
#   - Config 23/27
#     · Month 5/20 processed | running...RMSE=0.8884
#     · Month 10/20 processed | running...RMSE=1.2388
#     · Month 15/20 processed | running...RMSE=2.6031
#     · Month 20/20 processed | running...RMSE=2.6130
#   - Config 24/27
#     · Month 5/20 processed | running...RMSE=0.8924
#     · Month 10/20 processed | running...RMSE=1.2132
#     · Month 15/20 processed | running...RMSE=2.5451
#     · Month 20/20 processed | running...RMSE=2.5603
#   - Config 25/27
#     · Month 5/20 processed | running...RMSE=0.8933
#     · Month 10/20 processed | running...RMSE=1.2326
#     · Month 15/20 processed | running...RMSE=2.6368
#     · Month 20/20 processed | running...RMSE=2.6342
#   - Config 26/27
#     · Month 5/20 processed | running...RMSE=0.9016
#     · Month 10/20 processed | running...RMSE=1.2170
#     · Month 15/20 processed | running...RMSE=2.5119
#     · Month 20/20 processed | running...RMSE=2.5401
#   - Config 27/27
#     · Month 5/20 processed | running...RMSE=0.8948
#     · Month 10/20 processed | running...RMSE=1.2352
#     · Month 15/20 processed | running...RMSE=2.6126
#     · Month 20/20 processed | running...RMSE=2.6230
# [Stage A][Block 2] kept 14 configs (floor=13).
# [Stage A][Block 3] train_end=220, OOS=221-240 | configs=14
#   - Config 1/14
#     · Month 5/20 processed | running...RMSE=2.0548
#     · Month 10/20 processed | running...RMSE=1.9165
#     · Month 15/20 processed | running...RMSE=1.7812
#     · Month 20/20 processed | running...RMSE=1.6211
#   - Config 2/14
#     · Month 5/20 processed | running...RMSE=2.0482
#     · Month 10/20 processed | running...RMSE=1.8845
#     · Month 15/20 processed | running...RMSE=1.7440
#     · Month 20/20 processed | running...RMSE=1.5868
#   - Config 3/14
#     · Month 5/20 processed | running...RMSE=2.0548
#     · Month 10/20 processed | running...RMSE=1.9165
#     · Month 15/20 processed | running...RMSE=1.7812
#     · Month 20/20 processed | running...RMSE=1.6211
#   - Config 4/14
#     · Month 5/20 processed | running...RMSE=2.0881
#     · Month 10/20 processed | running...RMSE=1.9133
#     · Month 15/20 processed | running...RMSE=1.7655
#     · Month 20/20 processed | running...RMSE=1.5973
#   - Config 5/14
#     · Month 5/20 processed | running...RMSE=2.0668
#     · Month 10/20 processed | running...RMSE=1.9004
#     · Month 15/20 processed | running...RMSE=1.7550
#     · Month 20/20 processed | running...RMSE=1.5903
#   - Config 6/14
#     · Month 5/20 processed | running...RMSE=2.0624
#     · Month 10/20 processed | running...RMSE=1.9179
#     · Month 15/20 processed | running...RMSE=1.7796
#     · Month 20/20 processed | running...RMSE=1.6160
#   - Config 7/14
#     · Month 5/20 processed | running...RMSE=2.0668
#     · Month 10/20 processed | running...RMSE=1.9004
#     · Month 15/20 processed | running...RMSE=1.7550
#     · Month 20/20 processed | running...RMSE=1.5903
#   - Config 8/14
#     · Month 5/20 processed | running...RMSE=2.0624
#     · Month 10/20 processed | running...RMSE=1.9179
#     · Month 15/20 processed | running...RMSE=1.7796
#     · Month 20/20 processed | running...RMSE=1.6160
#   - Config 9/14
#     · Month 5/20 processed | running...RMSE=2.0811
#     · Month 10/20 processed | running...RMSE=1.9089
#     · Month 15/20 processed | running...RMSE=1.7617
#     · Month 20/20 processed | running...RMSE=1.5933
#   - Config 10/14
#     · Month 5/20 processed | running...RMSE=2.0662
#     · Month 10/20 processed | running...RMSE=1.9000
#     · Month 15/20 processed | running...RMSE=1.7526
#     · Month 20/20 processed | running...RMSE=1.5874
#   - Config 11/14
#     · Month 5/20 processed | running...RMSE=2.0617
#     · Month 10/20 processed | running...RMSE=1.9161
#     · Month 15/20 processed | running...RMSE=1.7771
#     · Month 20/20 processed | running...RMSE=1.6139
#   - Config 12/14
#     · Month 5/20 processed | running...RMSE=2.0662
#     · Month 10/20 processed | running...RMSE=1.9000
#     · Month 15/20 processed | running...RMSE=1.7526
#     · Month 20/20 processed | running...RMSE=1.5874
#   - Config 13/14
#     · Month 5/20 processed | running...RMSE=2.0617
#     · Month 10/20 processed | running...RMSE=1.9161
#     · Month 15/20 processed | running...RMSE=1.7771
#     · Month 20/20 processed | running...RMSE=1.6139
#   - Config 14/14
#     · Month 5/20 processed | running...RMSE=2.0825
#     · Month 10/20 processed | running...RMSE=1.9126
#     · Month 15/20 processed | running...RMSE=1.7642
#     · Month 20/20 processed | running...RMSE=1.5956
# [Stage A][Block 3] kept 13 configs (floor=13).
# [Stage A] Shortlist saved with 5 configs.
# [Stage B] Using DYNAMIC FI pipeline (Gleis 3).
# [Stage B] Month origin t=240 | evaluating 5 configs | active=1
# [Stage B] Month origin t=241 | evaluating 5 configs | active=2
# [Stage B] Month origin t=242 | evaluating 5 configs | active=2
# [Stage B] Month origin t=243 | evaluating 5 configs | active=2
# [Stage B] Month origin t=244 | evaluating 5 configs | active=2
# [Stage B] Month origin t=245 | evaluating 5 configs | active=2
# [Stage B] Month origin t=246 | evaluating 5 configs | active=2
# [Stage B] Month origin t=247 | evaluating 5 configs | active=2
# [Stage B] Month origin t=248 | evaluating 5 configs | active=2
# [Stage B] Month origin t=249 | evaluating 5 configs | active=2
# [Stage B] Month origin t=250 | evaluating 5 configs | active=2
# [Stage B] Month origin t=251 | evaluating 5 configs | active=2
# [Stage B] Month origin t=252 | evaluating 5 configs | active=2
# [Stage B] Month origin t=253 | evaluating 5 configs | active=2
# [Stage B] Month origin t=254 | evaluating 5 configs | active=2
# [Stage B] Month origin t=255 | evaluating 5 configs | active=2
# [Stage B] Month origin t=256 | evaluating 5 configs | active=2
# [Stage B] Month origin t=257 | evaluating 5 configs | active=2
# [Stage B] Month origin t=258 | evaluating 5 configs | active=2
# [Stage B] Month origin t=259 | evaluating 5 configs | active=2
# [Stage B] Month origin t=260 | evaluating 5 configs | active=2
# [Stage B] Month origin t=261 | evaluating 5 configs | active=2
# [Stage B] Month origin t=262 | evaluating 5 configs | active=2
# [Stage B] Month origin t=263 | evaluating 5 configs | active=2
# [Stage B] Month origin t=264 | evaluating 5 configs | active=2
# [Stage B] Month origin t=265 | evaluating 5 configs | active=2
# [Stage B] Month origin t=266 | evaluating 5 configs | active=2
# [Stage B] Month origin t=267 | evaluating 5 configs | active=2
# [Stage B] Month origin t=268 | evaluating 5 configs | active=2
# [Stage B] Month origin t=269 | evaluating 5 configs | active=2
# [Stage B] Month origin t=270 | evaluating 5 configs | active=2
# [Stage B] Month origin t=271 | evaluating 5 configs | active=2
# [Stage B] Month origin t=272 | evaluating 5 configs | active=2
# [Stage B] Month origin t=273 | evaluating 5 configs | active=2
# [Stage B] Month origin t=274 | evaluating 5 configs | active=2
# [Stage B] Month origin t=275 | evaluating 5 configs | active=2
# [Stage B] Month origin t=276 | evaluating 5 configs | active=2
# [Stage B] Month origin t=277 | evaluating 5 configs | active=2
# [Stage B] Month origin t=278 | evaluating 5 configs | active=2
# [Stage B] Month origin t=279 | evaluating 5 configs | active=2
# [Stage B] Month origin t=280 | evaluating 5 configs | active=2
# [Stage B] Month origin t=281 | evaluating 5 configs | active=2
# [Stage B] Month origin t=282 | evaluating 5 configs | active=2
# [Stage B] Month origin t=283 | evaluating 5 configs | active=2
# [Stage B] Month origin t=284 | evaluating 5 configs | active=2
# [Stage B] Month origin t=285 | evaluating 5 configs | active=2
# [Stage B] Month origin t=286 | evaluating 5 configs | active=2
# [Stage B] Month origin t=287 | evaluating 5 configs | active=2
# [Stage B] Month origin t=288 | evaluating 5 configs | active=2
# [Stage B] Month origin t=289 | evaluating 5 configs | active=2
# [Stage B] Month origin t=290 | evaluating 5 configs | active=2
# [Stage B] Month origin t=291 | evaluating 5 configs | active=2
# [Stage B] Month origin t=292 | evaluating 5 configs | active=2
# [Stage B] Month origin t=293 | evaluating 5 configs | active=2
# [Stage B] Month origin t=294 | evaluating 5 configs | active=2
# [Stage B] Month origin t=295 | evaluating 5 configs | active=2
# [Stage B] Month origin t=296 | evaluating 5 configs | active=2
# [Stage B] Month origin t=297 | evaluating 5 configs | active=2
# [Stage B] Month origin t=298 | evaluating 5 configs | active=2
# [Stage B] Month origin t=299 | evaluating 5 configs | active=2
# [Stage B] Month origin t=300 | evaluating 5 configs | active=2
# [Stage B] Month origin t=301 | evaluating 5 configs | active=2
# [Stage B] Month origin t=302 | evaluating 5 configs | active=2
# [Stage B] Month origin t=303 | evaluating 5 configs | active=2
# [Stage B] Month origin t=304 | evaluating 5 configs | active=2
# [Stage B] Month origin t=305 | evaluating 5 configs | active=2
# [Stage B] Month origin t=306 | evaluating 5 configs | active=2
# [Stage B] Month origin t=307 | evaluating 5 configs | active=2
# [Stage B] Month origin t=308 | evaluating 5 configs | active=2
# [Stage B] Month origin t=309 | evaluating 5 configs | active=2
# [Stage B] Month origin t=310 | evaluating 5 configs | active=2
# [Stage B] Month origin t=311 | evaluating 5 configs | active=2
# [Stage B] Month origin t=312 | evaluating 5 configs | active=2
# [Stage B] Month origin t=313 | evaluating 5 configs | active=2
# [Stage B] Month origin t=314 | evaluating 5 configs | active=2
# [Stage B] Month origin t=315 | evaluating 5 configs | active=2
# [Stage B] Month origin t=316 | evaluating 5 configs | active=2
# [Stage B] Month origin t=317 | evaluating 5 configs | active=2
# [Stage B] Month origin t=318 | evaluating 5 configs | active=2
# [Stage B] Month origin t=319 | evaluating 5 configs | active=2
# [Stage B] Month origin t=320 | evaluating 5 configs | active=2
# [Stage B] Month origin t=321 | evaluating 5 configs | active=2
# [Stage B] Month origin t=322 | evaluating 5 configs | active=2
# [Stage B] Month origin t=323 | evaluating 5 configs | active=2
# [Stage B] Month origin t=324 | evaluating 5 configs | active=2
# [Stage B] Month origin t=325 | evaluating 5 configs | active=2
# [Stage B] Month origin t=326 | evaluating 5 configs | active=2
# [Stage B] Month origin t=327 | evaluating 5 configs | active=2
# [Stage B] Month origin t=328 | evaluating 5 configs | active=2
# [Stage B] Month origin t=329 | evaluating 5 configs | active=2
# [Stage B] Month origin t=330 | evaluating 5 configs | active=2
# [Stage B] Month origin t=331 | evaluating 5 configs | active=2
# [Stage B] Month origin t=332 | evaluating 5 configs | active=2
# [Stage B] Month origin t=333 | evaluating 5 configs | active=2
# [Stage B] Month origin t=334 | evaluating 5 configs | active=2
# [Stage B] Month origin t=335 | evaluating 5 configs | active=2
# [Stage B] Month origin t=336 | evaluating 5 configs | active=2
# [Stage B] Month origin t=337 | evaluating 5 configs | active=2
# [Stage B] Month origin t=338 | evaluating 5 configs | active=2
# [Stage B] Month origin t=339 | evaluating 5 configs | active=2
# [Stage B] Month origin t=340 | evaluating 5 configs | active=2
# [Stage B] Month origin t=341 | evaluating 5 configs | active=2
# [Stage B] Month origin t=342 | evaluating 5 configs | active=2
# [Stage B] Month origin t=343 | evaluating 5 configs | active=2
# [Stage B] Month origin t=344 | evaluating 5 configs | active=2
# [Stage B] Month origin t=345 | evaluating 5 configs | active=2
# [Stage B] Month origin t=346 | evaluating 5 configs | active=2
# [Stage B] Month origin t=347 | evaluating 5 configs | active=2
# [Stage B] Month origin t=348 | evaluating 5 configs | active=2
# [Stage B] Month origin t=349 | evaluating 5 configs | active=2
# [Stage B] Month origin t=350 | evaluating 5 configs | active=2
# [Stage B] Month origin t=351 | evaluating 5 configs | active=2
# [Stage B] Month origin t=352 | evaluating 5 configs | active=2
# [Stage B] Month origin t=353 | evaluating 5 configs | active=2
# [Stage B] Month origin t=354 | evaluating 5 configs | active=2
# [Stage B] Month origin t=355 | evaluating 5 configs | active=2
# [Stage B] Month origin t=356 | evaluating 5 configs | active=2
# [Stage B] Month origin t=357 | evaluating 5 configs | active=2
# [Stage B] Month origin t=358 | evaluating 5 configs | active=2
# [Stage B] Month origin t=359 | evaluating 5 configs | active=2
# [Stage B] Month origin t=360 | evaluating 5 configs | active=2
# [Stage B] Month origin t=361 | evaluating 5 configs | active=2
# [Stage B] Month origin t=362 | evaluating 5 configs | active=2
# [Stage B] Month origin t=363 | evaluating 5 configs | active=2
# [Stage B] Month origin t=364 | evaluating 5 configs | active=2
# [Stage B] Month origin t=365 | evaluating 5 configs | active=2
# [Stage B] Month origin t=366 | evaluating 5 configs | active=2
# [Stage B] Month origin t=367 | evaluating 5 configs | active=2
# [Stage B] Month origin t=368 | evaluating 5 configs | active=2
# [Stage B] Month origin t=369 | evaluating 5 configs | active=2
# [Stage B] Month origin t=370 | evaluating 5 configs | active=2
# [Stage B] Month origin t=371 | evaluating 5 configs | active=2
# [Stage B] Month origin t=372 | evaluating 5 configs | active=2
# [Stage B] Month origin t=373 | evaluating 5 configs | active=2
# [Stage B] Month origin t=374 | evaluating 5 configs | active=2
# [Stage B] Month origin t=375 | evaluating 5 configs | active=2
# [Stage B] Month origin t=376 | evaluating 5 configs | active=2
# [Stage B] Month origin t=377 | evaluating 5 configs | active=2
# [Stage B] Month origin t=378 | evaluating 5 configs | active=2
# [Stage B] Month origin t=379 | evaluating 5 configs | active=2
# [Stage B] Month origin t=380 | evaluating 5 configs | active=2
# [Stage B] Month origin t=381 | evaluating 5 configs | active=2
# [Stage B] Month origin t=382 | evaluating 5 configs | active=2
# [Stage B] Month origin t=383 | evaluating 5 configs | active=2
# [Stage B] Month origin t=384 | evaluating 5 configs | active=2
# [Stage B] Month origin t=385 | evaluating 5 configs | active=2
# [Stage B] Month origin t=386 | evaluating 5 configs | active=2
# [Stage B] Month origin t=387 | evaluating 5 configs | active=2
# [Stage B] Month origin t=388 | evaluating 5 configs | active=2
# [Stage B] Month origin t=389 | evaluating 5 configs | active=2
# [Stage B] Month origin t=390 | evaluating 5 configs | active=2
# [Stage B] Month origin t=391 | evaluating 5 configs | active=2
# [Stage B] Month origin t=392 | evaluating 5 configs | active=2
# [Stage B] Month origin t=393 | evaluating 5 configs | active=2
# [Stage B] Month origin t=394 | evaluating 5 configs | active=2
# [Stage B] Month origin t=395 | evaluating 5 configs | active=2
# [Stage B] Month origin t=396 | evaluating 5 configs | active=2
# [Stage B] Month origin t=397 | evaluating 5 configs | active=2
# [Stage B] Month origin t=398 | evaluating 5 configs | active=2
# [Stage B] Month origin t=399 | evaluating 5 configs | active=2
# [Stage B] Month origin t=400 | evaluating 5 configs | active=2
# [Stage B] Month origin t=401 | evaluating 5 configs | active=2
# [Stage B] Month origin t=402 | evaluating 5 configs | active=2
# [Stage B] Month origin t=403 | evaluating 5 configs | active=2
# [Stage B] Month origin t=404 | evaluating 5 configs | active=2
# [Stage B] Month origin t=405 | evaluating 5 configs | active=2
# [Stage B] done → /Users/jonasschernich/Documents/Masterarbeit/Code/outputs/stageB/extra_trees_dynamic_fi/monthly
# [Stage B] summary.csv & summary_active.txt geschrieben.
#
# Done. Check outputs/stageA|stageB/extra_trees_dynamic_fi for results.
