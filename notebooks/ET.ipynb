# %%
# --- Setup & Imports ---
import os, sys
from pathlib import Path
import pandas as pd
import numpy as np

# --- 1. Pfad-Setup ---
def _locate_repo_root(start: Path) -> Path:
    cur = start.resolve()
    for _ in range(5):  # walk up to 5 levels
        if (cur / 'src').exists():
            return cur
        if cur.parent == cur:
            break
        cur = cur.parent
    return start.resolve()

NOTEBOOK_DIR = Path.cwd()
PROJECT_ROOT = _locate_repo_root(NOTEBOOK_DIR)
os.environ['PROJECT_ROOT'] = str(PROJECT_ROOT)
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from src.config import GlobalConfig, DEFAULT_CORR_SPEC, EWMA_CORR_SPEC, outputs_for_model
from src.tuning import run_stageA, run_stageB
from src.io_timesplits import load_target, load_ifo_features
# --- MODELL-IMPORT ---
from src.models.ET import ForecastModel # Nutzt ExtraTreesRegressor

print('PROJECT_ROOT =', PROJECT_ROOT)

# --- MODELLNAME ---
MODEL_NAME = "extra_trees"
outputs_for_model(MODEL_NAME)
print(f'Modell {MODEL_NAME} wird getunt.')

# --- 2. Daten laden ---
y = load_target()  # ΔIP with DatetimeIndex
X_ifo = load_ifo_features() # ifo features

idx = y.index.intersection(X_ifo.index)
y, X_ifo = y.loc[idx], X_ifo.loc[idx]
print('Shapes:', X_ifo.shape, y.shape)

# --- 3. Base config (splits & policy as in thesis) ---
def base_cfg() -> GlobalConfig:
    cfg = GlobalConfig()
    cfg.W0_A     = 180
    cfg.BLOCKS_A = [(181,200), (201,220), (221,240)]
    cfg.W0_B     = 240
    # Policy Parameter
    cfg.policy_window   = 24
    cfg.policy_decay    = 0.95
    cfg.policy_gain_min = 0.03
    cfg.policy_cooldown = 3
    return cfg

cfg0 = base_cfg()

# --- 4. Helper für Korrelations-Spezifikation (bleibt gleich) ---
def make_corr_spec(kind: str) -> dict:
    if kind == 'expanding':
        return dict(DEFAULT_CORR_SPEC)
    elif kind == 'ewm':
        return dict(EWMA_CORR_SPEC)
    else:
        raise ValueError("kind must be 'expanding' or 'ewm'")

# --- 5. OPTIMIERTES TUNING-GRID ---

# A) Feature Engineering Parameter Listen
corr_options = [
    ("expanding", make_corr_spec("expanding")),
    ("ewm", make_corr_spec("ewm"))
]
lag_candidates_list = [(1, 2, 3, 6, 12)] # Halten wir einfach für ET
top_k_lags_list = [1, 2] # Testen, ob 2 Lags helfen
use_rm3_list = [True, False] # Testen mit und ohne Glättung
k1_topk_list = [100, 300] # Engeres Screening vs. breiteres Screening vor DR
redundancy_param_list = [0.90, 0.95] # Zwei Redundanzlevel testen
# DR Optionen - PCA/PLS machen nur nach breiterem Screening Sinn
dr_options_list = [
    {'dr_method': 'none'},
    {'dr_method': 'pca', 'pca_var_target': 0.95, 'pca_kmax': 50},
    {'dr_method': 'pls', 'pls_components': 8} # PLS als Alternative
]

# B) Extra Trees Hyperparameter Listen
n_estimators_list = [300] # Etwas mehr Bäume fixieren
max_features_list = ['sqrt', 0.2, 0.4] # Drei Optionen für Feature Subsampling
min_samples_leaf_list = [5, 15, 30] # Drei Regularisierungslevel

# C) Target Blocks & Weighting Listen
target_block_options = [ None, ["AR1"], ["Chronos"], ["TSFresh"] ] # Einzeln testen
weighting_options = [
    {"sample_weight_decay": None}, # Standard: kein Decay
    {"sample_weight_decay": 0.98}  # Option: Exponentielles Decay
]

# D) Grid zusammensetzen (Optimierte Logik)
def build_model_grid():
    hp_grid = []
    for corr_tag, corr_spec in corr_options:
        for lags in lag_candidates_list:
            for k_lags in top_k_lags_list:
                for rm3 in use_rm3_list:
                    for k1 in k1_topk_list:
                        for red in redundancy_param_list:
                            for dr_opt in dr_options_list:
                                # *** WICHTIGE EINSCHRÄNKUNG für Laufzeit ***
                                # DR (PCA/PLS) nur anwenden, wenn wir breiter gescreent haben (k1=300)
                                if k1 == 100 and dr_opt['dr_method'] != 'none': continue
                                # Kein DR macht bei k1=300 wenig Sinn (zu viele Features für ET)
                                # Erlauben wir es trotzdem als Testfall
                                # if k1 == 300 and dr_opt['dr_method'] == 'none': continue

                                for n_est in n_estimators_list:
                                    for max_feat in max_features_list:
                                        for min_leaf in min_samples_leaf_list:
                                            for block_set in target_block_options:
                                                for weight_hp in weighting_options:
                                                    hp = {
                                                        # FE Params
                                                        'lag_candidates': lags,
                                                        'top_k_lags_per_feature': k_lags,
                                                        'use_rm3': rm3,
                                                        'k1_topk': k1,
                                                        'redundancy_param': red,
                                                        **dr_opt,
                                                        # ET Params
                                                        'n_estimators': n_est,
                                                        'max_features': max_feat,
                                                        'min_samples_leaf': min_leaf,
                                                        # Other Params
                                                        **weight_hp,
                                                        'corr_tag': corr_tag,
                                                        'corr_spec': corr_spec,
                                                        'target_block_set': block_set
                                                    }
                                                    hp_grid.append(hp)
    return hp_grid

model_grid = build_model_grid()
# Ungefähre Größe: 2(Corr)*1*2(kL)*2(RM)*[ (1(k1)*1(DR)) + (1(k1)*3(DR)) ]*2(Red)*1(nEst)*3(MaxF)*3(MinL)*4(Block)*2(Weight)
# = 8 * [1 + 3] * 2 * 1 * 9 * 4 * 2 = 8 * 4 * 2 * 9 * 8 = 64 * 72 = 4608 (Immer noch groß!)
# Reduzieren wir es weiter:
# Fixieren k_lags=1, rm3=True, red=0.90, weight=None
# Size: 2(Corr)*1*1*1 * [1 + 3] * 1 * 1 * 3(MaxF)*3(MinL)*4(Block)*1(Weight)
# = 2 * 4 * 1 * 9 * 4 * 1 = 8 * 36 = 288 (Das ist akzeptabler)

# --- ANGEPASSTES GRID für akzeptable Laufzeit ---
k_lags_list = [1]
use_rm3_list = [True]
redundancy_param_list = [0.90]
weighting_options = [ {"sample_weight_decay": None} ]
max_features_list = ['sqrt', 0.3] # Reduziert auf 2
min_samples_leaf_list = [5, 15]   # Reduziert auf 2

# Neuberechnung Grid Size: 2*1*1*1 * [1+3] * 1 * 1 * 2 * 2 * 4 * 1 = 2 * 4 * 4 * 4 = 128
# Das ist ein guter Kompromiss.

def build_model_grid_optimized():
    hp_grid = []
    for corr_tag, corr_spec in corr_options: # 2
        for lags in lag_candidates_list: # 1
            for k_lags in k_lags_list: # 1
                for rm3 in use_rm3_list: # 1
                    for k1 in k1_topk_list: # 2
                        for red in redundancy_param_list: # 1
                            for dr_opt in dr_options_list: # 3
                                # Einschränkung
                                if k1 == 100 and dr_opt['dr_method'] != 'none': continue # Lässt (100, none) -> 1
                                # if k1 == 300 and dr_opt['dr_method'] == 'none': continue # Erlauben wir testweise
                                # Lässt (300, none), (300, pca), (300, pls) -> 3. Total FE/DR = 1+3 = 4

                                for n_est in n_estimators_list: # 1
                                    for max_feat in max_features_list: # 2
                                        for min_leaf in min_samples_leaf_list: # 2
                                            for block_set in target_block_options: # 4
                                                for weight_hp in weighting_options: # 1
                                                    hp = {
                                                        # FE Params
                                                        'lag_candidates': lags,
                                                        'top_k_lags_per_feature': k_lags,
                                                        'use_rm3': rm3,
                                                        'k1_topk': k1,
                                                        'redundancy_param': red,
                                                        **dr_opt,
                                                        # ET Params
                                                        'n_estimators': n_est,
                                                        'max_features': max_feat,
                                                        'min_samples_leaf': min_leaf,
                                                        # Other Params
                                                        **weight_hp,
                                                        'corr_tag': corr_tag,
                                                        'corr_spec': corr_spec,
                                                        'target_block_set': block_set
                                                    }
                                                    hp_grid.append(hp)
    return hp_grid

model_grid = build_model_grid_optimized()
print("Optimierte HP-Kombinationen:", len(model_grid)) # 2*1*1*1 * 4 * 1 * 1 * 2 * 2 * 4 * 1 = 128
print("Erstes HP-Set:", model_grid[0] if model_grid else "Grid ist leer")


# --- 6. Stage A/B Lauf ---
if model_grid: # Nur ausführen, wenn das Grid nicht leer ist
    shortlist = run_stageA(
        model_name=MODEL_NAME,
        model_ctor=lambda hp: ForecastModel(hp),
        model_grid=model_grid,
        X=X_ifo, y=y, cfg=cfg0,
        keep_top_k_final=min(5, len(model_grid)),
        min_survivors_per_block=max(1, len(model_grid)//4), # Reduziere Überlebende pro Block etwas
    )

    run_stageB(
        model_name=MODEL_NAME,
        model_ctor=lambda hp: ForecastModel(hp),
        shortlist=shortlist,
        X=X_ifo, y=y, cfg=cfg0,
        # max_months=12,   # Optional: Begrenze Stage B für schnellen Test
    )
else:
    print("Keine gültigen HP-Kombinationen gefunden, Stages übersprungen.")

print(f"\nDone. Check outputs/stageA|stageB/{MODEL_NAME} for results.")
# Out:
# PROJECT_ROOT = /Users/jonasschernich/Documents/Masterarbeit/Code
# Modell extra_trees wird getunt.
# INFO in load_ifo_features: Renaming columns to ensure validity.
# Shapes: (407, 2160) (407,)
# Optimierte HP-Kombinationen: 128
# Erstes HP-Set: {'lag_candidates': (1, 2, 3, 6, 12), 'top_k_lags_per_feature': 1, 'use_rm3': True, 'k1_topk': 100, 'redundancy_param': 0.9, 'dr_method': 'none', 'n_estimators': 300, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'sample_weight_decay': None, 'corr_tag': 'expanding', 'corr_spec': {'mode': 'expanding', 'window': None, 'lam': None}, 'target_block_set': None}
# [Stage A][Block 1] train_end=180, OOS=181-200 | configs=128
#   - Config 1/128
#     · Month 1/20 processed | running...RMSE=1.6096
#     · Month 2/20 processed | running...RMSE=2.1772
#     · Month 3/20 processed | running...RMSE=1.8302
#     · Month 4/20 processed | running...RMSE=1.6064
#     · Month 5/20 processed | running...RMSE=1.5466
#     · Month 6/20 processed | running...RMSE=1.4189
#     · Month 7/20 processed | running...RMSE=1.3142
#     · Month 8/20 processed | running...RMSE=1.2338
#     · Month 9/20 processed | running...RMSE=1.3068
#     · Month 10/20 processed | running...RMSE=1.2894
#     · Month 11/20 processed | running...RMSE=1.2298
#     · Month 12/20 processed | running...RMSE=1.2150
#     · Month 13/20 processed | running...RMSE=1.1688
#     · Month 14/20 processed | running...RMSE=1.1497
#     · Month 15/20 processed | running...RMSE=1.2393
#     · Month 16/20 processed | running...RMSE=1.2039
#     · Month 17/20 processed | running...RMSE=1.1879
#     · Month 18/20 processed | running...RMSE=1.1623
#     · Month 19/20 processed | running...RMSE=1.1801
#     · Month 20/20 processed | running...RMSE=1.1534
#   - Config 2/128
#     · Month 1/20 processed | running...RMSE=1.6096
#     · Month 2/20 processed | running...RMSE=2.1772
#     · Month 3/20 processed | running...RMSE=1.8302
#     · Month 4/20 processed | running...RMSE=1.6064
#     · Month 5/20 processed | running...RMSE=1.5466
#     · Month 6/20 processed | running...RMSE=1.4189
#     · Month 7/20 processed | running...RMSE=1.3142
#     · Month 8/20 processed | running...RMSE=1.2338
#     · Month 9/20 processed | running...RMSE=1.3068
#     · Month 10/20 processed | running...RMSE=1.2894
#     · Month 11/20 processed | running...RMSE=1.2298
#     · Month 12/20 processed | running...RMSE=1.2150
#     · Month 13/20 processed | running...RMSE=1.1688
#     · Month 14/20 processed | running...RMSE=1.1497
#     · Month 15/20 processed | running...RMSE=1.2393
#     · Month 16/20 processed | running...RMSE=1.2039
#     · Month 17/20 processed | running...RMSE=1.1879
#     · Month 18/20 processed | running...RMSE=1.1623
#     · Month 19/20 processed | running...RMSE=1.1801
#     · Month 20/20 processed | running...RMSE=1.1534
#   - Config 3/128
#     · Month 1/20 processed | running...RMSE=1.6096
#     · Month 2/20 processed | running...RMSE=2.1772
#     · Month 3/20 processed | running...RMSE=1.8302
#     · Month 4/20 processed | running...RMSE=1.6064
#     · Month 5/20 processed | running...RMSE=1.5466
#     · Month 6/20 processed | running...RMSE=1.4189
#     · Month 7/20 processed | running...RMSE=1.3142
#     · Month 8/20 processed | running...RMSE=1.2338
#     · Month 9/20 processed | running...RMSE=1.3068
#     · Month 10/20 processed | running...RMSE=1.2894
#     · Month 11/20 processed | running...RMSE=1.2298
#     · Month 12/20 processed | running...RMSE=1.2150
#     · Month 13/20 processed | running...RMSE=1.1688
#     · Month 14/20 processed | running...RMSE=1.1497
#     · Month 15/20 processed | running...RMSE=1.2393
#     · Month 16/20 processed | running...RMSE=1.2039
#     · Month 17/20 processed | running...RMSE=1.1879
#     · Month 18/20 processed | running...RMSE=1.1623
#     · Month 19/20 processed | running...RMSE=1.1801
#     · Month 20/20 processed | running...RMSE=1.1534
#   - Config 4/128
#     · Month 1/20 processed | running...RMSE=1.6096
#     · Month 2/20 processed | running...RMSE=2.1772
#     · Month 3/20 processed | running...RMSE=1.8302
#     · Month 4/20 processed | running...RMSE=1.6064
#     · Month 5/20 processed | running...RMSE=1.5466
#     · Month 6/20 processed | running...RMSE=1.4189
#     · Month 7/20 processed | running...RMSE=1.3142
#     · Month 8/20 processed | running...RMSE=1.2338
#     · Month 9/20 processed | running...RMSE=1.3068
#     · Month 10/20 processed | running...RMSE=1.2894
#     · Month 11/20 processed | running...RMSE=1.2298
#     · Month 12/20 processed | running...RMSE=1.2150
#     · Month 13/20 processed | running...RMSE=1.1688
#     · Month 14/20 processed | running...RMSE=1.1497
#     · Month 15/20 processed | running...RMSE=1.2393
#     · Month 16/20 processed | running...RMSE=1.2039
#     · Month 17/20 processed | running...RMSE=1.1879
#     · Month 18/20 processed | running...RMSE=1.1623
#     · Month 19/20 processed | running...RMSE=1.1801
#     · Month 20/20 processed | running...RMSE=1.1534
#   - Config 5/128
#     · Month 1/20 processed | running...RMSE=1.5643
#     · Month 2/20 processed | running...RMSE=2.2174
#     · Month 3/20 processed | running...RMSE=1.8748
#     · Month 4/20 processed | running...RMSE=1.6384
#     · Month 5/20 processed | running...RMSE=1.5835
#     · Month 6/20 processed | running...RMSE=1.4526
#     · Month 7/20 processed | running...RMSE=1.3463
#     · Month 8/20 processed | running...RMSE=1.2662
#     · Month 9/20 processed | running...RMSE=1.3215
#     · Month 10/20 processed | running...RMSE=1.2903
#     · Month 11/20 processed | running...RMSE=1.2324
#     · Month 12/20 processed | running...RMSE=1.2097
#     · Month 13/20 processed | running...RMSE=1.1633
#     · Month 14/20 processed | running...RMSE=1.1482
#     · Month 15/20 processed | running...RMSE=1.2340
#     · Month 16/20 processed | running...RMSE=1.1990
#     · Month 17/20 processed | running...RMSE=1.1817
#     · Month 18/20 processed | running...RMSE=1.1550
#     · Month 19/20 processed | running...RMSE=1.1712
#     · Month 20/20 processed | running...RMSE=1.1440
#   - Config 6/128
#     · Month 1/20 processed | running...RMSE=1.5643
#     · Month 2/20 processed | running...RMSE=2.2174
#     · Month 3/20 processed | running...RMSE=1.8748
#     · Month 4/20 processed | running...RMSE=1.6384
#     · Month 5/20 processed | running...RMSE=1.5835
#     · Month 6/20 processed | running...RMSE=1.4526
#     · Month 7/20 processed | running...RMSE=1.3463
#     · Month 8/20 processed | running...RMSE=1.2662
#     · Month 9/20 processed | running...RMSE=1.3215
#     · Month 10/20 processed | running...RMSE=1.2903
#     · Month 11/20 processed | running...RMSE=1.2324
#     · Month 12/20 processed | running...RMSE=1.2097
#     · Month 13/20 processed | running...RMSE=1.1633
#     · Month 14/20 processed | running...RMSE=1.1482
#     · Month 15/20 processed | running...RMSE=1.2340
#     · Month 16/20 processed | running...RMSE=1.1990
#     · Month 17/20 processed | running...RMSE=1.1817
#     · Month 18/20 processed | running...RMSE=1.1550
#     · Month 19/20 processed | running...RMSE=1.1712
#     · Month 20/20 processed | running...RMSE=1.1440
#   - Config 7/128
#     · Month 1/20 processed | running...RMSE=1.5643
#     · Month 2/20 processed | running...RMSE=2.2174
#     · Month 3/20 processed | running...RMSE=1.8748
#     · Month 4/20 processed | running...RMSE=1.6384
#     · Month 5/20 processed | running...RMSE=1.5835
#     · Month 6/20 processed | running...RMSE=1.4526
#     · Month 7/20 processed | running...RMSE=1.3463
#     · Month 8/20 processed | running...RMSE=1.2662
#     · Month 9/20 processed | running...RMSE=1.3215
#     · Month 10/20 processed | running...RMSE=1.2903
#     · Month 11/20 processed | running...RMSE=1.2324
#     · Month 12/20 processed | running...RMSE=1.2097
#     · Month 13/20 processed | running...RMSE=1.1633
#     · Month 14/20 processed | running...RMSE=1.1482
#     · Month 15/20 processed | running...RMSE=1.2340
#     · Month 16/20 processed | running...RMSE=1.1990
#     · Month 17/20 processed | running...RMSE=1.1817
#     · Month 18/20 processed | running...RMSE=1.1550
#     · Month 19/20 processed | running...RMSE=1.1712
#     · Month 20/20 processed | running...RMSE=1.1440
#   - Config 8/128
#     · Month 1/20 processed | running...RMSE=1.5643
#     · Month 2/20 processed | running...RMSE=2.2174
#     · Month 3/20 processed | running...RMSE=1.8748
#     · Month 4/20 processed | running...RMSE=1.6384
#     · Month 5/20 processed | running...RMSE=1.5835
#     · Month 6/20 processed | running...RMSE=1.4526
#     · Month 7/20 processed | running...RMSE=1.3463
#     · Month 8/20 processed | running...RMSE=1.2662
#     · Month 9/20 processed | running...RMSE=1.3215
#     · Month 10/20 processed | running...RMSE=1.2903
#     · Month 11/20 processed | running...RMSE=1.2324
#     · Month 12/20 processed | running...RMSE=1.2097
#     · Month 13/20 processed | running...RMSE=1.1633
#     · Month 14/20 processed | running...RMSE=1.1482
#     · Month 15/20 processed | running...RMSE=1.2340
#     · Month 16/20 processed | running...RMSE=1.1990
#     · Month 17/20 processed | running...RMSE=1.1817
#     · Month 18/20 processed | running...RMSE=1.1550
#     · Month 19/20 processed | running...RMSE=1.1712
#     · Month 20/20 processed | running...RMSE=1.1440
#   - Config 9/128
#     · Month 1/20 processed | running...RMSE=1.7029
#     · Month 2/20 processed | running...RMSE=2.1657
#     · Month 3/20 processed | running...RMSE=1.8107
#     · Month 4/20 processed | running...RMSE=1.5850
#     · Month 5/20 processed | running...RMSE=1.5377
#     · Month 6/20 processed | running...RMSE=1.4143
#     · Month 7/20 processed | running...RMSE=1.3095
#     · Month 8/20 processed | running...RMSE=1.2271
#     · Month 9/20 processed | running...RMSE=1.3108
#     · Month 10/20 processed | running...RMSE=1.2910
#     · Month 11/20 processed | running...RMSE=1.2313
#     · Month 12/20 processed | running...RMSE=1.2181
#     · Month 13/20 processed | running...RMSE=1.1741
#     · Month 14/20 processed | running...RMSE=1.1508
#     · Month 15/20 processed | running...RMSE=1.2460
#     · Month 16/20 processed | running...RMSE=1.2116
#     · Month 17/20 processed | running...RMSE=1.1980
#     · Month 18/20 processed | running...RMSE=1.1747
#     · Month 19/20 processed | running...RMSE=1.1977
#     · Month 20/20 processed | running...RMSE=1.1721
#   - Config 10/128
#     · Month 1/20 processed | running...RMSE=1.7029
#     · Month 2/20 processed | running...RMSE=2.1657
#     · Month 3/20 processed | running...RMSE=1.8107
#     · Month 4/20 processed | running...RMSE=1.5850
#     · Month 5/20 processed | running...RMSE=1.5377
#     · Month 6/20 processed | running...RMSE=1.4143
#     · Month 7/20 processed | running...RMSE=1.3095
#     · Month 8/20 processed | running...RMSE=1.2271
#     · Month 9/20 processed | running...RMSE=1.3108
#     · Month 10/20 processed | running...RMSE=1.2910
#     · Month 11/20 processed | running...RMSE=1.2313
#     · Month 12/20 processed | running...RMSE=1.2181
#     · Month 13/20 processed | running...RMSE=1.1741
#     · Month 14/20 processed | running...RMSE=1.1508
#     · Month 15/20 processed | running...RMSE=1.2460
#     · Month 16/20 processed | running...RMSE=1.2116
#     · Month 17/20 processed | running...RMSE=1.1980
#     · Month 18/20 processed | running...RMSE=1.1747
#     · Month 19/20 processed | running...RMSE=1.1977
#     · Month 20/20 processed | running...RMSE=1.1721
#   - Config 11/128
#     · Month 1/20 processed | running...RMSE=1.7029
#     · Month 2/20 processed | running...RMSE=2.1657
#     · Month 3/20 processed | running...RMSE=1.8107
#     · Month 4/20 processed | running...RMSE=1.5850
#     · Month 5/20 processed | running...RMSE=1.5377
#     · Month 6/20 processed | running...RMSE=1.4143
#     · Month 7/20 processed | running...RMSE=1.3095
#     · Month 8/20 processed | running...RMSE=1.2271
#     · Month 9/20 processed | running...RMSE=1.3108
#     · Month 10/20 processed | running...RMSE=1.2910
#     · Month 11/20 processed | running...RMSE=1.2313
#     · Month 12/20 processed | running...RMSE=1.2181
#     · Month 13/20 processed | running...RMSE=1.1741
#     · Month 14/20 processed | running...RMSE=1.1508
#     · Month 15/20 processed | running...RMSE=1.2460
#     · Month 16/20 processed | running...RMSE=1.2116
#     · Month 17/20 processed | running...RMSE=1.1980
#     · Month 18/20 processed | running...RMSE=1.1747
#     · Month 19/20 processed | running...RMSE=1.1977
#     · Month 20/20 processed | running...RMSE=1.1721
#   - Config 12/128
#     · Month 1/20 processed | running...RMSE=1.7029
#     · Month 2/20 processed | running...RMSE=2.1657
#     · Month 3/20 processed | running...RMSE=1.8107
#     · Month 4/20 processed | running...RMSE=1.5850
#     · Month 5/20 processed | running...RMSE=1.5377
#     · Month 6/20 processed | running...RMSE=1.4143
#     · Month 7/20 processed | running...RMSE=1.3095
#     · Month 8/20 processed | running...RMSE=1.2271
#     · Month 9/20 processed | running...RMSE=1.3108
#     · Month 10/20 processed | running...RMSE=1.2910
#     · Month 11/20 processed | running...RMSE=1.2313
#     · Month 12/20 processed | running...RMSE=1.2181
#     · Month 13/20 processed | running...RMSE=1.1741
#     · Month 14/20 processed | running...RMSE=1.1508
#     · Month 15/20 processed | running...RMSE=1.2460
#     · Month 16/20 processed | running...RMSE=1.2116
#     · Month 17/20 processed | running...RMSE=1.1980
#     · Month 18/20 processed | running...RMSE=1.1747
#     · Month 19/20 processed | running...RMSE=1.1977
#     · Month 20/20 processed | running...RMSE=1.1721
#   - Config 13/128
#     · Month 1/20 processed | running...RMSE=1.6210
#     · Month 2/20 processed | running...RMSE=2.2158
#     · Month 3/20 processed | running...RMSE=1.8702
#     · Month 4/20 processed | running...RMSE=1.6333
#     · Month 5/20 processed | running...RMSE=1.5843
#     · Month 6/20 processed | running...RMSE=1.4547
#     · Month 7/20 processed | running...RMSE=1.3472
#     · Month 8/20 processed | running...RMSE=1.2646
#     · Month 9/20 processed | running...RMSE=1.3302
#     · Month 10/20 processed | running...RMSE=1.3036
#     · Month 11/20 processed | running...RMSE=1.2440
#     · Month 12/20 processed | running...RMSE=1.2232
#     · Month 13/20 processed | running...RMSE=1.1772
#     · Month 14/20 processed | running...RMSE=1.1563
#     · Month 15/20 processed | running...RMSE=1.2525
#     · Month 16/20 processed | running...RMSE=1.2183
#     · Month 17/20 processed | running...RMSE=1.2028
#     · Month 18/20 processed | running...RMSE=1.1772
#     · Month 19/20 processed | running...RMSE=1.1973
#     · Month 20/20 processed | running...RMSE=1.1709
#   - Config 14/128
#     · Month 1/20 processed | running...RMSE=1.6210
#     · Month 2/20 processed | running...RMSE=2.2158
#     · Month 3/20 processed | running...RMSE=1.8702
#     · Month 4/20 processed | running...RMSE=1.6333
#     · Month 5/20 processed | running...RMSE=1.5843
#     · Month 6/20 processed | running...RMSE=1.4547
#     · Month 7/20 processed | running...RMSE=1.3472
#     · Month 8/20 processed | running...RMSE=1.2646
#     · Month 9/20 processed | running...RMSE=1.3302
#     · Month 10/20 processed | running...RMSE=1.3036
#     · Month 11/20 processed | running...RMSE=1.2440
#     · Month 12/20 processed | running...RMSE=1.2232
#     · Month 13/20 processed | running...RMSE=1.1772
#     · Month 14/20 processed | running...RMSE=1.1563
#     · Month 15/20 processed | running...RMSE=1.2525
#     · Month 16/20 processed | running...RMSE=1.2183
#     · Month 17/20 processed | running...RMSE=1.2028
#     · Month 18/20 processed | running...RMSE=1.1772
#     · Month 19/20 processed | running...RMSE=1.1973
#     · Month 20/20 processed | running...RMSE=1.1709
#   - Config 15/128
#     · Month 1/20 processed | running...RMSE=1.6210
#     · Month 2/20 processed | running...RMSE=2.2158
#     · Month 3/20 processed | running...RMSE=1.8702
#     · Month 4/20 processed | running...RMSE=1.6333
#     · Month 5/20 processed | running...RMSE=1.5843
#     · Month 6/20 processed | running...RMSE=1.4547
#     · Month 7/20 processed | running...RMSE=1.3472
#     · Month 8/20 processed | running...RMSE=1.2646
#     · Month 9/20 processed | running...RMSE=1.3302
#     · Month 10/20 processed | running...RMSE=1.3036
#     · Month 11/20 processed | running...RMSE=1.2440
#     · Month 12/20 processed | running...RMSE=1.2232
#     · Month 13/20 processed | running...RMSE=1.1772
#     · Month 14/20 processed | running...RMSE=1.1563
#     · Month 15/20 processed | running...RMSE=1.2525
#     · Month 16/20 processed | running...RMSE=1.2183
#     · Month 17/20 processed | running...RMSE=1.2028
#     · Month 18/20 processed | running...RMSE=1.1772
#     · Month 19/20 processed | running...RMSE=1.1973
#     · Month 20/20 processed | running...RMSE=1.1709
#   - Config 16/128
#     · Month 1/20 processed | running...RMSE=1.6210
#     · Month 2/20 processed | running...RMSE=2.2158
#     · Month 3/20 processed | running...RMSE=1.8702
#     · Month 4/20 processed | running...RMSE=1.6333
#     · Month 5/20 processed | running...RMSE=1.5843
#     · Month 6/20 processed | running...RMSE=1.4547
#     · Month 7/20 processed | running...RMSE=1.3472
#     · Month 8/20 processed | running...RMSE=1.2646
#     · Month 9/20 processed | running...RMSE=1.3302
#     · Month 10/20 processed | running...RMSE=1.3036
#     · Month 11/20 processed | running...RMSE=1.2440
#     · Month 12/20 processed | running...RMSE=1.2232
#     · Month 13/20 processed | running...RMSE=1.1772
#     · Month 14/20 processed | running...RMSE=1.1563
#     · Month 15/20 processed | running...RMSE=1.2525
#     · Month 16/20 processed | running...RMSE=1.2183
#     · Month 17/20 processed | running...RMSE=1.2028
#     · Month 18/20 processed | running...RMSE=1.1772
#     · Month 19/20 processed | running...RMSE=1.1973
#     · Month 20/20 processed | running...RMSE=1.1709
#   - Config 17/128
#     · Month 1/20 processed | running...RMSE=1.6697
#     · Month 2/20 processed | running...RMSE=2.1746
#     · Month 3/20 processed | running...RMSE=1.8279
#     · Month 4/20 processed | running...RMSE=1.6031
#     · Month 5/20 processed | running...RMSE=1.5408
#     · Month 6/20 processed | running...RMSE=1.4098
#     · Month 7/20 processed | running...RMSE=1.3071
#     · Month 8/20 processed | running...RMSE=1.2317
#     · Month 9/20 processed | running...RMSE=1.2925
#     · Month 10/20 processed | running...RMSE=1.2631
#     · Month 11/20 processed | running...RMSE=1.2068
#     · Month 12/20 processed | running...RMSE=1.1867
#     · Month 13/20 processed | running...RMSE=1.1417
#     · Month 14/20 processed | running...RMSE=1.1208
#     · Month 15/20 processed | running...RMSE=1.2297
#     · Month 16/20 processed | running...RMSE=1.1979
#     · Month 17/20 processed | running...RMSE=1.1852
#     · Month 18/20 processed | running...RMSE=1.1595
#     · Month 19/20 processed | running...RMSE=1.1762
#     · Month 20/20 processed | running...RMSE=1.1504
#   - Config 18/128
#     · Month 1/20 processed | running...RMSE=1.6697
#     · Month 2/20 processed | running...RMSE=2.1746
#     · Month 3/20 processed | running...RMSE=1.8279
#     · Month 4/20 processed | running...RMSE=1.6031
#     · Month 5/20 processed | running...RMSE=1.5408
#     · Month 6/20 processed | running...RMSE=1.4098
#     · Month 7/20 processed | running...RMSE=1.3071
#     · Month 8/20 processed | running...RMSE=1.2317
#     · Month 9/20 processed | running...RMSE=1.2925
#     · Month 10/20 processed | running...RMSE=1.2631
#     · Month 11/20 processed | running...RMSE=1.2068
#     · Month 12/20 processed | running...RMSE=1.1867
#     · Month 13/20 processed | running...RMSE=1.1417
#     · Month 14/20 processed | running...RMSE=1.1208
#     · Month 15/20 processed | running...RMSE=1.2297
#     · Month 16/20 processed | running...RMSE=1.1979
#     · Month 17/20 processed | running...RMSE=1.1852
#     · Month 18/20 processed | running...RMSE=1.1595
#     · Month 19/20 processed | running...RMSE=1.1762
#     · Month 20/20 processed | running...RMSE=1.1504
#   - Config 19/128
#     · Month 1/20 processed | running...RMSE=1.6697
#     · Month 2/20 processed | running...RMSE=2.1746
#     · Month 3/20 processed | running...RMSE=1.8279
#     · Month 4/20 processed | running...RMSE=1.6031
#     · Month 5/20 processed | running...RMSE=1.5408
#     · Month 6/20 processed | running...RMSE=1.4098
#     · Month 7/20 processed | running...RMSE=1.3071
#     · Month 8/20 processed | running...RMSE=1.2317
#     · Month 9/20 processed | running...RMSE=1.2925
#     · Month 10/20 processed | running...RMSE=1.2631
#     · Month 11/20 processed | running...RMSE=1.2068
#     · Month 12/20 processed | running...RMSE=1.1867
#     · Month 13/20 processed | running...RMSE=1.1417
#     · Month 14/20 processed | running...RMSE=1.1208
#     · Month 15/20 processed | running...RMSE=1.2297
#     · Month 16/20 processed | running...RMSE=1.1979
#     · Month 17/20 processed | running...RMSE=1.1852
#     · Month 18/20 processed | running...RMSE=1.1595
#     · Month 19/20 processed | running...RMSE=1.1762
#     · Month 20/20 processed | running...RMSE=1.1504
#   - Config 20/128
#     · Month 1/20 processed | running...RMSE=1.6697
#     · Month 2/20 processed | running...RMSE=2.1746
#     · Month 3/20 processed | running...RMSE=1.8279
#     · Month 4/20 processed | running...RMSE=1.6031
#     · Month 5/20 processed | running...RMSE=1.5408
#     · Month 6/20 processed | running...RMSE=1.4098
#     · Month 7/20 processed | running...RMSE=1.3071
#     · Month 8/20 processed | running...RMSE=1.2317
#     · Month 9/20 processed | running...RMSE=1.2925
#     · Month 10/20 processed | running...RMSE=1.2631
#     · Month 11/20 processed | running...RMSE=1.2068
#     · Month 12/20 processed | running...RMSE=1.1867
#     · Month 13/20 processed | running...RMSE=1.1417
#     · Month 14/20 processed | running...RMSE=1.1208
#     · Month 15/20 processed | running...RMSE=1.2297
#     · Month 16/20 processed | running...RMSE=1.1979
#     · Month 17/20 processed | running...RMSE=1.1852
#     · Month 18/20 processed | running...RMSE=1.1595
#     · Month 19/20 processed | running...RMSE=1.1762
#     · Month 20/20 processed | running...RMSE=1.1504
#   - Config 21/128
#     · Month 1/20 processed | running...RMSE=1.6436
#     · Month 2/20 processed | running...RMSE=2.2090
#     · Month 3/20 processed | running...RMSE=1.8641
#     · Month 4/20 processed | running...RMSE=1.6310
#     · Month 5/20 processed | running...RMSE=1.5696
#     · Month 6/20 processed | running...RMSE=1.4363
#     · Month 7/20 processed | running...RMSE=1.3328
#     · Month 8/20 processed | running...RMSE=1.2549
#     · Month 9/20 processed | running...RMSE=1.3108
#     · Month 10/20 processed | running...RMSE=1.2797
#     · Month 11/20 processed | running...RMSE=1.2226
#     · Month 12/20 processed | running...RMSE=1.1996
#     · Month 13/20 processed | running...RMSE=1.1539
#     · Month 14/20 processed | running...RMSE=1.1364
#     · Month 15/20 processed | running...RMSE=1.2332
#     · Month 16/20 processed | running...RMSE=1.1989
#     · Month 17/20 processed | running...RMSE=1.1827
#     · Month 18/20 processed | running...RMSE=1.1548
#     · Month 19/20 processed | running...RMSE=1.1691
#     · Month 20/20 processed | running...RMSE=1.1417
#   - Config 22/128
#     · Month 1/20 processed | running...RMSE=1.6436
#     · Month 2/20 processed | running...RMSE=2.2090
#     · Month 3/20 processed | running...RMSE=1.8641
#     · Month 4/20 processed | running...RMSE=1.6310
#     · Month 5/20 processed | running...RMSE=1.5696
#     · Month 6/20 processed | running...RMSE=1.4363
#     · Month 7/20 processed | running...RMSE=1.3328
#     · Month 8/20 processed | running...RMSE=1.2549
#     · Month 9/20 processed | running...RMSE=1.3108
#     · Month 10/20 processed | running...RMSE=1.2797
#     · Month 11/20 processed | running...RMSE=1.2226
#     · Month 12/20 processed | running...RMSE=1.1996
#     · Month 13/20 processed | running...RMSE=1.1539
#     · Month 14/20 processed | running...RMSE=1.1364
#     · Month 15/20 processed | running...RMSE=1.2332
#     · Month 16/20 processed | running...RMSE=1.1989
#     · Month 17/20 processed | running...RMSE=1.1827
#     · Month 18/20 processed | running...RMSE=1.1548
#     · Month 19/20 processed | running...RMSE=1.1691
#     · Month 20/20 processed | running...RMSE=1.1417
#   - Config 23/128
#     · Month 1/20 processed | running...RMSE=1.6436
#     · Month 2/20 processed | running...RMSE=2.2090
#     · Month 3/20 processed | running...RMSE=1.8641
#     · Month 4/20 processed | running...RMSE=1.6310
#     · Month 5/20 processed | running...RMSE=1.5696
#     · Month 6/20 processed | running...RMSE=1.4363
#     · Month 7/20 processed | running...RMSE=1.3328
#     · Month 8/20 processed | running...RMSE=1.2549
#     · Month 9/20 processed | running...RMSE=1.3108
#     · Month 10/20 processed | running...RMSE=1.2797
#     · Month 11/20 processed | running...RMSE=1.2226
#     · Month 12/20 processed | running...RMSE=1.1996
#     · Month 13/20 processed | running...RMSE=1.1539
#     · Month 14/20 processed | running...RMSE=1.1364
#     · Month 15/20 processed | running...RMSE=1.2332
#     · Month 16/20 processed | running...RMSE=1.1989
#     · Month 17/20 processed | running...RMSE=1.1827
#     · Month 18/20 processed | running...RMSE=1.1548
#     · Month 19/20 processed | running...RMSE=1.1691
#     · Month 20/20 processed | running...RMSE=1.1417
#   - Config 24/128
#     · Month 1/20 processed | running...RMSE=1.6436
#     · Month 2/20 processed | running...RMSE=2.2090
#     · Month 3/20 processed | running...RMSE=1.8641
#     · Month 4/20 processed | running...RMSE=1.6310
#     · Month 5/20 processed | running...RMSE=1.5696
#     · Month 6/20 processed | running...RMSE=1.4363
#     · Month 7/20 processed | running...RMSE=1.3328
#     · Month 8/20 processed | running...RMSE=1.2549
#     · Month 9/20 processed | running...RMSE=1.3108
#     · Month 10/20 processed | running...RMSE=1.2797
#     · Month 11/20 processed | running...RMSE=1.2226
#     · Month 12/20 processed | running...RMSE=1.1996
#     · Month 13/20 processed | running...RMSE=1.1539
#     · Month 14/20 processed | running...RMSE=1.1364
#     · Month 15/20 processed | running...RMSE=1.2332
#     · Month 16/20 processed | running...RMSE=1.1989
#     · Month 17/20 processed | running...RMSE=1.1827
#     · Month 18/20 processed | running...RMSE=1.1548
#     · Month 19/20 processed | running...RMSE=1.1691
#     · Month 20/20 processed | running...RMSE=1.1417
#   - Config 25/128
#     · Month 1/20 processed | running...RMSE=1.7918
#     · Month 2/20 processed | running...RMSE=2.1473
#     · Month 3/20 processed | running...RMSE=1.7865
#     · Month 4/20 processed | running...RMSE=1.5850
#     · Month 5/20 processed | running...RMSE=1.5005
#     · Month 6/20 processed | running...RMSE=1.3719
#     · Month 7/20 processed | running...RMSE=1.2719
#     · Month 8/20 processed | running...RMSE=1.1959
#     · Month 9/20 processed | running...RMSE=1.2675
#     · Month 10/20 processed | running...RMSE=1.2482
#     · Month 11/20 processed | running...RMSE=1.1906
#     · Month 12/20 processed | running...RMSE=1.1805
#     · Month 13/20 processed | running...RMSE=1.1365
#     · Month 14/20 processed | running...RMSE=1.1116
#     · Month 15/20 processed | running...RMSE=1.2401
#     · Month 16/20 processed | running...RMSE=1.2097
#     · Month 17/20 processed | running...RMSE=1.2002
#     · Month 18/20 processed | running...RMSE=1.1778
#     · Month 19/20 processed | running...RMSE=1.2044
#     · Month 20/20 processed | running...RMSE=1.1793
#   - Config 26/128
#     · Month 1/20 processed | running...RMSE=1.7918
#     · Month 2/20 processed | running...RMSE=2.1473
#     · Month 3/20 processed | running...RMSE=1.7865
#     · Month 4/20 processed | running...RMSE=1.5850
#     · Month 5/20 processed | running...RMSE=1.5005
#     · Month 6/20 processed | running...RMSE=1.3719
#     · Month 7/20 processed | running...RMSE=1.2719
#     · Month 8/20 processed | running...RMSE=1.1959
#     · Month 9/20 processed | running...RMSE=1.2675
#     · Month 10/20 processed | running...RMSE=1.2482
#     · Month 11/20 processed | running...RMSE=1.1906
#     · Month 12/20 processed | running...RMSE=1.1805
#     · Month 13/20 processed | running...RMSE=1.1365
#     · Month 14/20 processed | running...RMSE=1.1116
#     · Month 15/20 processed | running...RMSE=1.2401
#     · Month 16/20 processed | running...RMSE=1.2097
#     · Month 17/20 processed | running...RMSE=1.2002
#     · Month 18/20 processed | running...RMSE=1.1778
#     · Month 19/20 processed | running...RMSE=1.2044
#     · Month 20/20 processed | running...RMSE=1.1793
#   - Config 27/128
#     · Month 1/20 processed | running...RMSE=1.7918
#     · Month 2/20 processed | running...RMSE=2.1473
#     · Month 3/20 processed | running...RMSE=1.7865
#     · Month 4/20 processed | running...RMSE=1.5850
#     · Month 5/20 processed | running...RMSE=1.5005
#     · Month 6/20 processed | running...RMSE=1.3719
#     · Month 7/20 processed | running...RMSE=1.2719
#     · Month 8/20 processed | running...RMSE=1.1959
#     · Month 9/20 processed | running...RMSE=1.2675
#     · Month 10/20 processed | running...RMSE=1.2482
#     · Month 11/20 processed | running...RMSE=1.1906
#     · Month 12/20 processed | running...RMSE=1.1805
#     · Month 13/20 processed | running...RMSE=1.1365
#     · Month 14/20 processed | running...RMSE=1.1116
#     · Month 15/20 processed | running...RMSE=1.2401
#     · Month 16/20 processed | running...RMSE=1.2097
#     · Month 17/20 processed | running...RMSE=1.2002
#     · Month 18/20 processed | running...RMSE=1.1778
#     · Month 19/20 processed | running...RMSE=1.2044
#     · Month 20/20 processed | running...RMSE=1.1793
#   - Config 28/128
#     · Month 1/20 processed | running...RMSE=1.7918
#     · Month 2/20 processed | running...RMSE=2.1473
#     · Month 3/20 processed | running...RMSE=1.7865
#     · Month 4/20 processed | running...RMSE=1.5850
#     · Month 5/20 processed | running...RMSE=1.5005
#     · Month 6/20 processed | running...RMSE=1.3719
#     · Month 7/20 processed | running...RMSE=1.2719
#     · Month 8/20 processed | running...RMSE=1.1959
#     · Month 9/20 processed | running...RMSE=1.2675
#     · Month 10/20 processed | running...RMSE=1.2482
#     · Month 11/20 processed | running...RMSE=1.1906
#     · Month 12/20 processed | running...RMSE=1.1805
#     · Month 13/20 processed | running...RMSE=1.1365
#     · Month 14/20 processed | running...RMSE=1.1116
#     · Month 15/20 processed | running...RMSE=1.2401
#     · Month 16/20 processed | running...RMSE=1.2097
#     · Month 17/20 processed | running...RMSE=1.2002
#     · Month 18/20 processed | running...RMSE=1.1778
#     · Month 19/20 processed | running...RMSE=1.2044
#     · Month 20/20 processed | running...RMSE=1.1793
#   - Config 29/128
#     · Month 1/20 processed | running...RMSE=1.7369
#     · Month 2/20 processed | running...RMSE=2.1752
#     · Month 3/20 processed | running...RMSE=1.8206
#     · Month 4/20 processed | running...RMSE=1.6006
#     · Month 5/20 processed | running...RMSE=1.5296
#     · Month 6/20 processed | running...RMSE=1.3995
#     · Month 7/20 processed | running...RMSE=1.2986
#     · Month 8/20 processed | running...RMSE=1.2234
#     · Month 9/20 processed | running...RMSE=1.2879
#     · Month 10/20 processed | running...RMSE=1.2634
#     · Month 11/20 processed | running...RMSE=1.2060
#     · Month 12/20 processed | running...RMSE=1.1875
#     · Month 13/20 processed | running...RMSE=1.1421
#     · Month 14/20 processed | running...RMSE=1.1234
#     · Month 15/20 processed | running...RMSE=1.2245
#     · Month 16/20 processed | running...RMSE=1.1923
#     · Month 17/20 processed | running...RMSE=1.1791
#     · Month 18/20 processed | running...RMSE=1.1541
#     · Month 19/20 processed | running...RMSE=1.1736
#     · Month 20/20 processed | running...RMSE=1.1479
#   - Config 30/128
#     · Month 1/20 processed | running...RMSE=1.7369
#     · Month 2/20 processed | running...RMSE=2.1752
#     · Month 3/20 processed | running...RMSE=1.8206
#     · Month 4/20 processed | running...RMSE=1.6006
#     · Month 5/20 processed | running...RMSE=1.5296
#     · Month 6/20 processed | running...RMSE=1.3995
#     · Month 7/20 processed | running...RMSE=1.2986
#     · Month 8/20 processed | running...RMSE=1.2234
#     · Month 9/20 processed | running...RMSE=1.2879
#     · Month 10/20 processed | running...RMSE=1.2634
#     · Month 11/20 processed | running...RMSE=1.2060
#     · Month 12/20 processed | running...RMSE=1.1875
#     · Month 13/20 processed | running...RMSE=1.1421
#     · Month 14/20 processed | running...RMSE=1.1234
#     · Month 15/20 processed | running...RMSE=1.2245
#     · Month 16/20 processed | running...RMSE=1.1923
#     · Month 17/20 processed | running...RMSE=1.1791
#     · Month 18/20 processed | running...RMSE=1.1541
#     · Month 19/20 processed | running...RMSE=1.1736
#     · Month 20/20 processed | running...RMSE=1.1479
#   - Config 31/128
#     · Month 1/20 processed | running...RMSE=1.7369
#     · Month 2/20 processed | running...RMSE=2.1752
#     · Month 3/20 processed | running...RMSE=1.8206
#     · Month 4/20 processed | running...RMSE=1.6006
#     · Month 5/20 processed | running...RMSE=1.5296
#     · Month 6/20 processed | running...RMSE=1.3995
#     · Month 7/20 processed | running...RMSE=1.2986
#     · Month 8/20 processed | running...RMSE=1.2234
#     · Month 9/20 processed | running...RMSE=1.2879
#     · Month 10/20 processed | running...RMSE=1.2634
#     · Month 11/20 processed | running...RMSE=1.2060
#     · Month 12/20 processed | running...RMSE=1.1875
#     · Month 13/20 processed | running...RMSE=1.1421
#     · Month 14/20 processed | running...RMSE=1.1234
#     · Month 15/20 processed | running...RMSE=1.2245
#     · Month 16/20 processed | running...RMSE=1.1923
#     · Month 17/20 processed | running...RMSE=1.1791
#     · Month 18/20 processed | running...RMSE=1.1541
#     · Month 19/20 processed | running...RMSE=1.1736
#     · Month 20/20 processed | running...RMSE=1.1479
#   - Config 32/128
#     · Month 1/20 processed | running...RMSE=1.7369
#     · Month 2/20 processed | running...RMSE=2.1752
#     · Month 3/20 processed | running...RMSE=1.8206
#     · Month 4/20 processed | running...RMSE=1.6006
#     · Month 5/20 processed | running...RMSE=1.5296
#     · Month 6/20 processed | running...RMSE=1.3995
#     · Month 7/20 processed | running...RMSE=1.2986
#     · Month 8/20 processed | running...RMSE=1.2234
#     · Month 9/20 processed | running...RMSE=1.2879
#     · Month 10/20 processed | running...RMSE=1.2634
#     · Month 11/20 processed | running...RMSE=1.2060
#     · Month 12/20 processed | running...RMSE=1.1875
#     · Month 13/20 processed | running...RMSE=1.1421
#     · Month 14/20 processed | running...RMSE=1.1234
#     · Month 15/20 processed | running...RMSE=1.2245
#     · Month 16/20 processed | running...RMSE=1.1923
#     · Month 17/20 processed | running...RMSE=1.1791
#     · Month 18/20 processed | running...RMSE=1.1541
#     · Month 19/20 processed | running...RMSE=1.1736
#     · Month 20/20 processed | running...RMSE=1.1479
#   - Config 33/128
#     · Month 1/20 processed | running...RMSE=1.6324
#     · Month 2/20 processed | running...RMSE=2.2532
#     · Month 3/20 processed | running...RMSE=1.9244
#     · Month 4/20 processed | running...RMSE=1.6787
#     · Month 5/20 processed | running...RMSE=1.6312
#     · Month 6/20 processed | running...RMSE=1.4949
#     · Month 7/20 processed | running...RMSE=1.3856
#     · Month 8/20 processed | running...RMSE=1.3001
#     · Month 9/20 processed | running...RMSE=1.3572
#     · Month 10/20 processed | running...RMSE=1.3242
#     · Month 11/20 processed | running...RMSE=1.2649
#     · Month 12/20 processed | running...RMSE=1.2365
#     · Month 13/20 processed | running...RMSE=1.1882
#     · Month 14/20 processed | running...RMSE=1.1788
#     · Month 15/20 processed | running...RMSE=1.2514
#     · Month 16/20 processed | running...RMSE=1.2142
#     · Month 17/20 processed | running...RMSE=1.1898
#     · Month 18/20 processed | running...RMSE=1.1594
#     · Month 19/20 processed | running...RMSE=1.1678
#     · Month 20/20 processed | running...RMSE=1.1388
#   - Config 34/128
#     · Month 1/20 processed | running...RMSE=1.6324
#     · Month 2/20 processed | running...RMSE=2.2532
#     · Month 3/20 processed | running...RMSE=1.9244
#     · Month 4/20 processed | running...RMSE=1.6787
#     · Month 5/20 processed | running...RMSE=1.6312
#     · Month 6/20 processed | running...RMSE=1.4949
#     · Month 7/20 processed | running...RMSE=1.3856
#     · Month 8/20 processed | running...RMSE=1.3001
#     · Month 9/20 processed | running...RMSE=1.3572
#     · Month 10/20 processed | running...RMSE=1.3242
#     · Month 11/20 processed | running...RMSE=1.2649
#     · Month 12/20 processed | running...RMSE=1.2365
#     · Month 13/20 processed | running...RMSE=1.1882
#     · Month 14/20 processed | running...RMSE=1.1788
#     · Month 15/20 processed | running...RMSE=1.2514
#     · Month 16/20 processed | running...RMSE=1.2142
#     · Month 17/20 processed | running...RMSE=1.1898
#     · Month 18/20 processed | running...RMSE=1.1594
#     · Month 19/20 processed | running...RMSE=1.1678
#     · Month 20/20 processed | running...RMSE=1.1388
#   - Config 35/128
#     · Month 1/20 processed | running...RMSE=1.6324
#     · Month 2/20 processed | running...RMSE=2.2532
#     · Month 3/20 processed | running...RMSE=1.9244
#     · Month 4/20 processed | running...RMSE=1.6787
#     · Month 5/20 processed | running...RMSE=1.6312
#     · Month 6/20 processed | running...RMSE=1.4949
#     · Month 7/20 processed | running...RMSE=1.3856
#     · Month 8/20 processed | running...RMSE=1.3001
#     · Month 9/20 processed | running...RMSE=1.3572
#     · Month 10/20 processed | running...RMSE=1.3242
#     · Month 11/20 processed | running...RMSE=1.2649
#     · Month 12/20 processed | running...RMSE=1.2365
#     · Month 13/20 processed | running...RMSE=1.1882
#     · Month 14/20 processed | running...RMSE=1.1788
#     · Month 15/20 processed | running...RMSE=1.2514
#     · Month 16/20 processed | running...RMSE=1.2142
#     · Month 17/20 processed | running...RMSE=1.1898
#     · Month 18/20 processed | running...RMSE=1.1594
#     · Month 19/20 processed | running...RMSE=1.1678
#     · Month 20/20 processed | running...RMSE=1.1388
#   - Config 36/128
#     · Month 1/20 processed | running...RMSE=1.6324
#     · Month 2/20 processed | running...RMSE=2.2532
#     · Month 3/20 processed | running...RMSE=1.9244
#     · Month 4/20 processed | running...RMSE=1.6787
#     · Month 5/20 processed | running...RMSE=1.6312
#     · Month 6/20 processed | running...RMSE=1.4949
#     · Month 7/20 processed | running...RMSE=1.3856
#     · Month 8/20 processed | running...RMSE=1.3001
#     · Month 9/20 processed | running...RMSE=1.3572
#     · Month 10/20 processed | running...RMSE=1.3242
#     · Month 11/20 processed | running...RMSE=1.2649
#     · Month 12/20 processed | running...RMSE=1.2365
#     · Month 13/20 processed | running...RMSE=1.1882
#     · Month 14/20 processed | running...RMSE=1.1788
#     · Month 15/20 processed | running...RMSE=1.2514
#     · Month 16/20 processed | running...RMSE=1.2142
#     · Month 17/20 processed | running...RMSE=1.1898
#     · Month 18/20 processed | running...RMSE=1.1594
#     · Month 19/20 processed | running...RMSE=1.1678
#     · Month 20/20 processed | running...RMSE=1.1388
#   - Config 37/128
#     · Month 1/20 processed | running...RMSE=1.5234
#     · Month 2/20 processed | running...RMSE=2.2705
#     · Month 3/20 processed | running...RMSE=1.9458
#     · Month 4/20 processed | running...RMSE=1.6918
#     · Month 5/20 processed | running...RMSE=1.6432
#     · Month 6/20 processed | running...RMSE=1.5070
#     · Month 7/20 processed | running...RMSE=1.3961
#     · Month 8/20 processed | running...RMSE=1.3107
#     · Month 9/20 processed | running...RMSE=1.3602
#     · Month 10/20 processed | running...RMSE=1.3254
#     · Month 11/20 processed | running...RMSE=1.2674
#     · Month 12/20 processed | running...RMSE=1.2355
#     · Month 13/20 processed | running...RMSE=1.1871
#     · Month 14/20 processed | running...RMSE=1.1791
#     · Month 15/20 processed | running...RMSE=1.2447
#     · Month 16/20 processed | running...RMSE=1.2062
#     · Month 17/20 processed | running...RMSE=1.1798
#     · Month 18/20 processed | running...RMSE=1.1480
#     · Month 19/20 processed | running...RMSE=1.1481
#     · Month 20/20 processed | running...RMSE=1.1190
#   - Config 38/128
#     · Month 1/20 processed | running...RMSE=1.5234
#     · Month 2/20 processed | running...RMSE=2.2705
#     · Month 3/20 processed | running...RMSE=1.9458
#     · Month 4/20 processed | running...RMSE=1.6918
#     · Month 5/20 processed | running...RMSE=1.6432
#     · Month 6/20 processed | running...RMSE=1.5070
#     · Month 7/20 processed | running...RMSE=1.3961
#     · Month 8/20 processed | running...RMSE=1.3107
#     · Month 9/20 processed | running...RMSE=1.3602
#     · Month 10/20 processed | running...RMSE=1.3254
#     · Month 11/20 processed | running...RMSE=1.2674
#     · Month 12/20 processed | running...RMSE=1.2355
#     · Month 13/20 processed | running...RMSE=1.1871
#     · Month 14/20 processed | running...RMSE=1.1791
#     · Month 15/20 processed | running...RMSE=1.2447
#     · Month 16/20 processed | running...RMSE=1.2062
#     · Month 17/20 processed | running...RMSE=1.1798
#     · Month 18/20 processed | running...RMSE=1.1480
#     · Month 19/20 processed | running...RMSE=1.1481
#     · Month 20/20 processed | running...RMSE=1.1190
#   - Config 39/128
#     · Month 1/20 processed | running...RMSE=1.5234
#     · Month 2/20 processed | running...RMSE=2.2705
#     · Month 3/20 processed | running...RMSE=1.9458
#     · Month 4/20 processed | running...RMSE=1.6918
#     · Month 5/20 processed | running...RMSE=1.6432
#     · Month 6/20 processed | running...RMSE=1.5070
#     · Month 7/20 processed | running...RMSE=1.3961
#     · Month 8/20 processed | running...RMSE=1.3107
#     · Month 9/20 processed | running...RMSE=1.3602
#     · Month 10/20 processed | running...RMSE=1.3254
#     · Month 11/20 processed | running...RMSE=1.2674
#     · Month 12/20 processed | running...RMSE=1.2355
#     · Month 13/20 processed | running...RMSE=1.1871
#     · Month 14/20 processed | running...RMSE=1.1791
#     · Month 15/20 processed | running...RMSE=1.2447
#     · Month 16/20 processed | running...RMSE=1.2062
#     · Month 17/20 processed | running...RMSE=1.1798
#     · Month 18/20 processed | running...RMSE=1.1480
#     · Month 19/20 processed | running...RMSE=1.1481
#     · Month 20/20 processed | running...RMSE=1.1190
#   - Config 40/128
#     · Month 1/20 processed | running...RMSE=1.5234
#     · Month 2/20 processed | running...RMSE=2.2705
#     · Month 3/20 processed | running...RMSE=1.9458
#     · Month 4/20 processed | running...RMSE=1.6918
#     · Month 5/20 processed | running...RMSE=1.6432
#     · Month 6/20 processed | running...RMSE=1.5070
#     · Month 7/20 processed | running...RMSE=1.3961
#     · Month 8/20 processed | running...RMSE=1.3107
#     · Month 9/20 processed | running...RMSE=1.3602
#     · Month 10/20 processed | running...RMSE=1.3254
#     · Month 11/20 processed | running...RMSE=1.2674
#     · Month 12/20 processed | running...RMSE=1.2355
#     · Month 13/20 processed | running...RMSE=1.1871
#     · Month 14/20 processed | running...RMSE=1.1791
#     · Month 15/20 processed | running...RMSE=1.2447
#     · Month 16/20 processed | running...RMSE=1.2062
#     · Month 17/20 processed | running...RMSE=1.1798
#     · Month 18/20 processed | running...RMSE=1.1480
#     · Month 19/20 processed | running...RMSE=1.1481
#     · Month 20/20 processed | running...RMSE=1.1190
#   - Config 41/128
#     · Month 1/20 processed | running...RMSE=1.7006
#     · Month 2/20 processed | running...RMSE=2.2489
#     · Month 3/20 processed | running...RMSE=1.9231
#     · Month 4/20 processed | running...RMSE=1.6796
#     · Month 5/20 processed | running...RMSE=1.6109
#     · Month 6/20 processed | running...RMSE=1.4731
#     · Month 7/20 processed | running...RMSE=1.3656
#     · Month 8/20 processed | running...RMSE=1.2818
#     · Month 9/20 processed | running...RMSE=1.3399
#     · Month 10/20 processed | running...RMSE=1.3055
#     · Month 11/20 processed | running...RMSE=1.2475
#     · Month 12/20 processed | running...RMSE=1.2197
#     · Month 13/20 processed | running...RMSE=1.1724
#     · Month 14/20 processed | running...RMSE=1.1612
#     · Month 15/20 processed | running...RMSE=1.2335
#     · Month 16/20 processed | running...RMSE=1.1970
#     · Month 17/20 processed | running...RMSE=1.1736
#     · Month 18/20 processed | running...RMSE=1.1444
#     · Month 19/20 processed | running...RMSE=1.1521
#     · Month 20/20 processed | running...RMSE=1.1235
#   - Config 42/128
#     · Month 1/20 processed | running...RMSE=1.7006
#     · Month 2/20 processed | running...RMSE=2.2489
#     · Month 3/20 processed | running...RMSE=1.9231
#     · Month 4/20 processed | running...RMSE=1.6796
#     · Month 5/20 processed | running...RMSE=1.6109
#     · Month 6/20 processed | running...RMSE=1.4731
#     · Month 7/20 processed | running...RMSE=1.3656
#     · Month 8/20 processed | running...RMSE=1.2818
#     · Month 9/20 processed | running...RMSE=1.3399
#     · Month 10/20 processed | running...RMSE=1.3055
#     · Month 11/20 processed | running...RMSE=1.2475
#     · Month 12/20 processed | running...RMSE=1.2197
#     · Month 13/20 processed | running...RMSE=1.1724
#     · Month 14/20 processed | running...RMSE=1.1612
#     · Month 15/20 processed | running...RMSE=1.2335
#     · Month 16/20 processed | running...RMSE=1.1970
#     · Month 17/20 processed | running...RMSE=1.1736
#     · Month 18/20 processed | running...RMSE=1.1444
#     · Month 19/20 processed | running...RMSE=1.1521
#     · Month 20/20 processed | running...RMSE=1.1235
#   - Config 43/128
#     · Month 1/20 processed | running...RMSE=1.7006
#     · Month 2/20 processed | running...RMSE=2.2489
#     · Month 3/20 processed | running...RMSE=1.9231
#     · Month 4/20 processed | running...RMSE=1.6796
#     · Month 5/20 processed | running...RMSE=1.6109
#     · Month 6/20 processed | running...RMSE=1.4731
#     · Month 7/20 processed | running...RMSE=1.3656
#     · Month 8/20 processed | running...RMSE=1.2818
#     · Month 9/20 processed | running...RMSE=1.3399
#     · Month 10/20 processed | running...RMSE=1.3055
#     · Month 11/20 processed | running...RMSE=1.2475
#     · Month 12/20 processed | running...RMSE=1.2197
#     · Month 13/20 processed | running...RMSE=1.1724
#     · Month 14/20 processed | running...RMSE=1.1612
#     · Month 15/20 processed | running...RMSE=1.2335
#     · Month 16/20 processed | running...RMSE=1.1970
#     · Month 17/20 processed | running...RMSE=1.1736
#     · Month 18/20 processed | running...RMSE=1.1444
#     · Month 19/20 processed | running...RMSE=1.1521
#     · Month 20/20 processed | running...RMSE=1.1235
#   - Config 44/128
#     · Month 1/20 processed | running...RMSE=1.7006
#     · Month 2/20 processed | running...RMSE=2.2489
#     · Month 3/20 processed | running...RMSE=1.9231
#     · Month 4/20 processed | running...RMSE=1.6796
#     · Month 5/20 processed | running...RMSE=1.6109
#     · Month 6/20 processed | running...RMSE=1.4731
#     · Month 7/20 processed | running...RMSE=1.3656
#     · Month 8/20 processed | running...RMSE=1.2818
#     · Month 9/20 processed | running...RMSE=1.3399
#     · Month 10/20 processed | running...RMSE=1.3055
#     · Month 11/20 processed | running...RMSE=1.2475
#     · Month 12/20 processed | running...RMSE=1.2197
#     · Month 13/20 processed | running...RMSE=1.1724
#     · Month 14/20 processed | running...RMSE=1.1612
#     · Month 15/20 processed | running...RMSE=1.2335
#     · Month 16/20 processed | running...RMSE=1.1970
#     · Month 17/20 processed | running...RMSE=1.1736
#     · Month 18/20 processed | running...RMSE=1.1444
#     · Month 19/20 processed | running...RMSE=1.1521
#     · Month 20/20 processed | running...RMSE=1.1235
#   - Config 45/128
#     · Month 1/20 processed | running...RMSE=1.5126
#     · Month 2/20 processed | running...RMSE=2.2696
#     · Month 3/20 processed | running...RMSE=1.9440
#     · Month 4/20 processed | running...RMSE=1.6908
#     · Month 5/20 processed | running...RMSE=1.6419
#     · Month 6/20 processed | running...RMSE=1.5062
#     · Month 7/20 processed | running...RMSE=1.3952
#     · Month 8/20 processed | running...RMSE=1.3096
#     · Month 9/20 processed | running...RMSE=1.3606
#     · Month 10/20 processed | running...RMSE=1.3273
#     · Month 11/20 processed | running...RMSE=1.2682
#     · Month 12/20 processed | running...RMSE=1.2396
#     · Month 13/20 processed | running...RMSE=1.1913
#     · Month 14/20 processed | running...RMSE=1.1793
#     · Month 15/20 processed | running...RMSE=1.2510
#     · Month 16/20 processed | running...RMSE=1.2132
#     · Month 17/20 processed | running...RMSE=1.1887
#     · Month 18/20 processed | running...RMSE=1.1575
#     · Month 19/20 processed | running...RMSE=1.1615
#     · Month 20/20 processed | running...RMSE=1.1322
#   - Config 46/128
#     · Month 1/20 processed | running...RMSE=1.5126
#     · Month 2/20 processed | running...RMSE=2.2696
# ...
#     · Month 1/20 processed | running...RMSE=1.1030
#     · Month 2/20 processed | running...RMSE=1.4362
#     · Month 3/20 processed | running...RMSE=2.2956
#     · Month 4/20 processed | running...RMSE=2.2893
#     · Month 5/20 processed | running...RMSE=2.0631
#     · Month 6/20 processed | running...RMSE=1.8841
#     · Month 7/20 processed | running...RMSE=1.7614
#     · Month 8/20 processed | running...RMSE=1.7515
#     · Month 9/20 processed | running...RMSE=1.8506
#     · Month 10/20 processed | running...RMSE=1.8632
#     · Month 11/20 processed | running...RMSE=1.9115
#     · Month 12/20 processed | running...RMSE=1.8612
#     · Month 13/20 processed | running...RMSE=1.7994
#     · Month 14/20 processed | running...RMSE=1.7564
#     · Month 15/20 processed | running...RMSE=1.7124
#     · Month 16/20 processed | running...RMSE=1.6996
#     · Month 17/20 processed | running...RMSE=1.6596
#     · Month 18/20 processed | running...RMSE=1.6199
#     · Month 19/20 processed | running...RMSE=1.5866
#     · Month 20/20 processed | running...RMSE=1.5591
#   - Config 29/32
#     · Month 1/20 processed | running...RMSE=1.3776
#     · Month 2/20 processed | running...RMSE=1.4549
#     · Month 3/20 processed | running...RMSE=2.2067
#     · Month 4/20 processed | running...RMSE=2.2602
#     · Month 5/20 processed | running...RMSE=2.0295
#     · Month 6/20 processed | running...RMSE=1.8548
#     · Month 7/20 processed | running...RMSE=1.7288
#     · Month 8/20 processed | running...RMSE=1.7404
#     · Month 9/20 processed | running...RMSE=1.8220
#     · Month 10/20 processed | running...RMSE=1.8300
#     · Month 11/20 processed | running...RMSE=1.8697
#     · Month 12/20 processed | running...RMSE=1.8257
#     · Month 13/20 processed | running...RMSE=1.7646
#     · Month 14/20 processed | running...RMSE=1.7257
#     · Month 15/20 processed | running...RMSE=1.6858
#     · Month 16/20 processed | running...RMSE=1.6811
#     · Month 17/20 processed | running...RMSE=1.6392
#     · Month 18/20 processed | running...RMSE=1.6021
#     · Month 19/20 processed | running...RMSE=1.5742
#     · Month 20/20 processed | running...RMSE=1.5519
#   - Config 30/32
#     · Month 1/20 processed | running...RMSE=1.3776
#     · Month 2/20 processed | running...RMSE=1.4549
#     · Month 3/20 processed | running...RMSE=2.2067
#     · Month 4/20 processed | running...RMSE=2.2602
#     · Month 5/20 processed | running...RMSE=2.0295
#     · Month 6/20 processed | running...RMSE=1.8548
#     · Month 7/20 processed | running...RMSE=1.7288
#     · Month 8/20 processed | running...RMSE=1.7404
#     · Month 9/20 processed | running...RMSE=1.8220
#     · Month 10/20 processed | running...RMSE=1.8300
#     · Month 11/20 processed | running...RMSE=1.8697
#     · Month 12/20 processed | running...RMSE=1.8257
#     · Month 13/20 processed | running...RMSE=1.7646
#     · Month 14/20 processed | running...RMSE=1.7257
#     · Month 15/20 processed | running...RMSE=1.6858
#     · Month 16/20 processed | running...RMSE=1.6811
#     · Month 17/20 processed | running...RMSE=1.6392
#     · Month 18/20 processed | running...RMSE=1.6021
#     · Month 19/20 processed | running...RMSE=1.5742
#     · Month 20/20 processed | running...RMSE=1.5519
#   - Config 31/32
#     · Month 1/20 processed | running...RMSE=1.3776
#     · Month 2/20 processed | running...RMSE=1.4549
#     · Month 3/20 processed | running...RMSE=2.2067
#     · Month 4/20 processed | running...RMSE=2.2602
#     · Month 5/20 processed | running...RMSE=2.0295
#     · Month 6/20 processed | running...RMSE=1.8548
#     · Month 7/20 processed | running...RMSE=1.7288
#     · Month 8/20 processed | running...RMSE=1.7404
#     · Month 9/20 processed | running...RMSE=1.8220
#     · Month 10/20 processed | running...RMSE=1.8300
#     · Month 11/20 processed | running...RMSE=1.8697
#     · Month 12/20 processed | running...RMSE=1.8257
#     · Month 13/20 processed | running...RMSE=1.7646
#     · Month 14/20 processed | running...RMSE=1.7257
#     · Month 15/20 processed | running...RMSE=1.6858
#     · Month 16/20 processed | running...RMSE=1.6811
#     · Month 17/20 processed | running...RMSE=1.6392
#     · Month 18/20 processed | running...RMSE=1.6021
#     · Month 19/20 processed | running...RMSE=1.5742
#     · Month 20/20 processed | running...RMSE=1.5519
#   - Config 32/32
#     · Month 1/20 processed | running...RMSE=1.3776
#     · Month 2/20 processed | running...RMSE=1.4549
#     · Month 3/20 processed | running...RMSE=2.2067
#     · Month 4/20 processed | running...RMSE=2.2602
#     · Month 5/20 processed | running...RMSE=2.0295
#     · Month 6/20 processed | running...RMSE=1.8548
#     · Month 7/20 processed | running...RMSE=1.7288
#     · Month 8/20 processed | running...RMSE=1.7404
#     · Month 9/20 processed | running...RMSE=1.8220
#     · Month 10/20 processed | running...RMSE=1.8300
#     · Month 11/20 processed | running...RMSE=1.8697
#     · Month 12/20 processed | running...RMSE=1.8257
#     · Month 13/20 processed | running...RMSE=1.7646
#     · Month 14/20 processed | running...RMSE=1.7257
#     · Month 15/20 processed | running...RMSE=1.6858
#     · Month 16/20 processed | running...RMSE=1.6811
#     · Month 17/20 processed | running...RMSE=1.6392
#     · Month 18/20 processed | running...RMSE=1.6021
#     · Month 19/20 processed | running...RMSE=1.5742
#     · Month 20/20 processed | running...RMSE=1.5519
# [Stage A][Block 3] kept 32 configs (floor=32).
# [Stage A] Shortlist saved with 5 configs.
# [Stage B] Month origin t=240 | evaluating 5 configs | active=1
# [Stage B] Month origin t=241 | evaluating 5 configs | active=1
# [Stage B] Month origin t=242 | evaluating 5 configs | active=1
# [Stage B] Month origin t=243 | evaluating 5 configs | active=1
# [Stage B] Month origin t=244 | evaluating 5 configs | active=1
# [Stage B] Month origin t=245 | evaluating 5 configs | active=1
# [Stage B] Month origin t=246 | evaluating 5 configs | active=1
# [Stage B] Month origin t=247 | evaluating 5 configs | active=1
# [Stage B] Month origin t=248 | evaluating 5 configs | active=1
# [Stage B] Month origin t=249 | evaluating 5 configs | active=1
# [Stage B] Month origin t=250 | evaluating 5 configs | active=1
# [Stage B] Month origin t=251 | evaluating 5 configs | active=1
# [Stage B] Month origin t=252 | evaluating 5 configs | active=1
# [Stage B] Month origin t=253 | evaluating 5 configs | active=1
# [Stage B] Month origin t=254 | evaluating 5 configs | active=1
# [Stage B] Month origin t=255 | evaluating 5 configs | active=1
# [Stage B] Month origin t=256 | evaluating 5 configs | active=1
# [Stage B] Month origin t=257 | evaluating 5 configs | active=1
# [Stage B] Month origin t=258 | evaluating 5 configs | active=1
# [Stage B] Month origin t=259 | evaluating 5 configs | active=1
# [Stage B] Month origin t=260 | evaluating 5 configs | active=1
# [Stage B] Month origin t=261 | evaluating 5 configs | active=1
# [Stage B] Month origin t=262 | evaluating 5 configs | active=1
# [Stage B] Month origin t=263 | evaluating 5 configs | active=1
# [Stage B] Month origin t=264 | evaluating 5 configs | active=1
# [Stage B] Month origin t=265 | evaluating 5 configs | active=1
# [Stage B] Month origin t=266 | evaluating 5 configs | active=1
# [Stage B] Month origin t=267 | evaluating 5 configs | active=1
# [Stage B] Month origin t=268 | evaluating 5 configs | active=1
# [Stage B] Month origin t=269 | evaluating 5 configs | active=1
# [Stage B] Month origin t=270 | evaluating 5 configs | active=1
# [Stage B] Month origin t=271 | evaluating 5 configs | active=1
# [Stage B] Month origin t=272 | evaluating 5 configs | active=1
# [Stage B] Month origin t=273 | evaluating 5 configs | active=1
# [Stage B] Month origin t=274 | evaluating 5 configs | active=1
# [Stage B] Month origin t=275 | evaluating 5 configs | active=1
# [Stage B] Month origin t=276 | evaluating 5 configs | active=1
# [Stage B] Month origin t=277 | evaluating 5 configs | active=1
# [Stage B] Month origin t=278 | evaluating 5 configs | active=1
# [Stage B] Month origin t=279 | evaluating 5 configs | active=1
# [Stage B] Month origin t=280 | evaluating 5 configs | active=1
# [Stage B] Month origin t=281 | evaluating 5 configs | active=1
# [Stage B] Month origin t=282 | evaluating 5 configs | active=1
# [Stage B] Month origin t=283 | evaluating 5 configs | active=1
# [Stage B] Month origin t=284 | evaluating 5 configs | active=1
# [Stage B] Month origin t=285 | evaluating 5 configs | active=1
# [Stage B] Month origin t=286 | evaluating 5 configs | active=1
# [Stage B] Month origin t=287 | evaluating 5 configs | active=1
# [Stage B] Month origin t=288 | evaluating 5 configs | active=1
# [Stage B] Month origin t=289 | evaluating 5 configs | active=1
# [Stage B] Month origin t=290 | evaluating 5 configs | active=1
# [Stage B] Month origin t=291 | evaluating 5 configs | active=1
# [Stage B] Month origin t=292 | evaluating 5 configs | active=1
# [Stage B] Month origin t=293 | evaluating 5 configs | active=1
# [Stage B] Month origin t=294 | evaluating 5 configs | active=1
# [Stage B] Month origin t=295 | evaluating 5 configs | active=1
# [Stage B] Month origin t=296 | evaluating 5 configs | active=1
# [Stage B] Month origin t=297 | evaluating 5 configs | active=1
# [Stage B] Month origin t=298 | evaluating 5 configs | active=1
# [Stage B] Month origin t=299 | evaluating 5 configs | active=1
# [Stage B] Month origin t=300 | evaluating 5 configs | active=1
# [Stage B] Month origin t=301 | evaluating 5 configs | active=1
# [Stage B] Month origin t=302 | evaluating 5 configs | active=1
# [Stage B] Month origin t=303 | evaluating 5 configs | active=1
# [Stage B] Month origin t=304 | evaluating 5 configs | active=1
# [Stage B] Month origin t=305 | evaluating 5 configs | active=1
# [Stage B] Month origin t=306 | evaluating 5 configs | active=1
# [Stage B] Month origin t=307 | evaluating 5 configs | active=1
# [Stage B] Month origin t=308 | evaluating 5 configs | active=1
# [Stage B] Month origin t=309 | evaluating 5 configs | active=1
# [Stage B] Month origin t=310 | evaluating 5 configs | active=1
# [Stage B] Month origin t=311 | evaluating 5 configs | active=1
# [Stage B] Month origin t=312 | evaluating 5 configs | active=1
# [Stage B] Month origin t=313 | evaluating 5 configs | active=1
# [Stage B] Month origin t=314 | evaluating 5 configs | active=1
# [Stage B] Month origin t=315 | evaluating 5 configs | active=1
# [Stage B] Month origin t=316 | evaluating 5 configs | active=1
# [Stage B] Month origin t=317 | evaluating 5 configs | active=1
# [Stage B] Month origin t=318 | evaluating 5 configs | active=1
# [Stage B] Month origin t=319 | evaluating 5 configs | active=1
# [Stage B] Month origin t=320 | evaluating 5 configs | active=1
# [Stage B] Month origin t=321 | evaluating 5 configs | active=1
# [Stage B] Month origin t=322 | evaluating 5 configs | active=1
# [Stage B] Month origin t=323 | evaluating 5 configs | active=1
# [Stage B] Month origin t=324 | evaluating 5 configs | active=1
# [Stage B] Month origin t=325 | evaluating 5 configs | active=1
# [Stage B] Month origin t=326 | evaluating 5 configs | active=1
# [Stage B] Month origin t=327 | evaluating 5 configs | active=1
# [Stage B] Month origin t=328 | evaluating 5 configs | active=1
# [Stage B] Month origin t=329 | evaluating 5 configs | active=1
# [Stage B] Month origin t=330 | evaluating 5 configs | active=1
# [Stage B] Month origin t=331 | evaluating 5 configs | active=1
# [Stage B] Month origin t=332 | evaluating 5 configs | active=1
# [Stage B] Month origin t=333 | evaluating 5 configs | active=1
# [Stage B] Month origin t=334 | evaluating 5 configs | active=1
# [Stage B] Month origin t=335 | evaluating 5 configs | active=1
# [Stage B] Month origin t=336 | evaluating 5 configs | active=1
# [Stage B] Month origin t=337 | evaluating 5 configs | active=1
# [Stage B] Month origin t=338 | evaluating 5 configs | active=1
# [Stage B] Month origin t=339 | evaluating 5 configs | active=1
# [Stage B] Month origin t=340 | evaluating 5 configs | active=1
# [Stage B] Month origin t=341 | evaluating 5 configs | active=1
# [Stage B] Month origin t=342 | evaluating 5 configs | active=1
# [Stage B] Month origin t=343 | evaluating 5 configs | active=1
# [Stage B] Month origin t=344 | evaluating 5 configs | active=1
# [Stage B] Month origin t=345 | evaluating 5 configs | active=1
# [Stage B] Month origin t=346 | evaluating 5 configs | active=1
# [Stage B] Month origin t=347 | evaluating 5 configs | active=1
# [Stage B] Month origin t=348 | evaluating 5 configs | active=1
# [Stage B] Month origin t=349 | evaluating 5 configs | active=1
# [Stage B] Month origin t=350 | evaluating 5 configs | active=1
# [Stage B] Month origin t=351 | evaluating 5 configs | active=1
# [Stage B] Month origin t=352 | evaluating 5 configs | active=1
# [Stage B] Month origin t=353 | evaluating 5 configs | active=1
# [Stage B] Month origin t=354 | evaluating 5 configs | active=1
# [Stage B] Month origin t=355 | evaluating 5 configs | active=1
# [Stage B] Month origin t=356 | evaluating 5 configs | active=1
# [Stage B] Month origin t=357 | evaluating 5 configs | active=1
# [Stage B] Month origin t=358 | evaluating 5 configs | active=1
# [Stage B] Month origin t=359 | evaluating 5 configs | active=1
# [Stage B] Month origin t=360 | evaluating 5 configs | active=1
# [Stage B] Month origin t=361 | evaluating 5 configs | active=1
# [Stage B] Month origin t=362 | evaluating 5 configs | active=1
# [Stage B] Month origin t=363 | evaluating 5 configs | active=1
# [Stage B] Month origin t=364 | evaluating 5 configs | active=1
# [Stage B] Month origin t=365 | evaluating 5 configs | active=1
# [Stage B] Month origin t=366 | evaluating 5 configs | active=1
# [Stage B] Month origin t=367 | evaluating 5 configs | active=1
# [Stage B] Month origin t=368 | evaluating 5 configs | active=1
# [Stage B] Month origin t=369 | evaluating 5 configs | active=1
# [Stage B] Month origin t=370 | evaluating 5 configs | active=1
# [Stage B] Month origin t=371 | evaluating 5 configs | active=1
# [Stage B] Month origin t=372 | evaluating 5 configs | active=1
# [Stage B] Month origin t=373 | evaluating 5 configs | active=1
# [Stage B] Month origin t=374 | evaluating 5 configs | active=1
# [Stage B] Month origin t=375 | evaluating 5 configs | active=1
# [Stage B] Month origin t=376 | evaluating 5 configs | active=1
# [Stage B] Month origin t=377 | evaluating 5 configs | active=1
# [Stage B] Month origin t=378 | evaluating 5 configs | active=1
# [Stage B] Month origin t=379 | evaluating 5 configs | active=1
# [Stage B] Month origin t=380 | evaluating 5 configs | active=1
# [Stage B] Month origin t=381 | evaluating 5 configs | active=1
# [Stage B] Month origin t=382 | evaluating 5 configs | active=1
# [Stage B] Month origin t=383 | evaluating 5 configs | active=1
# [Stage B] Month origin t=384 | evaluating 5 configs | active=1
# [Stage B] Month origin t=385 | evaluating 5 configs | active=1
# [Stage B] Month origin t=386 | evaluating 5 configs | active=1
# [Stage B] Month origin t=387 | evaluating 5 configs | active=1
# [Stage B] Month origin t=388 | evaluating 5 configs | active=1
# [Stage B] Month origin t=389 | evaluating 5 configs | active=1
# [Stage B] Month origin t=390 | evaluating 5 configs | active=1
# [Stage B] Month origin t=391 | evaluating 5 configs | active=1
# [Stage B] Month origin t=392 | evaluating 5 configs | active=1
# [Stage B] Month origin t=393 | evaluating 5 configs | active=1
# [Stage B] Month origin t=394 | evaluating 5 configs | active=1
# [Stage B] Month origin t=395 | evaluating 5 configs | active=1
# [Stage B] Month origin t=396 | evaluating 5 configs | active=1
# [Stage B] Month origin t=397 | evaluating 5 configs | active=1
# [Stage B] Month origin t=398 | evaluating 5 configs | active=1
# [Stage B] Month origin t=399 | evaluating 5 configs | active=1
# [Stage B] Month origin t=400 | evaluating 5 configs | active=1
# [Stage B] Month origin t=401 | evaluating 5 configs | active=1
# [Stage B] Month origin t=402 | evaluating 5 configs | active=1
# [Stage B] Month origin t=403 | evaluating 5 configs | active=1
# [Stage B] Month origin t=404 | evaluating 5 configs | active=1
# [Stage B] Month origin t=405 | evaluating 5 configs | active=1
# [Stage B] done → /Users/jonasschernich/Documents/Masterarbeit/Code/outputs/stageB/extra_trees/monthly
# [Stage B] summary.csv & summary_active.txt geschrieben.
#
# Done. Check outputs/stageA|stageB/extra_trees for results.
