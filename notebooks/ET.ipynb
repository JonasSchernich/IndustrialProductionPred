# %%
# --- Setup & Imports ---
import os, sys
from pathlib import Path
import pandas as pd
import numpy as np

# --- 1. Pfad-Setup ---
def _locate_repo_root(start: Path) -> Path:
    cur = start.resolve()
    for _ in range(5):  # walk up to 5 levels
        if (cur / 'src').exists():
            return cur
        if cur.parent == cur:
            break
        cur = cur.parent
    return start.resolve()

NOTEBOOK_DIR = Path.cwd()
PROJECT_ROOT = _locate_repo_root(NOTEBOOK_DIR)
os.environ['PROJECT_ROOT'] = str(PROJECT_ROOT)
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from src.config import GlobalConfig, DEFAULT_CORR_SPEC, EWMA_CORR_SPEC, outputs_for_model
from src.tuning import run_stageA, run_stageB
from src.io_timesplits import load_target, load_ifo_features
# --- MODELL-IMPORT ---
from src.models.ET import ForecastModel # Nutzt ExtraTreesRegressor

print('PROJECT_ROOT =', PROJECT_ROOT)

# --- MODELLNAME ---
MODEL_NAME = "extra_trees"
outputs_for_model(MODEL_NAME)
print(f'Modell {MODEL_NAME} wird getunt.')

# --- 2. Daten laden ---
y = load_target()  # ΔIP with DatetimeIndex
X_ifo = load_ifo_features() # ifo features

idx = y.index.intersection(X_ifo.index)
y, X_ifo = y.loc[idx], X_ifo.loc[idx]
print('Shapes:', X_ifo.shape, y.shape)

# --- 3. Base config (splits & policy as in thesis) ---
def base_cfg() -> GlobalConfig:
    cfg = GlobalConfig()
    cfg.W0_A     = 180
    cfg.BLOCKS_A = [(181,200), (201,220), (221,240)]
    cfg.W0_B     = 240
    # Policy Parameter
    cfg.policy_window   = 24
    cfg.policy_decay    = 0.95
    cfg.policy_gain_min = 0.03
    cfg.policy_cooldown = 3
    return cfg

cfg0 = base_cfg()

# --- 4. Helper für Korrelations-Spezifikation (bleibt gleich) ---
def make_corr_spec(kind: str) -> dict:
    if kind == 'expanding':
        return dict(DEFAULT_CORR_SPEC)
    elif kind == 'ewm':
        return dict(EWMA_CORR_SPEC)
    else:
        raise ValueError("kind must be 'expanding' or 'ewm'")

# --- 5. OPTIMIERTES TUNING-GRID ---

# A) Feature Engineering Parameter Listen
corr_options = [
    ("expanding", make_corr_spec("expanding")),
    ("ewm", make_corr_spec("ewm"))
]
lag_candidates_list = [(1, 2, 3, 6, 12)] # Halten wir einfach für ET
top_k_lags_list = [1, 2] # Testen, ob 2 Lags helfen
use_rm3_list = [True, False] # Testen mit und ohne Glättung
k1_topk_list = [100, 300] # Engeres Screening vs. breiteres Screening vor DR
redundancy_param_list = [0.90, 0.95] # Zwei Redundanzlevel testen
# DR Optionen - PCA/PLS machen nur nach breiterem Screening Sinn
dr_options_list = [
    {'dr_method': 'none'},
    {'dr_method': 'pca', 'pca_var_target': 0.95, 'pca_kmax': 50},
    {'dr_method': 'pls', 'pls_components': 8} # PLS als Alternative
]

# B) Extra Trees Hyperparameter Listen
n_estimators_list = [300] # Etwas mehr Bäume fixieren
max_features_list = ['sqrt', 0.2, 0.4] # Drei Optionen für Feature Subsampling
min_samples_leaf_list = [5, 15, 30] # Drei Regularisierungslevel

# C) Target Blocks & Weighting Listen
target_block_options = [ None, ["AR1"], ["Chronos"], ["TSFresh"] ] # Einzeln testen
weighting_options = [
    {"sample_weight_decay": None}, # Standard: kein Decay
    {"sample_weight_decay": 0.98}  # Option: Exponentielles Decay
]

# D) Grid zusammensetzen (Optimierte Logik)
def build_model_grid():
    hp_grid = []
    for corr_tag, corr_spec in corr_options:
        for lags in lag_candidates_list:
            for k_lags in top_k_lags_list:
                for rm3 in use_rm3_list:
                    for k1 in k1_topk_list:
                        for red in redundancy_param_list:
                            for dr_opt in dr_options_list:
                                # *** WICHTIGE EINSCHRÄNKUNG für Laufzeit ***
                                # DR (PCA/PLS) nur anwenden, wenn wir breiter gescreent haben (k1=300)
                                if k1 == 100 and dr_opt['dr_method'] != 'none': continue
                                # Kein DR macht bei k1=300 wenig Sinn (zu viele Features für ET)
                                # Erlauben wir es trotzdem als Testfall
                                # if k1 == 300 and dr_opt['dr_method'] == 'none': continue

                                for n_est in n_estimators_list:
                                    for max_feat in max_features_list:
                                        for min_leaf in min_samples_leaf_list:
                                            for block_set in target_block_options:
                                                for weight_hp in weighting_options:
                                                    hp = {
                                                        # FE Params
                                                        'lag_candidates': lags,
                                                        'top_k_lags_per_feature': k_lags,
                                                        'use_rm3': rm3,
                                                        'k1_topk': k1,
                                                        'redundancy_param': red,
                                                        **dr_opt,
                                                        # ET Params
                                                        'n_estimators': n_est,
                                                        'max_features': max_feat,
                                                        'min_samples_leaf': min_leaf,
                                                        # Other Params
                                                        **weight_hp,
                                                        'corr_tag': corr_tag,
                                                        'corr_spec': corr_spec,
                                                        'target_block_set': block_set
                                                    }
                                                    hp_grid.append(hp)
    return hp_grid

model_grid = build_model_grid()
# Ungefähre Größe: 2(Corr)*1*2(kL)*2(RM)*[ (1(k1)*1(DR)) + (1(k1)*3(DR)) ]*2(Red)*1(nEst)*3(MaxF)*3(MinL)*4(Block)*2(Weight)
# = 8 * [1 + 3] * 2 * 1 * 9 * 4 * 2 = 8 * 4 * 2 * 9 * 8 = 64 * 72 = 4608 (Immer noch groß!)
# Reduzieren wir es weiter:
# Fixieren k_lags=1, rm3=True, red=0.90, weight=None
# Size: 2(Corr)*1*1*1 * [1 + 3] * 1 * 1 * 3(MaxF)*3(MinL)*4(Block)*1(Weight)
# = 2 * 4 * 1 * 9 * 4 * 1 = 8 * 36 = 288 (Das ist akzeptabler)

# --- ANGEPASSTES GRID für akzeptable Laufzeit ---
k_lags_list = [1]
use_rm3_list = [True]
redundancy_param_list = [0.90]
weighting_options = [ {"sample_weight_decay": None} ]
max_features_list = ['sqrt', 0.3] # Reduziert auf 2
min_samples_leaf_list = [5, 15]   # Reduziert auf 2

# Neuberechnung Grid Size: 2*1*1*1 * [1+3] * 1 * 1 * 2 * 2 * 4 * 1 = 2 * 4 * 4 * 4 = 128
# Das ist ein guter Kompromiss.

def build_model_grid_optimized():
    hp_grid = []
    for corr_tag, corr_spec in corr_options: # 2
        for lags in lag_candidates_list: # 1
            for k_lags in k_lags_list: # 1
                for rm3 in use_rm3_list: # 1
                    for k1 in k1_topk_list: # 2
                        for red in redundancy_param_list: # 1
                            for dr_opt in dr_options_list: # 3
                                # Einschränkung
                                if k1 == 100 and dr_opt['dr_method'] != 'none': continue # Lässt (100, none) -> 1
                                # if k1 == 300 and dr_opt['dr_method'] == 'none': continue # Erlauben wir testweise
                                # Lässt (300, none), (300, pca), (300, pls) -> 3. Total FE/DR = 1+3 = 4

                                for n_est in n_estimators_list: # 1
                                    for max_feat in max_features_list: # 2
                                        for min_leaf in min_samples_leaf_list: # 2
                                            for block_set in target_block_options: # 4
                                                for weight_hp in weighting_options: # 1
                                                    hp = {
                                                        # FE Params
                                                        'lag_candidates': lags,
                                                        'top_k_lags_per_feature': k_lags,
                                                        'use_rm3': rm3,
                                                        'k1_topk': k1,
                                                        'redundancy_param': red,
                                                        **dr_opt,
                                                        # ET Params
                                                        'n_estimators': n_est,
                                                        'max_features': max_feat,
                                                        'min_samples_leaf': min_leaf,
                                                        # Other Params
                                                        **weight_hp,
                                                        'corr_tag': corr_tag,
                                                        'corr_spec': corr_spec,
                                                        'target_block_set': block_set
                                                    }
                                                    hp_grid.append(hp)
    return hp_grid

model_grid = build_model_grid_optimized()
print("Optimierte HP-Kombinationen:", len(model_grid)) # 2*1*1*1 * 4 * 1 * 1 * 2 * 2 * 4 * 1 = 128
print("Erstes HP-Set:", model_grid[0] if model_grid else "Grid ist leer")


# --- 6. Stage A/B Lauf ---
if model_grid: # Nur ausführen, wenn das Grid nicht leer ist
    shortlist = run_stageA(
        model_name=MODEL_NAME,
        model_ctor=lambda hp: ForecastModel(hp),
        model_grid=model_grid,
        X=X_ifo, y=y, cfg=cfg0,
        keep_top_k_final=min(5, len(model_grid)),
        min_survivors_per_block=max(1, len(model_grid)//4), # Reduziere Überlebende pro Block etwas
    )

    run_stageB(
        model_name=MODEL_NAME,
        model_ctor=lambda hp: ForecastModel(hp),
        shortlist=shortlist,
        X=X_ifo, y=y, cfg=cfg0,
        # max_months=12,   # Optional: Begrenze Stage B für schnellen Test
    )
else:
    print("Keine gültigen HP-Kombinationen gefunden, Stages übersprungen.")

print(f"\nDone. Check outputs/stageA|stageB/{MODEL_NAME} for results.")
# Out:
# PROJECT_ROOT = /Users/jonasschernich/Documents/Masterarbeit/Code
# Modell extra_trees wird getunt.
# INFO in load_ifo_features: Renaming columns to ensure validity.
# Shapes: (407, 2160) (407,)
# HP-Kombinationen: 16
# Erstes HP-Set: {'lag_candidates': (1, 2, 3, 6, 12), 'top_k_lags_per_feature': 1, 'use_rm3': True, 'k1_topk': 100, 'redundancy_param': 0.9, 'dr_method': 'none', 'n_estimators': 200, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'sample_weight_decay': None, 'corr_tag': 'expanding', 'corr_spec': {'mode': 'expanding', 'window': None, 'lam': None}, 'target_block_set': None}
# [Stage A][Block 1] train_end=180, OOS=181-200 | configs=16
#   - Config 1/16
#     · Month 1/20 processed | running...RMSE=1.5731
#     · Month 2/20 processed | running...RMSE=2.1779
#     · Month 3/20 processed | running...RMSE=1.8362
#     · Month 4/20 processed | running...RMSE=1.6111
#     · Month 5/20 processed | running...RMSE=1.5473
#     · Month 6/20 processed | running...RMSE=1.4197
#     · Month 7/20 processed | running...RMSE=1.3150
#     · Month 8/20 processed | running...RMSE=1.2351
#     · Month 9/20 processed | running...RMSE=1.3024
#     · Month 10/20 processed | running...RMSE=1.2827
#     · Month 11/20 processed | running...RMSE=1.2233
#     · Month 12/20 processed | running...RMSE=1.2092
#     · Month 13/20 processed | running...RMSE=1.1630
#     · Month 14/20 processed | running...RMSE=1.1447
#     · Month 15/20 processed | running...RMSE=1.2308
#     · Month 16/20 processed | running...RMSE=1.1955
#     · Month 17/20 processed | running...RMSE=1.1796
#     · Month 18/20 processed | running...RMSE=1.1547
#     · Month 19/20 processed | running...RMSE=1.1720
#     · Month 20/20 processed | running...RMSE=1.1458
#   - Config 2/16
#     · Month 1/20 processed | running...RMSE=1.5731
#     · Month 2/20 processed | running...RMSE=2.1779
#     · Month 3/20 processed | running...RMSE=1.8362
#     · Month 4/20 processed | running...RMSE=1.6111
#     · Month 5/20 processed | running...RMSE=1.5473
#     · Month 6/20 processed | running...RMSE=1.4197
#     · Month 7/20 processed | running...RMSE=1.3150
#     · Month 8/20 processed | running...RMSE=1.2351
#     · Month 9/20 processed | running...RMSE=1.3024
#     · Month 10/20 processed | running...RMSE=1.2827
#     · Month 11/20 processed | running...RMSE=1.2233
#     · Month 12/20 processed | running...RMSE=1.2092
#     · Month 13/20 processed | running...RMSE=1.1630
#     · Month 14/20 processed | running...RMSE=1.1447
#     · Month 15/20 processed | running...RMSE=1.2308
#     · Month 16/20 processed | running...RMSE=1.1955
#     · Month 17/20 processed | running...RMSE=1.1796
#     · Month 18/20 processed | running...RMSE=1.1547
#     · Month 19/20 processed | running...RMSE=1.1720
#     · Month 20/20 processed | running...RMSE=1.1458
#   - Config 3/16
#     · Month 1/20 processed | running...RMSE=1.6081
#     · Month 2/20 processed | running...RMSE=2.2229
#     · Month 3/20 processed | running...RMSE=1.8775
#     · Month 4/20 processed | running...RMSE=1.6435
#     · Month 5/20 processed | running...RMSE=1.5820
#     · Month 6/20 processed | running...RMSE=1.4507
#     · Month 7/20 processed | running...RMSE=1.3443
#     · Month 8/20 processed | running...RMSE=1.2639
#     · Month 9/20 processed | running...RMSE=1.3231
#     · Month 10/20 processed | running...RMSE=1.2933
#     · Month 11/20 processed | running...RMSE=1.2346
#     · Month 12/20 processed | running...RMSE=1.2143
#     · Month 13/20 processed | running...RMSE=1.1679
#     · Month 14/20 processed | running...RMSE=1.1517
#     · Month 15/20 processed | running...RMSE=1.2398
#     · Month 16/20 processed | running...RMSE=1.2047
#     · Month 17/20 processed | running...RMSE=1.1872
#     · Month 18/20 processed | running...RMSE=1.1607
#     · Month 19/20 processed | running...RMSE=1.1773
#     · Month 20/20 processed | running...RMSE=1.1502
#   - Config 4/16
#     · Month 1/20 processed | running...RMSE=1.6081
#     · Month 2/20 processed | running...RMSE=2.2229
#     · Month 3/20 processed | running...RMSE=1.8775
#     · Month 4/20 processed | running...RMSE=1.6435
#     · Month 5/20 processed | running...RMSE=1.5820
#     · Month 6/20 processed | running...RMSE=1.4507
#     · Month 7/20 processed | running...RMSE=1.3443
#     · Month 8/20 processed | running...RMSE=1.2639
#     · Month 9/20 processed | running...RMSE=1.3231
#     · Month 10/20 processed | running...RMSE=1.2933
#     · Month 11/20 processed | running...RMSE=1.2346
#     · Month 12/20 processed | running...RMSE=1.2143
#     · Month 13/20 processed | running...RMSE=1.1679
#     · Month 14/20 processed | running...RMSE=1.1517
#     · Month 15/20 processed | running...RMSE=1.2398
#     · Month 16/20 processed | running...RMSE=1.2047
#     · Month 17/20 processed | running...RMSE=1.1872
#     · Month 18/20 processed | running...RMSE=1.1607
#     · Month 19/20 processed | running...RMSE=1.1773
#     · Month 20/20 processed | running...RMSE=1.1502
#   - Config 5/16
#     · Month 1/20 processed | running...RMSE=1.7777
#     · Month 2/20 processed | running...RMSE=2.1773
#     · Month 3/20 processed | running...RMSE=1.8245
#     · Month 4/20 processed | running...RMSE=1.5960
#     · Month 5/20 processed | running...RMSE=1.5433
#     · Month 6/20 processed | running...RMSE=1.4181
#     · Month 7/20 processed | running...RMSE=1.3132
#     · Month 8/20 processed | running...RMSE=1.2302
#     · Month 9/20 processed | running...RMSE=1.3131
#     · Month 10/20 processed | running...RMSE=1.2926
#     · Month 11/20 processed | running...RMSE=1.2329
#     · Month 12/20 processed | running...RMSE=1.2194
#     · Month 13/20 processed | running...RMSE=1.1745
#     · Month 14/20 processed | running...RMSE=1.1513
#     · Month 15/20 processed | running...RMSE=1.2474
#     · Month 16/20 processed | running...RMSE=1.2135
#     · Month 17/20 processed | running...RMSE=1.2005
#     · Month 18/20 processed | running...RMSE=1.1767
#     · Month 19/20 processed | running...RMSE=1.1998
#     · Month 20/20 processed | running...RMSE=1.1744
#   - Config 6/16
#     · Month 1/20 processed | running...RMSE=1.7777
#     · Month 2/20 processed | running...RMSE=2.1773
#     · Month 3/20 processed | running...RMSE=1.8245
#     · Month 4/20 processed | running...RMSE=1.5960
#     · Month 5/20 processed | running...RMSE=1.5433
#     · Month 6/20 processed | running...RMSE=1.4181
#     · Month 7/20 processed | running...RMSE=1.3132
#     · Month 8/20 processed | running...RMSE=1.2302
#     · Month 9/20 processed | running...RMSE=1.3131
#     · Month 10/20 processed | running...RMSE=1.2926
#     · Month 11/20 processed | running...RMSE=1.2329
#     · Month 12/20 processed | running...RMSE=1.2194
#     · Month 13/20 processed | running...RMSE=1.1745
#     · Month 14/20 processed | running...RMSE=1.1513
#     · Month 15/20 processed | running...RMSE=1.2474
#     · Month 16/20 processed | running...RMSE=1.2135
#     · Month 17/20 processed | running...RMSE=1.2005
#     · Month 18/20 processed | running...RMSE=1.1767
#     · Month 19/20 processed | running...RMSE=1.1998
#     · Month 20/20 processed | running...RMSE=1.1744
#   - Config 7/16
#     · Month 1/20 processed | running...RMSE=1.6517
#     · Month 2/20 processed | running...RMSE=2.1953
#     · Month 3/20 processed | running...RMSE=1.8477
#     · Month 4/20 processed | running...RMSE=1.6156
#     · Month 5/20 processed | running...RMSE=1.5673
#     · Month 6/20 processed | running...RMSE=1.4390
#     · Month 7/20 processed | running...RMSE=1.3328
#     · Month 8/20 processed | running...RMSE=1.2509
#     · Month 9/20 processed | running...RMSE=1.3222
#     · Month 10/20 processed | running...RMSE=1.2978
#     · Month 11/20 processed | running...RMSE=1.2381
#     · Month 12/20 processed | running...RMSE=1.2230
#     · Month 13/20 processed | running...RMSE=1.1779
#     · Month 14/20 processed | running...RMSE=1.1544
#     · Month 15/20 processed | running...RMSE=1.2534
#     · Month 16/20 processed | running...RMSE=1.2194
#     · Month 17/20 processed | running...RMSE=1.2032
#     · Month 18/20 processed | running...RMSE=1.1782
#     · Month 19/20 processed | running...RMSE=1.1993
#     · Month 20/20 processed | running...RMSE=1.1730
#   - Config 8/16
#     · Month 1/20 processed | running...RMSE=1.6517
#     · Month 2/20 processed | running...RMSE=2.1953
#     · Month 3/20 processed | running...RMSE=1.8477
#     · Month 4/20 processed | running...RMSE=1.6156
#     · Month 5/20 processed | running...RMSE=1.5673
#     · Month 6/20 processed | running...RMSE=1.4390
#     · Month 7/20 processed | running...RMSE=1.3328
#     · Month 8/20 processed | running...RMSE=1.2509
#     · Month 9/20 processed | running...RMSE=1.3222
#     · Month 10/20 processed | running...RMSE=1.2978
#     · Month 11/20 processed | running...RMSE=1.2381
#     · Month 12/20 processed | running...RMSE=1.2230
#     · Month 13/20 processed | running...RMSE=1.1779
#     · Month 14/20 processed | running...RMSE=1.1544
#     · Month 15/20 processed | running...RMSE=1.2534
#     · Month 16/20 processed | running...RMSE=1.2194
#     · Month 17/20 processed | running...RMSE=1.2032
#     · Month 18/20 processed | running...RMSE=1.1782
#     · Month 19/20 processed | running...RMSE=1.1993
#     · Month 20/20 processed | running...RMSE=1.1730
#   - Config 9/16
#     · Month 1/20 processed | running...RMSE=1.5314
#     · Month 2/20 processed | running...RMSE=2.2367
#     · Month 3/20 processed | running...RMSE=1.9052
#     · Month 4/20 processed | running...RMSE=1.6568
#     · Month 5/20 processed | running...RMSE=1.6266
#     · Month 6/20 processed | running...RMSE=1.4900
#     · Month 7/20 processed | running...RMSE=1.3812
#     · Month 8/20 processed | running...RMSE=1.2956
#     · Month 9/20 processed | running...RMSE=1.3536
#     · Month 10/20 processed | running...RMSE=1.3266
#     · Month 11/20 processed | running...RMSE=1.2668
#     · Month 12/20 processed | running...RMSE=1.2438
#     · Month 13/20 processed | running...RMSE=1.1973
#     · Month 14/20 processed | running...RMSE=1.1763
#     · Month 15/20 processed | running...RMSE=1.2588
#     · Month 16/20 processed | running...RMSE=1.2215
#     · Month 17/20 processed | running...RMSE=1.1982
#     · Month 18/20 processed | running...RMSE=1.1674
#     · Month 19/20 processed | running...RMSE=1.1738
#     · Month 20/20 processed | running...RMSE=1.1445
#   - Config 10/16
#     · Month 1/20 processed | running...RMSE=1.5314
#     · Month 2/20 processed | running...RMSE=2.2367
#     · Month 3/20 processed | running...RMSE=1.9052
#     · Month 4/20 processed | running...RMSE=1.6568
#     · Month 5/20 processed | running...RMSE=1.6266
#     · Month 6/20 processed | running...RMSE=1.4900
#     · Month 7/20 processed | running...RMSE=1.3812
#     · Month 8/20 processed | running...RMSE=1.2956
#     · Month 9/20 processed | running...RMSE=1.3536
#     · Month 10/20 processed | running...RMSE=1.3266
#     · Month 11/20 processed | running...RMSE=1.2668
#     · Month 12/20 processed | running...RMSE=1.2438
#     · Month 13/20 processed | running...RMSE=1.1973
#     · Month 14/20 processed | running...RMSE=1.1763
#     · Month 15/20 processed | running...RMSE=1.2588
#     · Month 16/20 processed | running...RMSE=1.2215
#     · Month 17/20 processed | running...RMSE=1.1982
#     · Month 18/20 processed | running...RMSE=1.1674
#     · Month 19/20 processed | running...RMSE=1.1738
#     · Month 20/20 processed | running...RMSE=1.1445
#   - Config 11/16
#     · Month 1/20 processed | running...RMSE=1.5400
#     · Month 2/20 processed | running...RMSE=2.2754
#     · Month 3/20 processed | running...RMSE=1.9451
#     · Month 4/20 processed | running...RMSE=1.6909
#     · Month 5/20 processed | running...RMSE=1.6414
#     · Month 6/20 processed | running...RMSE=1.5051
#     · Month 7/20 processed | running...RMSE=1.3942
#     · Month 8/20 processed | running...RMSE=1.3086
#     · Month 9/20 processed | running...RMSE=1.3588
#     · Month 10/20 processed | running...RMSE=1.3267
#     · Month 11/20 processed | running...RMSE=1.2675
#     · Month 12/20 processed | running...RMSE=1.2407
#     · Month 13/20 processed | running...RMSE=1.1931
#     · Month 14/20 processed | running...RMSE=1.1787
#     · Month 15/20 processed | running...RMSE=1.2527
#     · Month 16/20 processed | running...RMSE=1.2148
#     · Month 17/20 processed | running...RMSE=1.1895
#     · Month 18/20 processed | running...RMSE=1.1577
#     · Month 19/20 processed | running...RMSE=1.1588
#     · Month 20/20 processed | running...RMSE=1.1296
#   - Config 12/16
#     · Month 1/20 processed | running...RMSE=1.5400
#     · Month 2/20 processed | running...RMSE=2.2754
#     · Month 3/20 processed | running...RMSE=1.9451
#     · Month 4/20 processed | running...RMSE=1.6909
#     · Month 5/20 processed | running...RMSE=1.6414
#     · Month 6/20 processed | running...RMSE=1.5051
#     · Month 7/20 processed | running...RMSE=1.3942
#     · Month 8/20 processed | running...RMSE=1.3086
#     · Month 9/20 processed | running...RMSE=1.3588
#     · Month 10/20 processed | running...RMSE=1.3267
#     · Month 11/20 processed | running...RMSE=1.2675
#     · Month 12/20 processed | running...RMSE=1.2407
#     · Month 13/20 processed | running...RMSE=1.1931
#     · Month 14/20 processed | running...RMSE=1.1787
#     · Month 15/20 processed | running...RMSE=1.2527
#     · Month 16/20 processed | running...RMSE=1.2148
#     · Month 17/20 processed | running...RMSE=1.1895
#     · Month 18/20 processed | running...RMSE=1.1577
#     · Month 19/20 processed | running...RMSE=1.1588
#     · Month 20/20 processed | running...RMSE=1.1296
#   - Config 13/16
#     · Month 1/20 processed | running...RMSE=1.4625
#     · Month 2/20 processed | running...RMSE=2.1951
#     · Month 3/20 processed | running...RMSE=1.8623
#     · Month 4/20 processed | running...RMSE=1.6249
#     · Month 5/20 processed | running...RMSE=1.5873
#     · Month 6/20 processed | running...RMSE=1.4531
#     · Month 7/20 processed | running...RMSE=1.3461
#     · Month 8/20 processed | running...RMSE=1.2629
#     · Month 9/20 processed | running...RMSE=1.3195
#     · Month 10/20 processed | running...RMSE=1.2955
#     · Month 11/20 processed | running...RMSE=1.2381
#     · Month 12/20 processed | running...RMSE=1.2228
#     · Month 13/20 processed | running...RMSE=1.1791
#     · Month 14/20 processed | running...RMSE=1.1520
#     · Month 15/20 processed | running...RMSE=1.2599
#     · Month 16/20 processed | running...RMSE=1.2283
#     · Month 17/20 processed | running...RMSE=1.2100
#     · Month 18/20 processed | running...RMSE=1.1812
#     · Month 19/20 processed | running...RMSE=1.1877
#     · Month 20/20 processed | running...RMSE=1.1581
#   - Config 14/16
#     · Month 1/20 processed | running...RMSE=1.4625
#     · Month 2/20 processed | running...RMSE=2.1951
#     · Month 3/20 processed | running...RMSE=1.8623
#     · Month 4/20 processed | running...RMSE=1.6249
#     · Month 5/20 processed | running...RMSE=1.5873
#     · Month 6/20 processed | running...RMSE=1.4531
#     · Month 7/20 processed | running...RMSE=1.3461
#     · Month 8/20 processed | running...RMSE=1.2629
#     · Month 9/20 processed | running...RMSE=1.3195
#     · Month 10/20 processed | running...RMSE=1.2955
#     · Month 11/20 processed | running...RMSE=1.2381
#     · Month 12/20 processed | running...RMSE=1.2228
#     · Month 13/20 processed | running...RMSE=1.1791
#     · Month 14/20 processed | running...RMSE=1.1520
#     · Month 15/20 processed | running...RMSE=1.2599
#     · Month 16/20 processed | running...RMSE=1.2283
#     · Month 17/20 processed | running...RMSE=1.2100
#     · Month 18/20 processed | running...RMSE=1.1812
#     · Month 19/20 processed | running...RMSE=1.1877
#     · Month 20/20 processed | running...RMSE=1.1581
#   - Config 15/16
#     · Month 1/20 processed | running...RMSE=1.4773
#     · Month 2/20 processed | running...RMSE=2.2609
#     · Month 3/20 processed | running...RMSE=1.9264
#     · Month 4/20 processed | running...RMSE=1.6779
#     · Month 5/20 processed | running...RMSE=1.6330
#     · Month 6/20 processed | running...RMSE=1.4981
#     · Month 7/20 processed | running...RMSE=1.3876
#     · Month 8/20 processed | running...RMSE=1.3023
#     · Month 9/20 processed | running...RMSE=1.3563
#     · Month 10/20 processed | running...RMSE=1.3278
#     · Month 11/20 processed | running...RMSE=1.2687
#     · Month 12/20 processed | running...RMSE=1.2440
#     · Month 13/20 processed | running...RMSE=1.1969
#     · Month 14/20 processed | running...RMSE=1.1813
#     · Month 15/20 processed | running...RMSE=1.2581
#     · Month 16/20 processed | running...RMSE=1.2210
#     · Month 17/20 processed | running...RMSE=1.1990
#     · Month 18/20 processed | running...RMSE=1.1685
#     · Month 19/20 processed | running...RMSE=1.1728
#     · Month 20/20 processed | running...RMSE=1.1434
#   - Config 16/16
#     · Month 1/20 processed | running...RMSE=1.4773
#     · Month 2/20 processed | running...RMSE=2.2609
#     · Month 3/20 processed | running...RMSE=1.9264
#     · Month 4/20 processed | running...RMSE=1.6779
#     · Month 5/20 processed | running...RMSE=1.6330
#     · Month 6/20 processed | running...RMSE=1.4981
#     · Month 7/20 processed | running...RMSE=1.3876
#     · Month 8/20 processed | running...RMSE=1.3023
#     · Month 9/20 processed | running...RMSE=1.3563
#     · Month 10/20 processed | running...RMSE=1.3278
#     · Month 11/20 processed | running...RMSE=1.2687
#     · Month 12/20 processed | running...RMSE=1.2440
#     · Month 13/20 processed | running...RMSE=1.1969
#     · Month 14/20 processed | running...RMSE=1.1813
#     · Month 15/20 processed | running...RMSE=1.2581
#     · Month 16/20 processed | running...RMSE=1.2210
#     · Month 17/20 processed | running...RMSE=1.1990
#     · Month 18/20 processed | running...RMSE=1.1685
#     · Month 19/20 processed | running...RMSE=1.1728
#     · Month 20/20 processed | running...RMSE=1.1434
# [Stage A][Block 1] kept 8 configs (floor=8).
# [Stage A][Block 2] train_end=200, OOS=201-220 | configs=8
#   - Config 1/8
#     · Month 1/20 processed | running...RMSE=0.4039
#     · Month 2/20 processed | running...RMSE=0.4988
#     · Month 3/20 processed | running...RMSE=0.9519
#     · Month 4/20 processed | running...RMSE=0.8745
#     · Month 5/20 processed | running...RMSE=0.8913
#     · Month 6/20 processed | running...RMSE=0.8373
#     · Month 7/20 processed | running...RMSE=1.0946
#     · Month 8/20 processed | running...RMSE=1.0814
#     · Month 9/20 processed | running...RMSE=1.1251
#     · Month 10/20 processed | running...RMSE=1.2069
#     · Month 11/20 processed | running...RMSE=1.2567
#     · Month 12/20 processed | running...RMSE=1.3370
#     · Month 13/20 processed | running...RMSE=1.7085
#     · Month 14/20 processed | running...RMSE=1.8364
#     · Month 15/20 processed | running...RMSE=2.5234
#     · Month 16/20 processed | running...RMSE=2.5576
#     · Month 17/20 processed | running...RMSE=2.4834
#     · Month 18/20 processed | running...RMSE=2.4878
#     · Month 19/20 processed | running...RMSE=2.5854
#     · Month 20/20 processed | running...RMSE=2.5504
#   - Config 2/8
#     · Month 1/20 processed | running...RMSE=0.4039
#     · Month 2/20 processed | running...RMSE=0.4988
#     · Month 3/20 processed | running...RMSE=0.9519
#     · Month 4/20 processed | running...RMSE=0.8745
#     · Month 5/20 processed | running...RMSE=0.8913
#     · Month 6/20 processed | running...RMSE=0.8373
#     · Month 7/20 processed | running...RMSE=1.0946
#     · Month 8/20 processed | running...RMSE=1.0814
#     · Month 9/20 processed | running...RMSE=1.1251
#     · Month 10/20 processed | running...RMSE=1.2069
#     · Month 11/20 processed | running...RMSE=1.2567
#     · Month 12/20 processed | running...RMSE=1.3370
#     · Month 13/20 processed | running...RMSE=1.7085
#     · Month 14/20 processed | running...RMSE=1.8364
#     · Month 15/20 processed | running...RMSE=2.5234
#     · Month 16/20 processed | running...RMSE=2.5576
#     · Month 17/20 processed | running...RMSE=2.4834
#     · Month 18/20 processed | running...RMSE=2.4878
#     · Month 19/20 processed | running...RMSE=2.5854
#     · Month 20/20 processed | running...RMSE=2.5504
#   - Config 3/8
#     · Month 1/20 processed | running...RMSE=0.3340
#     · Month 2/20 processed | running...RMSE=0.4878
#     · Month 3/20 processed | running...RMSE=0.9389
#     · Month 4/20 processed | running...RMSE=0.8734
#     · Month 5/20 processed | running...RMSE=0.9089
#     · Month 6/20 processed | running...RMSE=0.8467
#     · Month 7/20 processed | running...RMSE=1.1187
#     · Month 8/20 processed | running...RMSE=1.0865
#     · Month 9/20 processed | running...RMSE=1.1583
#     · Month 10/20 processed | running...RMSE=1.2023
#     · Month 11/20 processed | running...RMSE=1.2894
#     · Month 12/20 processed | running...RMSE=1.4068
#     · Month 13/20 processed | running...RMSE=1.8045
#     · Month 14/20 processed | running...RMSE=1.9486
#     · Month 15/20 processed | running...RMSE=2.6239
#     · Month 16/20 processed | running...RMSE=2.6551
#     · Month 17/20 processed | running...RMSE=2.5776
#     · Month 18/20 processed | running...RMSE=2.5807
#     · Month 19/20 processed | running...RMSE=2.6653
#     · Month 20/20 processed | running...RMSE=2.6310
#   - Config 4/8
#     · Month 1/20 processed | running...RMSE=0.3340
#     · Month 2/20 processed | running...RMSE=0.4878
#     · Month 3/20 processed | running...RMSE=0.9389
#     · Month 4/20 processed | running...RMSE=0.8734
#     · Month 5/20 processed | running...RMSE=0.9089
#     · Month 6/20 processed | running...RMSE=0.8467
#     · Month 7/20 processed | running...RMSE=1.1187
#     · Month 8/20 processed | running...RMSE=1.0865
#     · Month 9/20 processed | running...RMSE=1.1583
#     · Month 10/20 processed | running...RMSE=1.2023
#     · Month 11/20 processed | running...RMSE=1.2894
#     · Month 12/20 processed | running...RMSE=1.4068
#     · Month 13/20 processed | running...RMSE=1.8045
#     · Month 14/20 processed | running...RMSE=1.9486
#     · Month 15/20 processed | running...RMSE=2.6239
#     · Month 16/20 processed | running...RMSE=2.6551
#     · Month 17/20 processed | running...RMSE=2.5776
#     · Month 18/20 processed | running...RMSE=2.5807
#     · Month 19/20 processed | running...RMSE=2.6653
#     · Month 20/20 processed | running...RMSE=2.6310
#   - Config 5/8
#     · Month 1/20 processed | running...RMSE=0.3599
#     · Month 2/20 processed | running...RMSE=0.4891
#     · Month 3/20 processed | running...RMSE=0.9488
#     · Month 4/20 processed | running...RMSE=0.8763
#     · Month 5/20 processed | running...RMSE=0.8981
#     · Month 6/20 processed | running...RMSE=0.8351
#     · Month 7/20 processed | running...RMSE=1.1267
#     · Month 8/20 processed | running...RMSE=1.0918
#     · Month 9/20 processed | running...RMSE=1.1604
#     · Month 10/20 processed | running...RMSE=1.2059
#     · Month 11/20 processed | running...RMSE=1.2885
#     · Month 12/20 processed | running...RMSE=1.3974
#     · Month 13/20 processed | running...RMSE=1.7935
#     · Month 14/20 processed | running...RMSE=1.9344
#     · Month 15/20 processed | running...RMSE=2.6043
#     · Month 16/20 processed | running...RMSE=2.6349
#     · Month 17/20 processed | running...RMSE=2.5578
#     · Month 18/20 processed | running...RMSE=2.5667
#     · Month 19/20 processed | running...RMSE=2.6467
#     · Month 20/20 processed | running...RMSE=2.6080
#   - Config 6/8
#     · Month 1/20 processed | running...RMSE=0.3599
#     · Month 2/20 processed | running...RMSE=0.4891
#     · Month 3/20 processed | running...RMSE=0.9488
#     · Month 4/20 processed | running...RMSE=0.8763
#     · Month 5/20 processed | running...RMSE=0.8981
#     · Month 6/20 processed | running...RMSE=0.8351
#     · Month 7/20 processed | running...RMSE=1.1267
#     · Month 8/20 processed | running...RMSE=1.0918
#     · Month 9/20 processed | running...RMSE=1.1604
#     · Month 10/20 processed | running...RMSE=1.2059
#     · Month 11/20 processed | running...RMSE=1.2885
#     · Month 12/20 processed | running...RMSE=1.3974
#     · Month 13/20 processed | running...RMSE=1.7935
#     · Month 14/20 processed | running...RMSE=1.9344
#     · Month 15/20 processed | running...RMSE=2.6043
#     · Month 16/20 processed | running...RMSE=2.6349
#     · Month 17/20 processed | running...RMSE=2.5578
#     · Month 18/20 processed | running...RMSE=2.5667
#     · Month 19/20 processed | running...RMSE=2.6467
#     · Month 20/20 processed | running...RMSE=2.6080
#   - Config 7/8
#     · Month 1/20 processed | running...RMSE=0.3693
#     · Month 2/20 processed | running...RMSE=0.5163
#     · Month 3/20 processed | running...RMSE=0.9826
#     · Month 4/20 processed | running...RMSE=0.8964
#     · Month 5/20 processed | running...RMSE=0.9100
#     · Month 6/20 processed | running...RMSE=0.8446
#     · Month 7/20 processed | running...RMSE=1.1381
#     · Month 8/20 processed | running...RMSE=1.1040
#     · Month 9/20 processed | running...RMSE=1.1699
#     · Month 10/20 processed | running...RMSE=1.2152
#     · Month 11/20 processed | running...RMSE=1.2977
#     · Month 12/20 processed | running...RMSE=1.4041
#     · Month 13/20 processed | running...RMSE=1.7992
#     · Month 14/20 processed | running...RMSE=1.9430
#     · Month 15/20 processed | running...RMSE=2.6158
#     · Month 16/20 processed | running...RMSE=2.6483
#     · Month 17/20 processed | running...RMSE=2.5709
#     · Month 18/20 processed | running...RMSE=2.5753
#     · Month 19/20 processed | running...RMSE=2.6589
#     · Month 20/20 processed | running...RMSE=2.6234
#   - Config 8/8
#     · Month 1/20 processed | running...RMSE=0.3693
#     · Month 2/20 processed | running...RMSE=0.5163
#     · Month 3/20 processed | running...RMSE=0.9826
#     · Month 4/20 processed | running...RMSE=0.8964
#     · Month 5/20 processed | running...RMSE=0.9100
#     · Month 6/20 processed | running...RMSE=0.8446
#     · Month 7/20 processed | running...RMSE=1.1381
#     · Month 8/20 processed | running...RMSE=1.1040
#     · Month 9/20 processed | running...RMSE=1.1699
#     · Month 10/20 processed | running...RMSE=1.2152
#     · Month 11/20 processed | running...RMSE=1.2977
#     · Month 12/20 processed | running...RMSE=1.4041
#     · Month 13/20 processed | running...RMSE=1.7992
#     · Month 14/20 processed | running...RMSE=1.9430
#     · Month 15/20 processed | running...RMSE=2.6158
#     · Month 16/20 processed | running...RMSE=2.6483
#     · Month 17/20 processed | running...RMSE=2.5709
#     · Month 18/20 processed | running...RMSE=2.5753
#     · Month 19/20 processed | running...RMSE=2.6589
#     · Month 20/20 processed | running...RMSE=2.6234
# [Stage A][Block 2] kept 8 configs (floor=8).
# [Stage A][Block 3] train_end=220, OOS=221-240 | configs=8
#   - Config 1/8
#     · Month 1/20 processed | running...RMSE=1.5368
#     · Month 2/20 processed | running...RMSE=1.5592
#     · Month 3/20 processed | running...RMSE=2.2515
#     · Month 4/20 processed | running...RMSE=2.2769
#     · Month 5/20 processed | running...RMSE=2.0466
#     · Month 6/20 processed | running...RMSE=1.8697
#     · Month 7/20 processed | running...RMSE=1.7451
#     · Month 8/20 processed | running...RMSE=1.7480
#     · Month 9/20 processed | running...RMSE=1.8364
#     · Month 10/20 processed | running...RMSE=1.8411
#     · Month 11/20 processed | running...RMSE=1.8882
#     · Month 12/20 processed | running...RMSE=1.8444
#     · Month 13/20 processed | running...RMSE=1.7870
#     · Month 14/20 processed | running...RMSE=1.7397
#     · Month 15/20 processed | running...RMSE=1.6966
#     · Month 16/20 processed | running...RMSE=1.6869
#     · Month 17/20 processed | running...RMSE=1.6438
#     · Month 18/20 processed | running...RMSE=1.6078
#     · Month 19/20 processed | running...RMSE=1.5802
#     · Month 20/20 processed | running...RMSE=1.5596
#   - Config 2/8
#     · Month 1/20 processed | running...RMSE=1.5368
#     · Month 2/20 processed | running...RMSE=1.5592
#     · Month 3/20 processed | running...RMSE=2.2515
#     · Month 4/20 processed | running...RMSE=2.2769
#     · Month 5/20 processed | running...RMSE=2.0466
#     · Month 6/20 processed | running...RMSE=1.8697
#     · Month 7/20 processed | running...RMSE=1.7451
#     · Month 8/20 processed | running...RMSE=1.7480
#     · Month 9/20 processed | running...RMSE=1.8364
#     · Month 10/20 processed | running...RMSE=1.8411
#     · Month 11/20 processed | running...RMSE=1.8882
#     · Month 12/20 processed | running...RMSE=1.8444
#     · Month 13/20 processed | running...RMSE=1.7870
#     · Month 14/20 processed | running...RMSE=1.7397
#     · Month 15/20 processed | running...RMSE=1.6966
#     · Month 16/20 processed | running...RMSE=1.6869
#     · Month 17/20 processed | running...RMSE=1.6438
#     · Month 18/20 processed | running...RMSE=1.6078
#     · Month 19/20 processed | running...RMSE=1.5802
#     · Month 20/20 processed | running...RMSE=1.5596
#   - Config 3/8
#     · Month 1/20 processed | running...RMSE=1.5542
#     · Month 2/20 processed | running...RMSE=1.5120
#     · Month 3/20 processed | running...RMSE=2.2819
#     · Month 4/20 processed | running...RMSE=2.2617
#     · Month 5/20 processed | running...RMSE=2.0452
#     · Month 6/20 processed | running...RMSE=1.8672
#     · Month 7/20 processed | running...RMSE=1.7588
#     · Month 8/20 processed | running...RMSE=1.7170
#     · Month 9/20 processed | running...RMSE=1.8736
#     · Month 10/20 processed | running...RMSE=1.9167
#     · Month 11/20 processed | running...RMSE=1.9924
#     · Month 12/20 processed | running...RMSE=1.9211
#     · Month 13/20 processed | running...RMSE=1.8473
#     · Month 14/20 processed | running...RMSE=1.8189
#     · Month 15/20 processed | running...RMSE=1.7834
#     · Month 16/20 processed | running...RMSE=1.7738
#     · Month 17/20 processed | running...RMSE=1.7289
#     · Month 18/20 processed | running...RMSE=1.6866
#     · Month 19/20 processed | running...RMSE=1.6501
#     · Month 20/20 processed | running...RMSE=1.6195
#   - Config 4/8
#     · Month 1/20 processed | running...RMSE=1.5542
#     · Month 2/20 processed | running...RMSE=1.5120
#     · Month 3/20 processed | running...RMSE=2.2819
#     · Month 4/20 processed | running...RMSE=2.2617
#     · Month 5/20 processed | running...RMSE=2.0452
#     · Month 6/20 processed | running...RMSE=1.8672
#     · Month 7/20 processed | running...RMSE=1.7588
#     · Month 8/20 processed | running...RMSE=1.7170
#     · Month 9/20 processed | running...RMSE=1.8736
#     · Month 10/20 processed | running...RMSE=1.9167
#     · Month 11/20 processed | running...RMSE=1.9924
#     · Month 12/20 processed | running...RMSE=1.9211
#     · Month 13/20 processed | running...RMSE=1.8473
#     · Month 14/20 processed | running...RMSE=1.8189
#     · Month 15/20 processed | running...RMSE=1.7834
#     · Month 16/20 processed | running...RMSE=1.7738
#     · Month 17/20 processed | running...RMSE=1.7289
#     · Month 18/20 processed | running...RMSE=1.6866
#     · Month 19/20 processed | running...RMSE=1.6501
#     · Month 20/20 processed | running...RMSE=1.6195
#   - Config 5/8
#     · Month 1/20 processed | running...RMSE=1.4073
#     · Month 2/20 processed | running...RMSE=1.4842
#     · Month 3/20 processed | running...RMSE=2.2848
#     · Month 4/20 processed | running...RMSE=2.2622
#     · Month 5/20 processed | running...RMSE=2.0473
#     · Month 6/20 processed | running...RMSE=1.8698
#     · Month 7/20 processed | running...RMSE=1.7673
#     · Month 8/20 processed | running...RMSE=1.7241
#     · Month 9/20 processed | running...RMSE=1.8777
#     · Month 10/20 processed | running...RMSE=1.9218
#     · Month 11/20 processed | running...RMSE=2.0012
#     · Month 12/20 processed | running...RMSE=1.9308
#     · Month 13/20 processed | running...RMSE=1.8565
#     · Month 14/20 processed | running...RMSE=1.8320
#     · Month 15/20 processed | running...RMSE=1.7957
#     · Month 16/20 processed | running...RMSE=1.7882
#     · Month 17/20 processed | running...RMSE=1.7414
#     · Month 18/20 processed | running...RMSE=1.7010
#     · Month 19/20 processed | running...RMSE=1.6648
#     · Month 20/20 processed | running...RMSE=1.6350
#   - Config 6/8
#     · Month 1/20 processed | running...RMSE=1.4073
#     · Month 2/20 processed | running...RMSE=1.4842
#     · Month 3/20 processed | running...RMSE=2.2848
#     · Month 4/20 processed | running...RMSE=2.2622
#     · Month 5/20 processed | running...RMSE=2.0473
#     · Month 6/20 processed | running...RMSE=1.8698
#     · Month 7/20 processed | running...RMSE=1.7673
#     · Month 8/20 processed | running...RMSE=1.7241
#     · Month 9/20 processed | running...RMSE=1.8777
#     · Month 10/20 processed | running...RMSE=1.9218
#     · Month 11/20 processed | running...RMSE=2.0012
#     · Month 12/20 processed | running...RMSE=1.9308
#     · Month 13/20 processed | running...RMSE=1.8565
#     · Month 14/20 processed | running...RMSE=1.8320
#     · Month 15/20 processed | running...RMSE=1.7957
#     · Month 16/20 processed | running...RMSE=1.7882
#     · Month 17/20 processed | running...RMSE=1.7414
#     · Month 18/20 processed | running...RMSE=1.7010
#     · Month 19/20 processed | running...RMSE=1.6648
#     · Month 20/20 processed | running...RMSE=1.6350
#   - Config 7/8
#     · Month 1/20 processed | running...RMSE=1.3868
#     · Month 2/20 processed | running...RMSE=1.5018
#     · Month 3/20 processed | running...RMSE=2.3003
#     · Month 4/20 processed | running...RMSE=2.2690
#     · Month 5/20 processed | running...RMSE=2.0525
#     · Month 6/20 processed | running...RMSE=1.8741
#     · Month 7/20 processed | running...RMSE=1.7659
#     · Month 8/20 processed | running...RMSE=1.7258
#     · Month 9/20 processed | running...RMSE=1.8732
#     · Month 10/20 processed | running...RMSE=1.9115
#     · Month 11/20 processed | running...RMSE=1.9884
#     · Month 12/20 processed | running...RMSE=1.9185
#     · Month 13/20 processed | running...RMSE=1.8442
#     · Month 14/20 processed | running...RMSE=1.8203
#     · Month 15/20 processed | running...RMSE=1.7839
#     · Month 16/20 processed | running...RMSE=1.7802
#     · Month 17/20 processed | running...RMSE=1.7332
#     · Month 18/20 processed | running...RMSE=1.6921
#     · Month 19/20 processed | running...RMSE=1.6567
#     · Month 20/20 processed | running...RMSE=1.6275
#   - Config 8/8
#     · Month 1/20 processed | running...RMSE=1.3868
#     · Month 2/20 processed | running...RMSE=1.5018
#     · Month 3/20 processed | running...RMSE=2.3003
#     · Month 4/20 processed | running...RMSE=2.2690
#     · Month 5/20 processed | running...RMSE=2.0525
#     · Month 6/20 processed | running...RMSE=1.8741
#     · Month 7/20 processed | running...RMSE=1.7659
#     · Month 8/20 processed | running...RMSE=1.7258
#     · Month 9/20 processed | running...RMSE=1.8732
#     · Month 10/20 processed | running...RMSE=1.9115
#     · Month 11/20 processed | running...RMSE=1.9884
#     · Month 12/20 processed | running...RMSE=1.9185
#     · Month 13/20 processed | running...RMSE=1.8442
#     · Month 14/20 processed | running...RMSE=1.8203
#     · Month 15/20 processed | running...RMSE=1.7839
#     · Month 16/20 processed | running...RMSE=1.7802
#     · Month 17/20 processed | running...RMSE=1.7332
#     · Month 18/20 processed | running...RMSE=1.6921
#     · Month 19/20 processed | running...RMSE=1.6567
#     · Month 20/20 processed | running...RMSE=1.6275
# [Stage A][Block 3] kept 8 configs (floor=8).
# [Stage A] Shortlist saved with 5 configs.
# [Stage B] Month origin t=240 | evaluating 5 configs | active=1
# [Stage B] Month origin t=241 | evaluating 5 configs | active=5
# [Stage B] Month origin t=242 | evaluating 5 configs | active=5
# [Stage B] Month origin t=243 | evaluating 5 configs | active=5
# [Stage B] Month origin t=244 | evaluating 5 configs | active=1
# [Stage B] Month origin t=245 | evaluating 5 configs | active=1
# [Stage B] Month origin t=246 | evaluating 5 configs | active=1
# [Stage B] Month origin t=247 | evaluating 5 configs | active=1
# [Stage B] Month origin t=248 | evaluating 5 configs | active=1
# [Stage B] Month origin t=249 | evaluating 5 configs | active=1
# [Stage B] Month origin t=250 | evaluating 5 configs | active=1
# [Stage B] Month origin t=251 | evaluating 5 configs | active=1
# [Stage B] Month origin t=252 | evaluating 5 configs | active=1
# [Stage B] Month origin t=253 | evaluating 5 configs | active=1
# [Stage B] Month origin t=254 | evaluating 5 configs | active=1
# [Stage B] Month origin t=255 | evaluating 5 configs | active=1
# [Stage B] Month origin t=256 | evaluating 5 configs | active=1
# [Stage B] Month origin t=257 | evaluating 5 configs | active=1
# [Stage B] Month origin t=258 | evaluating 5 configs | active=1
# [Stage B] Month origin t=259 | evaluating 5 configs | active=1
# [Stage B] Month origin t=260 | evaluating 5 configs | active=1
# [Stage B] Month origin t=261 | evaluating 5 configs | active=1
# [Stage B] Month origin t=262 | evaluating 5 configs | active=1
# [Stage B] Month origin t=263 | evaluating 5 configs | active=1
# [Stage B] Month origin t=264 | evaluating 5 configs | active=1
# [Stage B] Month origin t=265 | evaluating 5 configs | active=1
# [Stage B] Month origin t=266 | evaluating 5 configs | active=1
# [Stage B] Month origin t=267 | evaluating 5 configs | active=1
# [Stage B] Month origin t=268 | evaluating 5 configs | active=1
# [Stage B] Month origin t=269 | evaluating 5 configs | active=1
# [Stage B] Month origin t=270 | evaluating 5 configs | active=1
# [Stage B] Month origin t=271 | evaluating 5 configs | active=1
# [Stage B] Month origin t=272 | evaluating 5 configs | active=1
# [Stage B] Month origin t=273 | evaluating 5 configs | active=1
# [Stage B] Month origin t=274 | evaluating 5 configs | active=1
# [Stage B] Month origin t=275 | evaluating 5 configs | active=1
# [Stage B] Month origin t=276 | evaluating 5 configs | active=1
# [Stage B] Month origin t=277 | evaluating 5 configs | active=1
# [Stage B] Month origin t=278 | evaluating 5 configs | active=1
# [Stage B] Month origin t=279 | evaluating 5 configs | active=1
# [Stage B] Month origin t=280 | evaluating 5 configs | active=1
# [Stage B] Month origin t=281 | evaluating 5 configs | active=1
# [Stage B] Month origin t=282 | evaluating 5 configs | active=1
# [Stage B] Month origin t=283 | evaluating 5 configs | active=1
# [Stage B] Month origin t=284 | evaluating 5 configs | active=1
# [Stage B] Month origin t=285 | evaluating 5 configs | active=1
# [Stage B] Month origin t=286 | evaluating 5 configs | active=1
# [Stage B] Month origin t=287 | evaluating 5 configs | active=1
# [Stage B] Month origin t=288 | evaluating 5 configs | active=1
# [Stage B] Month origin t=289 | evaluating 5 configs | active=1
# [Stage B] Month origin t=290 | evaluating 5 configs | active=1
# [Stage B] Month origin t=291 | evaluating 5 configs | active=1
# [Stage B] Month origin t=292 | evaluating 5 configs | active=1
# [Stage B] Month origin t=293 | evaluating 5 configs | active=1
# [Stage B] Month origin t=294 | evaluating 5 configs | active=1
# [Stage B] Month origin t=295 | evaluating 5 configs | active=1
# [Stage B] Month origin t=296 | evaluating 5 configs | active=1
# [Stage B] Month origin t=297 | evaluating 5 configs | active=1
# [Stage B] Month origin t=298 | evaluating 5 configs | active=1
# [Stage B] Month origin t=299 | evaluating 5 configs | active=1
# [Stage B] Month origin t=300 | evaluating 5 configs | active=1
# [Stage B] Month origin t=301 | evaluating 5 configs | active=1
# [Stage B] Month origin t=302 | evaluating 5 configs | active=1
# [Stage B] Month origin t=303 | evaluating 5 configs | active=1
# [Stage B] Month origin t=304 | evaluating 5 configs | active=1
# [Stage B] Month origin t=305 | evaluating 5 configs | active=1
# [Stage B] Month origin t=306 | evaluating 5 configs | active=1
# [Stage B] Month origin t=307 | evaluating 5 configs | active=1
# [Stage B] Month origin t=308 | evaluating 5 configs | active=1
# [Stage B] Month origin t=309 | evaluating 5 configs | active=1
# [Stage B] Month origin t=310 | evaluating 5 configs | active=1
# [Stage B] Month origin t=311 | evaluating 5 configs | active=1
# [Stage B] Month origin t=312 | evaluating 5 configs | active=1
# [Stage B] Month origin t=313 | evaluating 5 configs | active=1
# [Stage B] Month origin t=314 | evaluating 5 configs | active=1
# [Stage B] Month origin t=315 | evaluating 5 configs | active=1
# [Stage B] Month origin t=316 | evaluating 5 configs | active=1
# [Stage B] Month origin t=317 | evaluating 5 configs | active=1
# [Stage B] Month origin t=318 | evaluating 5 configs | active=1
# [Stage B] Month origin t=319 | evaluating 5 configs | active=1
# [Stage B] Month origin t=320 | evaluating 5 configs | active=1
# [Stage B] Month origin t=321 | evaluating 5 configs | active=1
# [Stage B] Month origin t=322 | evaluating 5 configs | active=1
# [Stage B] Month origin t=323 | evaluating 5 configs | active=1
# [Stage B] Month origin t=324 | evaluating 5 configs | active=1
# [Stage B] Month origin t=325 | evaluating 5 configs | active=1
# [Stage B] Month origin t=326 | evaluating 5 configs | active=1
# [Stage B] Month origin t=327 | evaluating 5 configs | active=1
# [Stage B] Month origin t=328 | evaluating 5 configs | active=1
# [Stage B] Month origin t=329 | evaluating 5 configs | active=1
# [Stage B] Month origin t=330 | evaluating 5 configs | active=1
# [Stage B] Month origin t=331 | evaluating 5 configs | active=1
# [Stage B] Month origin t=332 | evaluating 5 configs | active=1
# [Stage B] Month origin t=333 | evaluating 5 configs | active=1
# [Stage B] Month origin t=334 | evaluating 5 configs | active=1
# [Stage B] Month origin t=335 | evaluating 5 configs | active=1
# [Stage B] Month origin t=336 | evaluating 5 configs | active=1
# [Stage B] Month origin t=337 | evaluating 5 configs | active=1
# [Stage B] Month origin t=338 | evaluating 5 configs | active=1
# [Stage B] Month origin t=339 | evaluating 5 configs | active=1
# [Stage B] Month origin t=340 | evaluating 5 configs | active=1
# [Stage B] Month origin t=341 | evaluating 5 configs | active=1
# [Stage B] Month origin t=342 | evaluating 5 configs | active=1
# [Stage B] Month origin t=343 | evaluating 5 configs | active=1
# [Stage B] Month origin t=344 | evaluating 5 configs | active=1
# [Stage B] Month origin t=345 | evaluating 5 configs | active=1
# [Stage B] Month origin t=346 | evaluating 5 configs | active=1
# [Stage B] Month origin t=347 | evaluating 5 configs | active=1
# [Stage B] Month origin t=348 | evaluating 5 configs | active=1
# [Stage B] Month origin t=349 | evaluating 5 configs | active=1
# [Stage B] Month origin t=350 | evaluating 5 configs | active=1
# [Stage B] Month origin t=351 | evaluating 5 configs | active=1
# [Stage B] Month origin t=352 | evaluating 5 configs | active=1
# [Stage B] Month origin t=353 | evaluating 5 configs | active=1
# [Stage B] Month origin t=354 | evaluating 5 configs | active=1
# [Stage B] Month origin t=355 | evaluating 5 configs | active=1
# [Stage B] Month origin t=356 | evaluating 5 configs | active=1
# [Stage B] Month origin t=357 | evaluating 5 configs | active=1
# [Stage B] Month origin t=358 | evaluating 5 configs | active=1
# [Stage B] Month origin t=359 | evaluating 5 configs | active=1
# [Stage B] Month origin t=360 | evaluating 5 configs | active=1
# [Stage B] Month origin t=361 | evaluating 5 configs | active=1
# [Stage B] Month origin t=362 | evaluating 5 configs | active=1
# [Stage B] Month origin t=363 | evaluating 5 configs | active=1
# [Stage B] Month origin t=364 | evaluating 5 configs | active=1
# [Stage B] Month origin t=365 | evaluating 5 configs | active=1
# [Stage B] Month origin t=366 | evaluating 5 configs | active=1
# [Stage B] Month origin t=367 | evaluating 5 configs | active=1
# [Stage B] Month origin t=368 | evaluating 5 configs | active=1
# [Stage B] Month origin t=369 | evaluating 5 configs | active=1
# [Stage B] Month origin t=370 | evaluating 5 configs | active=1
# [Stage B] Month origin t=371 | evaluating 5 configs | active=1
# [Stage B] Month origin t=372 | evaluating 5 configs | active=1
# [Stage B] Month origin t=373 | evaluating 5 configs | active=1
# [Stage B] Month origin t=374 | evaluating 5 configs | active=1
# [Stage B] Month origin t=375 | evaluating 5 configs | active=1
# [Stage B] Month origin t=376 | evaluating 5 configs | active=1
# [Stage B] Month origin t=377 | evaluating 5 configs | active=1
# [Stage B] Month origin t=378 | evaluating 5 configs | active=1
# [Stage B] Month origin t=379 | evaluating 5 configs | active=3
# [Stage B] Month origin t=380 | evaluating 5 configs | active=3
# [Stage B] Month origin t=381 | evaluating 5 configs | active=3
# [Stage B] Month origin t=382 | evaluating 5 configs | active=3
# [Stage B] Month origin t=383 | evaluating 5 configs | active=3
# [Stage B] Month origin t=384 | evaluating 5 configs | active=3
# [Stage B] Month origin t=385 | evaluating 5 configs | active=3
# [Stage B] Month origin t=386 | evaluating 5 configs | active=3
# [Stage B] Month origin t=387 | evaluating 5 configs | active=3
# [Stage B] Month origin t=388 | evaluating 5 configs | active=3
# [Stage B] Month origin t=389 | evaluating 5 configs | active=3
# [Stage B] Month origin t=390 | evaluating 5 configs | active=3
# [Stage B] Month origin t=391 | evaluating 5 configs | active=3
# [Stage B] Month origin t=392 | evaluating 5 configs | active=3
# [Stage B] Month origin t=393 | evaluating 5 configs | active=3
# [Stage B] Month origin t=394 | evaluating 5 configs | active=3
# [Stage B] Month origin t=395 | evaluating 5 configs | active=3
# [Stage B] Month origin t=396 | evaluating 5 configs | active=3
# [Stage B] Month origin t=397 | evaluating 5 configs | active=3
# [Stage B] Month origin t=398 | evaluating 5 configs | active=3
# [Stage B] Month origin t=399 | evaluating 5 configs | active=3
# [Stage B] Month origin t=400 | evaluating 5 configs | active=3
# [Stage B] Month origin t=401 | evaluating 5 configs | active=3
# [Stage B] Month origin t=402 | evaluating 5 configs | active=3
# [Stage B] Month origin t=403 | evaluating 5 configs | active=3
# [Stage B] Month origin t=404 | evaluating 5 configs | active=3
# [Stage B] Month origin t=405 | evaluating 5 configs | active=3
# [Stage B] done → /Users/jonasschernich/Documents/Masterarbeit/Code/outputs/stageB/extra_trees/monthly
# [Stage B] summary.csv & summary_active.txt geschrieben.
#
# Done. Check outputs/stageA|stageB/extra_trees for results.
