# %%
# ==============================================================================
# Extra Trees – Thesis Tuning Pipeline
# ==============================================================================
# Spezifikation gemäß Masterarbeit:
# - Setup I (ifo only) vs. Setup II (ifo + Target Blocks) im Grid integriert.
# - FE: Lags 0-6 fix, SIS {300, 5k, 50k}, Redundanz {0.9, 1.0}, DR {None, PCA, PLS}.
# - Model: n_est {500,1k,2k}, depth {None,4,8}, leaf {1,5,10}, feat {sqrt,0.1,0.25}.
# - Stage A Shortlist: Top 10 frozen.
# - Dynamic FI (Setup III): Strikt Top 50 Features.
# ==============================================================================

import os, sys
from pathlib import Path
import numpy as np
import pandas as pd
from itertools import product

# --- 1) Pfad-Setup ---
def _locate_repo_root(start: Path) -> Path:
    cur = start.resolve()
    for _ in range(6):
        if (cur / "src").exists():
            return cur
        if cur.parent == cur:
            break
        cur = cur.parent
    return start.resolve()

NOTEBOOK_DIR = Path.cwd()
PROJECT_ROOT = _locate_repo_root(NOTEBOOK_DIR)
os.environ["PROJECT_ROOT"] = str(PROJECT_ROOT)
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

# --- 2) Imports ---
from src.config import (
    GlobalConfig,
    DEFAULT_CORR_SPEC,
    EWMA_CORR_SPEC,
    outputs_for_model,
)
from src.tuning import run_stageA, run_stageB
from src.io_timesplits import (
    load_target,
    load_ifo_features,
    load_full_lagged_features,
    load_rolling_importance,
)
# WICHTIG: Modell-Import für Extra Trees
from src.models.ET import ForecastModel

# --- 3) Konfiguration ---
USE_DYNAMIC_FI_PIPELINE = False  # False = Standard Setup (I & II)
SEED = 42

if USE_DYNAMIC_FI_PIPELINE:
    MODEL_NAME = "extra_trees_dynamic_fi"
else:
    MODEL_NAME = "extra_trees"

outputs_for_model(MODEL_NAME)
print(f"--- Starte Tuning für: {MODEL_NAME} ---")

# --- 4) Daten laden ---
y = load_target()
X_ifo = load_ifo_features()

# Align Indizes
idx_common = y.index.intersection(X_ifo.index)
y = y.loc[idx_common]
X_ifo = X_ifo.loc[idx_common]

X_full_lagged = None
rolling_imp = None
y_fi = None

if USE_DYNAMIC_FI_PIPELINE:
    FI_BASE_DIR = PROJECT_ROOT / "outputs" / "feature_importance" / "outputs_no_missing"
    try:
        X_full_lagged = load_full_lagged_features(base_dir=FI_BASE_DIR)
        rolling_imp   = load_rolling_importance(base_dir=FI_BASE_DIR)

        idx_fi = y.index.intersection(X_full_lagged.index).intersection(rolling_imp.index)
        y_fi          = y.loc[idx_fi]
        X_full_lagged = X_full_lagged.loc[idx_fi]
        rolling_imp   = rolling_imp.loc[idx_fi]
        print(f"Dynamic FI Modus: {X_full_lagged.shape[1]} Features geladen.")
    except FileNotFoundError:
        print("FEHLER: Dynamic FI Artefakte nicht gefunden.")
        sys.exit(1)
else:
    print(f"Full FE Modus (Setup I/II): {X_ifo.shape[1]} Basis-Features.")

# --- 5) Config Defaults (Thesis Policy) ---
def get_thesis_cfg() -> GlobalConfig:
    cfg = GlobalConfig(preset="thesis")
    cfg.policy_window = 24
    cfg.policy_decay = 0.97
    cfg.selection_mode = "decayed_best"
    return cfg

cfg_obj = get_thesis_cfg()

# --- 6) Grid Definition ---------------------------------------

def build_grid_full_fe():
    """Setup I (ifo) und Setup II (ifo + TargetBlocks)."""

    # A) FE & DR
    lag_candidates = [tuple(range(7))]

    corr_opts = [
        {"corr_spec": dict(DEFAULT_CORR_SPEC)},
        {"corr_spec": dict(EWMA_CORR_SPEC)},
    ]

    k1_opts = [300, 5000, 50000]
    red_opts = [0.9, 1.0]

    dr_opts = [
        {"dr_method": "none"},
        {"dr_method": "pca", "pca_kmax": 15, "pca_var_target": 0.99},
        {"dr_method": "pca", "pca_kmax": 30, "pca_var_target": 0.99},
        {"dr_method": "pls", "pls_components": 15},
        {"dr_method": "pls", "pls_components": 30},
    ]

    # B) Setup II (Target Blocks)
    block_opts = [
        None,                                 # Setup I
        ["AR1", "Chronos"],                   # Setup II a
        ["AR1", "Chronos", "TSFresh"]         # Setup II b
    ]

    # C) Weights
    weight_opts = [
        {"sample_weight_decay": None},
        {"sample_weight_decay": 0.99}
    ]

    # D) Extra Trees Hyperparameter (Thesis Summary)
    n_estimators_list = [500, 1000, 2000]
    max_depth_list = [None, 4, 8]
    min_samples_leaf_list = [1, 5, 10]
    max_features_list = ['sqrt', 0.1, 0.25]

    grid = []

    # FE Loop
    for lags, corr, k1, red, dr in product(lag_candidates, corr_opts, k1_opts, red_opts, dr_opts):
        base_fe = {
            "lag_candidates": lags,
            "k1_topk": k1,
            "redundancy_param": red,
            **dr,
            **corr
        }
        # Blocks & Weights
        for blocks, weights in product(block_opts, weight_opts):
            # Model HPs
            for n_est, depth, leaf, feat in product(n_estimators_list, max_depth_list, min_samples_leaf_list, max_features_list):
                hp = {
                    **base_fe,
                    "target_block_set": blocks,
                    **weights,
                    "n_estimators": n_est,
                    "max_depth": depth,
                    "min_samples_leaf": leaf,
                    "max_features": feat,
                    "seed": SEED
                }
                grid.append(hp)
    return grid

def build_grid_dynamic_fi():
    """Setup III: Dynamic Feature Importance via strict Top-N."""

    n_features_list = [50]

    weight_opts = [{"sample_weight_decay": None}, {"sample_weight_decay": 0.99}]

    # ET Params
    n_estimators_list = [500, 1000, 2000]
    max_depth_list = [None, 4, 8]
    min_samples_leaf_list = [1, 5, 10]
    max_features_list = ['sqrt', 0.1, 0.25]

    grid = []
    for n_feat, w, n_est, depth, leaf, feat in product(n_features_list, weight_opts, n_estimators_list, max_depth_list, min_samples_leaf_list, max_features_list):
        hp = {
            "n_features_to_use": n_feat,
            **w,
            "n_estimators": n_est,
            "max_depth": depth,
            "min_samples_leaf": leaf,
            "max_features": feat,
            "seed": SEED
        }
        grid.append(hp)
    return grid

# --- 7) Ausführung --------------------------------------------

if USE_DYNAMIC_FI_PIPELINE:
    grid = build_grid_dynamic_fi()
    print(f"Dynamic FI Grid Größe (Setup III): {len(grid)} Konfigurationen.")

    shortlist = run_stageA(
        model_name=MODEL_NAME,
        model_ctor=lambda hp: ForecastModel(hp),
        model_grid=grid,
        X=X_ifo, # Dummy
        y=y_fi,
        cfg=cfg_obj,
        X_full_lagged=X_full_lagged,
        rolling_imp=rolling_imp,
        keep_top_k_final=10,
        min_survivors_per_block=0
    )

    run_stageB(
        model_name=MODEL_NAME,
        model_ctor=lambda hp: ForecastModel(hp),
        shortlist=shortlist,
        X=X_ifo, # Dummy
        y=y_fi,
        cfg=cfg_obj,
        X_full_lagged=X_full_lagged,
        rolling_imp=rolling_imp
    )

else:
    grid = build_grid_full_fe()
    print(f"Full FE Grid Größe (Setup I & II): {len(grid)} Konfigurationen.")
    # Grid ist sehr groß (~30k). ASHA wird hier aggressiv filtern.

    shortlist = run_stageA(
        model_name=MODEL_NAME,
        model_ctor=lambda hp: ForecastModel(hp),
        model_grid=grid,
        X=X_ifo,
        y=y,
        cfg=cfg_obj,
        keep_top_k_final=10,
        min_survivors_per_block=0
    )

    run_stageB(
        model_name=MODEL_NAME,
        model_ctor=lambda hp: ForecastModel(hp),
        shortlist=shortlist,
        X=X_ifo,
        y=y,
        cfg=cfg_obj
    )

print("\nTuning abgeschlossen.")
# Out:
# PROJECT_ROOT = /Users/jonasschernich/Documents/Masterarbeit/Code
# Modell extra_trees wird getunt.
# INFO in load_ifo_features: Renaming columns to ensure validity.
# Gleis 1/2-Daten geladen. Shapes: (407, 2160) (407,)
# Erstelle HP-Grid für 'Full FE' (Gleis 1/2)...
# Optimierte HP-Kombinationen: 96
# Erstes HP-Set: {'lag_candidates': (1, 2, 3, 6, 7, 8, 9, 10, 11), 'top_k_lags_per_feature': 1, 'use_rm3': True, 'k1_topk': 100, 'redundancy_param': 0.9, 'dr_method': 'none', 'n_estimators': 100, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'sample_weight_decay': None, 'corr_tag': 'expanding', 'corr_spec': {'mode': 'expanding', 'window': None, 'lam': None}, 'target_block_set': None}
# [Stage A] Using FULL FE (Gleis 1 & 2) pipeline.
# [Stage A][Block 1] train_end=180, OOS=181-200 | configs=96
#   - Config 1/96
#     · Month 5/20 processed | running...RMSE=1.5270
#     · Month 10/20 processed | running...RMSE=1.2462
#     · Month 15/20 processed | running...RMSE=1.2158
#     · Month 20/20 processed | running...RMSE=1.1218
#   - Config 2/96
#     · Month 5/20 processed | running...RMSE=1.5270
#     · Month 10/20 processed | running...RMSE=1.2462
#     · Month 15/20 processed | running...RMSE=1.2158
#     · Month 20/20 processed | running...RMSE=1.1218
#   - Config 3/96
#     · Month 5/20 processed | running...RMSE=1.5060
#     · Month 10/20 processed | running...RMSE=1.2367
#     · Month 15/20 processed | running...RMSE=1.2079
#     · Month 20/20 processed | running...RMSE=1.1509
#   - Config 4/96
#     · Month 5/20 processed | running...RMSE=1.6151
#     · Month 10/20 processed | running...RMSE=1.2836
#     · Month 15/20 processed | running...RMSE=1.2064
#     · Month 20/20 processed | running...RMSE=1.0750
#   - Config 5/96
#     · Month 5/20 processed | running...RMSE=1.5634
#     · Month 10/20 processed | running...RMSE=1.2745
#     · Month 15/20 processed | running...RMSE=1.2236
#     · Month 20/20 processed | running...RMSE=1.1269
#   - Config 6/96
#     · Month 5/20 processed | running...RMSE=1.5634
#     · Month 10/20 processed | running...RMSE=1.2745
#     · Month 15/20 processed | running...RMSE=1.2236
#     · Month 20/20 processed | running...RMSE=1.1269
#   - Config 7/96
#     · Month 5/20 processed | running...RMSE=1.5701
#     · Month 10/20 processed | running...RMSE=1.2843
#     · Month 15/20 processed | running...RMSE=1.2367
#     · Month 20/20 processed | running...RMSE=1.1409
#   - Config 8/96
#     · Month 5/20 processed | running...RMSE=1.6207
#     · Month 10/20 processed | running...RMSE=1.2895
#     · Month 15/20 processed | running...RMSE=1.2121
#     · Month 20/20 processed | running...RMSE=1.0798
#   - Config 9/96
#     · Month 5/20 processed | running...RMSE=1.5315
#     · Month 10/20 processed | running...RMSE=1.2634
#     · Month 15/20 processed | running...RMSE=1.2300
#     · Month 20/20 processed | running...RMSE=1.1582
#   - Config 10/96
#     · Month 5/20 processed | running...RMSE=1.5315
#     · Month 10/20 processed | running...RMSE=1.2634
#     · Month 15/20 processed | running...RMSE=1.2300
#     · Month 20/20 processed | running...RMSE=1.1582
#   - Config 11/96
#     · Month 5/20 processed | running...RMSE=1.5460
#     · Month 10/20 processed | running...RMSE=1.3047
#     · Month 15/20 processed | running...RMSE=1.2692
#     · Month 20/20 processed | running...RMSE=1.2091
#   - Config 12/96
#     · Month 5/20 processed | running...RMSE=1.6239
#     · Month 10/20 processed | running...RMSE=1.2950
#     · Month 15/20 processed | running...RMSE=1.2172
#     · Month 20/20 processed | running...RMSE=1.0847
#   - Config 13/96
#     · Month 5/20 processed | running...RMSE=1.5353
#     · Month 10/20 processed | running...RMSE=1.2755
#     · Month 15/20 processed | running...RMSE=1.2387
#     · Month 20/20 processed | running...RMSE=1.1554
#   - Config 14/96
#     · Month 5/20 processed | running...RMSE=1.5353
#     · Month 10/20 processed | running...RMSE=1.2755
#     · Month 15/20 processed | running...RMSE=1.2387
#     · Month 20/20 processed | running...RMSE=1.1554
#   - Config 15/96
#     · Month 5/20 processed | running...RMSE=1.5478
#     · Month 10/20 processed | running...RMSE=1.2815
#     · Month 15/20 processed | running...RMSE=1.2422
#     · Month 20/20 processed | running...RMSE=1.1604
#   - Config 16/96
#     · Month 5/20 processed | running...RMSE=1.6308
#     · Month 10/20 processed | running...RMSE=1.3002
#     · Month 15/20 processed | running...RMSE=1.2222
#     · Month 20/20 processed | running...RMSE=1.0896
#   - Config 17/96
#     · Month 5/20 processed | running...RMSE=1.5254
#     · Month 10/20 processed | running...RMSE=1.2478
#     · Month 15/20 processed | running...RMSE=1.2178
#     · Month 20/20 processed | running...RMSE=1.1397
#   - Config 18/96
#     · Month 5/20 processed | running...RMSE=1.5254
#     · Month 10/20 processed | running...RMSE=1.2478
#     · Month 15/20 processed | running...RMSE=1.2178
#     · Month 20/20 processed | running...RMSE=1.1397
#   - Config 19/96
#     · Month 5/20 processed | running...RMSE=1.5346
#     · Month 10/20 processed | running...RMSE=1.2577
#     · Month 15/20 processed | running...RMSE=1.2215
#     · Month 20/20 processed | running...RMSE=1.1468
#   - Config 20/96
#     · Month 5/20 processed | running...RMSE=1.6101
#     · Month 10/20 processed | running...RMSE=1.2799
#     · Month 15/20 processed | running...RMSE=1.2041
#     · Month 20/20 processed | running...RMSE=1.0738
#   - Config 21/96
#     · Month 5/20 processed | running...RMSE=1.5553
#     · Month 10/20 processed | running...RMSE=1.2756
#     · Month 15/20 processed | running...RMSE=1.2271
#     · Month 20/20 processed | running...RMSE=1.1335
#   - Config 22/96
#     · Month 5/20 processed | running...RMSE=1.5553
#     · Month 10/20 processed | running...RMSE=1.2756
#     · Month 15/20 processed | running...RMSE=1.2271
#     · Month 20/20 processed | running...RMSE=1.1335
#   - Config 23/96
#     · Month 5/20 processed | running...RMSE=1.5676
#     · Month 10/20 processed | running...RMSE=1.2795
#     · Month 15/20 processed | running...RMSE=1.2319
#     · Month 20/20 processed | running...RMSE=1.1419
#   - Config 24/96
#     · Month 5/20 processed | running...RMSE=1.6141
#     · Month 10/20 processed | running...RMSE=1.2850
#     · Month 15/20 processed | running...RMSE=1.2095
#     · Month 20/20 processed | running...RMSE=1.0782
#   - Config 25/96
#     · Month 5/20 processed | running...RMSE=1.5285
#     · Month 10/20 processed | running...RMSE=1.2616
#     · Month 15/20 processed | running...RMSE=1.2266
#     · Month 20/20 processed | running...RMSE=1.1550
#   - Config 26/96
#     · Month 5/20 processed | running...RMSE=1.5285
#     · Month 10/20 processed | running...RMSE=1.2616
#     · Month 15/20 processed | running...RMSE=1.2266
#     · Month 20/20 processed | running...RMSE=1.1550
#   - Config 27/96
#     · Month 5/20 processed | running...RMSE=1.5392
#     · Month 10/20 processed | running...RMSE=1.2930
#     · Month 15/20 processed | running...RMSE=1.2666
#     · Month 20/20 processed | running...RMSE=1.2106
#   - Config 28/96
#     · Month 5/20 processed | running...RMSE=1.6239
#     · Month 10/20 processed | running...RMSE=1.2944
#     · Month 15/20 processed | running...RMSE=1.2174
#     · Month 20/20 processed | running...RMSE=1.0854
#   - Config 29/96
#     · Month 5/20 processed | running...RMSE=1.5325
#     · Month 10/20 processed | running...RMSE=1.2706
#     · Month 15/20 processed | running...RMSE=1.2304
#     · Month 20/20 processed | running...RMSE=1.1482
#   - Config 30/96
#     · Month 5/20 processed | running...RMSE=1.5325
#     · Month 10/20 processed | running...RMSE=1.2706
#     · Month 15/20 processed | running...RMSE=1.2304
#     · Month 20/20 processed | running...RMSE=1.1482
#   - Config 31/96
#     · Month 5/20 processed | running...RMSE=1.5554
#     · Month 10/20 processed | running...RMSE=1.2846
#     · Month 15/20 processed | running...RMSE=1.2439
#     · Month 20/20 processed | running...RMSE=1.1615
#   - Config 32/96
#     · Month 5/20 processed | running...RMSE=1.6283
#     · Month 10/20 processed | running...RMSE=1.2984
#     · Month 15/20 processed | running...RMSE=1.2211
#     · Month 20/20 processed | running...RMSE=1.0888
#   - Config 33/96
#     · Month 5/20 processed | running...RMSE=1.5258
#     · Month 10/20 processed | running...RMSE=1.2475
#     · Month 15/20 processed | running...RMSE=1.2150
#     · Month 20/20 processed | running...RMSE=1.1362
#   - Config 34/96
#     · Month 5/20 processed | running...RMSE=1.5258
#     · Month 10/20 processed | running...RMSE=1.2475
#     · Month 15/20 processed | running...RMSE=1.2150
#     · Month 20/20 processed | running...RMSE=1.1362
#   - Config 35/96
#     · Month 5/20 processed | running...RMSE=1.5410
#     · Month 10/20 processed | running...RMSE=1.2603
#     · Month 15/20 processed | running...RMSE=1.2282
#     · Month 20/20 processed | running...RMSE=1.1552
#   - Config 36/96
#     · Month 5/20 processed | running...RMSE=1.6070
#     · Month 10/20 processed | running...RMSE=1.2778
#     · Month 15/20 processed | running...RMSE=1.2027
#     · Month 20/20 processed | running...RMSE=1.0728
#   - Config 37/96
#     · Month 5/20 processed | running...RMSE=1.5551
#     · Month 10/20 processed | running...RMSE=1.2701
#     · Month 15/20 processed | running...RMSE=1.2227
#     · Month 20/20 processed | running...RMSE=1.1304
#   - Config 38/96
#     · Month 5/20 processed | running...RMSE=1.5551
#     · Month 10/20 processed | running...RMSE=1.2701
#     · Month 15/20 processed | running...RMSE=1.2227
#     · Month 20/20 processed | running...RMSE=1.1304
#   - Config 39/96
#     · Month 5/20 processed | running...RMSE=1.5678
#     · Month 10/20 processed | running...RMSE=1.2795
#     · Month 15/20 processed | running...RMSE=1.2311
#     · Month 20/20 processed | running...RMSE=1.1401
#   - Config 40/96
#     · Month 5/20 processed | running...RMSE=1.6145
#     · Month 10/20 processed | running...RMSE=1.2852
#     · Month 15/20 processed | running...RMSE=1.2095
#     · Month 20/20 processed | running...RMSE=1.0782
#   - Config 41/96
#     · Month 5/20 processed | running...RMSE=1.5144
#     · Month 10/20 processed | running...RMSE=1.2506
#     · Month 15/20 processed | running...RMSE=1.2229
#     · Month 20/20 processed | running...RMSE=1.1538
#   - Config 42/96
#     · Month 5/20 processed | running...RMSE=1.5144
#     · Month 10/20 processed | running...RMSE=1.2506
#     · Month 15/20 processed | running...RMSE=1.2229
#     · Month 20/20 processed | running...RMSE=1.1538
#   - Config 43/96
#     · Month 5/20 processed | running...RMSE=1.5306
#     · Month 10/20 processed | running...RMSE=1.2788
#     · Month 15/20 processed | running...RMSE=1.2567
#     · Month 20/20 processed | running...RMSE=1.1977
#   - Config 44/96
#     · Month 5/20 processed | running...RMSE=1.6245
#     · Month 10/20 processed | running...RMSE=1.2945
#     · Month 15/20 processed | running...RMSE=1.2175
#     · Month 20/20 processed | running...RMSE=1.0852
#   - Config 45/96
#     · Month 5/20 processed | running...RMSE=1.5279
#     · Month 10/20 processed | running...RMSE=1.2608
#     · Month 15/20 processed | running...RMSE=1.2190
#     · Month 20/20 processed | running...RMSE=1.1380
#   - Config 46/96
#     · Month 5/20 processed | running...RMSE=1.5279
#     · Month 10/20 processed | running...RMSE=1.2608
#     · Month 15/20 processed | running...RMSE=1.2190
#     · Month 20/20 processed | running...RMSE=1.1380
#   - Config 47/96
#     · Month 5/20 processed | running...RMSE=1.5520
#     · Month 10/20 processed | running...RMSE=1.2803
#     · Month 15/20 processed | running...RMSE=1.2406
#     · Month 20/20 processed | running...RMSE=1.1590
#   - Config 48/96
#     · Month 5/20 processed | running...RMSE=1.6290
#     · Month 10/20 processed | running...RMSE=1.2986
#     · Month 15/20 processed | running...RMSE=1.2210
#     · Month 20/20 processed | running...RMSE=1.0886
#   - Config 49/96
#     · Month 5/20 processed | running...RMSE=1.5443
#     · Month 10/20 processed | running...RMSE=1.2414
#     · Month 15/20 processed | running...RMSE=1.1818
#     · Month 20/20 processed | running...RMSE=1.0681
#   - Config 50/96
#     · Month 5/20 processed | running...RMSE=1.5443
#     · Month 10/20 processed | running...RMSE=1.2414
#     · Month 15/20 processed | running...RMSE=1.1818
#     · Month 20/20 processed | running...RMSE=1.0681
#   - Config 51/96
#     · Month 5/20 processed | running...RMSE=1.5443
#     · Month 10/20 processed | running...RMSE=1.2414
#     · Month 15/20 processed | running...RMSE=1.1818
#     · Month 20/20 processed | running...RMSE=1.0681
#   - Config 52/96
#     · Month 5/20 processed | running...RMSE=1.6327
#     · Month 10/20 processed | running...RMSE=1.3013
#     · Month 15/20 processed | running...RMSE=1.2228
#     · Month 20/20 processed | running...RMSE=1.0898
#   - Config 53/96
#     · Month 5/20 processed | running...RMSE=1.5960
#     · Month 10/20 processed | running...RMSE=1.2746
#     · Month 15/20 processed | running...RMSE=1.2070
#     · Month 20/20 processed | running...RMSE=1.0870
#   - Config 54/96
#     · Month 5/20 processed | running...RMSE=1.5960
#     · Month 10/20 processed | running...RMSE=1.2746
#     · Month 15/20 processed | running...RMSE=1.2070
#     · Month 20/20 processed | running...RMSE=1.0870
#   - Config 55/96
#     · Month 5/20 processed | running...RMSE=1.5960
#     · Month 10/20 processed | running...RMSE=1.2746
#     · Month 15/20 processed | running...RMSE=1.2070
#     · Month 20/20 processed | running...RMSE=1.0870
#   - Config 56/96
#     · Month 5/20 processed | running...RMSE=1.6371
#     · Month 10/20 processed | running...RMSE=1.3044
#     · Month 15/20 processed | running...RMSE=1.2255
#     · Month 20/20 processed | running...RMSE=1.0925
#   - Config 57/96
#     · Month 5/20 processed | running...RMSE=1.5973
#     · Month 10/20 processed | running...RMSE=1.2775
#     · Month 15/20 processed | running...RMSE=1.2095
#     · Month 20/20 processed | running...RMSE=1.0858
#   - Config 58/96
#     · Month 5/20 processed | running...RMSE=1.5973
#     · Month 10/20 processed | running...RMSE=1.2775
#     · Month 15/20 processed | running...RMSE=1.2095
#     · Month 20/20 processed | running...RMSE=1.0858
#   - Config 59/96
#     · Month 5/20 processed | running...RMSE=1.5973
#     · Month 10/20 processed | running...RMSE=1.2775
#     · Month 15/20 processed | running...RMSE=1.2095
#     · Month 20/20 processed | running...RMSE=1.0858
#   - Config 60/96
#     · Month 5/20 processed | running...RMSE=1.6327
#     · Month 10/20 processed | running...RMSE=1.3013
#     · Month 15/20 processed | running...RMSE=1.2228
#     · Month 20/20 processed | running...RMSE=1.0898
#   - Config 61/96
#     · Month 5/20 processed | running...RMSE=1.6179
#     · Month 10/20 processed | running...RMSE=1.2899
#     · Month 15/20 processed | running...RMSE=1.2183
#     · Month 20/20 processed | running...RMSE=1.0911
#   - Config 62/96
#     · Month 5/20 processed | running...RMSE=1.6179
#     · Month 10/20 processed | running...RMSE=1.2899
#     · Month 15/20 processed | running...RMSE=1.2183
#     · Month 20/20 processed | running...RMSE=1.0911
#   - Config 63/96
#     · Month 5/20 processed | running...RMSE=1.6179
#     · Month 10/20 processed | running...RMSE=1.2899
#     · Month 15/20 processed | running...RMSE=1.2183
#     · Month 20/20 processed | running...RMSE=1.0911
#   - Config 64/96
#     · Month 5/20 processed | running...RMSE=1.6371
#     · Month 10/20 processed | running...RMSE=1.3044
#     · Month 15/20 processed | running...RMSE=1.2255
#     · Month 20/20 processed | running...RMSE=1.0925
#   - Config 65/96
#     · Month 5/20 processed | running...RMSE=1.5509
#     · Month 10/20 processed | running...RMSE=1.2534
#     · Month 15/20 processed | running...RMSE=1.1923
#     · Month 20/20 processed | running...RMSE=1.0760
#   - Config 66/96
#     · Month 5/20 processed | running...RMSE=1.5509
#     · Month 10/20 processed | running...RMSE=1.2534
#     · Month 15/20 processed | running...RMSE=1.1923
#     · Month 20/20 processed | running...RMSE=1.0760
#   - Config 67/96
#     · Month 5/20 processed | running...RMSE=1.5509
#     · Month 10/20 processed | running...RMSE=1.2534
#     · Month 15/20 processed | running...RMSE=1.1923
#     · Month 20/20 processed | running...RMSE=1.0760
#   - Config 68/96
#     · Month 5/20 processed | running...RMSE=1.6298
#     · Month 10/20 processed | running...RMSE=1.2987
#     · Month 15/20 processed | running...RMSE=1.2203
#     · Month 20/20 processed | running...RMSE=1.0873
#   - Config 69/96
#     · Month 5/20 processed | running...RMSE=1.5940
#     · Month 10/20 processed | running...RMSE=1.2748
#     · Month 15/20 processed | running...RMSE=1.2084
#     · Month 20/20 processed | running...RMSE=1.0888
#   - Config 70/96
#     · Month 5/20 processed | running...RMSE=1.5940
#     · Month 10/20 processed | running...RMSE=1.2748
#     · Month 15/20 processed | running...RMSE=1.2084
#     · Month 20/20 processed | running...RMSE=1.0888
#   - Config 71/96
#     · Month 5/20 processed | running...RMSE=1.5940
#     · Month 10/20 processed | running...RMSE=1.2748
#     · Month 15/20 processed | running...RMSE=1.2084
#     · Month 20/20 processed | running...RMSE=1.0888
#   - Config 72/96
#     · Month 5/20 processed | running...RMSE=1.6350
#     · Month 10/20 processed | running...RMSE=1.3026
#     · Month 15/20 processed | running...RMSE=1.2238
#     · Month 20/20 processed | running...RMSE=1.0907
#   - Config 73/96
#     · Month 5/20 processed | running...RMSE=1.5907
#     · Month 10/20 processed | running...RMSE=1.2761
#     · Month 15/20 processed | running...RMSE=1.2089
#     · Month 20/20 processed | running...RMSE=1.0865
#   - Config 74/96
#     · Month 5/20 processed | running...RMSE=1.5907
#     · Month 10/20 processed | running...RMSE=1.2761
#     · Month 15/20 processed | running...RMSE=1.2089
#     · Month 20/20 processed | running...RMSE=1.0865
#   - Config 75/96
#     · Month 5/20 processed | running...RMSE=1.5907
#     · Month 10/20 processed | running...RMSE=1.2761
#     · Month 15/20 processed | running...RMSE=1.2089
#     · Month 20/20 processed | running...RMSE=1.0865
#   - Config 76/96
#     · Month 5/20 processed | running...RMSE=1.6298
#     · Month 10/20 processed | running...RMSE=1.2987
#     · Month 15/20 processed | running...RMSE=1.2203
#     · Month 20/20 processed | running...RMSE=1.0873
#   - Config 77/96
#     · Month 5/20 processed | running...RMSE=1.6135
#     · Month 10/20 processed | running...RMSE=1.2874
#     · Month 15/20 processed | running...RMSE=1.2156
#     · Month 20/20 processed | running...RMSE=1.0892
#   - Config 78/96
#     · Month 5/20 processed | running...RMSE=1.6135
#     · Month 10/20 processed | running...RMSE=1.2874
#     · Month 15/20 processed | running...RMSE=1.2156
#     · Month 20/20 processed | running...RMSE=1.0892
#   - Config 79/96
#     · Month 5/20 processed | running...RMSE=1.6135
#     · Month 10/20 processed | running...RMSE=1.2874
#     · Month 15/20 processed | running...RMSE=1.2156
#     · Month 20/20 processed | running...RMSE=1.0892
#   - Config 80/96
#     · Month 5/20 processed | running...RMSE=1.6350
#     · Month 10/20 processed | running...RMSE=1.3026
#     · Month 15/20 processed | running...RMSE=1.2238
#     · Month 20/20 processed | running...RMSE=1.0907
#   - Config 81/96
#     · Month 5/20 processed | running...RMSE=1.5518
#     · Month 10/20 processed | running...RMSE=1.2528
#     · Month 15/20 processed | running...RMSE=1.1927
#     · Month 20/20 processed | running...RMSE=1.0773
#   - Config 82/96
#     · Month 5/20 processed | running...RMSE=1.5518
#     · Month 10/20 processed | running...RMSE=1.2528
#     · Month 15/20 processed | running...RMSE=1.1927
#     · Month 20/20 processed | running...RMSE=1.0773
#   - Config 83/96
#     · Month 5/20 processed | running...RMSE=1.5518
#     · Month 10/20 processed | running...RMSE=1.2528
#     · Month 15/20 processed | running...RMSE=1.1927
#     · Month 20/20 processed | running...RMSE=1.0773
#   - Config 84/96
#     · Month 5/20 processed | running...RMSE=1.6310
#     · Month 10/20 processed | running...RMSE=1.2990
#     · Month 15/20 processed | running...RMSE=1.2203
#     · Month 20/20 processed | running...RMSE=1.0871
#   - Config 85/96
#     · Month 5/20 processed | running...RMSE=1.5935
#     · Month 10/20 processed | running...RMSE=1.2753
#     · Month 15/20 processed | running...RMSE=1.2083
#     · Month 20/20 processed | running...RMSE=1.0886
#   - Config 86/96
#     · Month 5/20 processed | running...RMSE=1.5935
#     · Month 10/20 processed | running...RMSE=1.2753
#     · Month 15/20 processed | running...RMSE=1.2083
#     · Month 20/20 processed | running...RMSE=1.0886
#   - Config 87/96
#     · Month 5/20 processed | running...RMSE=1.5935
#     · Month 10/20 processed | running...RMSE=1.2753
#     · Month 15/20 processed | running...RMSE=1.2083
#     · Month 20/20 processed | running...RMSE=1.0886
#   - Config 88/96
#     · Month 5/20 processed | running...RMSE=1.6348
#     · Month 10/20 processed | running...RMSE=1.3023
#     · Month 15/20 processed | running...RMSE=1.2234
#     · Month 20/20 processed | running...RMSE=1.0902
#   - Config 89/96
#     · Month 5/20 processed | running...RMSE=1.5918
#     · Month 10/20 processed | running...RMSE=1.2776
#     · Month 15/20 processed | running...RMSE=1.2092
#     · Month 20/20 processed | running...RMSE=1.0858
#   - Config 90/96
#     · Month 5/20 processed | running...RMSE=1.5918
#     · Month 10/20 processed | running...RMSE=1.2776
#     · Month 15/20 processed | running...RMSE=1.2092
#     · Month 20/20 processed | running...RMSE=1.0858
#   - Config 91/96
#     · Month 5/20 processed | running...RMSE=1.5918
#     · Month 10/20 processed | running...RMSE=1.2776
#     · Month 15/20 processed | running...RMSE=1.2092
#     · Month 20/20 processed | running...RMSE=1.0858
#   - Config 92/96
#     · Month 5/20 processed | running...RMSE=1.6310
#     · Month 10/20 processed | running...RMSE=1.2990
#     · Month 15/20 processed | running...RMSE=1.2203
#     · Month 20/20 processed | running...RMSE=1.0871
#   - Config 93/96
#     · Month 5/20 processed | running...RMSE=1.6141
#     · Month 10/20 processed | running...RMSE=1.2884
#     · Month 15/20 processed | running...RMSE=1.2159
#     · Month 20/20 processed | running...RMSE=1.0891
#   - Config 94/96
#     · Month 5/20 processed | running...RMSE=1.6141
#     · Month 10/20 processed | running...RMSE=1.2884
#     · Month 15/20 processed | running...RMSE=1.2159
#     · Month 20/20 processed | running...RMSE=1.0891
#   - Config 95/96
#     · Month 5/20 processed | running...RMSE=1.6141
#     · Month 10/20 processed | running...RMSE=1.2884
#     · Month 15/20 processed | running...RMSE=1.2159
#     · Month 20/20 processed | running...RMSE=1.0891
#   - Config 96/96
#     · Month 5/20 processed | running...RMSE=1.6348
#     · Month 10/20 processed | running...RMSE=1.3023
#     · Month 15/20 processed | running...RMSE=1.2234
#     · Month 20/20 processed | running...RMSE=1.0902
# [Stage A][Block 1] kept 48 configs (floor=24).
# [Stage A][Block 2] train_end=200, OOS=201-220 | configs=48
#   - Config 1/48
#     · Month 5/20 processed | running...RMSE=0.8937
#     · Month 10/20 processed | running...RMSE=1.2146
#     · Month 15/20 processed | running...RMSE=2.6163
#     · Month 20/20 processed | running...RMSE=2.6132
#   - Config 2/48
#     · Month 5/20 processed | running...RMSE=0.8916
#     · Month 10/20 processed | running...RMSE=1.2126
#     · Month 15/20 processed | running...RMSE=2.6151
#     · Month 20/20 processed | running...RMSE=2.6120
#   - Config 3/48
#     · Month 5/20 processed | running...RMSE=0.8937
#     · Month 10/20 processed | running...RMSE=1.2146
#     · Month 15/20 processed | running...RMSE=2.6163
#     · Month 20/20 processed | running...RMSE=2.6132
#   - Config 4/48
#     · Month 5/20 processed | running...RMSE=0.8943
#     · Month 10/20 processed | running...RMSE=1.2149
#     · Month 15/20 processed | running...RMSE=2.6182
#     · Month 20/20 processed | running...RMSE=2.6148
#   - Config 5/48
#     · Month 5/20 processed | running...RMSE=0.8926
#     · Month 10/20 processed | running...RMSE=1.2134
#     · Month 15/20 processed | running...RMSE=2.6182
#     · Month 20/20 processed | running...RMSE=2.6144
#   - Config 6/48
#     · Month 5/20 processed | running...RMSE=0.8943
#     · Month 10/20 processed | running...RMSE=1.2149
#     · Month 15/20 processed | running...RMSE=2.6182
#     · Month 20/20 processed | running...RMSE=2.6148
#   - Config 7/48
#     · Month 5/20 processed | running...RMSE=0.8926
#     · Month 10/20 processed | running...RMSE=1.2134
#     · Month 15/20 processed | running...RMSE=2.6182
#     · Month 20/20 processed | running...RMSE=2.6144
#   - Config 8/48
#     · Month 5/20 processed | running...RMSE=0.8938
#     · Month 10/20 processed | running...RMSE=1.2150
#     · Month 15/20 processed | running...RMSE=2.6202
#     · Month 20/20 processed | running...RMSE=2.6164
#   - Config 9/48
#     · Month 5/20 processed | running...RMSE=0.8923
#     · Month 10/20 processed | running...RMSE=1.2133
#     · Month 15/20 processed | running...RMSE=2.6205
#     · Month 20/20 processed | running...RMSE=2.6162
#   - Config 10/48
#     · Month 5/20 processed | running...RMSE=0.8938
#     · Month 10/20 processed | running...RMSE=1.2150
#     · Month 15/20 processed | running...RMSE=2.6202
#     · Month 20/20 processed | running...RMSE=2.6164
#   - Config 11/48
#     · Month 5/20 processed | running...RMSE=0.8923
#     · Month 10/20 processed | running...RMSE=1.2133
#     · Month 15/20 processed | running...RMSE=2.6205
#     · Month 20/20 processed | running...RMSE=2.6162
#   - Config 12/48
#     · Month 5/20 processed | running...RMSE=0.9289
#     · Month 10/20 processed | running...RMSE=1.2431
#     · Month 15/20 processed | running...RMSE=2.5129
#     · Month 20/20 processed | running...RMSE=2.5427
#   - Config 13/48
#     · Month 5/20 processed | running...RMSE=0.9289
#     · Month 10/20 processed | running...RMSE=1.2431
#     · Month 15/20 processed | running...RMSE=2.5129
#     · Month 20/20 processed | running...RMSE=2.5427
#   - Config 14/48
#     · Month 5/20 processed | running...RMSE=0.9289
#     · Month 10/20 processed | running...RMSE=1.2431
#     · Month 15/20 processed | running...RMSE=2.5129
#     · Month 20/20 processed | running...RMSE=2.5427
#   - Config 15/48
#     · Month 5/20 processed | running...RMSE=0.8984
#     · Month 10/20 processed | running...RMSE=1.2194
#     · Month 15/20 processed | running...RMSE=2.5690
#     · Month 20/20 processed | running...RMSE=2.5801
#   - Config 16/48
#     · Month 5/20 processed | running...RMSE=0.8984
#     · Month 10/20 processed | running...RMSE=1.2194
#     · Month 15/20 processed | running...RMSE=2.5690
#     · Month 20/20 processed | running...RMSE=2.5801
#   - Config 17/48
#     · Month 5/20 processed | running...RMSE=0.8984
#     · Month 10/20 processed | running...RMSE=1.2194
#     · Month 15/20 processed | running...RMSE=2.5690
#     · Month 20/20 processed | running...RMSE=2.5801
#   - Config 18/48
#     · Month 5/20 processed | running...RMSE=0.9428
#     · Month 10/20 processed | running...RMSE=1.2416
#     · Month 15/20 processed | running...RMSE=2.4887
#     · Month 20/20 processed | running...RMSE=2.5200
#   - Config 19/48
#     · Month 5/20 processed | running...RMSE=0.9428
#     · Month 10/20 processed | running...RMSE=1.2416
#     · Month 15/20 processed | running...RMSE=2.4887
#     · Month 20/20 processed | running...RMSE=2.5200
#   - Config 20/48
#     · Month 5/20 processed | running...RMSE=0.9428
#     · Month 10/20 processed | running...RMSE=1.2416
#     · Month 15/20 processed | running...RMSE=2.4887
#     · Month 20/20 processed | running...RMSE=2.5200
#   - Config 21/48
#     · Month 5/20 processed | running...RMSE=0.9300
#     · Month 10/20 processed | running...RMSE=1.2337
#     · Month 15/20 processed | running...RMSE=2.5152
#     · Month 20/20 processed | running...RMSE=2.5371
#   - Config 22/48
#     · Month 5/20 processed | running...RMSE=0.9300
#     · Month 10/20 processed | running...RMSE=1.2337
#     · Month 15/20 processed | running...RMSE=2.5152
#     · Month 20/20 processed | running...RMSE=2.5371
#   - Config 23/48
#     · Month 5/20 processed | running...RMSE=0.9300
#     · Month 10/20 processed | running...RMSE=1.2337
#     · Month 15/20 processed | running...RMSE=2.5152
#     · Month 20/20 processed | running...RMSE=2.5371
#   - Config 24/48
#     · Month 5/20 processed | running...RMSE=0.8915
#     · Month 10/20 processed | running...RMSE=1.2134
#     · Month 15/20 processed | running...RMSE=2.6066
#     · Month 20/20 processed | running...RMSE=2.6053
#   - Config 25/48
#     · Month 5/20 processed | running...RMSE=0.8990
#     · Month 10/20 processed | running...RMSE=1.2178
#     · Month 15/20 processed | running...RMSE=2.5539
#     · Month 20/20 processed | running...RMSE=2.5661
#   - Config 26/48
#     · Month 5/20 processed | running...RMSE=0.8990
#     · Month 10/20 processed | running...RMSE=1.2178
#     · Month 15/20 processed | running...RMSE=2.5539
#     · Month 20/20 processed | running...RMSE=2.5661
#   - Config 27/48
#     · Month 5/20 processed | running...RMSE=0.8990
#     · Month 10/20 processed | running...RMSE=1.2178
#     · Month 15/20 processed | running...RMSE=2.5539
#     · Month 20/20 processed | running...RMSE=2.5661
#   - Config 28/48
#     · Month 5/20 processed | running...RMSE=0.9468
#     · Month 10/20 processed | running...RMSE=1.2462
#     · Month 15/20 processed | running...RMSE=2.5200
#     · Month 20/20 processed | running...RMSE=2.5424
#   - Config 29/48
#     · Month 5/20 processed | running...RMSE=0.9468
#     · Month 10/20 processed | running...RMSE=1.2462
#     · Month 15/20 processed | running...RMSE=2.5200
#     · Month 20/20 processed | running...RMSE=2.5424
#   - Config 30/48
#     · Month 5/20 processed | running...RMSE=0.9468
#     · Month 10/20 processed | running...RMSE=1.2462
#     · Month 15/20 processed | running...RMSE=2.5200
#     · Month 20/20 processed | running...RMSE=2.5424
#   - Config 31/48
#     · Month 5/20 processed | running...RMSE=0.8915
#     · Month 10/20 processed | running...RMSE=1.2134
#     · Month 15/20 processed | running...RMSE=2.6066
#     · Month 20/20 processed | running...RMSE=2.6053
#   - Config 32/48
#     · Month 5/20 processed | running...RMSE=0.9032
#     · Month 10/20 processed | running...RMSE=1.2192
#     · Month 15/20 processed | running...RMSE=2.5413
#     · Month 20/20 processed | running...RMSE=2.5560
#   - Config 33/48
#     · Month 5/20 processed | running...RMSE=0.9032
#     · Month 10/20 processed | running...RMSE=1.2192
#     · Month 15/20 processed | running...RMSE=2.5413
#     · Month 20/20 processed | running...RMSE=2.5560
#   - Config 34/48
#     · Month 5/20 processed | running...RMSE=0.9032
#     · Month 10/20 processed | running...RMSE=1.2192
#     · Month 15/20 processed | running...RMSE=2.5413
#     · Month 20/20 processed | running...RMSE=2.5560
#   - Config 35/48
#     · Month 5/20 processed | running...RMSE=0.9333
#     · Month 10/20 processed | running...RMSE=1.2384
#     · Month 15/20 processed | running...RMSE=2.5180
#     · Month 20/20 processed | running...RMSE=2.5387
#   - Config 36/48
#     · Month 5/20 processed | running...RMSE=0.9333
#     · Month 10/20 processed | running...RMSE=1.2384
#     · Month 15/20 processed | running...RMSE=2.5180
#     · Month 20/20 processed | running...RMSE=2.5387
#   - Config 37/48
#     · Month 5/20 processed | running...RMSE=0.9333
#     · Month 10/20 processed | running...RMSE=1.2384
#     · Month 15/20 processed | running...RMSE=2.5180
#     · Month 20/20 processed | running...RMSE=2.5387
#   - Config 38/48
#     · Month 5/20 processed | running...RMSE=0.8915
#     · Month 10/20 processed | running...RMSE=1.2134
#     · Month 15/20 processed | running...RMSE=2.6066
#     · Month 20/20 processed | running...RMSE=2.6053
#   - Config 39/48
#     · Month 5/20 processed | running...RMSE=0.9003
#     · Month 10/20 processed | running...RMSE=1.2183
#     · Month 15/20 processed | running...RMSE=2.5577
#     · Month 20/20 processed | running...RMSE=2.5694
#   - Config 40/48
#     · Month 5/20 processed | running...RMSE=0.9003
#     · Month 10/20 processed | running...RMSE=1.2183
#     · Month 15/20 processed | running...RMSE=2.5577
#     · Month 20/20 processed | running...RMSE=2.5694
#   - Config 41/48
#     · Month 5/20 processed | running...RMSE=0.9003
#     · Month 10/20 processed | running...RMSE=1.2183
#     · Month 15/20 processed | running...RMSE=2.5577
#     · Month 20/20 processed | running...RMSE=2.5694
#   - Config 42/48
#     · Month 5/20 processed | running...RMSE=0.9449
#     · Month 10/20 processed | running...RMSE=1.2460
#     · Month 15/20 processed | running...RMSE=2.5130
#     · Month 20/20 processed | running...RMSE=2.5370
#   - Config 43/48
#     · Month 5/20 processed | running...RMSE=0.9449
#     · Month 10/20 processed | running...RMSE=1.2460
#     · Month 15/20 processed | running...RMSE=2.5130
#     · Month 20/20 processed | running...RMSE=2.5370
#   - Config 44/48
#     · Month 5/20 processed | running...RMSE=0.9449
#     · Month 10/20 processed | running...RMSE=1.2460
#     · Month 15/20 processed | running...RMSE=2.5130
#     · Month 20/20 processed | running...RMSE=2.5370
#   - Config 45/48
#     · Month 5/20 processed | running...RMSE=0.8915
#     · Month 10/20 processed | running...RMSE=1.2134
#     · Month 15/20 processed | running...RMSE=2.6066
#     · Month 20/20 processed | running...RMSE=2.6053
#   - Config 46/48
#     · Month 5/20 processed | running...RMSE=0.9047
#     · Month 10/20 processed | running...RMSE=1.2214
#     · Month 15/20 processed | running...RMSE=2.5442
#     · Month 20/20 processed | running...RMSE=2.5580
#   - Config 47/48
#     · Month 5/20 processed | running...RMSE=0.9047
#     · Month 10/20 processed | running...RMSE=1.2214
#     · Month 15/20 processed | running...RMSE=2.5442
#     · Month 20/20 processed | running...RMSE=2.5580
#   - Config 48/48
#     · Month 5/20 processed | running...RMSE=0.9047
#     · Month 10/20 processed | running...RMSE=1.2214
#     · Month 15/20 processed | running...RMSE=2.5442
#     · Month 20/20 processed | running...RMSE=2.5580
# [Stage A][Block 2] kept 24 configs (floor=24).
# [Stage A][Block 3] train_end=220, OOS=221-240 | configs=24
#   - Config 1/24
#     · Month 5/20 processed | running...RMSE=2.0489
#     · Month 10/20 processed | running...RMSE=1.8705
#     · Month 15/20 processed | running...RMSE=1.7454
#     · Month 20/20 processed | running...RMSE=1.6168
#   - Config 2/24
#     · Month 5/20 processed | running...RMSE=2.0489
#     · Month 10/20 processed | running...RMSE=1.8705
#     · Month 15/20 processed | running...RMSE=1.7454
#     · Month 20/20 processed | running...RMSE=1.6168
#   - Config 3/24
#     · Month 5/20 processed | running...RMSE=2.0489
#     · Month 10/20 processed | running...RMSE=1.8705
#     · Month 15/20 processed | running...RMSE=1.7454
#     · Month 20/20 processed | running...RMSE=1.6168
#   - Config 4/24
#     · Month 5/20 processed | running...RMSE=2.0440
#     · Month 10/20 processed | running...RMSE=1.8749
#     · Month 15/20 processed | running...RMSE=1.7299
#     · Month 20/20 processed | running...RMSE=1.5986
#   - Config 5/24
#     · Month 5/20 processed | running...RMSE=2.0440
#     · Month 10/20 processed | running...RMSE=1.8749
#     · Month 15/20 processed | running...RMSE=1.7299
#     · Month 20/20 processed | running...RMSE=1.5986
#   - Config 6/24
#     · Month 5/20 processed | running...RMSE=2.0440
#     · Month 10/20 processed | running...RMSE=1.8749
#     · Month 15/20 processed | running...RMSE=1.7299
#     · Month 20/20 processed | running...RMSE=1.5986
#   - Config 7/24
#     · Month 5/20 processed | running...RMSE=2.0642
#     · Month 10/20 processed | running...RMSE=1.8813
#     · Month 15/20 processed | running...RMSE=1.7444
#     · Month 20/20 processed | running...RMSE=1.6065
#   - Config 8/24
#     · Month 5/20 processed | running...RMSE=2.0642
#     · Month 10/20 processed | running...RMSE=1.8813
#     · Month 15/20 processed | running...RMSE=1.7444
#     · Month 20/20 processed | running...RMSE=1.6065
#   - Config 9/24
#     · Month 5/20 processed | running...RMSE=2.0642
#     · Month 10/20 processed | running...RMSE=1.8813
#     · Month 15/20 processed | running...RMSE=1.7444
#     · Month 20/20 processed | running...RMSE=1.6065
#   - Config 10/24
#     · Month 5/20 processed | running...RMSE=2.0548
#     · Month 10/20 processed | running...RMSE=1.8683
#     · Month 15/20 processed | running...RMSE=1.7316
#     · Month 20/20 processed | running...RMSE=1.6015
#   - Config 11/24
#     · Month 5/20 processed | running...RMSE=2.0548
#     · Month 10/20 processed | running...RMSE=1.8683
#     · Month 15/20 processed | running...RMSE=1.7316
#     · Month 20/20 processed | running...RMSE=1.6015
#   - Config 12/24
#     · Month 5/20 processed | running...RMSE=2.0548
#     · Month 10/20 processed | running...RMSE=1.8683
#     · Month 15/20 processed | running...RMSE=1.7316
#     · Month 20/20 processed | running...RMSE=1.6015
#   - Config 13/24
#     · Month 5/20 processed | running...RMSE=2.0506
#     · Month 10/20 processed | running...RMSE=1.8792
#     · Month 15/20 processed | running...RMSE=1.7495
#     · Month 20/20 processed | running...RMSE=1.6267
#   - Config 14/24
#     · Month 5/20 processed | running...RMSE=2.0506
#     · Month 10/20 processed | running...RMSE=1.8792
#     · Month 15/20 processed | running...RMSE=1.7495
#     · Month 20/20 processed | running...RMSE=1.6267
#   - Config 15/24
#     · Month 5/20 processed | running...RMSE=2.0506
#     · Month 10/20 processed | running...RMSE=1.8792
#     · Month 15/20 processed | running...RMSE=1.7495
#     · Month 20/20 processed | running...RMSE=1.6267
#   - Config 16/24
#     · Month 5/20 processed | running...RMSE=2.0497
#     · Month 10/20 processed | running...RMSE=1.8646
#     · Month 15/20 processed | running...RMSE=1.7292
#     · Month 20/20 processed | running...RMSE=1.5892
#   - Config 17/24
#     · Month 5/20 processed | running...RMSE=2.0497
#     · Month 10/20 processed | running...RMSE=1.8646
#     · Month 15/20 processed | running...RMSE=1.7292
#     · Month 20/20 processed | running...RMSE=1.5892
#   - Config 18/24
#     · Month 5/20 processed | running...RMSE=2.0497
#     · Month 10/20 processed | running...RMSE=1.8646
#     · Month 15/20 processed | running...RMSE=1.7292
#     · Month 20/20 processed | running...RMSE=1.5892
#   - Config 19/24
#     · Month 5/20 processed | running...RMSE=2.0459
#     · Month 10/20 processed | running...RMSE=1.8590
#     · Month 15/20 processed | running...RMSE=1.7252
#     · Month 20/20 processed | running...RMSE=1.5933
#   - Config 20/24
#     · Month 5/20 processed | running...RMSE=2.0459
#     · Month 10/20 processed | running...RMSE=1.8590
#     · Month 15/20 processed | running...RMSE=1.7252
#     · Month 20/20 processed | running...RMSE=1.5933
#   - Config 21/24
#     · Month 5/20 processed | running...RMSE=2.0459
#     · Month 10/20 processed | running...RMSE=1.8590
#     · Month 15/20 processed | running...RMSE=1.7252
#     · Month 20/20 processed | running...RMSE=1.5933
#   - Config 22/24
#     · Month 5/20 processed | running...RMSE=2.0543
#     · Month 10/20 processed | running...RMSE=1.8775
#     · Month 15/20 processed | running...RMSE=1.7454
#     · Month 20/20 processed | running...RMSE=1.6152
#   - Config 23/24
#     · Month 5/20 processed | running...RMSE=2.0543
#     · Month 10/20 processed | running...RMSE=1.8775
#     · Month 15/20 processed | running...RMSE=1.7454
#     · Month 20/20 processed | running...RMSE=1.6152
#   - Config 24/24
#     · Month 5/20 processed | running...RMSE=2.0543
#     · Month 10/20 processed | running...RMSE=1.8775
#     · Month 15/20 processed | running...RMSE=1.7454
#     · Month 20/20 processed | running...RMSE=1.6152
# [Stage A][Block 3] kept 24 configs (floor=24).
# [Stage A] Shortlist saved with 5 configs.
# [Stage B] Using FULL FE (Gleis 1 & 2) pipeline.
# [Stage B] Month origin t=240 | evaluating 5 configs | active=1
# [Stage B] Month origin t=241 | evaluating 5 configs | active=4
# [Stage B] Month origin t=242 | evaluating 5 configs | active=4
# [Stage B] Month origin t=243 | evaluating 5 configs | active=4
# [Stage B] Month origin t=244 | evaluating 5 configs | active=4
# [Stage B] Month origin t=245 | evaluating 5 configs | active=4
# [Stage B] Month origin t=246 | evaluating 5 configs | active=4
# [Stage B] Month origin t=247 | evaluating 5 configs | active=4
# [Stage B] Month origin t=248 | evaluating 5 configs | active=4
# [Stage B] Month origin t=249 | evaluating 5 configs | active=4
# [Stage B] Month origin t=250 | evaluating 5 configs | active=4
# [Stage B] Month origin t=251 | evaluating 5 configs | active=4
# [Stage B] Month origin t=252 | evaluating 5 configs | active=4
# [Stage B] Month origin t=253 | evaluating 5 configs | active=1
# [Stage B] Month origin t=254 | evaluating 5 configs | active=1
# [Stage B] Month origin t=255 | evaluating 5 configs | active=1
# [Stage B] Month origin t=256 | evaluating 5 configs | active=1
# [Stage B] Month origin t=257 | evaluating 5 configs | active=1
# [Stage B] Month origin t=258 | evaluating 5 configs | active=1
# [Stage B] Month origin t=259 | evaluating 5 configs | active=1
# [Stage B] Month origin t=260 | evaluating 5 configs | active=1
# [Stage B] Month origin t=261 | evaluating 5 configs | active=1
# [Stage B] Month origin t=262 | evaluating 5 configs | active=1
# [Stage B] Month origin t=263 | evaluating 5 configs | active=1
# [Stage B] Month origin t=264 | evaluating 5 configs | active=1
# [Stage B] Month origin t=265 | evaluating 5 configs | active=1
# [Stage B] Month origin t=266 | evaluating 5 configs | active=1
# [Stage B] Month origin t=267 | evaluating 5 configs | active=1
# [Stage B] Month origin t=268 | evaluating 5 configs | active=1
# [Stage B] Month origin t=269 | evaluating 5 configs | active=1
# [Stage B] Month origin t=270 | evaluating 5 configs | active=1
# [Stage B] Month origin t=271 | evaluating 5 configs | active=1
# [Stage B] Month origin t=272 | evaluating 5 configs | active=1
# [Stage B] Month origin t=273 | evaluating 5 configs | active=1
# [Stage B] Month origin t=274 | evaluating 5 configs | active=1
# [Stage B] Month origin t=275 | evaluating 5 configs | active=1
# [Stage B] Month origin t=276 | evaluating 5 configs | active=1
# [Stage B] Month origin t=277 | evaluating 5 configs | active=1
# [Stage B] Month origin t=278 | evaluating 5 configs | active=1
# [Stage B] Month origin t=279 | evaluating 5 configs | active=1
# [Stage B] Month origin t=280 | evaluating 5 configs | active=1
# [Stage B] Month origin t=281 | evaluating 5 configs | active=1
# [Stage B] Month origin t=282 | evaluating 5 configs | active=1
# [Stage B] Month origin t=283 | evaluating 5 configs | active=1
# [Stage B] Month origin t=284 | evaluating 5 configs | active=1
# [Stage B] Month origin t=285 | evaluating 5 configs | active=1
# [Stage B] Month origin t=286 | evaluating 5 configs | active=1
# [Stage B] Month origin t=287 | evaluating 5 configs | active=1
# [Stage B] Month origin t=288 | evaluating 5 configs | active=1
# [Stage B] Month origin t=289 | evaluating 5 configs | active=1
# [Stage B] Month origin t=290 | evaluating 5 configs | active=1
# [Stage B] Month origin t=291 | evaluating 5 configs | active=1
# [Stage B] Month origin t=292 | evaluating 5 configs | active=1
# [Stage B] Month origin t=293 | evaluating 5 configs | active=1
# [Stage B] Month origin t=294 | evaluating 5 configs | active=1
# [Stage B] Month origin t=295 | evaluating 5 configs | active=1
# [Stage B] Month origin t=296 | evaluating 5 configs | active=1
# [Stage B] Month origin t=297 | evaluating 5 configs | active=1
# [Stage B] Month origin t=298 | evaluating 5 configs | active=1
# [Stage B] Month origin t=299 | evaluating 5 configs | active=1
# [Stage B] Month origin t=300 | evaluating 5 configs | active=1
# [Stage B] Month origin t=301 | evaluating 5 configs | active=1
# [Stage B] Month origin t=302 | evaluating 5 configs | active=1
# [Stage B] Month origin t=303 | evaluating 5 configs | active=1
# [Stage B] Month origin t=304 | evaluating 5 configs | active=1
# [Stage B] Month origin t=305 | evaluating 5 configs | active=1
# [Stage B] Month origin t=306 | evaluating 5 configs | active=1
# [Stage B] Month origin t=307 | evaluating 5 configs | active=1
# [Stage B] Month origin t=308 | evaluating 5 configs | active=1
# [Stage B] Month origin t=309 | evaluating 5 configs | active=1
# [Stage B] Month origin t=310 | evaluating 5 configs | active=1
# [Stage B] Month origin t=311 | evaluating 5 configs | active=1
# [Stage B] Month origin t=312 | evaluating 5 configs | active=1
# [Stage B] Month origin t=313 | evaluating 5 configs | active=1
# [Stage B] Month origin t=314 | evaluating 5 configs | active=1
# [Stage B] Month origin t=315 | evaluating 5 configs | active=1
# [Stage B] Month origin t=316 | evaluating 5 configs | active=1
# [Stage B] Month origin t=317 | evaluating 5 configs | active=1
# [Stage B] Month origin t=318 | evaluating 5 configs | active=1
# [Stage B] Month origin t=319 | evaluating 5 configs | active=1
# [Stage B] Month origin t=320 | evaluating 5 configs | active=1
# [Stage B] Month origin t=321 | evaluating 5 configs | active=1
# [Stage B] Month origin t=322 | evaluating 5 configs | active=1
# [Stage B] Month origin t=323 | evaluating 5 configs | active=1
# [Stage B] Month origin t=324 | evaluating 5 configs | active=1
# [Stage B] Month origin t=325 | evaluating 5 configs | active=1
# [Stage B] Month origin t=326 | evaluating 5 configs | active=1
# [Stage B] Month origin t=327 | evaluating 5 configs | active=1
# [Stage B] Month origin t=328 | evaluating 5 configs | active=1
# [Stage B] Month origin t=329 | evaluating 5 configs | active=1
# [Stage B] Month origin t=330 | evaluating 5 configs | active=1
# [Stage B] Month origin t=331 | evaluating 5 configs | active=1
# [Stage B] Month origin t=332 | evaluating 5 configs | active=1
# [Stage B] Month origin t=333 | evaluating 5 configs | active=1
# [Stage B] Month origin t=334 | evaluating 5 configs | active=1
# [Stage B] Month origin t=335 | evaluating 5 configs | active=1
# [Stage B] Month origin t=336 | evaluating 5 configs | active=1
# [Stage B] Month origin t=337 | evaluating 5 configs | active=1
# [Stage B] Month origin t=338 | evaluating 5 configs | active=1
# [Stage B] Month origin t=339 | evaluating 5 configs | active=1
# [Stage B] Month origin t=340 | evaluating 5 configs | active=1
# [Stage B] Month origin t=341 | evaluating 5 configs | active=1
# [Stage B] Month origin t=342 | evaluating 5 configs | active=1
# [Stage B] Month origin t=343 | evaluating 5 configs | active=1
# [Stage B] Month origin t=344 | evaluating 5 configs | active=1
# [Stage B] Month origin t=345 | evaluating 5 configs | active=1
# [Stage B] Month origin t=346 | evaluating 5 configs | active=1
# [Stage B] Month origin t=347 | evaluating 5 configs | active=1
# [Stage B] Month origin t=348 | evaluating 5 configs | active=1
# [Stage B] Month origin t=349 | evaluating 5 configs | active=1
# [Stage B] Month origin t=350 | evaluating 5 configs | active=1
# [Stage B] Month origin t=351 | evaluating 5 configs | active=1
# [Stage B] Month origin t=352 | evaluating 5 configs | active=1
# [Stage B] Month origin t=353 | evaluating 5 configs | active=1
# [Stage B] Month origin t=354 | evaluating 5 configs | active=1
# [Stage B] Month origin t=355 | evaluating 5 configs | active=1
# [Stage B] Month origin t=356 | evaluating 5 configs | active=1
# [Stage B] Month origin t=357 | evaluating 5 configs | active=1
# [Stage B] Month origin t=358 | evaluating 5 configs | active=1
# [Stage B] Month origin t=359 | evaluating 5 configs | active=1
# [Stage B] Month origin t=360 | evaluating 5 configs | active=1
# [Stage B] Month origin t=361 | evaluating 5 configs | active=1
# [Stage B] Month origin t=362 | evaluating 5 configs | active=1
# [Stage B] Month origin t=363 | evaluating 5 configs | active=1
# [Stage B] Month origin t=364 | evaluating 5 configs | active=1
# [Stage B] Month origin t=365 | evaluating 5 configs | active=1
# [Stage B] Month origin t=366 | evaluating 5 configs | active=1
# [Stage B] Month origin t=367 | evaluating 5 configs | active=1
# [Stage B] Month origin t=368 | evaluating 5 configs | active=1
# [Stage B] Month origin t=369 | evaluating 5 configs | active=1
# [Stage B] Month origin t=370 | evaluating 5 configs | active=1
# [Stage B] Month origin t=371 | evaluating 5 configs | active=1
# [Stage B] Month origin t=372 | evaluating 5 configs | active=1
# [Stage B] Month origin t=373 | evaluating 5 configs | active=1
# [Stage B] Month origin t=374 | evaluating 5 configs | active=1
# [Stage B] Month origin t=375 | evaluating 5 configs | active=1
# [Stage B] Month origin t=376 | evaluating 5 configs | active=1
# [Stage B] Month origin t=377 | evaluating 5 configs | active=1
# [Stage B] Month origin t=378 | evaluating 5 configs | active=1
# [Stage B] Month origin t=379 | evaluating 5 configs | active=1
# [Stage B] Month origin t=380 | evaluating 5 configs | active=1
# [Stage B] Month origin t=381 | evaluating 5 configs | active=1
# [Stage B] Month origin t=382 | evaluating 5 configs | active=1
# [Stage B] Month origin t=383 | evaluating 5 configs | active=1
# [Stage B] Month origin t=384 | evaluating 5 configs | active=1
# [Stage B] Month origin t=385 | evaluating 5 configs | active=1
# [Stage B] Month origin t=386 | evaluating 5 configs | active=1
# [Stage B] Month origin t=387 | evaluating 5 configs | active=1
# [Stage B] Month origin t=388 | evaluating 5 configs | active=1
# [Stage B] Month origin t=389 | evaluating 5 configs | active=1
# [Stage B] Month origin t=390 | evaluating 5 configs | active=1
# [Stage B] Month origin t=391 | evaluating 5 configs | active=1
# [Stage B] Month origin t=392 | evaluating 5 configs | active=1
# [Stage B] Month origin t=393 | evaluating 5 configs | active=1
# [Stage B] Month origin t=394 | evaluating 5 configs | active=1
# [Stage B] Month origin t=395 | evaluating 5 configs | active=1
# [Stage B] Month origin t=396 | evaluating 5 configs | active=1
# [Stage B] Month origin t=397 | evaluating 5 configs | active=1
# [Stage B] Month origin t=398 | evaluating 5 configs | active=1
# [Stage B] Month origin t=399 | evaluating 5 configs | active=1
# [Stage B] Month origin t=400 | evaluating 5 configs | active=1
# [Stage B] Month origin t=401 | evaluating 5 configs | active=1
# [Stage B] Month origin t=402 | evaluating 5 configs | active=1
# [Stage B] Month origin t=403 | evaluating 5 configs | active=1
# [Stage B] Month origin t=404 | evaluating 5 configs | active=1
# [Stage B] Month origin t=405 | evaluating 5 configs | active=1
# [Stage B] done → /Users/jonasschernich/Documents/Masterarbeit/Code/outputs/stageB/extra_trees/monthly
# [Stage B] summary.csv & summary_active.txt geschrieben.
#
# Done. Check outputs/stageA|stageB/extra_trees for results.
