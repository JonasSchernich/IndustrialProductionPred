# %%
# ==============================================================================
# Extra Trees – Thesis Tuning Pipeline
# ==============================================================================
# Spezifikation gemäß Masterarbeit:
# - Setup I (ifo only) vs. Setup II (ifo + Target Blocks) im Grid integriert.
# - FE: Lags 0-6 fix, SIS {300, 5k, 50k}, Redundanz {0.9, 1.0}, DR {None, PCA, PLS}.
# - Model: n_est {500,1k,2k}, depth {None,4,8}, leaf {1,5,10}, feat {sqrt,0.1,0.25}.
# - Stage A Shortlist: Top 10 frozen.
# - Dynamic FI (Setup III): Strikt Top 50 Features.
# ==============================================================================

import os, sys
from pathlib import Path
import numpy as np
import pandas as pd
from itertools import product

# --- 1) Pfad-Setup ---
def _locate_repo_root(start: Path) -> Path:
    cur = start.resolve()
    for _ in range(6):
        if (cur / "src").exists():
            return cur
        if cur.parent == cur:
            break
        cur = cur.parent
    return start.resolve()

NOTEBOOK_DIR = Path.cwd()
PROJECT_ROOT = _locate_repo_root(NOTEBOOK_DIR)
os.environ["PROJECT_ROOT"] = str(PROJECT_ROOT)
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

# --- 2) Imports ---
from src.config import (
    GlobalConfig,
    DEFAULT_CORR_SPEC,
    EWMA_CORR_SPEC,
    outputs_for_model,
)
from src.tuning import run_stageA, run_stageB
from src.io_timesplits import (
    load_target,
    load_ifo_features,
    load_full_lagged_features,
    load_rolling_importance,
)
# WICHTIG: Modell-Import für Extra Trees
from src.models.ET import ForecastModel

# --- 3) Konfiguration ---
USE_DYNAMIC_FI_PIPELINE = False  # False = Standard Setup (I & II)
SEED = 42

if USE_DYNAMIC_FI_PIPELINE:
    MODEL_NAME = "extra_trees_dynamic_fi"
else:
    MODEL_NAME = "extra_trees"

outputs_for_model(MODEL_NAME)
print(f"--- Starte Tuning für: {MODEL_NAME} ---")

# --- 4) Daten laden ---
y = load_target()
X_ifo = load_ifo_features()

# Align Indizes
idx_common = y.index.intersection(X_ifo.index)
y = y.loc[idx_common]
X_ifo = X_ifo.loc[idx_common]

X_full_lagged = None
rolling_imp = None
y_fi = None

if USE_DYNAMIC_FI_PIPELINE:
    FI_BASE_DIR = PROJECT_ROOT / "outputs" / "feature_importance" / "outputs_no_missing"
    try:
        X_full_lagged = load_full_lagged_features(base_dir=FI_BASE_DIR)
        rolling_imp   = load_rolling_importance(base_dir=FI_BASE_DIR)

        idx_fi = y.index.intersection(X_full_lagged.index).intersection(rolling_imp.index)
        y_fi          = y.loc[idx_fi]
        X_full_lagged = X_full_lagged.loc[idx_fi]
        rolling_imp   = rolling_imp.loc[idx_fi]
        print(f"Dynamic FI Modus: {X_full_lagged.shape[1]} Features geladen.")
    except FileNotFoundError:
        print("FEHLER: Dynamic FI Artefakte nicht gefunden.")
        sys.exit(1)
else:
    print(f"Full FE Modus (Setup I/II): {X_ifo.shape[1]} Basis-Features.")

# --- 5) Config Defaults (Thesis Policy) ---
def get_thesis_cfg() -> GlobalConfig:
    cfg = GlobalConfig(preset="thesis")
    cfg.policy_window = 24
    cfg.policy_decay = 0.97
    cfg.selection_mode = "decayed_best"
    return cfg

cfg_obj = get_thesis_cfg()

# --- 6) Grid Definition ---------------------------------------

def build_grid_full_fe():
    """Setup I (ifo) und Setup II (ifo + TargetBlocks)."""

    # A) FE & DR
    lag_candidates = [tuple(range(7))]

    corr_opts = [
        {"corr_spec": dict(DEFAULT_CORR_SPEC)},
        {"corr_spec": dict(EWMA_CORR_SPEC)},
    ]

    k1_opts = [700]
    red_opts = [0.9, 1.0]

    dr_opts = [
        {"dr_method": "none"},
        {"dr_method": "pca", "pca_kmax": 30, "pca_var_target": 0.99},
        {"dr_method": "pls", "pls_components": 30},
    ]

    # B) Setup II (Target Blocks)
    block_opts = [
        #None,                                 # Setup I
        ["AR1", "Chronos", "TSFresh"],                   # Setup II
    ]

    # C) Weights
    weight_opts = [
        {"sample_weight_decay": None},
        {"sample_weight_decay": 0.99}
    ]

    # D) Extra Trees Hyperparameter (Thesis Summary)
    n_estimators_list = [500, 1000, 2000]
    max_depth_list = [None, 4, 8]
    min_samples_leaf_list = [1, 5, 10]
    max_features_list = ['sqrt', 0.1, 0.25]

    grid = []

    # FE Loop
    for lags, corr, k1, red, dr in product(lag_candidates, corr_opts, k1_opts, red_opts, dr_opts):
        base_fe = {
            "lag_candidates": lags,
            "k1_topk": k1,
            "redundancy_param": red,
            **dr,
            **corr
        }
        # Blocks & Weights
        for blocks, weights in product(block_opts, weight_opts):
            # Model HPs
            for n_est, depth, leaf, feat in product(n_estimators_list, max_depth_list, min_samples_leaf_list, max_features_list):
                hp = {
                    **base_fe,
                    "target_block_set": blocks,
                    **weights,
                    "n_estimators": n_est,
                    "max_depth": depth,
                    "min_samples_leaf": leaf,
                    "max_features": feat,
                    "seed": SEED
                }
                grid.append(hp)
    return grid

def build_grid_dynamic_fi():
    """Setup III: Dynamic Feature Importance via strict Top-N."""

    n_features_list = [50]

    weight_opts = [{"sample_weight_decay": None}, {"sample_weight_decay": 0.99}]

    # ET Params
    n_estimators_list = [500, 1000, 2000]
    max_depth_list = [None, 4, 8]
    min_samples_leaf_list = [1, 5, 10]
    max_features_list = ['sqrt', 0.1, 0.25]

    grid = []
    for n_feat, w, n_est, depth, leaf, feat in product(n_features_list, weight_opts, n_estimators_list, max_depth_list, min_samples_leaf_list, max_features_list):
        hp = {
            "n_features_to_use": n_feat,
            **w,
            "n_estimators": n_est,
            "max_depth": depth,
            "min_samples_leaf": leaf,
            "max_features": feat,
            "seed": SEED
        }
        grid.append(hp)
    return grid

# --- 7) Ausführung --------------------------------------------

if USE_DYNAMIC_FI_PIPELINE:
    grid = build_grid_dynamic_fi()
    print(f"Dynamic FI Grid Größe (Setup III): {len(grid)} Konfigurationen.")

    shortlist = run_stageA(
        model_name=MODEL_NAME,
        model_ctor=lambda hp: ForecastModel(hp),
        model_grid=grid,
        X=X_ifo,
        y=y_fi,
        cfg=cfg_obj,
        X_full_lagged=X_full_lagged,
        rolling_imp=rolling_imp,
        keep_top_k_final=5,
        min_survivors_per_block=5
    )

    run_stageB(
        model_name=MODEL_NAME,
        model_ctor=lambda hp: ForecastModel(hp),
        shortlist=shortlist,
        X=X_ifo,
        y=y_fi,
        cfg=cfg_obj,
        X_full_lagged=X_full_lagged,
        rolling_imp=rolling_imp
    )

else:
    grid = build_grid_full_fe()
    print(f"Full FE Grid Größe (Setup I & II): {len(grid)} Konfigurationen.")
    # Grid ist sehr groß (~30k). ASHA wird hier aggressiv filtern.

    shortlist = run_stageA(
        model_name=MODEL_NAME,
        model_ctor=lambda hp: ForecastModel(hp),
        model_grid=grid,
        X=X_ifo,
        y=y,
        cfg=cfg_obj,
        keep_top_k_final=5,
        min_survivors_per_block=5
    )

    run_stageB(
        model_name=MODEL_NAME,
        model_ctor=lambda hp: ForecastModel(hp),
        shortlist=shortlist,
        X=X_ifo,
        y=y,
        cfg=cfg_obj
    )

print("\nTuning abgeschlossen.")
# Out:
# --- Starte Tuning für: extra_trees ---
# INFO in load_ifo_features: Renaming columns to ensure validity.
# Full FE Modus (Setup I/II): 2160 Basis-Features.
# Full FE Grid Größe (Setup I & II): 1944 Konfigurationen.
# [Stage A] Using FULL FE (Gleis 1 & 2) pipeline.
# [Stage A][Block 1] train_end=180, OOS=181-200 | configs=1944
#   - Config 1/1944
#     · Month 5/20 processed | running...RMSE=1.4304
#     · Month 10/20 processed | running...RMSE=1.1014
#     · Month 15/20 processed | running...RMSE=1.0370
#     · Month 20/20 processed | running...RMSE=0.9524
#   - Config 2/1944
#     · Month 5/20 processed | running...RMSE=1.4640
#     · Month 10/20 processed | running...RMSE=1.1302
#     · Month 15/20 processed | running...RMSE=1.0619
#     · Month 20/20 processed | running...RMSE=0.9604
#   - Config 3/1944
#     · Month 5/20 processed | running...RMSE=1.4640
#     · Month 10/20 processed | running...RMSE=1.1302
#     · Month 15/20 processed | running...RMSE=1.0619
#     · Month 20/20 processed | running...RMSE=0.9604
#   - Config 4/1944
#     · Month 5/20 processed | running...RMSE=1.4843
#     · Month 10/20 processed | running...RMSE=1.1732
#     · Month 15/20 processed | running...RMSE=1.1201
#     · Month 20/20 processed | running...RMSE=1.0057
#   - Config 5/1944
#     · Month 5/20 processed | running...RMSE=1.5489
#     · Month 10/20 processed | running...RMSE=1.2249
#     · Month 15/20 processed | running...RMSE=1.1641
#     · Month 20/20 processed | running...RMSE=1.0415
#   - Config 6/1944
#     · Month 5/20 processed | running...RMSE=1.5489
#     · Month 10/20 processed | running...RMSE=1.2249
#     · Month 15/20 processed | running...RMSE=1.1641
#     · Month 20/20 processed | running...RMSE=1.0415
#   - Config 7/1944
#     · Month 5/20 processed | running...RMSE=1.5722
#     · Month 10/20 processed | running...RMSE=1.2530
#     · Month 15/20 processed | running...RMSE=1.1802
#     · Month 20/20 processed | running...RMSE=1.0535
#   - Config 8/1944
#     · Month 5/20 processed | running...RMSE=1.6107
#     · Month 10/20 processed | running...RMSE=1.2847
#     · Month 15/20 processed | running...RMSE=1.2075
#     · Month 20/20 processed | running...RMSE=1.0768
#   - Config 9/1944
#     · Month 5/20 processed | running...RMSE=1.6107
#     · Month 10/20 processed | running...RMSE=1.2847
#     · Month 15/20 processed | running...RMSE=1.2075
#     · Month 20/20 processed | running...RMSE=1.0768
#   - Config 10/1944
#     · Month 5/20 processed | running...RMSE=1.4803
#     · Month 10/20 processed | running...RMSE=1.1633
#     · Month 15/20 processed | running...RMSE=1.1068
#     · Month 20/20 processed | running...RMSE=0.9941
#   - Config 11/1944
#     · Month 5/20 processed | running...RMSE=1.5041
#     · Month 10/20 processed | running...RMSE=1.1747
#     · Month 15/20 processed | running...RMSE=1.1210
#     · Month 20/20 processed | running...RMSE=0.9985
#   - Config 12/1944
#     · Month 5/20 processed | running...RMSE=1.5041
#     · Month 10/20 processed | running...RMSE=1.1747
#     · Month 15/20 processed | running...RMSE=1.1210
#     · Month 20/20 processed | running...RMSE=0.9985
#   - Config 13/1944
#     · Month 5/20 processed | running...RMSE=1.4923
#     · Month 10/20 processed | running...RMSE=1.1789
#     · Month 15/20 processed | running...RMSE=1.1253
#     · Month 20/20 processed | running...RMSE=1.0100
#   - Config 14/1944
#     · Month 5/20 processed | running...RMSE=1.5504
#     · Month 10/20 processed | running...RMSE=1.2264
#     · Month 15/20 processed | running...RMSE=1.1662
#     · Month 20/20 processed | running...RMSE=1.0425
#   - Config 15/1944
#     · Month 5/20 processed | running...RMSE=1.5504
#     · Month 10/20 processed | running...RMSE=1.2264
#     · Month 15/20 processed | running...RMSE=1.1662
#     · Month 20/20 processed | running...RMSE=1.0425
#   - Config 16/1944
#     · Month 5/20 processed | running...RMSE=1.5729
#     · Month 10/20 processed | running...RMSE=1.2530
#     · Month 15/20 processed | running...RMSE=1.1799
#     · Month 20/20 processed | running...RMSE=1.0529
#   - Config 17/1944
#     · Month 5/20 processed | running...RMSE=1.6108
#     · Month 10/20 processed | running...RMSE=1.2848
#     · Month 15/20 processed | running...RMSE=1.2077
#     · Month 20/20 processed | running...RMSE=1.0769
#   - Config 18/1944
#     · Month 5/20 processed | running...RMSE=1.6108
#     · Month 10/20 processed | running...RMSE=1.2848
#     · Month 15/20 processed | running...RMSE=1.2077
#     · Month 20/20 processed | running...RMSE=1.0769
#   - Config 19/1944
#     · Month 5/20 processed | running...RMSE=1.4307
#     · Month 10/20 processed | running...RMSE=1.1148
#     · Month 15/20 processed | running...RMSE=1.0598
#     · Month 20/20 processed | running...RMSE=0.9652
#   - Config 20/1944
#     · Month 5/20 processed | running...RMSE=1.4750
#     · Month 10/20 processed | running...RMSE=1.1422
#     · Month 15/20 processed | running...RMSE=1.0862
#     · Month 20/20 processed | running...RMSE=0.9709
#   - Config 21/1944
#     · Month 5/20 processed | running...RMSE=1.4750
#     · Month 10/20 processed | running...RMSE=1.1422
#     · Month 15/20 processed | running...RMSE=1.0862
#     · Month 20/20 processed | running...RMSE=0.9709
#   - Config 22/1944
#     · Month 5/20 processed | running...RMSE=1.4842
#     · Month 10/20 processed | running...RMSE=1.1733
#     · Month 15/20 processed | running...RMSE=1.1201
#     · Month 20/20 processed | running...RMSE=1.0056
#   - Config 23/1944
#     · Month 5/20 processed | running...RMSE=1.5493
#     · Month 10/20 processed | running...RMSE=1.2252
#     · Month 15/20 processed | running...RMSE=1.1646
#     · Month 20/20 processed | running...RMSE=1.0418
#   - Config 24/1944
#     · Month 5/20 processed | running...RMSE=1.5493
#     · Month 10/20 processed | running...RMSE=1.2252
#     · Month 15/20 processed | running...RMSE=1.1646
#     · Month 20/20 processed | running...RMSE=1.0418
#   - Config 25/1944
#     · Month 5/20 processed | running...RMSE=1.5722
#     · Month 10/20 processed | running...RMSE=1.2530
#     · Month 15/20 processed | running...RMSE=1.1802
#     · Month 20/20 processed | running...RMSE=1.0535
#   - Config 26/1944
#     · Month 5/20 processed | running...RMSE=1.6107
#     · Month 10/20 processed | running...RMSE=1.2847
#     · Month 15/20 processed | running...RMSE=1.2075
#     · Month 20/20 processed | running...RMSE=1.0768
#   - Config 27/1944
#     · Month 5/20 processed | running...RMSE=1.6107
#     · Month 10/20 processed | running...RMSE=1.2847
#     · Month 15/20 processed | running...RMSE=1.2075
#     · Month 20/20 processed | running...RMSE=1.0768
#   - Config 28/1944
#     · Month 5/20 processed | running...RMSE=1.4218
#     · Month 10/20 processed | running...RMSE=1.0958
#     · Month 15/20 processed | running...RMSE=1.0308
#     · Month 20/20 processed | running...RMSE=0.9478
#   - Config 29/1944
#     · Month 5/20 processed | running...RMSE=1.4611
#     · Month 10/20 processed | running...RMSE=1.1275
#     · Month 15/20 processed | running...RMSE=1.0560
#     · Month 20/20 processed | running...RMSE=0.9574
#   - Config 30/1944
#     · Month 5/20 processed | running...RMSE=1.4611
#     · Month 10/20 processed | running...RMSE=1.1275
#     · Month 15/20 processed | running...RMSE=1.0560
#     · Month 20/20 processed | running...RMSE=0.9574
#   - Config 31/1944
#     · Month 5/20 processed | running...RMSE=1.4777
#     · Month 10/20 processed | running...RMSE=1.1686
#     · Month 15/20 processed | running...RMSE=1.1153
#     · Month 20/20 processed | running...RMSE=1.0017
#   - Config 32/1944
#     · Month 5/20 processed | running...RMSE=1.5404
#     · Month 10/20 processed | running...RMSE=1.2180
#     · Month 15/20 processed | running...RMSE=1.1583
#     · Month 20/20 processed | running...RMSE=1.0364
#   - Config 33/1944
#     · Month 5/20 processed | running...RMSE=1.5404
#     · Month 10/20 processed | running...RMSE=1.2180
#     · Month 15/20 processed | running...RMSE=1.1583
#     · Month 20/20 processed | running...RMSE=1.0364
#   - Config 34/1944
#     · Month 5/20 processed | running...RMSE=1.5706
#     · Month 10/20 processed | running...RMSE=1.2533
#     · Month 15/20 processed | running...RMSE=1.1796
#     · Month 20/20 processed | running...RMSE=1.0522
#   - Config 35/1944
#     · Month 5/20 processed | running...RMSE=1.6083
#     · Month 10/20 processed | running...RMSE=1.2830
#     · Month 15/20 processed | running...RMSE=1.2064
#     · Month 20/20 processed | running...RMSE=1.0761
#   - Config 36/1944
#     · Month 5/20 processed | running...RMSE=1.6083
#     · Month 10/20 processed | running...RMSE=1.2830
#     · Month 15/20 processed | running...RMSE=1.2064
#     · Month 20/20 processed | running...RMSE=1.0761
#   - Config 37/1944
#     · Month 5/20 processed | running...RMSE=1.4711
#     · Month 10/20 processed | running...RMSE=1.1545
#     · Month 15/20 processed | running...RMSE=1.1002
#     · Month 20/20 processed | running...RMSE=0.9888
#   - Config 38/1944
#     · Month 5/20 processed | running...RMSE=1.5054
#     · Month 10/20 processed | running...RMSE=1.1780
#     · Month 15/20 processed | running...RMSE=1.1228
#     · Month 20/20 processed | running...RMSE=0.9997
#   - Config 39/1944
#     · Month 5/20 processed | running...RMSE=1.5054
#     · Month 10/20 processed | running...RMSE=1.1780
#     · Month 15/20 processed | running...RMSE=1.1228
#     · Month 20/20 processed | running...RMSE=0.9997
#   - Config 40/1944
#     · Month 5/20 processed | running...RMSE=1.4838
#     · Month 10/20 processed | running...RMSE=1.1727
#     · Month 15/20 processed | running...RMSE=1.1194
#     · Month 20/20 processed | running...RMSE=1.0038
#   - Config 41/1944
#     · Month 5/20 processed | running...RMSE=1.5431
#     · Month 10/20 processed | running...RMSE=1.2199
#     · Month 15/20 processed | running...RMSE=1.1608
#     · Month 20/20 processed | running...RMSE=1.0378
#   - Config 42/1944
#     · Month 5/20 processed | running...RMSE=1.5431
#     · Month 10/20 processed | running...RMSE=1.2199
#     · Month 15/20 processed | running...RMSE=1.1608
#     · Month 20/20 processed | running...RMSE=1.0378
#   - Config 43/1944
#     · Month 5/20 processed | running...RMSE=1.5709
#     · Month 10/20 processed | running...RMSE=1.2530
#     · Month 15/20 processed | running...RMSE=1.1793
#     · Month 20/20 processed | running...RMSE=1.0519
#   - Config 44/1944
#     · Month 5/20 processed | running...RMSE=1.6081
#     · Month 10/20 processed | running...RMSE=1.2829
#     · Month 15/20 processed | running...RMSE=1.2062
#     · Month 20/20 processed | running...RMSE=1.0759
#   - Config 45/1944
#     · Month 5/20 processed | running...RMSE=1.6081
#     · Month 10/20 processed | running...RMSE=1.2829
#     · Month 15/20 processed | running...RMSE=1.2062
#     · Month 20/20 processed | running...RMSE=1.0759
#   - Config 46/1944
#     · Month 5/20 processed | running...RMSE=1.4243
#     · Month 10/20 processed | running...RMSE=1.1070
#     · Month 15/20 processed | running...RMSE=1.0530
#     · Month 20/20 processed | running...RMSE=0.9558
#   - Config 47/1944
#     · Month 5/20 processed | running...RMSE=1.4691
#     · Month 10/20 processed | running...RMSE=1.1397
#     · Month 15/20 processed | running...RMSE=1.0853
#     · Month 20/20 processed | running...RMSE=0.9707
#   - Config 48/1944
#     · Month 5/20 processed | running...RMSE=1.4691
#     · Month 10/20 processed | running...RMSE=1.1397
#     · Month 15/20 processed | running...RMSE=1.0853
#     · Month 20/20 processed | running...RMSE=0.9707
#   - Config 49/1944
#     · Month 5/20 processed | running...RMSE=1.4782
#     · Month 10/20 processed | running...RMSE=1.1690
#     · Month 15/20 processed | running...RMSE=1.1154
#     · Month 20/20 processed | running...RMSE=1.0016
#   - Config 50/1944
#     · Month 5/20 processed | running...RMSE=1.5403
#     · Month 10/20 processed | running...RMSE=1.2179
#     · Month 15/20 processed | running...RMSE=1.1583
#     · Month 20/20 processed | running...RMSE=1.0362
#   - Config 51/1944
#     · Month 5/20 processed | running...RMSE=1.5403
#     · Month 10/20 processed | running...RMSE=1.2179
#     · Month 15/20 processed | running...RMSE=1.1583
#     · Month 20/20 processed | running...RMSE=1.0362
#   - Config 52/1944
#     · Month 5/20 processed | running...RMSE=1.5707
#     · Month 10/20 processed | running...RMSE=1.2533
#     · Month 15/20 processed | running...RMSE=1.1796
#     · Month 20/20 processed | running...RMSE=1.0522
#   - Config 53/1944
#     · Month 5/20 processed | running...RMSE=1.6083
#     · Month 10/20 processed | running...RMSE=1.2830
#     · Month 15/20 processed | running...RMSE=1.2064
#     · Month 20/20 processed | running...RMSE=1.0761
#   - Config 54/1944
#     · Month 5/20 processed | running...RMSE=1.6083
#     · Month 10/20 processed | running...RMSE=1.2830
#     · Month 15/20 processed | running...RMSE=1.2064
#     · Month 20/20 processed | running...RMSE=1.0761
#   - Config 55/1944
#     · Month 5/20 processed | running...RMSE=1.4247
#     · Month 10/20 processed | running...RMSE=1.0993
#     · Month 15/20 processed | running...RMSE=1.0317
#     · Month 20/20 processed | running...RMSE=0.9489
#   - Config 56/1944
#     · Month 5/20 processed | running...RMSE=1.4618
#     · Month 10/20 processed | running...RMSE=1.1302
#     · Month 15/20 processed | running...RMSE=1.0573
#     · Month 20/20 processed | running...RMSE=0.9571
#   - Config 57/1944
#     · Month 5/20 processed | running...RMSE=1.4618
#     · Month 10/20 processed | running...RMSE=1.1302
#     · Month 15/20 processed | running...RMSE=1.0573
#     · Month 20/20 processed | running...RMSE=0.9571
#   - Config 58/1944
#     · Month 5/20 processed | running...RMSE=1.4779
#     · Month 10/20 processed | running...RMSE=1.1689
#     · Month 15/20 processed | running...RMSE=1.1134
#     · Month 20/20 processed | running...RMSE=0.9993
#   - Config 59/1944
#     · Month 5/20 processed | running...RMSE=1.5471
#     · Month 10/20 processed | running...RMSE=1.2241
#     · Month 15/20 processed | running...RMSE=1.1635
#     · Month 20/20 processed | running...RMSE=1.0406
#   - Config 60/1944
#     · Month 5/20 processed | running...RMSE=1.5471
#     · Month 10/20 processed | running...RMSE=1.2241
#     · Month 15/20 processed | running...RMSE=1.1635
#     · Month 20/20 processed | running...RMSE=1.0406
#   - Config 61/1944
#     · Month 5/20 processed | running...RMSE=1.5690
#     · Month 10/20 processed | running...RMSE=1.2514
#     · Month 15/20 processed | running...RMSE=1.1777
#     · Month 20/20 processed | running...RMSE=1.0501
#   - Config 62/1944
#     · Month 5/20 processed | running...RMSE=1.6070
#     · Month 10/20 processed | running...RMSE=1.2822
#     · Month 15/20 processed | running...RMSE=1.2060
#     · Month 20/20 processed | running...RMSE=1.0754
#   - Config 63/1944
#     · Month 5/20 processed | running...RMSE=1.6070
#     · Month 10/20 processed | running...RMSE=1.2822
#     · Month 15/20 processed | running...RMSE=1.2060
#     · Month 20/20 processed | running...RMSE=1.0754
#   - Config 64/1944
#     · Month 5/20 processed | running...RMSE=1.4663
#     · Month 10/20 processed | running...RMSE=1.1497
#     · Month 15/20 processed | running...RMSE=1.0966
#     · Month 20/20 processed | running...RMSE=0.9850
#   - Config 65/1944
#     · Month 5/20 processed | running...RMSE=1.5047
#     · Month 10/20 processed | running...RMSE=1.1803
#     · Month 15/20 processed | running...RMSE=1.1236
#     · Month 20/20 processed | running...RMSE=1.0006
#   - Config 66/1944
#     · Month 5/20 processed | running...RMSE=1.5047
#     · Month 10/20 processed | running...RMSE=1.1803
#     · Month 15/20 processed | running...RMSE=1.1236
#     · Month 20/20 processed | running...RMSE=1.0006
#   - Config 67/1944
#     · Month 5/20 processed | running...RMSE=1.4840
#     · Month 10/20 processed | running...RMSE=1.1719
#     · Month 15/20 processed | running...RMSE=1.1181
#     · Month 20/20 processed | running...RMSE=1.0020
#   - Config 68/1944
#     · Month 5/20 processed | running...RMSE=1.5503
#     · Month 10/20 processed | running...RMSE=1.2266
#     · Month 15/20 processed | running...RMSE=1.1662
#     · Month 20/20 processed | running...RMSE=1.0423
#   - Config 69/1944
#     · Month 5/20 processed | running...RMSE=1.5503
#     · Month 10/20 processed | running...RMSE=1.2266
#     · Month 15/20 processed | running...RMSE=1.1662
#     · Month 20/20 processed | running...RMSE=1.0423
#   - Config 70/1944
#     · Month 5/20 processed | running...RMSE=1.5699
#     · Month 10/20 processed | running...RMSE=1.2518
#     · Month 15/20 processed | running...RMSE=1.1780
#     · Month 20/20 processed | running...RMSE=1.0505
#   - Config 71/1944
#     · Month 5/20 processed | running...RMSE=1.6071
#     · Month 10/20 processed | running...RMSE=1.2823
#     · Month 15/20 processed | running...RMSE=1.2061
#     · Month 20/20 processed | running...RMSE=1.0756
#   - Config 72/1944
#     · Month 5/20 processed | running...RMSE=1.6071
#     · Month 10/20 processed | running...RMSE=1.2823
#     · Month 15/20 processed | running...RMSE=1.2061
#     · Month 20/20 processed | running...RMSE=1.0756
#   - Config 73/1944
#     · Month 5/20 processed | running...RMSE=1.4356
#     · Month 10/20 processed | running...RMSE=1.1144
#     · Month 15/20 processed | running...RMSE=1.0569
#     · Month 20/20 processed | running...RMSE=0.9602
#   - Config 74/1944
#     · Month 5/20 processed | running...RMSE=1.4676
#     · Month 10/20 processed | running...RMSE=1.1391
#     · Month 15/20 processed | running...RMSE=1.0825
#     · Month 20/20 processed | running...RMSE=0.9688
#   - Config 75/1944
#     · Month 5/20 processed | running...RMSE=1.4676
#     · Month 10/20 processed | running...RMSE=1.1391
#     · Month 15/20 processed | running...RMSE=1.0825
#     · Month 20/20 processed | running...RMSE=0.9688
#   - Config 76/1944
#     · Month 5/20 processed | running...RMSE=1.4772
#     · Month 10/20 processed | running...RMSE=1.1683
#     · Month 15/20 processed | running...RMSE=1.1131
#     · Month 20/20 processed | running...RMSE=0.9990
#   - Config 77/1944
#     · Month 5/20 processed | running...RMSE=1.5468
#     · Month 10/20 processed | running...RMSE=1.2239
#     · Month 15/20 processed | running...RMSE=1.1632
#     · Month 20/20 processed | running...RMSE=1.0402
#   - Config 78/1944
#     · Month 5/20 processed | running...RMSE=1.5468
#     · Month 10/20 processed | running...RMSE=1.2239
#     · Month 15/20 processed | running...RMSE=1.1632
#     · Month 20/20 processed | running...RMSE=1.0402
#   - Config 79/1944
#     · Month 5/20 processed | running...RMSE=1.5691
#     · Month 10/20 processed | running...RMSE=1.2515
#     · Month 15/20 processed | running...RMSE=1.1777
#     · Month 20/20 processed | running...RMSE=1.0502
#   - Config 80/1944
#     · Month 5/20 processed | running...RMSE=1.6070
#     · Month 10/20 processed | running...RMSE=1.2822
#     · Month 15/20 processed | running...RMSE=1.2060
#     · Month 20/20 processed | running...RMSE=1.0754
#   - Config 81/1944
#     · Month 5/20 processed | running...RMSE=1.6070
#     · Month 10/20 processed | running...RMSE=1.2822
#     · Month 15/20 processed | running...RMSE=1.2060
#     · Month 20/20 processed | running...RMSE=1.0754
#   - Config 82/1944
#     · Month 5/20 processed | running...RMSE=1.4365
#     · Month 10/20 processed | running...RMSE=1.1092
#     · Month 15/20 processed | running...RMSE=1.0309
#     · Month 20/20 processed | running...RMSE=0.9553
#   - Config 83/1944
#     · Month 5/20 processed | running...RMSE=1.4640
#     · Month 10/20 processed | running...RMSE=1.1302
#     · Month 15/20 processed | running...RMSE=1.0619
#     · Month 20/20 processed | running...RMSE=0.9604
#   - Config 84/1944
#     · Month 5/20 processed | running...RMSE=1.4640
#     · Month 10/20 processed | running...RMSE=1.1302
#     · Month 15/20 processed | running...RMSE=1.0619
#     · Month 20/20 processed | running...RMSE=0.9604
#   - Config 85/1944
#     · Month 5/20 processed | running...RMSE=1.4817
#     · Month 10/20 processed | running...RMSE=1.1708
#     · Month 15/20 processed | running...RMSE=1.1162
#     · Month 20/20 processed | running...RMSE=1.0013
#   - Config 86/1944
#     · Month 5/20 processed | running...RMSE=1.5413
#     · Month 10/20 processed | running...RMSE=1.2180
#     · Month 15/20 processed | running...RMSE=1.1577
#     · Month 20/20 processed | running...RMSE=1.0343
#   - Config 87/1944
#     · Month 5/20 processed | running...RMSE=1.5413
#     · Month 10/20 processed | running...RMSE=1.2180
#     · Month 15/20 processed | running...RMSE=1.1577
#     · Month 20/20 processed | running...RMSE=1.0343
#   - Config 88/1944
#     · Month 5/20 processed | running...RMSE=1.5601
#     · Month 10/20 processed | running...RMSE=1.2415
#     · Month 15/20 processed | running...RMSE=1.1700
#     · Month 20/20 processed | running...RMSE=1.0432
#   - Config 89/1944
#     · Month 5/20 processed | running...RMSE=1.5975
#     · Month 10/20 processed | running...RMSE=1.2712
#     · Month 15/20 processed | running...RMSE=1.1961
#     · Month 20/20 processed | running...RMSE=1.0646
#   - Config 90/1944
#     · Month 5/20 processed | running...RMSE=1.5975
#     · Month 10/20 processed | running...RMSE=1.2712
#     · Month 15/20 processed | running...RMSE=1.1961
#     · Month 20/20 processed | running...RMSE=1.0646
#   - Config 91/1944
#     · Month 5/20 processed | running...RMSE=1.4679
#     · Month 10/20 processed | running...RMSE=1.1497
#     · Month 15/20 processed | running...RMSE=1.0974
#     · Month 20/20 processed | running...RMSE=0.9862
#   - Config 92/1944
#     · Month 5/20 processed | running...RMSE=1.5023
#     · Month 10/20 processed | running...RMSE=1.1729
#     · Month 15/20 processed | running...RMSE=1.1194
#     · Month 20/20 processed | running...RMSE=0.9971
#   - Config 93/1944
#     · Month 5/20 processed | running...RMSE=1.5023
#     · Month 10/20 processed | running...RMSE=1.1729
#     · Month 15/20 processed | running...RMSE=1.1194
#     · Month 20/20 processed | running...RMSE=0.9971
#   - Config 94/1944
#     · Month 5/20 processed | running...RMSE=1.4886
#     · Month 10/20 processed | running...RMSE=1.1740
#     · Month 15/20 processed | running...RMSE=1.1221
#     · Month 20/20 processed | running...RMSE=1.0078
#   - Config 95/1944
#     · Month 5/20 processed | running...RMSE=1.5425
#     · Month 10/20 processed | running...RMSE=1.2191
#     · Month 15/20 processed | running...RMSE=1.1595
#     · Month 20/20 processed | running...RMSE=1.0351
#   - Config 96/1944
#     · Month 5/20 processed | running...RMSE=1.5425
#     · Month 10/20 processed | running...RMSE=1.2191
#     · Month 15/20 processed | running...RMSE=1.1595
#     · Month 20/20 processed | running...RMSE=1.0351
#   - Config 97/1944
#     · Month 5/20 processed | running...RMSE=1.5608
#     · Month 10/20 processed | running...RMSE=1.2416
#     · Month 15/20 processed | running...RMSE=1.1698
#     · Month 20/20 processed | running...RMSE=1.0426
#   - Config 98/1944
#     · Month 5/20 processed | running...RMSE=1.5975
#     · Month 10/20 processed | running...RMSE=1.2713
#     · Month 15/20 processed | running...RMSE=1.1962
#     · Month 20/20 processed | running...RMSE=1.0646
#   - Config 99/1944
#     · Month 5/20 processed | running...RMSE=1.5975
#     · Month 10/20 processed | running...RMSE=1.2713
#     · Month 15/20 processed | running...RMSE=1.1962
#     · Month 20/20 processed | running...RMSE=1.0646
#   - Config 100/1944
#     · Month 5/20 processed | running...RMSE=1.4280
#     · Month 10/20 processed | running...RMSE=1.1103
#     · Month 15/20 processed | running...RMSE=1.0560
#     · Month 20/20 processed | running...RMSE=0.9608
#   - Config 101/1944
#     · Month 5/20 processed | running...RMSE=1.4749
#     · Month 10/20 processed | running...RMSE=1.1421
#     · Month 15/20 processed | running...RMSE=1.0861
#     · Month 20/20 processed | running...RMSE=0.9714
#   - Config 102/1944
#     · Month 5/20 processed | running...RMSE=1.4749
#     · Month 10/20 processed | running...RMSE=1.1421
#     · Month 15/20 processed | running...RMSE=1.0861
#     · Month 20/20 processed | running...RMSE=0.9714
#   - Config 103/1944
#     · Month 5/20 processed | running...RMSE=1.4822
#     · Month 10/20 processed | running...RMSE=1.1713
#     · Month 15/20 processed | running...RMSE=1.1171
#     · Month 20/20 processed | running...RMSE=1.0025
#   - Config 104/1944
#     · Month 5/20 processed | running...RMSE=1.5417
#     · Month 10/20 processed | running...RMSE=1.2182
#     · Month 15/20 processed | running...RMSE=1.1582
#     · Month 20/20 processed | running...RMSE=1.0345
#   - Config 105/1944
#     · Month 5/20 processed | running...RMSE=1.5417
#     · Month 10/20 processed | running...RMSE=1.2182
#     · Month 15/20 processed | running...RMSE=1.1582
#     · Month 20/20 processed | running...RMSE=1.0345
#   - Config 106/1944
#     · Month 5/20 processed | running...RMSE=1.5601
#     · Month 10/20 processed | running...RMSE=1.2415
#     · Month 15/20 processed | running...RMSE=1.1700
#     · Month 20/20 processed | running...RMSE=1.0432
#   - Config 107/1944
#     · Month 5/20 processed | running...RMSE=1.5975
#     · Month 10/20 processed | running...RMSE=1.2712
#     · Month 15/20 processed | running...RMSE=1.1961
#     · Month 20/20 processed | running...RMSE=1.0646
#   - Config 108/1944
#     · Month 5/20 processed | running...RMSE=1.5975
#     · Month 10/20 processed | running...RMSE=1.2712
#     · Month 15/20 processed | running...RMSE=1.1961
#     · Month 20/20 processed | running...RMSE=1.0646
#   - Config 109/1944
#     · Month 5/20 processed | running...RMSE=1.4392
#     · Month 10/20 processed | running...RMSE=1.1139
#     · Month 15/20 processed | running...RMSE=1.0319
#     · Month 20/20 processed | running...RMSE=0.9520
#   - Config 110/1944
#     · Month 5/20 processed | running...RMSE=1.4611
#     · Month 10/20 processed | running...RMSE=1.1275
#     · Month 15/20 processed | running...RMSE=1.0560
#     · Month 20/20 processed | running...RMSE=0.9574
#   - Config 111/1944
#     · Month 5/20 processed | running...RMSE=1.4611
#     · Month 10/20 processed | running...RMSE=1.1275
#     · Month 15/20 processed | running...RMSE=1.0560
#     · Month 20/20 processed | running...RMSE=0.9574
#   - Config 112/1944
#     · Month 5/20 processed | running...RMSE=1.4770
#     · Month 10/20 processed | running...RMSE=1.1675
#     · Month 15/20 processed | running...RMSE=1.1129
#     · Month 20/20 processed | running...RMSE=0.9986
#   - Config 113/1944
#     · Month 5/20 processed | running...RMSE=1.5334
#     · Month 10/20 processed | running...RMSE=1.2115
#     · Month 15/20 processed | running...RMSE=1.1523
#     · Month 20/20 processed | running...RMSE=1.0295
#   - Config 114/1944
#     · Month 5/20 processed | running...RMSE=1.5334
#     · Month 10/20 processed | running...RMSE=1.2115
#     · Month 15/20 processed | running...RMSE=1.1523
#     · Month 20/20 processed | running...RMSE=1.0295
#   - Config 115/1944
#     · Month 5/20 processed | running...RMSE=1.5588
#     · Month 10/20 processed | running...RMSE=1.2423
#     · Month 15/20 processed | running...RMSE=1.1699
#     · Month 20/20 processed | running...RMSE=1.0423
#   - Config 116/1944
#     · Month 5/20 processed | running...RMSE=1.5948
#     · Month 10/20 processed | running...RMSE=1.2693
#     · Month 15/20 processed | running...RMSE=1.1947
#     · Month 20/20 processed | running...RMSE=1.0636
#   - Config 117/1944
#     · Month 5/20 processed | running...RMSE=1.5948
#     · Month 10/20 processed | running...RMSE=1.2693
#     · Month 15/20 processed | running...RMSE=1.1947
#     · Month 20/20 processed | running...RMSE=1.0636
#   - Config 118/1944
#     · Month 5/20 processed | running...RMSE=1.4691
#     · Month 10/20 processed | running...RMSE=1.1477
#     · Month 15/20 processed | running...RMSE=1.0960
#     · Month 20/20 processed | running...RMSE=0.9847
#   - Config 119/1944
#     · Month 5/20 processed | running...RMSE=1.5036
#     · Month 10/20 processed | running...RMSE=1.1765
#     · Month 15/20 processed | running...RMSE=1.1214
#     · Month 20/20 processed | running...RMSE=0.9986
#   - Config 120/1944
#     · Month 5/20 processed | running...RMSE=1.5036
#     · Month 10/20 processed | running...RMSE=1.1765
#     · Month 15/20 processed | running...RMSE=1.1214
#     · Month 20/20 processed | running...RMSE=0.9986
#   - Config 121/1944
#     · Month 5/20 processed | running...RMSE=1.4815
#     · Month 10/20 processed | running...RMSE=1.1697
#     · Month 15/20 processed | running...RMSE=1.1171
#     · Month 20/20 processed | running...RMSE=1.0020
#   - Config 122/1944
#     · Month 5/20 processed | running...RMSE=1.5359
#     · Month 10/20 processed | running...RMSE=1.2132
#     · Month 15/20 processed | running...RMSE=1.1547
#     · Month 20/20 processed | running...RMSE=1.0308
#   - Config 123/1944
#     · Month 5/20 processed | running...RMSE=1.5359
#     · Month 10/20 processed | running...RMSE=1.2132
#     · Month 15/20 processed | running...RMSE=1.1547
#     · Month 20/20 processed | running...RMSE=1.0308
#   - Config 124/1944
#     · Month 5/20 processed | running...RMSE=1.5597
#     · Month 10/20 processed | running...RMSE=1.2425
#     · Month 15/20 processed | running...RMSE=1.1702
#     · Month 20/20 processed | running...RMSE=1.0424
#   - Config 125/1944
#     · Month 5/20 processed | running...RMSE=1.5946
#     · Month 10/20 processed | running...RMSE=1.2692
#     · Month 15/20 processed | running...RMSE=1.1946
#     · Month 20/20 processed | running...RMSE=1.0635
#   - Config 126/1944
#     · Month 5/20 processed | running...RMSE=1.5946
#     · Month 10/20 processed | running...RMSE=1.2692
#     · Month 15/20 processed | running...RMSE=1.1946
#     · Month 20/20 processed | running...RMSE=1.0635
#   - Config 127/1944
#     · Month 5/20 processed | running...RMSE=1.4367
#     · Month 10/20 processed | running...RMSE=1.1144
#     · Month 15/20 processed | running...RMSE=1.0559
#     · Month 20/20 processed | running...RMSE=0.9609
#   - Config 128/1944
#     · Month 5/20 processed | running...RMSE=1.4692
#     · Month 10/20 processed | running...RMSE=1.1398
#     · Month 15/20 processed | running...RMSE=1.0853
#     · Month 20/20 processed | running...RMSE=0.9713
#   - Config 129/1944
#     · Month 5/20 processed | running...RMSE=1.4692
#     · Month 10/20 processed | running...RMSE=1.1398
#     · Month 15/20 processed | running...RMSE=1.0853
#     · Month 20/20 processed | running...RMSE=0.9713
#   - Config 130/1944
#     · Month 5/20 processed | running...RMSE=1.4778
#     · Month 10/20 processed | running...RMSE=1.1679
#     · Month 15/20 processed | running...RMSE=1.1135
#     · Month 20/20 processed | running...RMSE=0.9995
#   - Config 131/1944
#     · Month 5/20 processed | running...RMSE=1.5334
#     · Month 10/20 processed | running...RMSE=1.2115
#     · Month 15/20 processed | running...RMSE=1.1524
#     · Month 20/20 processed | running...RMSE=1.0293
#   - Config 132/1944
#     · Month 5/20 processed | running...RMSE=1.5334
#     · Month 10/20 processed | running...RMSE=1.2115
#     · Month 15/20 processed | running...RMSE=1.1524
#     · Month 20/20 processed | running...RMSE=1.0293
#   - Config 133/1944
#     · Month 5/20 processed | running...RMSE=1.5588
#     · Month 10/20 processed | running...RMSE=1.2423
#     · Month 15/20 processed | running...RMSE=1.1699
#     · Month 20/20 processed | running...RMSE=1.0423
#   - Config 134/1944
#     · Month 5/20 processed | running...RMSE=1.5948
#     · Month 10/20 processed | running...RMSE=1.2693
#     · Month 15/20 processed | running...RMSE=1.1947
#     · Month 20/20 processed | running...RMSE=1.0636
#   - Config 135/1944
#     · Month 5/20 processed | running...RMSE=1.5948
#     · Month 10/20 processed | running...RMSE=1.2693
#     · Month 15/20 processed | running...RMSE=1.1947
#     · Month 20/20 processed | running...RMSE=1.0636
#   - Config 136/1944
#     · Month 5/20 processed | running...RMSE=1.4416
#     · Month 10/20 processed | running...RMSE=1.1134
#     · Month 15/20 processed | running...RMSE=1.0325
#     · Month 20/20 processed | running...RMSE=0.9515
#   - Config 137/1944
#     · Month 5/20 processed | running...RMSE=1.4618
#     · Month 10/20 processed | running...RMSE=1.1302
#     · Month 15/20 processed | running...RMSE=1.0573
#     · Month 20/20 processed | running...RMSE=0.9571
#   - Config 138/1944
#     · Month 5/20 processed | running...RMSE=1.4618
#     · Month 10/20 processed | running...RMSE=1.1302
#     · Month 15/20 processed | running...RMSE=1.0573
#     · Month 20/20 processed | running...RMSE=0.9571
#   - Config 139/1944
#     · Month 5/20 processed | running...RMSE=1.4748
#     · Month 10/20 processed | running...RMSE=1.1662
#     · Month 15/20 processed | running...RMSE=1.1103
#     · Month 20/20 processed | running...RMSE=0.9960
#   - Config 140/1944
#     · Month 5/20 processed | running...RMSE=1.5395
#     · Month 10/20 processed | running...RMSE=1.2171
#     · Month 15/20 processed | running...RMSE=1.1570
#     · Month 20/20 processed | running...RMSE=1.0332
#   - Config 141/1944
#     · Month 5/20 processed | running...RMSE=1.5395
#     · Month 10/20 processed | running...RMSE=1.2171
#     · Month 15/20 processed | running...RMSE=1.1570
#     · Month 20/20 processed | running...RMSE=1.0332
#   - Config 142/1944
#     · Month 5/20 processed | running...RMSE=1.5579
#     · Month 10/20 processed | running...RMSE=1.2410
#     · Month 15/20 processed | running...RMSE=1.1688
#     · Month 20/20 processed | running...RMSE=1.0410
#   - Config 143/1944
#     · Month 5/20 processed | running...RMSE=1.5934
#     · Month 10/20 processed | running...RMSE=1.2685
#     · Month 15/20 processed | running...RMSE=1.1943
#     · Month 20/20 processed | running...RMSE=1.0630
#   - Config 144/1944
#     · Month 5/20 processed | running...RMSE=1.5934
#     · Month 10/20 processed | running...RMSE=1.2685
#     · Month 15/20 processed | running...RMSE=1.1943
#     · Month 20/20 processed | running...RMSE=1.0630
#   - Config 145/1944
#     · Month 5/20 processed | running...RMSE=1.4651
#     · Month 10/20 processed | running...RMSE=1.1447
#     · Month 15/20 processed | running...RMSE=1.0934
#     · Month 20/20 processed | running...RMSE=0.9818
#   - Config 146/1944
#     · Month 5/20 processed | running...RMSE=1.5034
#     · Month 10/20 processed | running...RMSE=1.1790
#     · Month 15/20 processed | running...RMSE=1.1224
#     · Month 20/20 processed | running...RMSE=0.9997
#   - Config 147/1944
#     · Month 5/20 processed | running...RMSE=1.5034
#     · Month 10/20 processed | running...RMSE=1.1790
#     · Month 15/20 processed | running...RMSE=1.1224
#     · Month 20/20 processed | running...RMSE=0.9997
#   - Config 148/1944
#     · Month 5/20 processed | running...RMSE=1.4789
#     · Month 10/20 processed | running...RMSE=1.1675
#     · Month 15/20 processed | running...RMSE=1.1142
#     · Month 20/20 processed | running...RMSE=0.9992
#   - Config 149/1944
#     · Month 5/20 processed | running...RMSE=1.5423
#     · Month 10/20 processed | running...RMSE=1.2192
#     · Month 15/20 processed | running...RMSE=1.1594
#     · Month 20/20 processed | running...RMSE=1.0348
#   - Config 150/1944
#     · Month 5/20 processed | running...RMSE=1.5423
#     · Month 10/20 processed | running...RMSE=1.2192
#     · Month 15/20 processed | running...RMSE=1.1594
#     · Month 20/20 processed | running...RMSE=1.0348
#   - Config 151/1944
#     · Month 5/20 processed | running...RMSE=1.5596
#     · Month 10/20 processed | running...RMSE=1.2420
#     · Month 15/20 processed | running...RMSE=1.1697
#     · Month 20/20 processed | running...RMSE=1.0418
#   - Config 152/1944
#     · Month 5/20 processed | running...RMSE=1.5937
#     · Month 10/20 processed | running...RMSE=1.2687
#     · Month 15/20 processed | running...RMSE=1.1945
#     · Month 20/20 processed | running...RMSE=1.0632
#   - Config 153/1944
#     · Month 5/20 processed | running...RMSE=1.5937
#     · Month 10/20 processed | running...RMSE=1.2687
#     · Month 15/20 processed | running...RMSE=1.1945
#     · Month 20/20 processed | running...RMSE=1.0632
#   - Config 154/1944
#     · Month 5/20 processed | running...RMSE=1.4430
#     · Month 10/20 processed | running...RMSE=1.1175
#     · Month 15/20 processed | running...RMSE=1.0594
#     · Month 20/20 processed | running...RMSE=0.9660
#   - Config 155/1944
#     · Month 5/20 processed | running...RMSE=1.4674
#     · Month 10/20 processed | running...RMSE=1.1391
#     · Month 15/20 processed | running...RMSE=1.0825
#     · Month 20/20 processed | running...RMSE=0.9695
#   - Config 156/1944
#     · Month 5/20 processed | running...RMSE=1.4674
#     · Month 10/20 processed | running...RMSE=1.1391
#     · Month 15/20 processed | running...RMSE=1.0825
#     · Month 20/20 processed | running...RMSE=0.9695
#   - Config 157/1944
#     · Month 5/20 processed | running...RMSE=1.4751
#     · Month 10/20 processed | running...RMSE=1.1662
#     · Month 15/20 processed | running...RMSE=1.1107
#     · Month 20/20 processed | running...RMSE=0.9967
#   - Config 158/1944
#     · Month 5/20 processed | running...RMSE=1.5392
#     · Month 10/20 processed | running...RMSE=1.2169
#     · Month 15/20 processed | running...RMSE=1.1568
#     · Month 20/20 processed | running...RMSE=1.0328
#   - Config 159/1944
#     · Month 5/20 processed | running...RMSE=1.5392
#     · Month 10/20 processed | running...RMSE=1.2169
#     · Month 15/20 processed | running...RMSE=1.1568
#     · Month 20/20 processed | running...RMSE=1.0328
#   - Config 160/1944
#     · Month 5/20 processed | running...RMSE=1.5580
#     · Month 10/20 processed | running...RMSE=1.2411
#     · Month 15/20 processed | running...RMSE=1.1688
#     · Month 20/20 processed | running...RMSE=1.0410
#   - Config 161/1944
#     · Month 5/20 processed | running...RMSE=1.5934
#     · Month 10/20 processed | running...RMSE=1.2685
#     · Month 15/20 processed | running...RMSE=1.1943
#     · Month 20/20 processed | running...RMSE=1.0630
#   - Config 162/1944
#     · Month 5/20 processed | running...RMSE=1.5934
#     · Month 10/20 processed | running...RMSE=1.2685
#     · Month 15/20 processed | running...RMSE=1.1943
#     · Month 20/20 processed | running...RMSE=1.0630
#   - Config 163/1944
#     · Month 5/20 processed | running...RMSE=1.5275
#     · Month 10/20 processed | running...RMSE=1.2079
#     · Month 15/20 processed | running...RMSE=1.1313
#     · Month 20/20 processed | running...RMSE=1.0691
#   - Config 164/1944
#     · Month 5/20 processed | running...RMSE=1.5252
#     · Month 10/20 processed | running...RMSE=1.1971
#     · Month 15/20 processed | running...RMSE=1.1380
#     · Month 20/20 processed | running...RMSE=1.0820
#   - Config 165/1944
#     · Month 5/20 processed | running...RMSE=1.5252
#     · Month 10/20 processed | running...RMSE=1.1971
#     · Month 15/20 processed | running...RMSE=1.1380
#     · Month 20/20 processed | running...RMSE=1.0820
#   - Config 166/1944
#     · Month 5/20 processed | running...RMSE=1.4668
#     · Month 10/20 processed | running...RMSE=1.1680
#     · Month 15/20 processed | running...RMSE=1.1194
#     · Month 20/20 processed | running...RMSE=1.0095
#   - Config 167/1944
#     · Month 5/20 processed | running...RMSE=1.5401
#     · Month 10/20 processed | running...RMSE=1.2223
#     · Month 15/20 processed | running...RMSE=1.1634
#     · Month 20/20 processed | running...RMSE=1.0434
#   - Config 168/1944
#     · Month 5/20 processed | running...RMSE=1.5401
#     · Month 10/20 processed | running...RMSE=1.2223
#     · Month 15/20 processed | running...RMSE=1.1634
#     · Month 20/20 processed | running...RMSE=1.0434
#   - Config 169/1944
#     · Month 5/20 processed | running...RMSE=1.5746
#     · Month 10/20 processed | running...RMSE=1.2567
#     · Month 15/20 processed | running...RMSE=1.1837
#     · Month 20/20 processed | running...RMSE=1.0584
#   - Config 170/1944
#     · Month 5/20 processed | running...RMSE=1.6134
#     · Month 10/20 processed | running...RMSE=1.2876
#     · Month 15/20 processed | running...RMSE=1.2113
#     · Month 20/20 processed | running...RMSE=1.0826
#   - Config 171/1944
#     · Month 5/20 processed | running...RMSE=1.6134
#     · Month 10/20 processed | running...RMSE=1.2876
#     · Month 15/20 processed | running...RMSE=1.2113
#     · Month 20/20 processed | running...RMSE=1.0826
#   - Config 172/1944
#     · Month 5/20 processed | running...RMSE=1.4835
#     · Month 10/20 processed | running...RMSE=1.1692
#     · Month 15/20 processed | running...RMSE=1.1141
#     · Month 20/20 processed | running...RMSE=1.0064
#   - Config 173/1944
#     · Month 5/20 processed | running...RMSE=1.5087
#     · Month 10/20 processed | running...RMSE=1.1869
#     · Month 15/20 processed | running...RMSE=1.1329
#     · Month 20/20 processed | running...RMSE=1.0199
#   - Config 174/1944
#     · Month 5/20 processed | running...RMSE=1.5087
#     · Month 10/20 processed | running...RMSE=1.1869
#     · Month 15/20 processed | running...RMSE=1.1329
#     · Month 20/20 processed | running...RMSE=1.0199
#   - Config 175/1944
#     · Month 5/20 processed | running...RMSE=1.4757
#     · Month 10/20 processed | running...RMSE=1.1715
#     · Month 15/20 processed | running...RMSE=1.1213
#     · Month 20/20 processed | running...RMSE=1.0087
#   - Config 176/1944
#     · Month 5/20 processed | running...RMSE=1.5453
#     · Month 10/20 processed | running...RMSE=1.2245
#     · Month 15/20 processed | running...RMSE=1.1650
#     · Month 20/20 processed | running...RMSE=1.0448
#   - Config 177/1944
#     · Month 5/20 processed | running...RMSE=1.5453
#     · Month 10/20 processed | running...RMSE=1.2245
#     · Month 15/20 processed | running...RMSE=1.1650
#     · Month 20/20 processed | running...RMSE=1.0448
#   - Config 178/1944
#     · Month 5/20 processed | running...RMSE=1.5773
#     · Month 10/20 processed | running...RMSE=1.2585
#     · Month 15/20 processed | running...RMSE=1.1853
#     · Month 20/20 processed | running...RMSE=1.0594
#   - Config 179/1944
#     · Month 5/20 processed | running...RMSE=1.6138
#     · Month 10/20 processed | running...RMSE=1.2877
#     · Month 15/20 processed | running...RMSE=1.2116
#     · Month 20/20 processed | running...RMSE=1.0828
#   - Config 180/1944
#     · Month 5/20 processed | running...RMSE=1.6138
#     · Month 10/20 processed | running...RMSE=1.2877
#     · Month 15/20 processed | running...RMSE=1.2116
#     · Month 20/20 processed | running...RMSE=1.0828
#   - Config 181/1944
#     · Month 5/20 processed | running...RMSE=1.4897
#     · Month 10/20 processed | running...RMSE=1.1766
#     · Month 15/20 processed | running...RMSE=1.1170
#     · Month 20/20 processed | running...RMSE=1.0376
#   - Config 182/1944
#     · Month 5/20 processed | running...RMSE=1.4805
#     · Month 10/20 processed | running...RMSE=1.1676
#     · Month 15/20 processed | running...RMSE=1.1245
#     · Month 20/20 processed | running...RMSE=1.0386
#   - Config 183/1944
#     · Month 5/20 processed | running...RMSE=1.4805
#     · Month 10/20 processed | running...RMSE=1.1676
#     · Month 15/20 processed | running...RMSE=1.1245
#     · Month 20/20 processed | running...RMSE=1.0386
#   - Config 184/1944
#     · Month 5/20 processed | running...RMSE=1.4676
#     · Month 10/20 processed | running...RMSE=1.1679
#     · Month 15/20 processed | running...RMSE=1.1196
#     · Month 20/20 processed | running...RMSE=1.0112
#   - Config 185/1944
#     · Month 5/20 processed | running...RMSE=1.5401
#     · Month 10/20 processed | running...RMSE=1.2223
#     · Month 15/20 processed | running...RMSE=1.1632
#     · Month 20/20 processed | running...RMSE=1.0432
#   - Config 186/1944
#     · Month 5/20 processed | running...RMSE=1.5401
#     · Month 10/20 processed | running...RMSE=1.2223
#     · Month 15/20 processed | running...RMSE=1.1632
#     · Month 20/20 processed | running...RMSE=1.0432
#   - Config 187/1944
#     · Month 5/20 processed | running...RMSE=1.5746
#     · Month 10/20 processed | running...RMSE=1.2567
#     · Month 15/20 processed | running...RMSE=1.1837
#     · Month 20/20 processed | running...RMSE=1.0584
#   - Config 188/1944
#     · Month 5/20 processed | running...RMSE=1.6134
#     · Month 10/20 processed | running...RMSE=1.2876
#     · Month 15/20 processed | running...RMSE=1.2113
#     · Month 20/20 processed | running...RMSE=1.0826
#   - Config 189/1944
#     · Month 5/20 processed | running...RMSE=1.6134
#     · Month 10/20 processed | running...RMSE=1.2876
#     · Month 15/20 processed | running...RMSE=1.2113
#     · Month 20/20 processed | running...RMSE=1.0826
#   - Config 190/1944
#     · Month 5/20 processed | running...RMSE=1.5168
#     · Month 10/20 processed | running...RMSE=1.1980
#     · Month 15/20 processed | running...RMSE=1.1254
#     · Month 20/20 processed | running...RMSE=1.0643
#   - Config 191/1944
#     · Month 5/20 processed | running...RMSE=1.5235
#     · Month 10/20 processed | running...RMSE=1.1993
#     · Month 15/20 processed | running...RMSE=1.1319
#     · Month 20/20 processed | running...RMSE=1.0633
#   - Config 192/1944
#     · Month 5/20 processed | running...RMSE=1.5235
#     · Month 10/20 processed | running...RMSE=1.1993
#     · Month 15/20 processed | running...RMSE=1.1319
#     · Month 20/20 processed | running...RMSE=1.0633
#   - Config 193/1944
#     · Month 5/20 processed | running...RMSE=1.4697
#     · Month 10/20 processed | running...RMSE=1.1688
#     · Month 15/20 processed | running...RMSE=1.1188
#     · Month 20/20 processed | running...RMSE=1.0088
#   - Config 194/1944
#     · Month 5/20 processed | running...RMSE=1.5369
#     · Month 10/20 processed | running...RMSE=1.2192
#     · Month 15/20 processed | running...RMSE=1.1618
#     · Month 20/20 processed | running...RMSE=1.0414
#   - Config 195/1944
#     · Month 5/20 processed | running...RMSE=1.5369
#     · Month 10/20 processed | running...RMSE=1.2192
#     · Month 15/20 processed | running...RMSE=1.1618
#     · Month 20/20 processed | running...RMSE=1.0414
#   - Config 196/1944
#     · Month 5/20 processed | running...RMSE=1.5764
#     · Month 10/20 processed | running...RMSE=1.2584
#     · Month 15/20 processed | running...RMSE=1.1858
#     · Month 20/20 processed | running...RMSE=1.0600
#   - Config 197/1944
#     · Month 5/20 processed | running...RMSE=1.6154
#     · Month 10/20 processed | running...RMSE=1.2889
#     · Month 15/20 processed | running...RMSE=1.2124
#     · Month 20/20 processed | running...RMSE=1.0828
#   - Config 198/1944
#     · Month 5/20 processed | running...RMSE=1.6154
#     · Month 10/20 processed | running...RMSE=1.2889
#     · Month 15/20 processed | running...RMSE=1.2124
#     · Month 20/20 processed | running...RMSE=1.0828
#   - Config 199/1944
#     · Month 5/20 processed | running...RMSE=1.4759
#     · Month 10/20 processed | running...RMSE=1.1647
#     · Month 15/20 processed | running...RMSE=1.1100
#     · Month 20/20 processed | running...RMSE=1.0019
#   - Config 200/1944
#     · Month 5/20 processed | running...RMSE=1.5071
#     · Month 10/20 processed | running...RMSE=1.1854
#     · Month 15/20 processed | running...RMSE=1.1321
#     · Month 20/20 processed | running...RMSE=1.0184
#   - Config 201/1944
#     · Month 5/20 processed | running...RMSE=1.5071
#     · Month 10/20 processed | running...RMSE=1.1854
#     · Month 15/20 processed | running...RMSE=1.1321
#     · Month 20/20 processed | running...RMSE=1.0184
#   - Config 202/1944
#     · Month 5/20 processed | running...RMSE=1.4771
#     · Month 10/20 processed | running...RMSE=1.1721
#     · Month 15/20 processed | running...RMSE=1.1228
#     · Month 20/20 processed | running...RMSE=1.0106
#   - Config 203/1944
#     · Month 5/20 processed | running...RMSE=1.5412
#     · Month 10/20 processed | running...RMSE=1.2211
#     · Month 15/20 processed | running...RMSE=1.1632
#     · Month 20/20 processed | running...RMSE=1.0425
#   - Config 204/1944
#     · Month 5/20 processed | running...RMSE=1.5412
#     · Month 10/20 processed | running...RMSE=1.2211
#     · Month 15/20 processed | running...RMSE=1.1632
#     · Month 20/20 processed | running...RMSE=1.0425
#   - Config 205/1944
#     · Month 5/20 processed | running...RMSE=1.5778
#     · Month 10/20 processed | running...RMSE=1.2591
#     · Month 15/20 processed | running...RMSE=1.1863
#     · Month 20/20 processed | running...RMSE=1.0601
#   - Config 206/1944
#     · Month 5/20 processed | running...RMSE=1.6158
#     · Month 10/20 processed | running...RMSE=1.2891
#     · Month 15/20 processed | running...RMSE=1.2126
#     · Month 20/20 processed | running...RMSE=1.0830
#   - Config 207/1944
#     · Month 5/20 processed | running...RMSE=1.6158
#     · Month 10/20 processed | running...RMSE=1.2891
#     · Month 15/20 processed | running...RMSE=1.2126
#     · Month 20/20 processed | running...RMSE=1.0830
#   - Config 208/1944
#     · Month 5/20 processed | running...RMSE=1.4917
#     · Month 10/20 processed | running...RMSE=1.1793
#     · Month 15/20 processed | running...RMSE=1.1181
#     · Month 20/20 processed | running...RMSE=1.0379
#   - Config 209/1944
#     · Month 5/20 processed | running...RMSE=1.4810
#     · Month 10/20 processed | running...RMSE=1.1676
#     · Month 15/20 processed | running...RMSE=1.1153
#     · Month 20/20 processed | running...RMSE=1.0256
#   - Config 210/1944
#     · Month 5/20 processed | running...RMSE=1.4810
#     · Month 10/20 processed | running...RMSE=1.1676
#     · Month 15/20 processed | running...RMSE=1.1153
#     · Month 20/20 processed | running...RMSE=1.0256
#   - Config 211/1944
#     · Month 5/20 processed | running...RMSE=1.4679
# ...
#     · Month 10/20 processed | running...RMSE=0.9566
#     · Month 15/20 processed | running...RMSE=2.1619
#     · Month 20/20 processed | running...RMSE=2.2291
#   - Config 194/195
#     · Month 5/20 processed | running...RMSE=0.8764
#     · Month 10/20 processed | running...RMSE=1.0045
#     · Month 15/20 processed | running...RMSE=2.2490
#     · Month 20/20 processed | running...RMSE=2.3127
#   - Config 195/195
#     · Month 5/20 processed | running...RMSE=0.8688
#     · Month 10/20 processed | running...RMSE=1.0462
#     · Month 15/20 processed | running...RMSE=2.3539
#     · Month 20/20 processed | running...RMSE=2.4007
# [Stage A][Block 2] kept 20 configs (floor=5).
# [Stage A][Block 3] train_end=220, OOS=221-240 | configs=20
#   - Config 1/20
#     · Month 5/20 processed | running...RMSE=1.4385
#     · Month 10/20 processed | running...RMSE=1.3664
#     · Month 15/20 processed | running...RMSE=1.2967
#     · Month 20/20 processed | running...RMSE=1.1967
#   - Config 2/20
#     · Month 5/20 processed | running...RMSE=1.5400
#     · Month 10/20 processed | running...RMSE=1.4433
#     · Month 15/20 processed | running...RMSE=1.3530
#     · Month 20/20 processed | running...RMSE=1.2346
#   - Config 3/20
#     · Month 5/20 processed | running...RMSE=1.4659
#     · Month 10/20 processed | running...RMSE=1.3905
#     · Month 15/20 processed | running...RMSE=1.3184
#     · Month 20/20 processed | running...RMSE=1.2159
#   - Config 4/20
#     · Month 5/20 processed | running...RMSE=1.5354
#     · Month 10/20 processed | running...RMSE=1.4423
#     · Month 15/20 processed | running...RMSE=1.3607
#     · Month 20/20 processed | running...RMSE=1.2453
#   - Config 5/20
#     · Month 5/20 processed | running...RMSE=1.5088
#     · Month 10/20 processed | running...RMSE=1.4216
#     · Month 15/20 processed | running...RMSE=1.3431
#     · Month 20/20 processed | running...RMSE=1.2349
#   - Config 6/20
#     · Month 5/20 processed | running...RMSE=1.5454
#     · Month 10/20 processed | running...RMSE=1.4548
#     · Month 15/20 processed | running...RMSE=1.3700
#     · Month 20/20 processed | running...RMSE=1.2514
#   - Config 7/20
#     · Month 5/20 processed | running...RMSE=1.5377
#     · Month 10/20 processed | running...RMSE=1.4795
#     · Month 15/20 processed | running...RMSE=1.3881
#     · Month 20/20 processed | running...RMSE=1.2700
#   - Config 8/20
#     · Month 5/20 processed | running...RMSE=1.5623
#     · Month 10/20 processed | running...RMSE=1.4925
#     · Month 15/20 processed | running...RMSE=1.3989
#     · Month 20/20 processed | running...RMSE=1.2757
#   - Config 9/20
#     · Month 5/20 processed | running...RMSE=1.5188
#     · Month 10/20 processed | running...RMSE=1.4538
#     · Month 15/20 processed | running...RMSE=1.3666
#     · Month 20/20 processed | running...RMSE=1.2502
#   - Config 10/20
#     · Month 5/20 processed | running...RMSE=1.7246
#     · Month 10/20 processed | running...RMSE=1.6124
#     · Month 15/20 processed | running...RMSE=1.5105
#     · Month 20/20 processed | running...RMSE=1.3689
#   - Config 11/20
#     · Month 5/20 processed | running...RMSE=1.7447
#     · Month 10/20 processed | running...RMSE=1.6290
#     · Month 15/20 processed | running...RMSE=1.5346
#     · Month 20/20 processed | running...RMSE=1.3937
#   - Config 12/20
#     · Month 5/20 processed | running...RMSE=1.7551
#     · Month 10/20 processed | running...RMSE=1.6561
#     · Month 15/20 processed | running...RMSE=1.5620
#     · Month 20/20 processed | running...RMSE=1.4219
#   - Config 13/20
#     · Month 5/20 processed | running...RMSE=1.7822
#     · Month 10/20 processed | running...RMSE=1.6838
#     · Month 15/20 processed | running...RMSE=1.5960
#     · Month 20/20 processed | running...RMSE=1.4542
#   - Config 14/20
#     · Month 5/20 processed | running...RMSE=1.7456
#     · Month 10/20 processed | running...RMSE=1.6482
#     · Month 15/20 processed | running...RMSE=1.5613
#     · Month 20/20 processed | running...RMSE=1.4213
#   - Config 15/20
#     · Month 5/20 processed | running...RMSE=1.7863
#     · Month 10/20 processed | running...RMSE=1.6940
#     · Month 15/20 processed | running...RMSE=1.6065
#     · Month 20/20 processed | running...RMSE=1.4675
#   - Config 16/20
#     · Month 5/20 processed | running...RMSE=1.8064
#     · Month 10/20 processed | running...RMSE=1.6761
#     · Month 15/20 processed | running...RMSE=1.5701
#     · Month 20/20 processed | running...RMSE=1.4239
#   - Config 17/20
#     · Month 5/20 processed | running...RMSE=1.8572
#     · Month 10/20 processed | running...RMSE=1.7058
#     · Month 15/20 processed | running...RMSE=1.5769
#     · Month 20/20 processed | running...RMSE=1.4250
#   - Config 18/20
#     · Month 5/20 processed | running...RMSE=1.8078
#     · Month 10/20 processed | running...RMSE=1.6792
#     · Month 15/20 processed | running...RMSE=1.5678
#     · Month 20/20 processed | running...RMSE=1.4218
#   - Config 19/20
#     · Month 5/20 processed | running...RMSE=1.7739
#     · Month 10/20 processed | running...RMSE=1.6443
#     · Month 15/20 processed | running...RMSE=1.5309
#     · Month 20/20 processed | running...RMSE=1.3870
#   - Config 20/20
#     · Month 5/20 processed | running...RMSE=1.7985
#     · Month 10/20 processed | running...RMSE=1.6543
#     · Month 15/20 processed | running...RMSE=1.5410
#     · Month 20/20 processed | running...RMSE=1.3966
# [Stage A][Block 3] kept 5 configs (floor=5).
# [Stage A] Shortlist saved with 5 configs.
# [Stage B] Using FULL FE (Gleis 1 & 2) pipeline.
# [Stage B] Month origin t=240 | evaluating 5 configs | active=1
# [Stage B] Month origin t=241 | evaluating 5 configs | active=5
# [Stage B] Month origin t=242 | evaluating 5 configs | active=5
# [Stage B] Month origin t=243 | evaluating 5 configs | active=5
# [Stage B] Month origin t=244 | evaluating 5 configs | active=1
# [Stage B] Month origin t=245 | evaluating 5 configs | active=1
# [Stage B] Month origin t=246 | evaluating 5 configs | active=1
# [Stage B] Month origin t=247 | evaluating 5 configs | active=1
# [Stage B] Month origin t=248 | evaluating 5 configs | active=1
# [Stage B] Month origin t=249 | evaluating 5 configs | active=1
# [Stage B] Month origin t=250 | evaluating 5 configs | active=1
# [Stage B] Month origin t=251 | evaluating 5 configs | active=1
# [Stage B] Month origin t=252 | evaluating 5 configs | active=1
# [Stage B] Month origin t=253 | evaluating 5 configs | active=1
# [Stage B] Month origin t=254 | evaluating 5 configs | active=1
# [Stage B] Month origin t=255 | evaluating 5 configs | active=1
# [Stage B] Month origin t=256 | evaluating 5 configs | active=1
# [Stage B] Month origin t=257 | evaluating 5 configs | active=1
# [Stage B] Month origin t=258 | evaluating 5 configs | active=1
# [Stage B] Month origin t=259 | evaluating 5 configs | active=1
# [Stage B] Month origin t=260 | evaluating 5 configs | active=1
# [Stage B] Month origin t=261 | evaluating 5 configs | active=1
# [Stage B] Month origin t=262 | evaluating 5 configs | active=1
# [Stage B] Month origin t=263 | evaluating 5 configs | active=1
# [Stage B] Month origin t=264 | evaluating 5 configs | active=1
# [Stage B] Month origin t=265 | evaluating 5 configs | active=1
# [Stage B] Month origin t=266 | evaluating 5 configs | active=1
# [Stage B] Month origin t=267 | evaluating 5 configs | active=1
# [Stage B] Month origin t=268 | evaluating 5 configs | active=2
# [Stage B] Month origin t=269 | evaluating 5 configs | active=2
# [Stage B] Month origin t=270 | evaluating 5 configs | active=2
# [Stage B] Month origin t=271 | evaluating 5 configs | active=2
# [Stage B] Month origin t=272 | evaluating 5 configs | active=2
# [Stage B] Month origin t=273 | evaluating 5 configs | active=2
# [Stage B] Month origin t=274 | evaluating 5 configs | active=2
# [Stage B] Month origin t=275 | evaluating 5 configs | active=2
# [Stage B] Month origin t=276 | evaluating 5 configs | active=2
# [Stage B] Month origin t=277 | evaluating 5 configs | active=2
# [Stage B] Month origin t=278 | evaluating 5 configs | active=2
# [Stage B] Month origin t=279 | evaluating 5 configs | active=2
# [Stage B] Month origin t=280 | evaluating 5 configs | active=2
# [Stage B] Month origin t=281 | evaluating 5 configs | active=2
# [Stage B] Month origin t=282 | evaluating 5 configs | active=2
# [Stage B] Month origin t=283 | evaluating 5 configs | active=2
# [Stage B] Month origin t=284 | evaluating 5 configs | active=2
# [Stage B] Month origin t=285 | evaluating 5 configs | active=2
# [Stage B] Month origin t=286 | evaluating 5 configs | active=2
# [Stage B] Month origin t=287 | evaluating 5 configs | active=2
# [Stage B] Month origin t=288 | evaluating 5 configs | active=2
# [Stage B] Month origin t=289 | evaluating 5 configs | active=2
# [Stage B] Month origin t=290 | evaluating 5 configs | active=2
# [Stage B] Month origin t=291 | evaluating 5 configs | active=2
# [Stage B] Month origin t=292 | evaluating 5 configs | active=2
# [Stage B] Month origin t=293 | evaluating 5 configs | active=2
# [Stage B] Month origin t=294 | evaluating 5 configs | active=4
# [Stage B] Month origin t=295 | evaluating 5 configs | active=4
# [Stage B] Month origin t=296 | evaluating 5 configs | active=4
# [Stage B] Month origin t=297 | evaluating 5 configs | active=2
# [Stage B] Month origin t=298 | evaluating 5 configs | active=4
# [Stage B] Month origin t=299 | evaluating 5 configs | active=1
# [Stage B] Month origin t=300 | evaluating 5 configs | active=1
# [Stage B] Month origin t=301 | evaluating 5 configs | active=1
# [Stage B] Month origin t=302 | evaluating 5 configs | active=1
# [Stage B] Month origin t=303 | evaluating 5 configs | active=1
# [Stage B] Month origin t=304 | evaluating 5 configs | active=1
# [Stage B] Month origin t=305 | evaluating 5 configs | active=1
# [Stage B] Month origin t=306 | evaluating 5 configs | active=1
# [Stage B] Month origin t=307 | evaluating 5 configs | active=1
# [Stage B] Month origin t=308 | evaluating 5 configs | active=1
# [Stage B] Month origin t=309 | evaluating 5 configs | active=1
# [Stage B] Month origin t=310 | evaluating 5 configs | active=4
# [Stage B] Month origin t=311 | evaluating 5 configs | active=1
# [Stage B] Month origin t=312 | evaluating 5 configs | active=1
# [Stage B] Month origin t=313 | evaluating 5 configs | active=1
# [Stage B] Month origin t=314 | evaluating 5 configs | active=1
# [Stage B] Month origin t=315 | evaluating 5 configs | active=1
# [Stage B] Month origin t=316 | evaluating 5 configs | active=1
# [Stage B] Month origin t=317 | evaluating 5 configs | active=1
# [Stage B] Month origin t=318 | evaluating 5 configs | active=1
# [Stage B] Month origin t=319 | evaluating 5 configs | active=1
# [Stage B] Month origin t=320 | evaluating 5 configs | active=1
# [Stage B] Month origin t=321 | evaluating 5 configs | active=1
# [Stage B] Month origin t=322 | evaluating 5 configs | active=1
# [Stage B] Month origin t=323 | evaluating 5 configs | active=1
# [Stage B] Month origin t=324 | evaluating 5 configs | active=4
# [Stage B] Month origin t=325 | evaluating 5 configs | active=4
# [Stage B] Month origin t=326 | evaluating 5 configs | active=4
# [Stage B] Month origin t=327 | evaluating 5 configs | active=4
# [Stage B] Month origin t=328 | evaluating 5 configs | active=4
# [Stage B] Month origin t=329 | evaluating 5 configs | active=4
# [Stage B] Month origin t=330 | evaluating 5 configs | active=1
# [Stage B] Month origin t=331 | evaluating 5 configs | active=1
# [Stage B] Month origin t=332 | evaluating 5 configs | active=4
# [Stage B] Month origin t=333 | evaluating 5 configs | active=1
# [Stage B] Month origin t=334 | evaluating 5 configs | active=4
# [Stage B] Month origin t=335 | evaluating 5 configs | active=4
# [Stage B] Month origin t=336 | evaluating 5 configs | active=4
# [Stage B] Month origin t=337 | evaluating 5 configs | active=4
# [Stage B] Month origin t=338 | evaluating 5 configs | active=4
# [Stage B] Month origin t=339 | evaluating 5 configs | active=4
# [Stage B] Month origin t=340 | evaluating 5 configs | active=4
# [Stage B] Month origin t=341 | evaluating 5 configs | active=4
# [Stage B] Month origin t=342 | evaluating 5 configs | active=4
# [Stage B] Month origin t=343 | evaluating 5 configs | active=4
# [Stage B] Month origin t=344 | evaluating 5 configs | active=4
# [Stage B] Month origin t=345 | evaluating 5 configs | active=4
# [Stage B] Month origin t=346 | evaluating 5 configs | active=4
# [Stage B] Month origin t=347 | evaluating 5 configs | active=2
# [Stage B] Month origin t=348 | evaluating 5 configs | active=1
# [Stage B] Month origin t=349 | evaluating 5 configs | active=1
# [Stage B] Month origin t=350 | evaluating 5 configs | active=1
# [Stage B] Month origin t=351 | evaluating 5 configs | active=1
# [Stage B] Month origin t=352 | evaluating 5 configs | active=1
# [Stage B] Month origin t=353 | evaluating 5 configs | active=1
# [Stage B] Month origin t=354 | evaluating 5 configs | active=1
# [Stage B] Month origin t=355 | evaluating 5 configs | active=1
# [Stage B] Month origin t=356 | evaluating 5 configs | active=1
# [Stage B] Month origin t=357 | evaluating 5 configs | active=1
# [Stage B] Month origin t=358 | evaluating 5 configs | active=1
# [Stage B] Month origin t=359 | evaluating 5 configs | active=1
# [Stage B] Month origin t=360 | evaluating 5 configs | active=1
# [Stage B] Month origin t=361 | evaluating 5 configs | active=1
# [Stage B] Month origin t=362 | evaluating 5 configs | active=1
# [Stage B] Month origin t=363 | evaluating 5 configs | active=1
# [Stage B] Month origin t=364 | evaluating 5 configs | active=1
# [Stage B] Month origin t=365 | evaluating 5 configs | active=1
# [Stage B] Month origin t=366 | evaluating 5 configs | active=1
# [Stage B] Month origin t=367 | evaluating 5 configs | active=1
# [Stage B] Month origin t=368 | evaluating 5 configs | active=1
# [Stage B] Month origin t=369 | evaluating 5 configs | active=1
# [Stage B] Month origin t=370 | evaluating 5 configs | active=1
# [Stage B] Month origin t=371 | evaluating 5 configs | active=1
# [Stage B] Month origin t=372 | evaluating 5 configs | active=1
# [Stage B] Month origin t=373 | evaluating 5 configs | active=1
# [Stage B] Month origin t=374 | evaluating 5 configs | active=1
# [Stage B] Month origin t=375 | evaluating 5 configs | active=1
# [Stage B] Month origin t=376 | evaluating 5 configs | active=1
# [Stage B] Month origin t=377 | evaluating 5 configs | active=1
# [Stage B] Month origin t=378 | evaluating 5 configs | active=1
# [Stage B] Month origin t=379 | evaluating 5 configs | active=1
# [Stage B] Month origin t=380 | evaluating 5 configs | active=1
# [Stage B] Month origin t=381 | evaluating 5 configs | active=1
# [Stage B] Month origin t=382 | evaluating 5 configs | active=1
# [Stage B] Month origin t=383 | evaluating 5 configs | active=1
# [Stage B] Month origin t=384 | evaluating 5 configs | active=2
# [Stage B] Month origin t=385 | evaluating 5 configs | active=2
# [Stage B] Month origin t=386 | evaluating 5 configs | active=2
# [Stage B] Month origin t=387 | evaluating 5 configs | active=1
# [Stage B] Month origin t=388 | evaluating 5 configs | active=1
# [Stage B] Month origin t=389 | evaluating 5 configs | active=1
# [Stage B] Month origin t=390 | evaluating 5 configs | active=1
# [Stage B] Month origin t=391 | evaluating 5 configs | active=1
# [Stage B] Month origin t=392 | evaluating 5 configs | active=1
# [Stage B] Month origin t=393 | evaluating 5 configs | active=1
# [Stage B] Month origin t=394 | evaluating 5 configs | active=1
# [Stage B] Month origin t=395 | evaluating 5 configs | active=1
# [Stage B] Month origin t=396 | evaluating 5 configs | active=1
# [Stage B] Month origin t=397 | evaluating 5 configs | active=1
# [Stage B] Month origin t=398 | evaluating 5 configs | active=1
# [Stage B] Month origin t=399 | evaluating 5 configs | active=2
# [Stage B] Month origin t=400 | evaluating 5 configs | active=2
# [Stage B] Month origin t=401 | evaluating 5 configs | active=2
# [Stage B] Month origin t=402 | evaluating 5 configs | active=1
# [Stage B] Month origin t=403 | evaluating 5 configs | active=4
# [Stage B] Month origin t=404 | evaluating 5 configs | active=4
# [Stage B] Month origin t=405 | evaluating 5 configs | active=4
# [Stage B] done → /Users/jonasschernich/Documents/Masterarbeit/Code/outputs/stageB/extra_trees/monthly
# [Stage B] summary.csv & summary_active.txt geschrieben.
#
# Tuning abgeschlossen.
