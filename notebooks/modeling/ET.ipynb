# %%
# ==============================================================================
# Extra Trees – Thesis Tuning Pipeline
# ==============================================================================
# Spezifikation gemäß Masterarbeit:
# - Setup I (ifo only) vs. Setup II (ifo + Target Blocks) im Grid integriert.
# - FE: Lags 0-6 fix, SIS {300, 5k, 50k}, Redundanz {0.9, 1.0}, DR {None, PCA, PLS}.
# - Model: n_est {500,1k,2k}, depth {None,4,8}, leaf {1,5,10}, feat {sqrt,0.1,0.25}.
# - Stage A Shortlist: Top 10 frozen.
# - Dynamic FI (Setup III): Strikt Top 50 Features.
# ==============================================================================

import os, sys
from pathlib import Path
import numpy as np
import pandas as pd
from itertools import product

# --- 1) Pfad-Setup ---
def _locate_repo_root(start: Path) -> Path:
    cur = start.resolve()
    for _ in range(6):
        if (cur / "src").exists():
            return cur
        if cur.parent == cur:
            break
        cur = cur.parent
    return start.resolve()

NOTEBOOK_DIR = Path.cwd()
PROJECT_ROOT = _locate_repo_root(NOTEBOOK_DIR)
os.environ["PROJECT_ROOT"] = str(PROJECT_ROOT)
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

# --- 2) Imports ---
from src.config import (
    GlobalConfig,
    DEFAULT_CORR_SPEC,
    EWMA_CORR_SPEC,
    outputs_for_model,
)
from src.tuning import run_stageA, run_stageB
from src.io_timesplits import (
    load_target,
    load_ifo_features,
    load_full_lagged_features,
    load_rolling_importance,
)
# WICHTIG: Modell-Import für Extra Trees
from src.models.ET import ForecastModel

# --- 3) Konfiguration ---
USE_DYNAMIC_FI_PIPELINE = True  # False = Standard Setup (I & II)
SEED = 42

if USE_DYNAMIC_FI_PIPELINE:
    MODEL_NAME = "extra_trees_dynamic_fi"
else:
    MODEL_NAME = "extra_trees"

outputs_for_model(MODEL_NAME)
print(f"--- Starte Tuning für: {MODEL_NAME} ---")

# --- 4) Daten laden ---
y = load_target()
X_ifo = load_ifo_features()

# Align Indizes
idx_common = y.index.intersection(X_ifo.index)
y = y.loc[idx_common]
X_ifo = X_ifo.loc[idx_common]

X_full_lagged = None
rolling_imp = None
y_fi = None

if USE_DYNAMIC_FI_PIPELINE:
    FI_BASE_DIR = PROJECT_ROOT / "outputs" / "feature_importance" / "outputs_no_missing"
    try:
        X_full_lagged = load_full_lagged_features(base_dir=FI_BASE_DIR)
        rolling_imp   = load_rolling_importance(base_dir=FI_BASE_DIR)

        idx_fi = y.index.intersection(X_full_lagged.index).intersection(rolling_imp.index)
        y_fi          = y.loc[idx_fi]
        X_full_lagged = X_full_lagged.loc[idx_fi]
        rolling_imp   = rolling_imp.loc[idx_fi]
        print(f"Dynamic FI Modus: {X_full_lagged.shape[1]} Features geladen.")
    except FileNotFoundError:
        print("FEHLER: Dynamic FI Artefakte nicht gefunden.")
        sys.exit(1)
else:
    print(f"Full FE Modus (Setup I/II): {X_ifo.shape[1]} Basis-Features.")

# --- 5) Config Defaults (Thesis Policy) ---
def get_thesis_cfg() -> GlobalConfig:
    cfg = GlobalConfig(preset="thesis")
    cfg.policy_window = 24
    cfg.policy_decay = 0.97
    cfg.selection_mode = "decayed_best"
    return cfg

cfg_obj = get_thesis_cfg()

# --- 6) Grid Definition ---------------------------------------

def build_grid_full_fe():
    """Setup I (ifo) und Setup II (ifo + TargetBlocks)."""

    # A) FE & DR
    lag_candidates = [tuple(range(7))]

    corr_opts = [
        {"corr_spec": dict(DEFAULT_CORR_SPEC)},
        {"corr_spec": dict(EWMA_CORR_SPEC)},
    ]

    k1_opts = [700]
    red_opts = [0.9, 1.0]

    dr_opts = [
        {"dr_method": "none"},
        {"dr_method": "pca", "pca_kmax": 30, "pca_var_target": 0.99},
        {"dr_method": "pls", "pls_components": 30},
    ]

    # B) Setup II (Target Blocks)
    block_opts = [
        None,                                 # Setup I
        #["AR1", "Chronos", "TSFresh"],                   # Setup II
    ]

    # C) Weights
    weight_opts = [
        {"sample_weight_decay": None},
        {"sample_weight_decay": 0.99}
    ]

    # D) Extra Trees Hyperparameter (Thesis Summary)
    n_estimators_list = [500, 1000, 2000]
    max_depth_list = [None, 4, 8]
    min_samples_leaf_list = [1, 5, 10]
    max_features_list = ['sqrt', 0.1, 0.25]

    grid = []

    # FE Loop
    for lags, corr, k1, red, dr in product(lag_candidates, corr_opts, k1_opts, red_opts, dr_opts):
        base_fe = {
            "lag_candidates": lags,
            "k1_topk": k1,
            "redundancy_param": red,
            **dr,
            **corr
        }
        # Blocks & Weights
        for blocks, weights in product(block_opts, weight_opts):
            # Model HPs
            for n_est, depth, leaf, feat in product(n_estimators_list, max_depth_list, min_samples_leaf_list, max_features_list):
                hp = {
                    **base_fe,
                    "target_block_set": blocks,
                    **weights,
                    "n_estimators": n_est,
                    "max_depth": depth,
                    "min_samples_leaf": leaf,
                    "max_features": feat,
                    "seed": SEED
                }
                grid.append(hp)
    return grid

def build_grid_dynamic_fi():
    """Setup III: Dynamic Feature Importance via strict Top-N."""

    n_features_list = [50]

    weight_opts = [{"sample_weight_decay": None}, {"sample_weight_decay": 0.99}]

    # ET Params
    n_estimators_list = [500, 1000, 2000]
    max_depth_list = [None, 4, 8]
    min_samples_leaf_list = [1, 5, 10]
    max_features_list = ['sqrt', 0.1, 0.25]

    grid = []
    for n_feat, w, n_est, depth, leaf, feat in product(n_features_list, weight_opts, n_estimators_list, max_depth_list, min_samples_leaf_list, max_features_list):
        hp = {
            "n_features_to_use": n_feat,
            **w,
            "n_estimators": n_est,
            "max_depth": depth,
            "min_samples_leaf": leaf,
            "max_features": feat,
            "seed": SEED
        }
        grid.append(hp)
    return grid

# --- 7) Ausführung --------------------------------------------

if USE_DYNAMIC_FI_PIPELINE:
    grid = build_grid_dynamic_fi()
    print(f"Dynamic FI Grid Größe (Setup III): {len(grid)} Konfigurationen.")

    shortlist = run_stageA(
        model_name=MODEL_NAME,
        model_ctor=lambda hp: ForecastModel(hp),
        model_grid=grid,
        X=X_ifo,
        y=y_fi,
        cfg=cfg_obj,
        X_full_lagged=X_full_lagged,
        rolling_imp=rolling_imp,
        keep_top_k_final=5,
        min_survivors_per_block=5
    )

    run_stageB(
        model_name=MODEL_NAME,
        model_ctor=lambda hp: ForecastModel(hp),
        shortlist=shortlist,
        X=X_ifo,
        y=y_fi,
        cfg=cfg_obj,
        X_full_lagged=X_full_lagged,
        rolling_imp=rolling_imp
    )

else:
    grid = build_grid_full_fe()
    print(f"Full FE Grid Größe (Setup I & II): {len(grid)} Konfigurationen.")
    # Grid ist sehr groß (~30k). ASHA wird hier aggressiv filtern.

    shortlist = run_stageA(
        model_name=MODEL_NAME,
        model_ctor=lambda hp: ForecastModel(hp),
        model_grid=grid,
        X=X_ifo,
        y=y,
        cfg=cfg_obj,
        keep_top_k_final=5,
        min_survivors_per_block=5
    )

    run_stageB(
        model_name=MODEL_NAME,
        model_ctor=lambda hp: ForecastModel(hp),
        shortlist=shortlist,
        X=X_ifo,
        y=y,
        cfg=cfg_obj
    )

print("\nTuning abgeschlossen.")
# Out:
# --- Starte Tuning für: extra_trees_dynamic_fi ---
# INFO in load_ifo_features: Renaming columns to ensure validity.
# Dynamic FI Modus: 4320 Features geladen.
# Dynamic FI Grid Größe (Setup III): 162 Konfigurationen.
# [Stage A] Using DYNAMIC FI (Gleis 3) pipeline.
# [Stage A][Block 1] train_end=180, OOS=181-200 | configs=162
#   - Config 1/162
#     · Month 5/20 processed | running...RMSE=1.7171
#     · Month 10/20 processed | running...RMSE=1.3879
#     · Month 15/20 processed | running...RMSE=1.2999
#     · Month 20/20 processed | running...RMSE=1.1690
#   - Config 2/162
#     · Month 5/20 processed | running...RMSE=1.6805
#     · Month 10/20 processed | running...RMSE=1.3701
#     · Month 15/20 processed | running...RMSE=1.2859
#     · Month 20/20 processed | running...RMSE=1.1556
#   - Config 3/162
#     · Month 5/20 processed | running...RMSE=1.7602
#     · Month 10/20 processed | running...RMSE=1.4236
#     · Month 15/20 processed | running...RMSE=1.3262
#     · Month 20/20 processed | running...RMSE=1.1936
#   - Config 4/162
#     · Month 5/20 processed | running...RMSE=1.6687
#     · Month 10/20 processed | running...RMSE=1.3473
#     · Month 15/20 processed | running...RMSE=1.2675
#     · Month 20/20 processed | running...RMSE=1.1354
#   - Config 5/162
#     · Month 5/20 processed | running...RMSE=1.6351
#     · Month 10/20 processed | running...RMSE=1.3226
#     · Month 15/20 processed | running...RMSE=1.2472
#     · Month 20/20 processed | running...RMSE=1.1199
#   - Config 6/162
#     · Month 5/20 processed | running...RMSE=1.6837
#     · Month 10/20 processed | running...RMSE=1.3644
#     · Month 15/20 processed | running...RMSE=1.2795
#     · Month 20/20 processed | running...RMSE=1.1438
#   - Config 7/162
#     · Month 5/20 processed | running...RMSE=1.6276
#     · Month 10/20 processed | running...RMSE=1.3092
#     · Month 15/20 processed | running...RMSE=1.2296
#     · Month 20/20 processed | running...RMSE=1.1006
#   - Config 8/162
#     · Month 5/20 processed | running...RMSE=1.6338
#     · Month 10/20 processed | running...RMSE=1.3108
#     · Month 15/20 processed | running...RMSE=1.2353
#     · Month 20/20 processed | running...RMSE=1.1066
#   - Config 9/162
#     · Month 5/20 processed | running...RMSE=1.6337
#     · Month 10/20 processed | running...RMSE=1.3193
#     · Month 15/20 processed | running...RMSE=1.2399
#     · Month 20/20 processed | running...RMSE=1.1114
#   - Config 10/162
#     · Month 5/20 processed | running...RMSE=1.6847
#     · Month 10/20 processed | running...RMSE=1.3700
#     · Month 15/20 processed | running...RMSE=1.2834
#     · Month 20/20 processed | running...RMSE=1.1505
#   - Config 11/162
#     · Month 5/20 processed | running...RMSE=1.6429
#     · Month 10/20 processed | running...RMSE=1.3243
#     · Month 15/20 processed | running...RMSE=1.2451
#     · Month 20/20 processed | running...RMSE=1.1164
#   - Config 12/162
#     · Month 5/20 processed | running...RMSE=1.6672
#     · Month 10/20 processed | running...RMSE=1.3502
#     · Month 15/20 processed | running...RMSE=1.2711
#     · Month 20/20 processed | running...RMSE=1.1381
#   - Config 13/162
#     · Month 5/20 processed | running...RMSE=1.6493
#     · Month 10/20 processed | running...RMSE=1.3239
#     · Month 15/20 processed | running...RMSE=1.2469
#     · Month 20/20 processed | running...RMSE=1.1170
#   - Config 14/162
#     · Month 5/20 processed | running...RMSE=1.6252
#     · Month 10/20 processed | running...RMSE=1.3061
#     · Month 15/20 processed | running...RMSE=1.2331
#     · Month 20/20 processed | running...RMSE=1.1058
#   - Config 15/162
#     · Month 5/20 processed | running...RMSE=1.6397
#     · Month 10/20 processed | running...RMSE=1.3207
#     · Month 15/20 processed | running...RMSE=1.2471
#     · Month 20/20 processed | running...RMSE=1.1209
#   - Config 16/162
#     · Month 5/20 processed | running...RMSE=1.6271
#     · Month 10/20 processed | running...RMSE=1.3112
#     · Month 15/20 processed | running...RMSE=1.2333
#     · Month 20/20 processed | running...RMSE=1.1046
#   - Config 17/162
#     · Month 5/20 processed | running...RMSE=1.6245
#     · Month 10/20 processed | running...RMSE=1.3056
#     · Month 15/20 processed | running...RMSE=1.2306
#     · Month 20/20 processed | running...RMSE=1.1031
#   - Config 18/162
#     · Month 5/20 processed | running...RMSE=1.6223
#     · Month 10/20 processed | running...RMSE=1.3073
#     · Month 15/20 processed | running...RMSE=1.2337
#     · Month 20/20 processed | running...RMSE=1.1042
#   - Config 19/162
#     · Month 5/20 processed | running...RMSE=1.7640
#     · Month 10/20 processed | running...RMSE=1.4289
#     · Month 15/20 processed | running...RMSE=1.3259
#     · Month 20/20 processed | running...RMSE=1.1919
#   - Config 20/162
#     · Month 5/20 processed | running...RMSE=1.6881
#     · Month 10/20 processed | running...RMSE=1.3456
#     · Month 15/20 processed | running...RMSE=1.2654
#     · Month 20/20 processed | running...RMSE=1.1274
#   - Config 21/162
#     · Month 5/20 processed | running...RMSE=1.7145
#     · Month 10/20 processed | running...RMSE=1.3972
#     · Month 15/20 processed | running...RMSE=1.3049
#     · Month 20/20 processed | running...RMSE=1.1704
#   - Config 22/162
#     · Month 5/20 processed | running...RMSE=1.6715
#     · Month 10/20 processed | running...RMSE=1.3540
#     · Month 15/20 processed | running...RMSE=1.2708
#     · Month 20/20 processed | running...RMSE=1.1404
#   - Config 23/162
#     · Month 5/20 processed | running...RMSE=1.6502
#     · Month 10/20 processed | running...RMSE=1.3272
#     · Month 15/20 processed | running...RMSE=1.2520
#     · Month 20/20 processed | running...RMSE=1.1225
#   - Config 24/162
#     · Month 5/20 processed | running...RMSE=1.6606
#     · Month 10/20 processed | running...RMSE=1.3518
#     · Month 15/20 processed | running...RMSE=1.2710
#     · Month 20/20 processed | running...RMSE=1.1389
#   - Config 25/162
#     · Month 5/20 processed | running...RMSE=1.6295
#     · Month 10/20 processed | running...RMSE=1.3111
#     · Month 15/20 processed | running...RMSE=1.2306
#     · Month 20/20 processed | running...RMSE=1.1013
#   - Config 26/162
#     · Month 5/20 processed | running...RMSE=1.6334
#     · Month 10/20 processed | running...RMSE=1.3101
#     · Month 15/20 processed | running...RMSE=1.2346
#     · Month 20/20 processed | running...RMSE=1.1057
#   - Config 27/162
#     · Month 5/20 processed | running...RMSE=1.6338
#     · Month 10/20 processed | running...RMSE=1.3206
#     · Month 15/20 processed | running...RMSE=1.2407
#     · Month 20/20 processed | running...RMSE=1.1119
#   - Config 28/162
#     · Month 5/20 processed | running...RMSE=1.7280
#     · Month 10/20 processed | running...RMSE=1.4036
#     · Month 15/20 processed | running...RMSE=1.3142
#     · Month 20/20 processed | running...RMSE=1.1810
#   - Config 29/162
#     · Month 5/20 processed | running...RMSE=1.7021
#     · Month 10/20 processed | running...RMSE=1.3845
#     · Month 15/20 processed | running...RMSE=1.2920
#     · Month 20/20 processed | running...RMSE=1.1597
#   - Config 30/162
#     · Month 5/20 processed | running...RMSE=1.7304
#     · Month 10/20 processed | running...RMSE=1.4071
#     · Month 15/20 processed | running...RMSE=1.3203
#     · Month 20/20 processed | running...RMSE=1.1880
#   - Config 31/162
#     · Month 5/20 processed | running...RMSE=1.6549
#     · Month 10/20 processed | running...RMSE=1.3323
#     · Month 15/20 processed | running...RMSE=1.2538
#     · Month 20/20 processed | running...RMSE=1.1250
#   - Config 32/162
#     · Month 5/20 processed | running...RMSE=1.6423
#     · Month 10/20 processed | running...RMSE=1.3266
#     · Month 15/20 processed | running...RMSE=1.2469
#     · Month 20/20 processed | running...RMSE=1.1187
#   - Config 33/162
#     · Month 5/20 processed | running...RMSE=1.6778
#     · Month 10/20 processed | running...RMSE=1.3570
#     · Month 15/20 processed | running...RMSE=1.2729
#     · Month 20/20 processed | running...RMSE=1.1426
#   - Config 34/162
#     · Month 5/20 processed | running...RMSE=1.6367
#     · Month 10/20 processed | running...RMSE=1.3178
#     · Month 15/20 processed | running...RMSE=1.2358
#     · Month 20/20 processed | running...RMSE=1.1066
#   - Config 35/162
#     · Month 5/20 processed | running...RMSE=1.6355
#     · Month 10/20 processed | running...RMSE=1.3154
#     · Month 15/20 processed | running...RMSE=1.2368
#     · Month 20/20 processed | running...RMSE=1.1087
#   - Config 36/162
#     · Month 5/20 processed | running...RMSE=1.6340
#     · Month 10/20 processed | running...RMSE=1.3174
#     · Month 15/20 processed | running...RMSE=1.2378
#     · Month 20/20 processed | running...RMSE=1.1090
#   - Config 37/162
#     · Month 5/20 processed | running...RMSE=1.6699
#     · Month 10/20 processed | running...RMSE=1.3520
#     · Month 15/20 processed | running...RMSE=1.2652
#     · Month 20/20 processed | running...RMSE=1.1340
#   - Config 38/162
#     · Month 5/20 processed | running...RMSE=1.6412
#     · Month 10/20 processed | running...RMSE=1.3216
#     · Month 15/20 processed | running...RMSE=1.2426
#     · Month 20/20 processed | running...RMSE=1.1136
#   - Config 39/162
#     · Month 5/20 processed | running...RMSE=1.6762
#     · Month 10/20 processed | running...RMSE=1.3533
#     · Month 15/20 processed | running...RMSE=1.2719
#     · Month 20/20 processed | running...RMSE=1.1393
#   - Config 40/162
#     · Month 5/20 processed | running...RMSE=1.6423
#     · Month 10/20 processed | running...RMSE=1.3198
#     · Month 15/20 processed | running...RMSE=1.2421
#     · Month 20/20 processed | running...RMSE=1.1128
#   - Config 41/162
#     · Month 5/20 processed | running...RMSE=1.6271
#     · Month 10/20 processed | running...RMSE=1.3076
#     · Month 15/20 processed | running...RMSE=1.2316
#     · Month 20/20 processed | running...RMSE=1.1037
#   - Config 42/162
#     · Month 5/20 processed | running...RMSE=1.6405
#     · Month 10/20 processed | running...RMSE=1.3224
#     · Month 15/20 processed | running...RMSE=1.2458
#     · Month 20/20 processed | running...RMSE=1.1180
#   - Config 43/162
#     · Month 5/20 processed | running...RMSE=1.6284
#     · Month 10/20 processed | running...RMSE=1.3117
#     · Month 15/20 processed | running...RMSE=1.2332
#     · Month 20/20 processed | running...RMSE=1.1044
#   - Config 44/162
#     · Month 5/20 processed | running...RMSE=1.6278
#     · Month 10/20 processed | running...RMSE=1.3093
#     · Month 15/20 processed | running...RMSE=1.2312
#     · Month 20/20 processed | running...RMSE=1.1034
#   - Config 45/162
#     · Month 5/20 processed | running...RMSE=1.6241
#     · Month 10/20 processed | running...RMSE=1.3116
#     · Month 15/20 processed | running...RMSE=1.2352
#     · Month 20/20 processed | running...RMSE=1.1050
#   - Config 46/162
#     · Month 5/20 processed | running...RMSE=1.7342
#     · Month 10/20 processed | running...RMSE=1.4007
#     · Month 15/20 processed | running...RMSE=1.3037
#     · Month 20/20 processed | running...RMSE=1.1734
#   - Config 47/162
#     · Month 5/20 processed | running...RMSE=1.6920
#     · Month 10/20 processed | running...RMSE=1.3609
#     · Month 15/20 processed | running...RMSE=1.2736
#     · Month 20/20 processed | running...RMSE=1.1398
#   - Config 48/162
#     · Month 5/20 processed | running...RMSE=1.7187
#     · Month 10/20 processed | running...RMSE=1.3939
#     · Month 15/20 processed | running...RMSE=1.3004
#     · Month 20/20 processed | running...RMSE=1.1668
#   - Config 49/162
#     · Month 5/20 processed | running...RMSE=1.6528
#     · Month 10/20 processed | running...RMSE=1.3315
#     · Month 15/20 processed | running...RMSE=1.2532
#     · Month 20/20 processed | running...RMSE=1.1252
#   - Config 50/162
#     · Month 5/20 processed | running...RMSE=1.6507
#     · Month 10/20 processed | running...RMSE=1.3289
#     · Month 15/20 processed | running...RMSE=1.2504
#     · Month 20/20 processed | running...RMSE=1.1210
#   - Config 51/162
#     · Month 5/20 processed | running...RMSE=1.6669
#     · Month 10/20 processed | running...RMSE=1.3548
#     · Month 15/20 processed | running...RMSE=1.2721
#     · Month 20/20 processed | running...RMSE=1.1426
#   - Config 52/162
#     · Month 5/20 processed | running...RMSE=1.6376
#     · Month 10/20 processed | running...RMSE=1.3189
#     · Month 15/20 processed | running...RMSE=1.2362
#     · Month 20/20 processed | running...RMSE=1.1069
#   - Config 53/162
#     · Month 5/20 processed | running...RMSE=1.6353
#     · Month 10/20 processed | running...RMSE=1.3150
#     · Month 15/20 processed | running...RMSE=1.2365
#     · Month 20/20 processed | running...RMSE=1.1083
#   - Config 54/162
#     · Month 5/20 processed | running...RMSE=1.6342
#     · Month 10/20 processed | running...RMSE=1.3183
#     · Month 15/20 processed | running...RMSE=1.2386
#     · Month 20/20 processed | running...RMSE=1.1096
#   - Config 55/162
#     · Month 5/20 processed | running...RMSE=1.7240
#     · Month 10/20 processed | running...RMSE=1.3992
#     · Month 15/20 processed | running...RMSE=1.3104
#     · Month 20/20 processed | running...RMSE=1.1775
#   - Config 56/162
#     · Month 5/20 processed | running...RMSE=1.7183
#     · Month 10/20 processed | running...RMSE=1.4009
#     · Month 15/20 processed | running...RMSE=1.3034
#     · Month 20/20 processed | running...RMSE=1.1712
#   - Config 57/162
#     · Month 5/20 processed | running...RMSE=1.7367
#     · Month 10/20 processed | running...RMSE=1.4083
#     · Month 15/20 processed | running...RMSE=1.3141
#     · Month 20/20 processed | running...RMSE=1.1830
#   - Config 58/162
#     · Month 5/20 processed | running...RMSE=1.6555
#     · Month 10/20 processed | running...RMSE=1.3388
#     · Month 15/20 processed | running...RMSE=1.2572
#     · Month 20/20 processed | running...RMSE=1.1278
#   - Config 59/162
#     · Month 5/20 processed | running...RMSE=1.6451
#     · Month 10/20 processed | running...RMSE=1.3263
#     · Month 15/20 processed | running...RMSE=1.2463
#     · Month 20/20 processed | running...RMSE=1.1173
#   - Config 60/162
#     · Month 5/20 processed | running...RMSE=1.6674
#     · Month 10/20 processed | running...RMSE=1.3514
#     · Month 15/20 processed | running...RMSE=1.2694
#     · Month 20/20 processed | running...RMSE=1.1410
#   - Config 61/162
#     · Month 5/20 processed | running...RMSE=1.6352
#     · Month 10/20 processed | running...RMSE=1.3174
#     · Month 15/20 processed | running...RMSE=1.2370
#     · Month 20/20 processed | running...RMSE=1.1081
#   - Config 62/162
#     · Month 5/20 processed | running...RMSE=1.6347
#     · Month 10/20 processed | running...RMSE=1.3156
#     · Month 15/20 processed | running...RMSE=1.2367
#     · Month 20/20 processed | running...RMSE=1.1083
#   - Config 63/162
#     · Month 5/20 processed | running...RMSE=1.6368
#     · Month 10/20 processed | running...RMSE=1.3195
#     · Month 15/20 processed | running...RMSE=1.2401
#     · Month 20/20 processed | running...RMSE=1.1112
#   - Config 64/162
#     · Month 5/20 processed | running...RMSE=1.6736
#     · Month 10/20 processed | running...RMSE=1.3535
#     · Month 15/20 processed | running...RMSE=1.2667
#     · Month 20/20 processed | running...RMSE=1.1359
#   - Config 65/162
#     · Month 5/20 processed | running...RMSE=1.6508
#     · Month 10/20 processed | running...RMSE=1.3309
#     · Month 15/20 processed | running...RMSE=1.2514
#     · Month 20/20 processed | running...RMSE=1.1204
#   - Config 66/162
#     · Month 5/20 processed | running...RMSE=1.6796
#     · Month 10/20 processed | running...RMSE=1.3563
#     · Month 15/20 processed | running...RMSE=1.2744
#     · Month 20/20 processed | running...RMSE=1.1421
#   - Config 67/162
#     · Month 5/20 processed | running...RMSE=1.6357
#     · Month 10/20 processed | running...RMSE=1.3170
#     · Month 15/20 processed | running...RMSE=1.2390
#     · Month 20/20 processed | running...RMSE=1.1105
#   - Config 68/162
#     · Month 5/20 processed | running...RMSE=1.6304
#     · Month 10/20 processed | running...RMSE=1.3094
#     · Month 15/20 processed | running...RMSE=1.2321
#     · Month 20/20 processed | running...RMSE=1.1037
#   - Config 69/162
#     · Month 5/20 processed | running...RMSE=1.6399
#     · Month 10/20 processed | running...RMSE=1.3244
#     · Month 15/20 processed | running...RMSE=1.2464
#     · Month 20/20 processed | running...RMSE=1.1185
#   - Config 70/162
#     · Month 5/20 processed | running...RMSE=1.6264
#     · Month 10/20 processed | running...RMSE=1.3112
#     · Month 15/20 processed | running...RMSE=1.2320
#     · Month 20/20 processed | running...RMSE=1.1033
#   - Config 71/162
#     · Month 5/20 processed | running...RMSE=1.6277
#     · Month 10/20 processed | running...RMSE=1.3097
#     · Month 15/20 processed | running...RMSE=1.2319
#     · Month 20/20 processed | running...RMSE=1.1032
#   - Config 72/162
#     · Month 5/20 processed | running...RMSE=1.6266
#     · Month 10/20 processed | running...RMSE=1.3132
#     · Month 15/20 processed | running...RMSE=1.2369
#     · Month 20/20 processed | running...RMSE=1.1072
#   - Config 73/162
#     · Month 5/20 processed | running...RMSE=1.7244
#     · Month 10/20 processed | running...RMSE=1.3997
#     · Month 15/20 processed | running...RMSE=1.3043
#     · Month 20/20 processed | running...RMSE=1.1742
#   - Config 74/162
#     · Month 5/20 processed | running...RMSE=1.6884
#     · Month 10/20 processed | running...RMSE=1.3638
#     · Month 15/20 processed | running...RMSE=1.2775
#     · Month 20/20 processed | running...RMSE=1.1453
#   - Config 75/162
#     · Month 5/20 processed | running...RMSE=1.7033
#     · Month 10/20 processed | running...RMSE=1.3847
#     · Month 15/20 processed | running...RMSE=1.2978
#     · Month 20/20 processed | running...RMSE=1.1656
#   - Config 76/162
#     · Month 5/20 processed | running...RMSE=1.6519
#     · Month 10/20 processed | running...RMSE=1.3339
#     · Month 15/20 processed | running...RMSE=1.2533
#     · Month 20/20 processed | running...RMSE=1.1258
#   - Config 77/162
#     · Month 5/20 processed | running...RMSE=1.6465
#     · Month 10/20 processed | running...RMSE=1.3253
#     · Month 15/20 processed | running...RMSE=1.2458
#     · Month 20/20 processed | running...RMSE=1.1172
#   - Config 78/162
#     · Month 5/20 processed | running...RMSE=1.6650
#     · Month 10/20 processed | running...RMSE=1.3508
#     · Month 15/20 processed | running...RMSE=1.2689
#     · Month 20/20 processed | running...RMSE=1.1401
#   - Config 79/162
#     · Month 5/20 processed | running...RMSE=1.6352
#     · Month 10/20 processed | running...RMSE=1.3174
#     · Month 15/20 processed | running...RMSE=1.2370
#     · Month 20/20 processed | running...RMSE=1.1081
#   - Config 80/162
#     · Month 5/20 processed | running...RMSE=1.6348
#     · Month 10/20 processed | running...RMSE=1.3154
#     · Month 15/20 processed | running...RMSE=1.2365
#     · Month 20/20 processed | running...RMSE=1.1080
#   - Config 81/162
#     · Month 5/20 processed | running...RMSE=1.6378
#     · Month 10/20 processed | running...RMSE=1.3209
#     · Month 15/20 processed | running...RMSE=1.2412
#     · Month 20/20 processed | running...RMSE=1.1121
#   - Config 82/162
#     · Month 5/20 processed | running...RMSE=1.7886
#     · Month 10/20 processed | running...RMSE=1.4446
#     · Month 15/20 processed | running...RMSE=1.3635
#     · Month 20/20 processed | running...RMSE=1.2328
#   - Config 83/162
#     · Month 5/20 processed | running...RMSE=1.7015
#     · Month 10/20 processed | running...RMSE=1.3858
#     · Month 15/20 processed | running...RMSE=1.3056
#     · Month 20/20 processed | running...RMSE=1.1798
#   - Config 84/162
#     · Month 5/20 processed | running...RMSE=1.7966
#     · Month 10/20 processed | running...RMSE=1.4383
#     · Month 15/20 processed | running...RMSE=1.3592
#     · Month 20/20 processed | running...RMSE=1.2361
#   - Config 85/162
#     · Month 5/20 processed | running...RMSE=1.6570
#     · Month 10/20 processed | running...RMSE=1.3317
#     · Month 15/20 processed | running...RMSE=1.2521
#     · Month 20/20 processed | running...RMSE=1.1265
#   - Config 86/162
#     · Month 5/20 processed | running...RMSE=1.6351
#     · Month 10/20 processed | running...RMSE=1.3132
#     · Month 15/20 processed | running...RMSE=1.2409
#     · Month 20/20 processed | running...RMSE=1.1153
#   - Config 87/162
#     · Month 5/20 processed | running...RMSE=1.7074
#     · Month 10/20 processed | running...RMSE=1.3743
#     · Month 15/20 processed | running...RMSE=1.2888
#     · Month 20/20 processed | running...RMSE=1.1607
#   - Config 88/162
#     · Month 5/20 processed | running...RMSE=1.6330
#     · Month 10/20 processed | running...RMSE=1.3082
#     · Month 15/20 processed | running...RMSE=1.2309
#     · Month 20/20 processed | running...RMSE=1.1008
#   - Config 89/162
#     · Month 5/20 processed | running...RMSE=1.6203
#     · Month 10/20 processed | running...RMSE=1.2948
#     · Month 15/20 processed | running...RMSE=1.2216
#     · Month 20/20 processed | running...RMSE=1.0935
#   - Config 90/162
#     · Month 5/20 processed | running...RMSE=1.6595
#     · Month 10/20 processed | running...RMSE=1.3344
#     · Month 15/20 processed | running...RMSE=1.2563
#     · Month 20/20 processed | running...RMSE=1.1285
#   - Config 91/162
#     · Month 5/20 processed | running...RMSE=1.6795
#     · Month 10/20 processed | running...RMSE=1.3493
#     · Month 15/20 processed | running...RMSE=1.2655
#     · Month 20/20 processed | running...RMSE=1.1353
#   - Config 92/162
#     · Month 5/20 processed | running...RMSE=1.6490
#     · Month 10/20 processed | running...RMSE=1.3223
#     · Month 15/20 processed | running...RMSE=1.2415
#     · Month 20/20 processed | running...RMSE=1.1145
#   - Config 93/162
#     · Month 5/20 processed | running...RMSE=1.7201
#     · Month 10/20 processed | running...RMSE=1.3673
#     · Month 15/20 processed | running...RMSE=1.2833
#     · Month 20/20 processed | running...RMSE=1.1531
#   - Config 94/162
#     · Month 5/20 processed | running...RMSE=1.6478
#     · Month 10/20 processed | running...RMSE=1.3176
#     · Month 15/20 processed | running...RMSE=1.2419
#     · Month 20/20 processed | running...RMSE=1.1142
#   - Config 95/162
#     · Month 5/20 processed | running...RMSE=1.6215
#     · Month 10/20 processed | running...RMSE=1.2969
#     · Month 15/20 processed | running...RMSE=1.2242
#     · Month 20/20 processed | running...RMSE=1.0958
#   - Config 96/162
#     · Month 5/20 processed | running...RMSE=1.6741
#     · Month 10/20 processed | running...RMSE=1.3393
#     · Month 15/20 processed | running...RMSE=1.2604
#     · Month 20/20 processed | running...RMSE=1.1328
#   - Config 97/162
#     · Month 5/20 processed | running...RMSE=1.6225
#     · Month 10/20 processed | running...RMSE=1.2971
#     · Month 15/20 processed | running...RMSE=1.2228
#     · Month 20/20 processed | running...RMSE=1.0923
#   - Config 98/162
#     · Month 5/20 processed | running...RMSE=1.6162
#     · Month 10/20 processed | running...RMSE=1.2913
#     · Month 15/20 processed | running...RMSE=1.2193
#     · Month 20/20 processed | running...RMSE=1.0916
#   - Config 99/162
#     · Month 5/20 processed | running...RMSE=1.6503
#     · Month 10/20 processed | running...RMSE=1.3244
#     · Month 15/20 processed | running...RMSE=1.2469
#     · Month 20/20 processed | running...RMSE=1.1170
#   - Config 100/162
#     · Month 5/20 processed | running...RMSE=1.7167
#     · Month 10/20 processed | running...RMSE=1.3718
#     · Month 15/20 processed | running...RMSE=1.2943
#     · Month 20/20 processed | running...RMSE=1.1658
#   - Config 101/162
#     · Month 5/20 processed | running...RMSE=1.6739
#     · Month 10/20 processed | running...RMSE=1.3751
#     · Month 15/20 processed | running...RMSE=1.2873
#     · Month 20/20 processed | running...RMSE=1.1581
#   - Config 102/162
#     · Month 5/20 processed | running...RMSE=1.8083
#     · Month 10/20 processed | running...RMSE=1.4577
#     · Month 15/20 processed | running...RMSE=1.3468
#     · Month 20/20 processed | running...RMSE=1.2320
#   - Config 103/162
#     · Month 5/20 processed | running...RMSE=1.6517
#     · Month 10/20 processed | running...RMSE=1.3290
#     · Month 15/20 processed | running...RMSE=1.2498
#     · Month 20/20 processed | running...RMSE=1.1221
#   - Config 104/162
#     · Month 5/20 processed | running...RMSE=1.6315
#     · Month 10/20 processed | running...RMSE=1.3140
#     · Month 15/20 processed | running...RMSE=1.2383
#     · Month 20/20 processed | running...RMSE=1.1092
#   - Config 105/162
#     · Month 5/20 processed | running...RMSE=1.6969
#     · Month 10/20 processed | running...RMSE=1.3719
#     · Month 15/20 processed | running...RMSE=1.2849
#     · Month 20/20 processed | running...RMSE=1.1552
#   - Config 106/162
#     · Month 5/20 processed | running...RMSE=1.6321
#     · Month 10/20 processed | running...RMSE=1.3083
#     · Month 15/20 processed | running...RMSE=1.2317
#     · Month 20/20 processed | running...RMSE=1.1012
#   - Config 107/162
#     · Month 5/20 processed | running...RMSE=1.6208
#     · Month 10/20 processed | running...RMSE=1.2949
#     · Month 15/20 processed | running...RMSE=1.2216
#     · Month 20/20 processed | running...RMSE=1.0934
#   - Config 108/162
#     · Month 5/20 processed | running...RMSE=1.6586
#     · Month 10/20 processed | running...RMSE=1.3328
#     · Month 15/20 processed | running...RMSE=1.2556
#     · Month 20/20 processed | running...RMSE=1.1279
#   - Config 109/162
#     · Month 5/20 processed | running...RMSE=1.7576
#     · Month 10/20 processed | running...RMSE=1.4308
#     · Month 15/20 processed | running...RMSE=1.3445
#     · Month 20/20 processed | running...RMSE=1.2115
#   - Config 110/162
#     · Month 5/20 processed | running...RMSE=1.6995
#     · Month 10/20 processed | running...RMSE=1.3898
#     · Month 15/20 processed | running...RMSE=1.3136
#     · Month 20/20 processed | running...RMSE=1.1848
#   - Config 111/162
#     · Month 5/20 processed | running...RMSE=1.7945
#     · Month 10/20 processed | running...RMSE=1.4497
#     · Month 15/20 processed | running...RMSE=1.3570
#     · Month 20/20 processed | running...RMSE=1.2338
#   - Config 112/162
#     · Month 5/20 processed | running...RMSE=1.6683
#     · Month 10/20 processed | running...RMSE=1.3426
#     · Month 15/20 processed | running...RMSE=1.2616
#     · Month 20/20 processed | running...RMSE=1.1344
#   - Config 113/162
#     · Month 5/20 processed | running...RMSE=1.6429
#     · Month 10/20 processed | running...RMSE=1.3194
#     · Month 15/20 processed | running...RMSE=1.2397
#     · Month 20/20 processed | running...RMSE=1.1137
#   - Config 114/162
#     · Month 5/20 processed | running...RMSE=1.7111
#     · Month 10/20 processed | running...RMSE=1.3762
#     · Month 15/20 processed | running...RMSE=1.2886
#     · Month 20/20 processed | running...RMSE=1.1610
#   - Config 115/162
#     · Month 5/20 processed | running...RMSE=1.6379
#     · Month 10/20 processed | running...RMSE=1.3134
#     · Month 15/20 processed | running...RMSE=1.2351
#     · Month 20/20 processed | running...RMSE=1.1050
#   - Config 116/162
#     · Month 5/20 processed | running...RMSE=1.6289
#     · Month 10/20 processed | running...RMSE=1.3036
#     · Month 15/20 processed | running...RMSE=1.2267
#     · Month 20/20 processed | running...RMSE=1.0977
#   - Config 117/162
#     · Month 5/20 processed | running...RMSE=1.6507
#     · Month 10/20 processed | running...RMSE=1.3248
#     · Month 15/20 processed | running...RMSE=1.2467
#     · Month 20/20 processed | running...RMSE=1.1185
#   - Config 118/162
#     · Month 5/20 processed | running...RMSE=1.6769
#     · Month 10/20 processed | running...RMSE=1.3465
#     · Month 15/20 processed | running...RMSE=1.2578
#     · Month 20/20 processed | running...RMSE=1.1278
#   - Config 119/162
#     · Month 5/20 processed | running...RMSE=1.6405
#     · Month 10/20 processed | running...RMSE=1.3164
#     · Month 15/20 processed | running...RMSE=1.2394
#     · Month 20/20 processed | running...RMSE=1.1124
#   - Config 120/162
#     · Month 5/20 processed | running...RMSE=1.7064
#     · Month 10/20 processed | running...RMSE=1.3603
#     · Month 15/20 processed | running...RMSE=1.2797
#     · Month 20/20 processed | running...RMSE=1.1526
#   - Config 121/162
#     · Month 5/20 processed | running...RMSE=1.6504
#     · Month 10/20 processed | running...RMSE=1.3210
#     · Month 15/20 processed | running...RMSE=1.2426
#     · Month 20/20 processed | running...RMSE=1.1137
#   - Config 122/162
#     · Month 5/20 processed | running...RMSE=1.6273
#     · Month 10/20 processed | running...RMSE=1.3030
#     · Month 15/20 processed | running...RMSE=1.2253
#     · Month 20/20 processed | running...RMSE=1.0973
#   - Config 123/162
#     · Month 5/20 processed | running...RMSE=1.6802
#     · Month 10/20 processed | running...RMSE=1.3426
#     · Month 15/20 processed | running...RMSE=1.2616
#     · Month 20/20 processed | running...RMSE=1.1344
#   - Config 124/162
#     · Month 5/20 processed | running...RMSE=1.6309
#     · Month 10/20 processed | running...RMSE=1.3078
#     · Month 15/20 processed | running...RMSE=1.2313
#     · Month 20/20 processed | running...RMSE=1.1007
#   - Config 125/162
#     · Month 5/20 processed | running...RMSE=1.6239
#     · Month 10/20 processed | running...RMSE=1.2989
#     · Month 15/20 processed | running...RMSE=1.2224
#     · Month 20/20 processed | running...RMSE=1.0939
#   - Config 126/162
#     · Month 5/20 processed | running...RMSE=1.6411
#     · Month 10/20 processed | running...RMSE=1.3148
#     · Month 15/20 processed | running...RMSE=1.2395
#     · Month 20/20 processed | running...RMSE=1.1095
#   - Config 127/162
#     · Month 5/20 processed | running...RMSE=1.7083
#     · Month 10/20 processed | running...RMSE=1.3732
#     · Month 15/20 processed | running...RMSE=1.2836
#     · Month 20/20 processed | running...RMSE=1.1561
#   - Config 128/162
#     · Month 5/20 processed | running...RMSE=1.6938
#     · Month 10/20 processed | running...RMSE=1.3719
#     · Month 15/20 processed | running...RMSE=1.2827
#     · Month 20/20 processed | running...RMSE=1.1568
#   - Config 129/162
#     · Month 5/20 processed | running...RMSE=1.7840
#     · Month 10/20 processed | running...RMSE=1.4502
#     · Month 15/20 processed | running...RMSE=1.3470
#     · Month 20/20 processed | running...RMSE=1.2279
#   - Config 130/162
#     · Month 5/20 processed | running...RMSE=1.6649
#     · Month 10/20 processed | running...RMSE=1.3391
#     · Month 15/20 processed | running...RMSE=1.2591
#     · Month 20/20 processed | running...RMSE=1.1317
#   - Config 131/162
#     · Month 5/20 processed | running...RMSE=1.6382
#     · Month 10/20 processed | running...RMSE=1.3180
#     · Month 15/20 processed | running...RMSE=1.2375
#     · Month 20/20 processed | running...RMSE=1.1095
#   - Config 132/162
#     · Month 5/20 processed | running...RMSE=1.7109
#     · Month 10/20 processed | running...RMSE=1.3792
#     · Month 15/20 processed | running...RMSE=1.2904
#     · Month 20/20 processed | running...RMSE=1.1600
#   - Config 133/162
#     · Month 5/20 processed | running...RMSE=1.6376
#     · Month 10/20 processed | running...RMSE=1.3137
#     · Month 15/20 processed | running...RMSE=1.2356
#     · Month 20/20 processed | running...RMSE=1.1055
#   - Config 134/162
#     · Month 5/20 processed | running...RMSE=1.6290
#     · Month 10/20 processed | running...RMSE=1.3033
#     · Month 15/20 processed | running...RMSE=1.2264
#     · Month 20/20 processed | running...RMSE=1.0972
#   - Config 135/162
#     · Month 5/20 processed | running...RMSE=1.6497
#     · Month 10/20 processed | running...RMSE=1.3230
#     · Month 15/20 processed | running...RMSE=1.2454
#     · Month 20/20 processed | running...RMSE=1.1174
#   - Config 136/162
#     · Month 5/20 processed | running...RMSE=1.7360
#     · Month 10/20 processed | running...RMSE=1.4129
#     · Month 15/20 processed | running...RMSE=1.3283
#     · Month 20/20 processed | running...RMSE=1.1996
#   - Config 137/162
#     · Month 5/20 processed | running...RMSE=1.7184
#     · Month 10/20 processed | running...RMSE=1.4062
#     · Month 15/20 processed | running...RMSE=1.3202
#     · Month 20/20 processed | running...RMSE=1.1891
#   - Config 138/162
#     · Month 5/20 processed | running...RMSE=1.8015
#     · Month 10/20 processed | running...RMSE=1.4623
#     · Month 15/20 processed | running...RMSE=1.3633
#     · Month 20/20 processed | running...RMSE=1.2382
#   - Config 139/162
#     · Month 5/20 processed | running...RMSE=1.6632
#     · Month 10/20 processed | running...RMSE=1.3373
#     · Month 15/20 processed | running...RMSE=1.2543
#     · Month 20/20 processed | running...RMSE=1.1275
#   - Config 140/162
#     · Month 5/20 processed | running...RMSE=1.6416
#     · Month 10/20 processed | running...RMSE=1.3194
#     · Month 15/20 processed | running...RMSE=1.2390
#     · Month 20/20 processed | running...RMSE=1.1128
#   - Config 141/162
#     · Month 5/20 processed | running...RMSE=1.6909
#     · Month 10/20 processed | running...RMSE=1.3631
#     · Month 15/20 processed | running...RMSE=1.2792
#     · Month 20/20 processed | running...RMSE=1.1534
#   - Config 142/162
#     · Month 5/20 processed | running...RMSE=1.6361
#     · Month 10/20 processed | running...RMSE=1.3120
#     · Month 15/20 processed | running...RMSE=1.2347
#     · Month 20/20 processed | running...RMSE=1.1045
#   - Config 143/162
#     · Month 5/20 processed | running...RMSE=1.6245
#     · Month 10/20 processed | running...RMSE=1.2996
#     · Month 15/20 processed | running...RMSE=1.2237
#     · Month 20/20 processed | running...RMSE=1.0946
#   - Config 144/162
#     · Month 5/20 processed | running...RMSE=1.6505
#     · Month 10/20 processed | running...RMSE=1.3239
#     · Month 15/20 processed | running...RMSE=1.2447
#     · Month 20/20 processed | running...RMSE=1.1160
#   - Config 145/162
#     · Month 5/20 processed | running...RMSE=1.6772
#     · Month 10/20 processed | running...RMSE=1.3422
#     · Month 15/20 processed | running...RMSE=1.2549
#     · Month 20/20 processed | running...RMSE=1.1257
#   - Config 146/162
#     · Month 5/20 processed | running...RMSE=1.6519
#     · Month 10/20 processed | running...RMSE=1.3251
#     · Month 15/20 processed | running...RMSE=1.2440
#     · Month 20/20 processed | running...RMSE=1.1164
#   - Config 147/162
#     · Month 5/20 processed | running...RMSE=1.6982
#     · Month 10/20 processed | running...RMSE=1.3580
#     · Month 15/20 processed | running...RMSE=1.2772
#     · Month 20/20 processed | running...RMSE=1.1507
#   - Config 148/162
#     · Month 5/20 processed | running...RMSE=1.6421
#     · Month 10/20 processed | running...RMSE=1.3154
#     · Month 15/20 processed | running...RMSE=1.2361
#     · Month 20/20 processed | running...RMSE=1.1077
#   - Config 149/162
#     · Month 5/20 processed | running...RMSE=1.6265
#     · Month 10/20 processed | running...RMSE=1.3014
#     · Month 15/20 processed | running...RMSE=1.2249
#     · Month 20/20 processed | running...RMSE=1.0968
#   - Config 150/162
#     · Month 5/20 processed | running...RMSE=1.6717
#     · Month 10/20 processed | running...RMSE=1.3394
#     · Month 15/20 processed | running...RMSE=1.2597
#     · Month 20/20 processed | running...RMSE=1.1325
#   - Config 151/162
#     · Month 5/20 processed | running...RMSE=1.6259
#     · Month 10/20 processed | running...RMSE=1.3042
#     · Month 15/20 processed | running...RMSE=1.2272
#     · Month 20/20 processed | running...RMSE=1.0974
#   - Config 152/162
#     · Month 5/20 processed | running...RMSE=1.6199
#     · Month 10/20 processed | running...RMSE=1.2950
#     · Month 15/20 processed | running...RMSE=1.2204
#     · Month 20/20 processed | running...RMSE=1.0912
#   - Config 153/162
#     · Month 5/20 processed | running...RMSE=1.6376
#     · Month 10/20 processed | running...RMSE=1.3132
#     · Month 15/20 processed | running...RMSE=1.2378
#     · Month 20/20 processed | running...RMSE=1.1082
#   - Config 154/162
#     · Month 5/20 processed | running...RMSE=1.7240
#     · Month 10/20 processed | running...RMSE=1.3921
#     · Month 15/20 processed | running...RMSE=1.2999
#     · Month 20/20 processed | running...RMSE=1.1729
#   - Config 155/162
#     · Month 5/20 processed | running...RMSE=1.6944
#     · Month 10/20 processed | running...RMSE=1.3686
#     · Month 15/20 processed | running...RMSE=1.2820
#     · Month 20/20 processed | running...RMSE=1.1553
#   - Config 156/162
#     · Month 5/20 processed | running...RMSE=1.7859
#     · Month 10/20 processed | running...RMSE=1.4444
#     · Month 15/20 processed | running...RMSE=1.3461
#     · Month 20/20 processed | running...RMSE=1.2249
#   - Config 157/162
#     · Month 5/20 processed | running...RMSE=1.6567
#     · Month 10/20 processed | running...RMSE=1.3331
#     · Month 15/20 processed | running...RMSE=1.2538
#     · Month 20/20 processed | running...RMSE=1.1272
#   - Config 158/162
#     · Month 5/20 processed | running...RMSE=1.6419
#     · Month 10/20 processed | running...RMSE=1.3205
#     · Month 15/20 processed | running...RMSE=1.2384
#     · Month 20/20 processed | running...RMSE=1.1113
#   - Config 159/162
#     · Month 5/20 processed | running...RMSE=1.6992
#     · Month 10/20 processed | running...RMSE=1.3666
#     · Month 15/20 processed | running...RMSE=1.2815
#     · Month 20/20 processed | running...RMSE=1.1533
#   - Config 160/162
#     · Month 5/20 processed | running...RMSE=1.6358
#     · Month 10/20 processed | running...RMSE=1.3120
#     · Month 15/20 processed | running...RMSE=1.2348
#     · Month 20/20 processed | running...RMSE=1.1046
#   - Config 161/162
#     · Month 5/20 processed | running...RMSE=1.6247
#     · Month 10/20 processed | running...RMSE=1.2996
#     · Month 15/20 processed | running...RMSE=1.2238
#     · Month 20/20 processed | running...RMSE=1.0946
#   - Config 162/162
#     · Month 5/20 processed | running...RMSE=1.6503
#     · Month 10/20 processed | running...RMSE=1.3231
#     · Month 15/20 processed | running...RMSE=1.2441
#     · Month 20/20 processed | running...RMSE=1.1155
# [Stage A][Block 1] kept 17 configs (floor=5).
# [Stage A][Block 2] train_end=200, OOS=201-220 | configs=17
#   - Config 1/17
#     · Month 5/20 processed | running...RMSE=0.8896
#     · Month 10/20 processed | running...RMSE=1.2076
#     · Month 15/20 processed | running...RMSE=2.4868
#     · Month 20/20 processed | running...RMSE=2.5117
#   - Config 2/17
#     · Month 5/20 processed | running...RMSE=0.9112
#     · Month 10/20 processed | running...RMSE=1.2285
#     · Month 15/20 processed | running...RMSE=2.5524
#     · Month 20/20 processed | running...RMSE=2.5632
#   - Config 3/17
#     · Month 5/20 processed | running...RMSE=0.9055
#     · Month 10/20 processed | running...RMSE=1.2319
#     · Month 15/20 processed | running...RMSE=2.5689
#     · Month 20/20 processed | running...RMSE=2.5730
#   - Config 4/17
#     · Month 5/20 processed | running...RMSE=0.9120
#     · Month 10/20 processed | running...RMSE=1.2312
#     · Month 15/20 processed | running...RMSE=2.5446
#     · Month 20/20 processed | running...RMSE=2.5535
#   - Config 5/17
#     · Month 5/20 processed | running...RMSE=0.9056
#     · Month 10/20 processed | running...RMSE=1.2301
#     · Month 15/20 processed | running...RMSE=2.5581
#     · Month 20/20 processed | running...RMSE=2.5674
#   - Config 6/17
#     · Month 5/20 processed | running...RMSE=0.9137
#     · Month 10/20 processed | running...RMSE=1.2384
#     · Month 15/20 processed | running...RMSE=2.5750
#     · Month 20/20 processed | running...RMSE=2.5777
#   - Config 7/17
#     · Month 5/20 processed | running...RMSE=0.9054
#     · Month 10/20 processed | running...RMSE=1.2328
#     · Month 15/20 processed | running...RMSE=2.5704
#     · Month 20/20 processed | running...RMSE=2.5742
#   - Config 8/17
#     · Month 5/20 processed | running...RMSE=0.9065
#     · Month 10/20 processed | running...RMSE=1.2286
#     · Month 15/20 processed | running...RMSE=2.5695
#     · Month 20/20 processed | running...RMSE=2.5748
#   - Config 9/17
#     · Month 5/20 processed | running...RMSE=0.9143
#     · Month 10/20 processed | running...RMSE=1.2325
#     · Month 15/20 processed | running...RMSE=2.5508
#     · Month 20/20 processed | running...RMSE=2.5604
#   - Config 10/17
#     · Month 5/20 processed | running...RMSE=0.9086
#     · Month 10/20 processed | running...RMSE=1.2347
#     · Month 15/20 processed | running...RMSE=2.5610
#     · Month 20/20 processed | running...RMSE=2.5694
#   - Config 11/17
#     · Month 5/20 processed | running...RMSE=0.9093
#     · Month 10/20 processed | running...RMSE=1.2323
#     · Month 15/20 processed | running...RMSE=2.5778
#     · Month 20/20 processed | running...RMSE=2.5815
#   - Config 12/17
#     · Month 5/20 processed | running...RMSE=0.9058
#     · Month 10/20 processed | running...RMSE=1.2288
#     · Month 15/20 processed | running...RMSE=2.5703
#     · Month 20/20 processed | running...RMSE=2.5755
#   - Config 13/17
#     · Month 5/20 processed | running...RMSE=0.9029
#     · Month 10/20 processed | running...RMSE=1.2278
#     · Month 15/20 processed | running...RMSE=2.5700
#     · Month 20/20 processed | running...RMSE=2.5758
#   - Config 14/17
#     · Month 5/20 processed | running...RMSE=0.9149
#     · Month 10/20 processed | running...RMSE=1.2356
#     · Month 15/20 processed | running...RMSE=2.5539
#     · Month 20/20 processed | running...RMSE=2.5645
#   - Config 15/17
#     · Month 5/20 processed | running...RMSE=0.9078
#     · Month 10/20 processed | running...RMSE=1.2312
#     · Month 15/20 processed | running...RMSE=2.5607
#     · Month 20/20 processed | running...RMSE=2.5689
#   - Config 16/17
#     · Month 5/20 processed | running...RMSE=0.9066
#     · Month 10/20 processed | running...RMSE=1.2302
#     · Month 15/20 processed | running...RMSE=2.5773
#     · Month 20/20 processed | running...RMSE=2.5819
#   - Config 17/17
#     · Month 5/20 processed | running...RMSE=0.9030
#     · Month 10/20 processed | running...RMSE=1.2286
#     · Month 15/20 processed | running...RMSE=2.5706
#     · Month 20/20 processed | running...RMSE=2.5764
# [Stage A][Block 2] kept 5 configs (floor=5).
# [Stage A][Block 3] train_end=220, OOS=221-240 | configs=5
#   - Config 1/5
#     · Month 5/20 processed | running...RMSE=2.0842
#     · Month 10/20 processed | running...RMSE=1.9209
#     · Month 15/20 processed | running...RMSE=1.7759
#     · Month 20/20 processed | running...RMSE=1.6025
#   - Config 2/5
#     · Month 5/20 processed | running...RMSE=2.0777
#     · Month 10/20 processed | running...RMSE=1.8973
#     · Month 15/20 processed | running...RMSE=1.7527
#     · Month 20/20 processed | running...RMSE=1.5813
#   - Config 3/5
#     · Month 5/20 processed | running...RMSE=2.0386
#     · Month 10/20 processed | running...RMSE=1.8712
#     · Month 15/20 processed | running...RMSE=1.7324
#     · Month 20/20 processed | running...RMSE=1.5645
#   - Config 4/5
#     · Month 5/20 processed | running...RMSE=2.0269
#     · Month 10/20 processed | running...RMSE=1.8644
#     · Month 15/20 processed | running...RMSE=1.7282
#     · Month 20/20 processed | running...RMSE=1.5605
#   - Config 5/5
#     · Month 5/20 processed | running...RMSE=2.0224
#     · Month 10/20 processed | running...RMSE=1.8605
#     · Month 15/20 processed | running...RMSE=1.7250
#     · Month 20/20 processed | running...RMSE=1.5587
# [Stage A][Block 3] kept 5 configs (floor=5).
# [Stage A] Shortlist saved with 5 configs.
# [Stage B] Using DYNAMIC FI (Gleis 3) pipeline.
# [Stage B] Month origin t=240 | evaluating 5 configs | active=1
# [Stage B] Month origin t=241 | evaluating 5 configs | active=5
# [Stage B] Month origin t=242 | evaluating 5 configs | active=5
# [Stage B] Month origin t=243 | evaluating 5 configs | active=1
# [Stage B] Month origin t=244 | evaluating 5 configs | active=3
# [Stage B] Month origin t=245 | evaluating 5 configs | active=5
# [Stage B] Month origin t=246 | evaluating 5 configs | active=5
# [Stage B] Month origin t=247 | evaluating 5 configs | active=5
# [Stage B] Month origin t=248 | evaluating 5 configs | active=5
# [Stage B] Month origin t=249 | evaluating 5 configs | active=5
# [Stage B] Month origin t=250 | evaluating 5 configs | active=5
# [Stage B] Month origin t=251 | evaluating 5 configs | active=5
# [Stage B] Month origin t=252 | evaluating 5 configs | active=5
# [Stage B] Month origin t=253 | evaluating 5 configs | active=3
# [Stage B] Month origin t=254 | evaluating 5 configs | active=5
# [Stage B] Month origin t=255 | evaluating 5 configs | active=3
# [Stage B] Month origin t=256 | evaluating 5 configs | active=3
# [Stage B] Month origin t=257 | evaluating 5 configs | active=3
# [Stage B] Month origin t=258 | evaluating 5 configs | active=3
# [Stage B] Month origin t=259 | evaluating 5 configs | active=3
# [Stage B] Month origin t=260 | evaluating 5 configs | active=3
# [Stage B] Month origin t=261 | evaluating 5 configs | active=3
# [Stage B] Month origin t=262 | evaluating 5 configs | active=3
# [Stage B] Month origin t=263 | evaluating 5 configs | active=5
# [Stage B] Month origin t=264 | evaluating 5 configs | active=5
# [Stage B] Month origin t=265 | evaluating 5 configs | active=3
# [Stage B] Month origin t=266 | evaluating 5 configs | active=3
# [Stage B] Month origin t=267 | evaluating 5 configs | active=5
# [Stage B] Month origin t=268 | evaluating 5 configs | active=3
# [Stage B] Month origin t=269 | evaluating 5 configs | active=3
# [Stage B] Month origin t=270 | evaluating 5 configs | active=3
# [Stage B] Month origin t=271 | evaluating 5 configs | active=3
# [Stage B] Month origin t=272 | evaluating 5 configs | active=3
# [Stage B] Month origin t=273 | evaluating 5 configs | active=3
# [Stage B] Month origin t=274 | evaluating 5 configs | active=3
# [Stage B] Month origin t=275 | evaluating 5 configs | active=3
# [Stage B] Month origin t=276 | evaluating 5 configs | active=3
# [Stage B] Month origin t=277 | evaluating 5 configs | active=5
# [Stage B] Month origin t=278 | evaluating 5 configs | active=3
# [Stage B] Month origin t=279 | evaluating 5 configs | active=5
# [Stage B] Month origin t=280 | evaluating 5 configs | active=5
# [Stage B] Month origin t=281 | evaluating 5 configs | active=5
# [Stage B] Month origin t=282 | evaluating 5 configs | active=5
# [Stage B] Month origin t=283 | evaluating 5 configs | active=5
# [Stage B] Month origin t=284 | evaluating 5 configs | active=5
# [Stage B] Month origin t=285 | evaluating 5 configs | active=5
# [Stage B] Month origin t=286 | evaluating 5 configs | active=3
# [Stage B] Month origin t=287 | evaluating 5 configs | active=3
# [Stage B] Month origin t=288 | evaluating 5 configs | active=3
# [Stage B] Month origin t=289 | evaluating 5 configs | active=5
# [Stage B] Month origin t=290 | evaluating 5 configs | active=3
# [Stage B] Month origin t=291 | evaluating 5 configs | active=3
# [Stage B] Month origin t=292 | evaluating 5 configs | active=5
# [Stage B] Month origin t=293 | evaluating 5 configs | active=3
# [Stage B] Month origin t=294 | evaluating 5 configs | active=2
# [Stage B] Month origin t=295 | evaluating 5 configs | active=2
# [Stage B] Month origin t=296 | evaluating 5 configs | active=2
# [Stage B] Month origin t=297 | evaluating 5 configs | active=2
# [Stage B] Month origin t=298 | evaluating 5 configs | active=2
# [Stage B] Month origin t=299 | evaluating 5 configs | active=2
# [Stage B] Month origin t=300 | evaluating 5 configs | active=2
# [Stage B] Month origin t=301 | evaluating 5 configs | active=2
# [Stage B] Month origin t=302 | evaluating 5 configs | active=2
# [Stage B] Month origin t=303 | evaluating 5 configs | active=2
# [Stage B] Month origin t=304 | evaluating 5 configs | active=2
# [Stage B] Month origin t=305 | evaluating 5 configs | active=2
# [Stage B] Month origin t=306 | evaluating 5 configs | active=2
# [Stage B] Month origin t=307 | evaluating 5 configs | active=2
# [Stage B] Month origin t=308 | evaluating 5 configs | active=2
# [Stage B] Month origin t=309 | evaluating 5 configs | active=2
# [Stage B] Month origin t=310 | evaluating 5 configs | active=2
# [Stage B] Month origin t=311 | evaluating 5 configs | active=2
# [Stage B] Month origin t=312 | evaluating 5 configs | active=2
# [Stage B] Month origin t=313 | evaluating 5 configs | active=2
# [Stage B] Month origin t=314 | evaluating 5 configs | active=2
# [Stage B] Month origin t=315 | evaluating 5 configs | active=2
# [Stage B] Month origin t=316 | evaluating 5 configs | active=2
# [Stage B] Month origin t=317 | evaluating 5 configs | active=2
# [Stage B] Month origin t=318 | evaluating 5 configs | active=5
# [Stage B] Month origin t=319 | evaluating 5 configs | active=5
# [Stage B] Month origin t=320 | evaluating 5 configs | active=3
# [Stage B] Month origin t=321 | evaluating 5 configs | active=5
# [Stage B] Month origin t=322 | evaluating 5 configs | active=5
# [Stage B] Month origin t=323 | evaluating 5 configs | active=5
# [Stage B] Month origin t=324 | evaluating 5 configs | active=3
# [Stage B] Month origin t=325 | evaluating 5 configs | active=3
# [Stage B] Month origin t=326 | evaluating 5 configs | active=3
# [Stage B] Month origin t=327 | evaluating 5 configs | active=5
# [Stage B] Month origin t=328 | evaluating 5 configs | active=5
# [Stage B] Month origin t=329 | evaluating 5 configs | active=5
# [Stage B] Month origin t=330 | evaluating 5 configs | active=5
# [Stage B] Month origin t=331 | evaluating 5 configs | active=5
# [Stage B] Month origin t=332 | evaluating 5 configs | active=5
# [Stage B] Month origin t=333 | evaluating 5 configs | active=5
# [Stage B] Month origin t=334 | evaluating 5 configs | active=5
# [Stage B] Month origin t=335 | evaluating 5 configs | active=5
# [Stage B] Month origin t=336 | evaluating 5 configs | active=5
# [Stage B] Month origin t=337 | evaluating 5 configs | active=5
# [Stage B] Month origin t=338 | evaluating 5 configs | active=5
# [Stage B] Month origin t=339 | evaluating 5 configs | active=5
# [Stage B] Month origin t=340 | evaluating 5 configs | active=5
# [Stage B] Month origin t=341 | evaluating 5 configs | active=5
# [Stage B] Month origin t=342 | evaluating 5 configs | active=5
# [Stage B] Month origin t=343 | evaluating 5 configs | active=5
# [Stage B] Month origin t=344 | evaluating 5 configs | active=5
# [Stage B] Month origin t=345 | evaluating 5 configs | active=5
# [Stage B] Month origin t=346 | evaluating 5 configs | active=5
# [Stage B] Month origin t=347 | evaluating 5 configs | active=5
# [Stage B] Month origin t=348 | evaluating 5 configs | active=5
# [Stage B] Month origin t=349 | evaluating 5 configs | active=5
# [Stage B] Month origin t=350 | evaluating 5 configs | active=3
# [Stage B] Month origin t=351 | evaluating 5 configs | active=5
# [Stage B] Month origin t=352 | evaluating 5 configs | active=5
# [Stage B] Month origin t=353 | evaluating 5 configs | active=5
# [Stage B] Month origin t=354 | evaluating 5 configs | active=5
# [Stage B] Month origin t=355 | evaluating 5 configs | active=5
# [Stage B] Month origin t=356 | evaluating 5 configs | active=5
# [Stage B] Month origin t=357 | evaluating 5 configs | active=5
# [Stage B] Month origin t=358 | evaluating 5 configs | active=5
# [Stage B] Month origin t=359 | evaluating 5 configs | active=5
# [Stage B] Month origin t=360 | evaluating 5 configs | active=5
# [Stage B] Month origin t=361 | evaluating 5 configs | active=5
# [Stage B] Month origin t=362 | evaluating 5 configs | active=5
# [Stage B] Month origin t=363 | evaluating 5 configs | active=5
# [Stage B] Month origin t=364 | evaluating 5 configs | active=5
# [Stage B] Month origin t=365 | evaluating 5 configs | active=5
# [Stage B] Month origin t=366 | evaluating 5 configs | active=5
# [Stage B] Month origin t=367 | evaluating 5 configs | active=5
# [Stage B] Month origin t=368 | evaluating 5 configs | active=5
# [Stage B] Month origin t=369 | evaluating 5 configs | active=5
# [Stage B] Month origin t=370 | evaluating 5 configs | active=5
# [Stage B] Month origin t=371 | evaluating 5 configs | active=5
# [Stage B] Month origin t=372 | evaluating 5 configs | active=5
# [Stage B] Month origin t=373 | evaluating 5 configs | active=5
# [Stage B] Month origin t=374 | evaluating 5 configs | active=5
# [Stage B] Month origin t=375 | evaluating 5 configs | active=5
# [Stage B] Month origin t=376 | evaluating 5 configs | active=5
# [Stage B] Month origin t=377 | evaluating 5 configs | active=5
# [Stage B] Month origin t=378 | evaluating 5 configs | active=5
# [Stage B] Month origin t=379 | evaluating 5 configs | active=5
# [Stage B] Month origin t=380 | evaluating 5 configs | active=5
# [Stage B] Month origin t=381 | evaluating 5 configs | active=5
# [Stage B] Month origin t=382 | evaluating 5 configs | active=5
# [Stage B] Month origin t=383 | evaluating 5 configs | active=5
# [Stage B] Month origin t=384 | evaluating 5 configs | active=5
# [Stage B] Month origin t=385 | evaluating 5 configs | active=5
# [Stage B] Month origin t=386 | evaluating 5 configs | active=5
# [Stage B] Month origin t=387 | evaluating 5 configs | active=5
# [Stage B] Month origin t=388 | evaluating 5 configs | active=5
# [Stage B] Month origin t=389 | evaluating 5 configs | active=5
# [Stage B] Month origin t=390 | evaluating 5 configs | active=5
# [Stage B] Month origin t=391 | evaluating 5 configs | active=5
# [Stage B] Month origin t=392 | evaluating 5 configs | active=5
# [Stage B] Month origin t=393 | evaluating 5 configs | active=5
# [Stage B] Month origin t=394 | evaluating 5 configs | active=5
# [Stage B] Month origin t=395 | evaluating 5 configs | active=5
# [Stage B] Month origin t=396 | evaluating 5 configs | active=5
# [Stage B] Month origin t=397 | evaluating 5 configs | active=5
# [Stage B] Month origin t=398 | evaluating 5 configs | active=5
# [Stage B] Month origin t=399 | evaluating 5 configs | active=5
# [Stage B] Month origin t=400 | evaluating 5 configs | active=5
# [Stage B] Month origin t=401 | evaluating 5 configs | active=5
# [Stage B] Month origin t=402 | evaluating 5 configs | active=5
# [Stage B] Month origin t=403 | evaluating 5 configs | active=5
# [Stage B] Month origin t=404 | evaluating 5 configs | active=5
# [Stage B] Month origin t=405 | evaluating 5 configs | active=5
# [Stage B] done → /Users/jonasschernich/Documents/Masterarbeit/Code/outputs/stageB/extra_trees_dynamic_fi/monthly
# [Stage B] summary.csv & summary_active.txt geschrieben.
#
# Tuning abgeschlossen.
