# %%
import os
import sys
from pathlib import Path

import numpy as np
import pandas as pd

from sklearn.linear_model import Ridge
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

# ----------------------------------------------------
# 1. Projekt-Root & Imports aus deinem Projekt
# ----------------------------------------------------
def _locate_repo_root(start: Path) -> Path:
    cur = start.resolve()
    for _ in range(5):
        if (cur / "src").exists():
            return cur
        if cur.parent == cur:
            break
        cur = cur.parent
    return start.resolve()

NOTEBOOK_DIR = Path.cwd()
PROJECT_ROOT = _locate_repo_root(NOTEBOOK_DIR)
os.environ["PROJECT_ROOT"] = str(PROJECT_ROOT)
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print("PROJECT_ROOT =", PROJECT_ROOT)

from src.io_timesplits import load_target, load_ifo_features
from src.evaluation import rmse
from src.config import GlobalConfig

# ----------------------------------------------------
# 2. Daten laden & Grundgrößen
# ----------------------------------------------------
print("Lade Daten...")
y = load_target()           # ΔIP (DatetimeIndex)
X_ifo = load_ifo_features() # ifo-Features (un-gelaggt)

# Gemeinsamer Index
idx = y.index.intersection(X_ifo.index)
y = y.loc[idx]
X_ifo = X_ifo.loc[idx]

print(f"Daten geladen. y shape: {y.shape}, X_ifo shape: {X_ifo.shape}")
print(f"Zeitspanne: {y.index.min().date()} -> {y.index.max().date()}")

# Ziel für h=1: y_{t+1}
y_target = y.shift(-1)      # Trainings-Label (für Modelle)
y_true_full = y.copy()      # echte ΔIP(t) (für Auswertung)

# ----------------------------------------------------
# 3. Lag-Matrix bauen (Lags 0..11)
# ----------------------------------------------------
print("\nErstelle lagged Feature-Matrix (Lags 0–11)...")

LAGS_TO_TEST = range(0, 12)  # Lags 0..11
lagged_list = []

n_features = len(X_ifo.columns)
for i, col in enumerate(X_ifo.columns, start=1):
    if i % 200 == 0:
        print(f"  ... erstelle Lags für Feature {i}/{n_features}")
    s = X_ifo[col]
    for lag in LAGS_TO_TEST:
        lagged_list.append(
            s.shift(lag).to_frame(f"{col}__lag{lag}")
        )

X_all_lags = pd.concat(lagged_list, axis=1)

# Finaler Index: dort, wo y_target definiert ist
idx_final = X_all_lags.index.intersection(y_target.dropna().index)
X_all_lags = X_all_lags.loc[idx_final]
y_model_target = y_target.loc[idx_final]
y_true_full = y_true_full.loc[idx_final]

print(f"Vollständige lag-Matrix Shape: {X_all_lags.shape}")
print(f"Finale Zeitspanne für Modellierung: {y_model_target.index.min().date()} -> {y_model_target.index.max().date()}")

# ----------------------------------------------------
# 4. Rolling-Origin-Setup (h=1, wie in deiner Pipeline)
# ----------------------------------------------------
cfg = GlobalConfig(preset="thesis")
SEED = cfg.seed
np.random.seed(SEED)

# Startpunkt des OOS-Fensters aus deinem GlobalConfig (W0_B)
# W0_B ist ein Integer-Index bezogen auf das ursprüngliche y-Array.
# Wir mappen ihn auf y_model_target, das am Anfang einige Monate verlieren kann.
raw_start_date = y.index[cfg.W0_B]

# Starte in y_model_target so nah wie möglich an raw_start_date (bfill, falls am Anfang Lags fehlen)
if raw_start_date in y_model_target.index:
    TRAIN_START_T_idx = y_model_target.index.get_loc(raw_start_date)
else:
    TRAIN_START_T_idx = y_model_target.index.get_indexer([raw_start_date], method="bfill")[0]

T_total = len(y_model_target)

print(f"\nTRAIN_START_T_idx = {TRAIN_START_T_idx} (entspricht Datum {y_model_target.index[TRAIN_START_T_idx].date()})")
print(f"Anzahl OOS-Schritte (ungefähr): {T_total - TRAIN_START_T_idx - 1}")

fixed_ridge_params = {
    "alpha": 1.0,
    "solver": "auto",
    "random_state": SEED
}

def run_rolling_forecast(feature_names):
    """
    Rolling-Origin-Forecast (h=1) ab TRAIN_START_T_idx.
    feature_names: Liste von Spaltennamen aus X_all_lags.

    - Train: bis t-1
    - Prognose: mit X_t
    - Wahrer Wert: y_{t+1}

    Rückgabe: RMSE über den OOS-Zeitraum.
    """

    # Baseline: 0-Features => Naive (immer 0) für ΔIP
    if not feature_names:
        true_vals = y_true_full.iloc[TRAIN_START_T_idx + 1 : T_total].values
        preds = np.zeros_like(true_vals)
        return rmse(true_vals, preds)

    X_subset = X_all_lags[feature_names]

    all_preds = []
    all_true = []

    for t in range(TRAIN_START_T_idx, T_total - 1):
        # Train bis t-1 (Index 0..t-1)
        train_slice = slice(0, t)
        X_tr = X_subset.iloc[train_slice, :]
        y_tr = y_model_target.iloc[train_slice]

        model = make_pipeline(
            StandardScaler(),
            Ridge(**fixed_ridge_params)
        )

        X_tr_clean = X_tr.fillna(0.0)
        model.fit(X_tr_clean, y_tr)

        # Prognose mit X_t
        x_eval = X_subset.iloc[[t], :].fillna(0.0)
        y_hat = model.predict(x_eval)[0]

        # Wahrer Wert: y_{t+1}
        y_true = y_true_full.iloc[t + 1]

        all_preds.append(y_hat)
        all_true.append(y_true)

    return rmse(all_true, all_preds)

print("\nRolling-Forecast-Funktion 'run_rolling_forecast' ist definiert.")

# ----------------------------------------------------
# 5. Feature-Ranking per Forward-Rolling-RMSE (ein Feature nach dem anderen)
# ----------------------------------------------------
print("\nStarte Feature-Ranking mit zeitlicher Forward-Validierung (ein Feature pro Lauf)...")

ALL_FEATURES = list(X_all_lags.columns)

# Optional: Begrenzung, falls du erstmal testen willst (z.B. erste 500 Features)
MAX_FEATURES_TO_RANK = None  # z.B. 500 setzen, um schneller zu sein
if MAX_FEATURES_TO_RANK is not None:
    features_to_rank = ALL_FEATURES[:MAX_FEATURES_TO_RANK]
else:
    features_to_rank = ALL_FEATURES

print(f"Anzahl Features, die gerankt werden: {len(features_to_rank)}")

feature_scores = []

for j, f in enumerate(features_to_rank, start=1):
    score = run_rolling_forecast([f])
    feature_scores.append((score, f))

    if j % 50 == 0 or j == len(features_to_rank):
        print(f"  {j}/{len(features_to_rank)} Features gerankt; letztes: {f}, RMSE = {score:.4f}")

# Sortieren: kleiner RMSE = besser
feature_scores.sort(key=lambda x: x[0])

print("\n=== Ranking abgeschlossen ===")
print(f"Beste 10 Features nach Forward-RMSE (h=1, Ridge, expandierendes Fenster):")
for rank, (score, name) in enumerate(feature_scores[:10], start=1):
    print(f"  {rank}. {name}  -> RMSE = {score:.6f}")

# Die vollständige Rangliste liegt in 'feature_scores'
# (Liste von Tupeln: (rmse, feature_name))
# Out:
# PROJECT_ROOT = /Users/jonasschernich/Documents/Masterarbeit/Code
# Lade Daten...
# INFO in load_ifo_features: Renaming columns to ensure validity.
# Daten geladen. y shape: (407,), X_ifo shape: (407, 2160)
# Zeitspanne: 1991-02-01 -> 2024-12-01
#
# Erstelle lagged Feature-Matrix (Lags 0–11)...
#   ... erstelle Lags für Feature 200/2160
#   ... erstelle Lags für Feature 400/2160
#   ... erstelle Lags für Feature 600/2160
#   ... erstelle Lags für Feature 800/2160
#   ... erstelle Lags für Feature 1000/2160
#   ... erstelle Lags für Feature 1200/2160
#   ... erstelle Lags für Feature 1400/2160
#   ... erstelle Lags für Feature 1600/2160
#   ... erstelle Lags für Feature 1800/2160
#   ... erstelle Lags für Feature 2000/2160
# Vollständige lag-Matrix Shape: (406, 25920)
# Finale Zeitspanne für Modellierung: 1991-02-01 -> 2024-11-01
#
# TRAIN_START_T_idx = 240 (entspricht Datum 2011-02-01)
# Anzahl OOS-Schritte (ungefähr): 165
#
# Rolling-Forecast-Funktion 'run_rolling_forecast' ist definiert.
#
# Starte Feature-Ranking mit zeitlicher Forward-Validierung (ein Feature pro Lauf)...
# Anzahl Features, die gerankt werden: 25920
#   50/25920 Features gerankt; letztes: Baumwollweberei.Fertigwarenlager_Beurteilung__lag1, RMSE = 2.3740
#   100/25920 Features gerankt; letztes: Baumwollweberei.Nachfrage_gegen_Vormonat__lag3, RMSE = 2.3603
#   150/25920 Features gerankt; letztes: Baumwollweberei.Produktionspl_ne__lag5, RMSE = 2.3548
#   200/25920 Features gerankt; letztes: Be__und_Verarbeitung_von_Naturwerk__und_Natursteinen.Exporterwartungen__lag7, RMSE = 2.3646
#   250/25920 Features gerankt; letztes: Be__und_Verarbeitung_von_Naturwerk__und_Natursteinen.Gesch_ftslage_Erwartungen__lag9, RMSE = 2.3627
#   300/25920 Features gerankt; letztes: Be__und_Verarbeitung_von_Naturwerk__und_Natursteinen.Produktionspl_ne__lag11, RMSE = 2.3653
#   350/25920 Features gerankt; letztes: Datenverarbeitungsger_te_elektronische_und_optische_Erzeugnisse.Fertigwarenlager_Beurteilung__lag1, RMSE = 2.3697
#   400/25920 Features gerankt; letztes: Datenverarbeitungsger_te_elektronische_und_optische_Erzeugnisse.Nachfrage_gegen_Vormonat__lag3, RMSE = 2.3686
#   450/25920 Features gerankt; letztes: Datenverarbeitungsger_te_elektronische_und_optische_Erzeugnisse.Produktionspl_ne__lag5, RMSE = 2.3663
#   500/25920 Features gerankt; letztes: Druck_und_Medienvorstufe.Exporterwartungen__lag7, RMSE = 2.3738
#   550/25920 Features gerankt; letztes: Druck_und_Medienvorstufe.Gesch_ftslage_Erwartungen__lag9, RMSE = 2.3732
#   600/25920 Features gerankt; letztes: Druck_und_Medienvorstufe.Produktion_gegen_Vormonat__lag11, RMSE = 2.3743
#   650/25920 Features gerankt; letztes: Drucken_a.n.g..Exporterwartungen__lag1, RMSE = 2.3689
#   700/25920 Features gerankt; letztes: Drucken_a.n.g..Gesch_ftslage_Erwartungen__lag3, RMSE = 2.3633
#   750/25920 Features gerankt; letztes: Drucken_a.n.g..Produktion_gegen_Vormonat__lag5, RMSE = 2.3584
#   800/25920 Features gerankt; letztes: Eisen__Stahl__und_Temperguss.Auftragsbestand_gegen_Vormonat__lag7, RMSE = 2.3709
#   850/25920 Features gerankt; letztes: Eisen__Stahl__und_Temperguss.Gesch_ftslage_Beurteilung__lag9, RMSE = 2.3595
#   900/25920 Features gerankt; letztes: Eisen__Stahl__und_Temperguss.Preiserwartungen__lag11, RMSE = 2.3580
#   950/25920 Features gerankt; letztes: Elektrizit_tsverteilungs__und_Schalteinrichtungen.Auftragsbestand_gegen_Vormonat__lag1, RMSE = 2.3756
#   1000/25920 Features gerankt; letztes: Elektrizit_tsverteilungs__und_Schalteinrichtungen.Gesch_ftslage_Beurteilung__lag3, RMSE = 2.3628
#   1050/25920 Features gerankt; letztes: Elektrizit_tsverteilungs__und_Schalteinrichtungen.Preiserwartungen__lag5, RMSE = 2.3683
#   1100/25920 Features gerankt; letztes: Ern_hrungsgewerbe_und_Tabakverarbeitung.Auftragsbestand_Beurteilung_Export__lag7, RMSE = 2.3658
#   1150/25920 Features gerankt; letztes: Ern_hrungsgewerbe_und_Tabakverarbeitung.Gesch_ftsklima__lag9, RMSE = 2.3781
#   1200/25920 Features gerankt; letztes: Ern_hrungsgewerbe_und_Tabakverarbeitung.Preise_gegen_Vormonat__lag11, RMSE = 2.4011
#   1250/25920 Features gerankt; letztes: Erzeugung_und_erste_Bearbeitung_von_NE_Metallen.Auftragsbestand_Beurteilung_Export__lag1, RMSE = 2.3649
#   1300/25920 Features gerankt; letztes: Erzeugung_und_erste_Bearbeitung_von_NE_Metallen.Gesch_ftsklima__lag3, RMSE = 2.3641
#   1350/25920 Features gerankt; letztes: Erzeugung_und_erste_Bearbeitung_von_NE_Metallen.Preise_gegen_Vormonat__lag5, RMSE = 2.3629
#   1400/25920 Features gerankt; letztes: Getr_nkeherstellung.Auftragsbestand_Beurteilung__lag7, RMSE = 2.3588
#   1450/25920 Features gerankt; letztes: Getr_nkeherstellung.Fertigwarenlager_Beurteilung__lag9, RMSE = 2.3653
#   1500/25920 Features gerankt; letztes: Getr_nkeherstellung.Nachfrage_gegen_Vormonat__lag11, RMSE = 2.3642
#   1550/25920 Features gerankt; letztes: Gie_ereien.Auftragsbestand_Beurteilung__lag1, RMSE = 2.3681
#   1600/25920 Features gerankt; letztes: Gie_ereien.Fertigwarenlager_Beurteilung__lag3, RMSE = 2.3682
#   1650/25920 Features gerankt; letztes: Gie_ereien.Nachfrage_gegen_Vormonat__lag5, RMSE = 2.3740
#   1700/25920 Features gerankt; letztes: Gie_ereien.Produktionspl_ne__lag7, RMSE = 2.3880
#   1750/25920 Features gerankt; letztes: Glas__Keramikgewerbe_Verarbeitung_von_Steinen_und_Erden.Exporterwartungen__lag9, RMSE = 2.3563
#   1800/25920 Features gerankt; letztes: Glas__Keramikgewerbe_Verarbeitung_von_Steinen_und_Erden.Gesch_ftslage_Erwartungen__lag11, RMSE = 2.3718
#   1850/25920 Features gerankt; letztes: Glas__Keramikgewerbe_Verarbeitung_von_Steinen_und_Erden.Produktionspl_ne__lag1, RMSE = 2.3976
#   1900/25920 Features gerankt; letztes: Herstellung_elektrischer_Mess__Kontroll__Navigationsinstrumente.Exporterwartungen__lag3, RMSE = 2.3638
#   1950/25920 Features gerankt; letztes: Herstellung_elektrischer_Mess__Kontroll__Navigationsinstrumente.Gesch_ftslage_Erwartungen__lag5, RMSE = 2.3655
#   2000/25920 Features gerankt; letztes: Herstellung_elektrischer_Mess__Kontroll__Navigationsinstrumente.Produktion_gegen_Vormonat__lag7, RMSE = 2.3675
#   2050/25920 Features gerankt; letztes: Herstellung_elektronischer_Bauelemente_und_Leiterplatten.Auftragsbestand_gegen_Vormonat__lag9, RMSE = 2.3706
#   2100/25920 Features gerankt; letztes: Herstellung_elektronischer_Bauelemente_und_Leiterplatten.Gesch_ftslage_Beurteilung__lag11, RMSE = 2.3632
#   2150/25920 Features gerankt; letztes: Herstellung_elektronischer_Bauelemente_und_Leiterplatten.Produktion_gegen_Vormonat__lag1, RMSE = 2.3755
#   2200/25920 Features gerankt; letztes: Herstellung_feinmechanisch_optischer_Messinstrumente.Auftragsbestand_gegen_Vormonat__lag3, RMSE = 2.3649
#   2250/25920 Features gerankt; letztes: Herstellung_feinmechanisch_optischer_Messinstrumente.Gesch_ftslage_Beurteilung__lag5, RMSE = 2.3665
#   2300/25920 Features gerankt; letztes: Herstellung_feinmechanisch_optischer_Messinstrumente.Preiserwartungen__lag7, RMSE = 2.3735
#   2350/25920 Features gerankt; letztes: Herstellung_isolierter_Elektrokabel__leitungen_und__dr_hte.Auftragsbestand_Beurteilung_Export__lag9, RMSE = 2.3644
#   2400/25920 Features gerankt; letztes: Herstellung_isolierter_Elektrokabel__leitungen_und__dr_hte.Gesch_ftsklima__lag11, RMSE = 2.3740
#   2450/25920 Features gerankt; letztes: Herstellung_isolierter_Elektrokabel__leitungen_und__dr_hte.Preiserwartungen__lag1, RMSE = 2.3704
#   2500/25920 Features gerankt; letztes: Herstellung_konfektionierter_Textilwaren__ohne_Bekleidung_.Auftragsbestand_Beurteilung_Export__lag3, RMSE = 2.3687
#   2550/25920 Features gerankt; letztes: Herstellung_konfektionierter_Textilwaren__ohne_Bekleidung_.Gesch_ftsklima__lag5, RMSE = 2.3666
#   2600/25920 Features gerankt; letztes: Herstellung_konfektionierter_Textilwaren__ohne_Bekleidung_.Preise_gegen_Vormonat__lag7, RMSE = 2.3984
#   2650/25920 Features gerankt; letztes: Herstellung_nicht_wirtschaftszweigspezifischer_Maschinen.Auftragsbestand_Beurteilung__lag9, RMSE = 2.3534
#   2700/25920 Features gerankt; letztes: Herstellung_nicht_wirtschaftszweigspezifischer_Maschinen.Fertigwarenlager_Beurteilung__lag11, RMSE = 2.3589
#   2750/25920 Features gerankt; letztes: Herstellung_nicht_wirtschaftszweigspezifischer_Maschinen.Preise_gegen_Vormonat__lag1, RMSE = 2.3666
#   2800/25920 Features gerankt; letztes: Herstellung_sonstiger_Holz__Flecht__Korb__und_Korkwaren.Auftragsbestand_Beurteilung__lag3, RMSE = 2.3679
#   2850/25920 Features gerankt; letztes: Herstellung_sonstiger_Holz__Flecht__Korb__und_Korkwaren.Fertigwarenlager_Beurteilung__lag5, RMSE = 2.3640
#   2900/25920 Features gerankt; letztes: Herstellung_sonstiger_Holz__Flecht__Korb__und_Korkwaren.Nachfrage_gegen_Vormonat__lag7, RMSE = 2.3648
#   2950/25920 Features gerankt; letztes: Herstellung_sonstiger_Holz__Flecht__Korb__und_Korkwaren.Produktionspl_ne__lag9, RMSE = 2.3695
#   3000/25920 Features gerankt; letztes: Herstellung_sonstiger_branchespezifischer_Maschinen_a.n.g..Exporterwartungen__lag11, RMSE = 2.3628
#   3050/25920 Features gerankt; letztes: Herstellung_sonstiger_branchespezifischer_Maschinen_a.n.g..Nachfrage_gegen_Vormonat__lag1, RMSE = 2.3853
#   3100/25920 Features gerankt; letztes: Herstellung_sonstiger_branchespezifischer_Maschinen_a.n.g..Produktionspl_ne__lag3, RMSE = 2.3670
#   3150/25920 Features gerankt; letztes: Herstellung_sonstiger_nicht_spezifischer_Maschinen_a.n.g..Exporterwartungen__lag5, RMSE = 2.3658
#   3200/25920 Features gerankt; letztes: Herstellung_sonstiger_nicht_spezifischer_Maschinen_a.n.g..Gesch_ftslage_Erwartungen__lag7, RMSE = 2.3681
#   3250/25920 Features gerankt; letztes: Herstellung_sonstiger_nicht_spezifischer_Maschinen_a.n.g..Produktion_gegen_Vormonat__lag9, RMSE = 2.3527
#   3300/25920 Features gerankt; letztes: Herstellung_sonstiger_nichtmetallischer_Erzeugnisse_a.n.g..Auftragsbestand_gegen_Vormonat__lag11, RMSE = 2.3591
#   3350/25920 Features gerankt; letztes: Herstellung_sonstiger_nichtmetallischer_Erzeugnisse_a.n.g..Gesch_ftslage_Erwartungen__lag1, RMSE = 2.4102
#   3400/25920 Features gerankt; letztes: Herstellung_sonstiger_nichtmetallischer_Erzeugnisse_a.n.g..Produktion_gegen_Vormonat__lag3, RMSE = 2.3662
#   3450/25920 Features gerankt; letztes: Herstellung_von_Anstrichmitteln_Druckfarben_und_Kitten.Auftragsbestand_gegen_Vormonat__lag5, RMSE = 2.3699
#   3500/25920 Features gerankt; letztes: Herstellung_von_Anstrichmitteln_Druckfarben_und_Kitten.Gesch_ftslage_Beurteilung__lag7, RMSE = 2.3701
#   3550/25920 Features gerankt; letztes: Herstellung_von_Anstrichmitteln_Druckfarben_und_Kitten.Preiserwartungen__lag9, RMSE = 2.3611
#   3600/25920 Features gerankt; letztes: Herstellung_von_Armaturen_a.n.g..Auftragsbestand_Beurteilung_Export__lag11, RMSE = 2.3622
#   3650/25920 Features gerankt; letztes: Herstellung_von_Armaturen_a.n.g..Gesch_ftslage_Beurteilung__lag1, RMSE = 2.3616
#   3700/25920 Features gerankt; letztes: Herstellung_von_Armaturen_a.n.g..Preiserwartungen__lag3, RMSE = 2.3697
#   3750/25920 Features gerankt; letztes: Herstellung_von_Ausbauelementen_aus_Metall.Auftragsbestand_Beurteilung_Export__lag5, RMSE = 2.3589
#   3800/25920 Features gerankt; letztes: Herstellung_von_Ausbauelementen_aus_Metall.Gesch_ftsklima__lag7, RMSE = 2.3743
#   3850/25920 Features gerankt; letztes: Herstellung_von_Ausbauelementen_aus_Metall.Preise_gegen_Vormonat__lag9, RMSE = 2.3573
#   3900/25920 Features gerankt; letztes: Herstellung_von_Back__und_Teigwaren.Auftragsbestand_Beurteilung__lag11, RMSE = 2.3691
#   3950/25920 Features gerankt; letztes: Herstellung_von_Back__und_Teigwaren.Gesch_ftsklima__lag1, RMSE = 2.3497
#   4000/25920 Features gerankt; letztes: Herstellung_von_Back__und_Teigwaren.Preise_gegen_Vormonat__lag3, RMSE = 2.3652
#   4050/25920 Features gerankt; letztes: Herstellung_von_Backwaren__ohne_Dauerbackwaren_.Auftragsbestand_Beurteilung__lag5, RMSE = 2.3641
#   4100/25920 Features gerankt; letztes: Herstellung_von_Backwaren__ohne_Dauerbackwaren_.Fertigwarenlager_Beurteilung__lag7, RMSE = 2.3713
#   4150/25920 Features gerankt; letztes: Herstellung_von_Backwaren__ohne_Dauerbackwaren_.Nachfrage_gegen_Vormonat__lag9, RMSE = 2.3622
#   4200/25920 Features gerankt; letztes: Herstellung_von_Backwaren__ohne_Dauerbackwaren_.Produktionspl_ne__lag11, RMSE = 2.3678
#   4250/25920 Features gerankt; letztes: Herstellung_von_Bau__und_Baustoffmaschinen.Fertigwarenlager_Beurteilung__lag1, RMSE = 2.3731
#   4300/25920 Features gerankt; letztes: Herstellung_von_Bau__und_Baustoffmaschinen.Nachfrage_gegen_Vormonat__lag3, RMSE = 2.3623
#   4350/25920 Features gerankt; letztes: Herstellung_von_Bau__und_Baustoffmaschinen.Produktionspl_ne__lag5, RMSE = 2.3643
#   4400/25920 Features gerankt; letztes: Herstellung_von_Baubedarfsartikeln_aus_Kunststoffen.Exporterwartungen__lag7, RMSE = 2.3711
#   4450/25920 Features gerankt; letztes: Herstellung_von_Baubedarfsartikeln_aus_Kunststoffen.Gesch_ftslage_Erwartungen__lag9, RMSE = 2.3662
#   4500/25920 Features gerankt; letztes: Herstellung_von_Baubedarfsartikeln_aus_Kunststoffen.Produktion_gegen_Vormonat__lag11, RMSE = 2.3632
#   4550/25920 Features gerankt; letztes: Herstellung_von_Beh_ltern.Exporterwartungen__lag1, RMSE = 2.3650
#   4600/25920 Features gerankt; letztes: Herstellung_von_Beh_ltern.Gesch_ftslage_Erwartungen__lag3, RMSE = 2.3621
#   4650/25920 Features gerankt; letztes: Herstellung_von_Beh_ltern.Produktion_gegen_Vormonat__lag5, RMSE = 2.3710
#   4700/25920 Features gerankt; letztes: Herstellung_von_Bekleidung.Auftragsbestand_gegen_Vormonat__lag7, RMSE = 2.3657
#   4750/25920 Features gerankt; letztes: Herstellung_von_Bekleidung.Gesch_ftslage_Beurteilung__lag9, RMSE = 2.3694
#   4800/25920 Features gerankt; letztes: Herstellung_von_Bekleidung.Preiserwartungen__lag11, RMSE = 2.3700
#   4850/25920 Features gerankt; letztes: Herstellung_von_Bekleidung__ohne_Pelzbekleidung_.Auftragsbestand_gegen_Vormonat__lag1, RMSE = 2.3770
#   4900/25920 Features gerankt; letztes: Herstellung_von_Bekleidung__ohne_Pelzbekleidung_.Gesch_ftslage_Beurteilung__lag3, RMSE = 2.3587
#   4950/25920 Features gerankt; letztes: Herstellung_von_Bekleidung__ohne_Pelzbekleidung_.Preiserwartungen__lag5, RMSE = 2.3864
#   5000/25920 Features gerankt; letztes: Herstellung_von_Bergwerks__Bau__und_Baustoffmaschinen.Auftragsbestand_Beurteilung_Export__lag7, RMSE = 2.3616
#   5050/25920 Features gerankt; letztes: Herstellung_von_Bergwerks__Bau__und_Baustoffmaschinen.Gesch_ftsklima__lag9, RMSE = 2.3604
#   5100/25920 Features gerankt; letztes: Herstellung_von_Bergwerks__Bau__und_Baustoffmaschinen.Preise_gegen_Vormonat__lag11, RMSE = 2.3713
#   5150/25920 Features gerankt; letztes: Herstellung_von_Besen_und_B_rsten.Auftragsbestand_Beurteilung_Export__lag1, RMSE = 2.3631
#   5200/25920 Features gerankt; letztes: Herstellung_von_Besen_und_B_rsten.Gesch_ftsklima__lag3, RMSE = 2.3639
#   5250/25920 Features gerankt; letztes: Herstellung_von_Besen_und_B_rsten.Preise_gegen_Vormonat__lag5, RMSE = 2.3721
#   5300/25920 Features gerankt; letztes: Herstellung_von_Bier.Auftragsbestand_Beurteilung__lag7, RMSE = 2.3724
#   5350/25920 Features gerankt; letztes: Herstellung_von_Bier.Fertigwarenlager_Beurteilung__lag9, RMSE = 2.3653
#   5400/25920 Features gerankt; letztes: Herstellung_von_Bier.Nachfrage_gegen_Vormonat__lag11, RMSE = 2.3667
#   5450/25920 Features gerankt; letztes: Herstellung_von_B_ro__und_Ladenm_beln.Auftragsbestand_Beurteilung__lag1, RMSE = 2.3562
#   5500/25920 Features gerankt; letztes: Herstellung_von_B_ro__und_Ladenm_beln.Fertigwarenlager_Beurteilung__lag3, RMSE = 2.3613
#   5550/25920 Features gerankt; letztes: Herstellung_von_B_ro__und_Ladenm_beln.Nachfrage_gegen_Vormonat__lag5, RMSE = 2.3700
#   5600/25920 Features gerankt; letztes: Herstellung_von_B_ro__und_Ladenm_beln.Produktionspl_ne__lag7, RMSE = 2.3639
#   5650/25920 Features gerankt; letztes: Herstellung_von_DV_Ger_ten_und_peripheren_Ger_ten.Exporterwartungen__lag9, RMSE = 2.3633
#   5700/25920 Features gerankt; letztes: Herstellung_von_DV_Ger_ten_und_peripheren_Ger_ten.Gesch_ftslage_Erwartungen__lag11, RMSE = 2.3626
#   5750/25920 Features gerankt; letztes: Herstellung_von_DV_Ger_ten_und_peripheren_Ger_ten.Produktionspl_ne__lag1, RMSE = 2.3678
#   5800/25920 Features gerankt; letztes: Herstellung_von_Druckerzeugnissen.Exporterwartungen__lag3, RMSE = 2.3705
#   5850/25920 Features gerankt; letztes: Herstellung_von_Druckerzeugnissen.Gesch_ftslage_Erwartungen__lag5, RMSE = 2.3635
#   5900/25920 Features gerankt; letztes: Herstellung_von_Druckerzeugnissen.Produktion_gegen_Vormonat__lag7, RMSE = 2.3663
#   5950/25920 Features gerankt; letztes: Herstellung_von_Druckerzeugnissen_BD_SBR.1.Auftragsbestand_gegen_Vormonat__lag9, RMSE = 2.3693
#   6000/25920 Features gerankt; letztes: Herstellung_von_Druckerzeugnissen_BD_SBR.1.Gesch_ftslage_Beurteilung__lag11, RMSE = 2.3673
#   6050/25920 Features gerankt; letztes: Herstellung_von_Druckerzeugnissen_BD_SBR.1.Produktion_gegen_Vormonat__lag1, RMSE = 2.3709
#   6100/25920 Features gerankt; letztes: Herstellung_von_Elektromotoren_Generatoren_Transformatoren.Auftragsbestand_gegen_Vormonat__lag3, RMSE = 2.3622
#   6150/25920 Features gerankt; letztes: Herstellung_von_Elektromotoren_Generatoren_Transformatoren.Gesch_ftslage_Beurteilung__lag5, RMSE = 2.3619
#   6200/25920 Features gerankt; letztes: Herstellung_von_Elektromotoren_Generatoren_Transformatoren.Preiserwartungen__lag7, RMSE = 2.3727
#   6250/25920 Features gerankt; letztes: Herstellung_von_Elektromotoren_Generatoren_Transformatoren_usw..Auftragsbestand_Beurteilung_Export__lag9, RMSE = 2.3573
#   6300/25920 Features gerankt; letztes: Herstellung_von_Elektromotoren_Generatoren_Transformatoren_usw..Gesch_ftsklima__lag11, RMSE = 2.3577
#   6350/25920 Features gerankt; letztes: Herstellung_von_Elektromotoren_Generatoren_Transformatoren_usw..Preiserwartungen__lag1, RMSE = 2.3693
#   6400/25920 Features gerankt; letztes: Herstellung_von_Erfrischungsgetr_nken_und_Mineralwasser.Fertigwarenlager_Beurteilung__lag3, RMSE = 2.3617
#   6450/25920 Features gerankt; letztes: Herstellung_von_Erfrischungsgetr_nken_und_Mineralwasser.Nachfrage_gegen_Vormonat__lag5, RMSE = 2.3604
#   6500/25920 Features gerankt; letztes: Herstellung_von_Erzeugnissen_aus_Beton.Auftragsbestand_Beurteilung__lag7, RMSE = 2.3728
#   6550/25920 Features gerankt; letztes: Herstellung_von_Erzeugnissen_aus_Beton.Fertigwarenlager_Beurteilung__lag9, RMSE = 2.3632
#   6600/25920 Features gerankt; letztes: Herstellung_von_Erzeugnissen_aus_Beton.Nachfrage_gegen_Vormonat__lag11, RMSE = 2.3630
#   6650/25920 Features gerankt; letztes: Herstellung_von_Erzeugnissen_aus_Beton_Zement_und_Gips.Auftragsbestand_Beurteilung__lag1, RMSE = 2.3700
#   6700/25920 Features gerankt; letztes: Herstellung_von_Erzeugnissen_aus_Beton_Zement_und_Gips.Fertigwarenlager_Beurteilung__lag3, RMSE = 2.3610
#   6750/25920 Features gerankt; letztes: Herstellung_von_Erzeugnissen_aus_Beton_Zement_und_Gips.Nachfrage_gegen_Vormonat__lag5, RMSE = 2.3642
#   6800/25920 Features gerankt; letztes: Herstellung_von_Erzeugnissen_aus_Beton_Zement_und_Gips.Produktionspl_ne__lag7, RMSE = 2.3689
#   6850/25920 Features gerankt; letztes: Herstellung_von_Fertigbauteilen_und_Ausbauelementen.Exporterwartungen__lag9, RMSE = 2.3634
#   6900/25920 Features gerankt; letztes: Herstellung_von_Fertigbauteilen_und_Ausbauelementen.Gesch_ftslage_Erwartungen__lag11, RMSE = 2.3643
#   6950/25920 Features gerankt; letztes: Herstellung_von_Fertigbauteilen_und_Ausbauelementen.Produktionspl_ne__lag1, RMSE = 2.3681
#   7000/25920 Features gerankt; letztes: Herstellung_von_Fl_ssigkeitspumpen.Exporterwartungen__lag3, RMSE = 2.3652
#   7050/25920 Features gerankt; letztes: Herstellung_von_Fl_ssigkeitspumpen.Gesch_ftslage_Erwartungen__lag5, RMSE = 2.3679
#   7100/25920 Features gerankt; letztes: Herstellung_von_Fl_ssigkeitspumpen.Produktion_gegen_Vormonat__lag7, RMSE = 2.3641
#   7150/25920 Features gerankt; letztes: Herstellung_von_Furnier__Sperrholz__und_Holzspanplatten.Auftragsbestand_gegen_Vormonat__lag9, RMSE = 2.3632
#   7200/25920 Features gerankt; letztes: Herstellung_von_Furnier__Sperrholz__und_Holzspanplatten.Gesch_ftslage_Beurteilung__lag11, RMSE = 2.3744
#   7250/25920 Features gerankt; letztes: Herstellung_von_Furnier__Sperrholz__und_Holzspanplatten.Produktion_gegen_Vormonat__lag1, RMSE = 2.3658
#   7300/25920 Features gerankt; letztes: Herstellung_von_Gebrauchsg_tern.Auftragsbestand_gegen_Vormonat__lag3, RMSE = 2.3641
#   7350/25920 Features gerankt; letztes: Herstellung_von_Gebrauchsg_tern.Gesch_ftslage_Beurteilung__lag5, RMSE = 2.3613
#   7400/25920 Features gerankt; letztes: Herstellung_von_Gebrauchsg_tern.Preiserwartungen__lag7, RMSE = 2.3697
#   7450/25920 Features gerankt; letztes: Herstellung_von_Ger_ten_der_Telekommunikationstechnik.Auftragsbestand_Beurteilung_Export__lag9, RMSE = 2.3752
#   7500/25920 Features gerankt; letztes: Herstellung_von_Ger_ten_der_Telekommunikationstechnik.Gesch_ftsklima__lag11, RMSE = 2.3664
#   7550/25920 Features gerankt; letztes: Herstellung_von_Ger_ten_der_Telekommunikationstechnik.Preiserwartungen__lag1, RMSE = 2.3657
#   7600/25920 Features gerankt; letztes: Herstellung_von_Getrieben_Zahnr_dern_und_Antriebselementen.Auftragsbestand_Beurteilung_Export__lag3, RMSE = 2.3586
#   7650/25920 Features gerankt; letztes: Herstellung_von_Getrieben_Zahnr_dern_und_Antriebselementen.Gesch_ftsklima__lag5, RMSE = 2.3613
#   7700/25920 Features gerankt; letztes: Herstellung_von_Getrieben_Zahnr_dern_und_Antriebselementen.Preise_gegen_Vormonat__lag7, RMSE = 2.3731
#   7750/25920 Features gerankt; letztes: Herstellung_von_Glas_und_Glaswaren.Auftragsbestand_Beurteilung__lag9, RMSE = 2.3626
#   7800/25920 Features gerankt; letztes: Herstellung_von_Glas_und_Glaswaren.Fertigwarenlager_Beurteilung__lag11, RMSE = 2.3648
#   7850/25920 Features gerankt; letztes: Herstellung_von_Glas_und_Glaswaren.Preise_gegen_Vormonat__lag1, RMSE = 2.3660
#   7900/25920 Features gerankt; letztes: Herstellung_von_Gummi__und_Kunststoffindustriemaschinen.Auftragsbestand_Beurteilung__lag3, RMSE = 2.3628
#   7950/25920 Features gerankt; letztes: Herstellung_von_Gummi__und_Kunststoffindustriemaschinen.Fertigwarenlager_Beurteilung__lag5, RMSE = 2.3616
#   8000/25920 Features gerankt; letztes: Herstellung_von_Gummi__und_Kunststoffindustriemaschinen.Nachfrage_gegen_Vormonat__lag7, RMSE = 2.3619
#   8050/25920 Features gerankt; letztes: Herstellung_von_Gummi__und_Kunststoffindustriemaschinen.Produktionspl_ne__lag9, RMSE = 2.3536
#   8100/25920 Features gerankt; letztes: Herstellung_von_Gummi__und_Kunststoffwaren.Exporterwartungen__lag11, RMSE = 2.3639
#   8150/25920 Features gerankt; letztes: Herstellung_von_Gummi__und_Kunststoffwaren.Nachfrage_gegen_Vormonat__lag1, RMSE = 2.3982
#   8200/25920 Features gerankt; letztes: Herstellung_von_Gummi__und_Kunststoffwaren.Produktionspl_ne__lag3, RMSE = 2.3666
#   8250/25920 Features gerankt; letztes: Herstellung_von_Gummiwaren.Exporterwartungen__lag5, RMSE = 2.3616
#   8300/25920 Features gerankt; letztes: Herstellung_von_Gummiwaren.Gesch_ftslage_Erwartungen__lag7, RMSE = 2.3662
#   8350/25920 Features gerankt; letztes: Herstellung_von_Gummiwaren.Produktion_gegen_Vormonat__lag9, RMSE = 2.3449
#   8400/25920 Features gerankt; letztes: Herstellung_von_Haushaltsger_ten.Auftragsbestand_gegen_Vormonat__lag11, RMSE = 2.3686
#   8450/25920 Features gerankt; letztes: Herstellung_von_Haushaltsger_ten.Gesch_ftslage_Erwartungen__lag1, RMSE = 2.3757
#   8500/25920 Features gerankt; letztes: Herstellung_von_Haushaltsger_ten.Produktion_gegen_Vormonat__lag3, RMSE = 2.3734
#   8550/25920 Features gerankt; letztes: Herstellung_von_Hebezeugen_und_F_rdermitteln.Auftragsbestand_gegen_Vormonat__lag5, RMSE = 2.3694
#   8600/25920 Features gerankt; letztes: Herstellung_von_Hebezeugen_und_F_rdermitteln.Gesch_ftslage_Beurteilung__lag7, RMSE = 2.3632
#   8650/25920 Features gerankt; letztes: Herstellung_von_Hebezeugen_und_F_rdermitteln.Preiserwartungen__lag9, RMSE = 2.3676
#   8700/25920 Features gerankt; letztes: Herstellung_von_Heizkesseln_f_r_Zentralheizungen.Auftragsbestand_Beurteilung_Export__lag11, RMSE = 2.3628
#   8750/25920 Features gerankt; letztes: Herstellung_von_Heizkesseln_f_r_Zentralheizungen.Gesch_ftslage_Beurteilung__lag1, RMSE = 2.3647
#   8800/25920 Features gerankt; letztes: Herstellung_von_Heizkesseln_f_r_Zentralheizungen.Preiserwartungen__lag3, RMSE = 2.3788
#   8850/25920 Features gerankt; letztes: Herstellung_von_Heizkesseln_und__k_rpern_f_r_Zentralheizungen.Auftragsbestand_Beurteilung_Export__lag5, RMSE = 2.3604
#   8900/25920 Features gerankt; letztes: Herstellung_von_Heizkesseln_und__k_rpern_f_r_Zentralheizungen.Gesch_ftsklima__lag7, RMSE = 2.3668
#   8950/25920 Features gerankt; letztes: Herstellung_von_Heizkesseln_und__k_rpern_f_r_Zentralheizungen.Preise_gegen_Vormonat__lag9, RMSE = 2.3657
#   9000/25920 Features gerankt; letztes: Herstellung_von_Hohlglas.Auftragsbestand_Beurteilung__lag11, RMSE = 2.3648
#   9050/25920 Features gerankt; letztes: Herstellung_von_Hohlglas.Gesch_ftsklima__lag1, RMSE = 2.3719
#   9100/25920 Features gerankt; letztes: Herstellung_von_Hohlglas.Preise_gegen_Vormonat__lag3, RMSE = 2.3655
#   9150/25920 Features gerankt; letztes: Herstellung_von_Holz__und_Zellstoff_Papier_Karton_und_Pappe.Auftragsbestand_Beurteilung__lag5, RMSE = 2.3645
#   9200/25920 Features gerankt; letztes: Herstellung_von_Holz__und_Zellstoff_Papier_Karton_und_Pappe.Fertigwarenlager_Beurteilung__lag7, RMSE = 2.3630
#   9250/25920 Features gerankt; letztes: Herstellung_von_Holz__und_Zellstoff_Papier_Karton_und_Pappe.Nachfrage_gegen_Vormonat__lag9, RMSE = 2.3658
#   9300/25920 Features gerankt; letztes: Herstellung_von_Holz__und_Zellstoff_Papier_Karton_und_Pappe.Produktionspl_ne__lag11, RMSE = 2.3687
#   9350/25920 Features gerankt; letztes: Herstellung_von_Investitionsg_tern.Fertigwarenlager_Beurteilung__lag1, RMSE = 2.3676
#   9400/25920 Features gerankt; letztes: Herstellung_von_Investitionsg_tern.Nachfrage_gegen_Vormonat__lag3, RMSE = 2.3647
#   9450/25920 Features gerankt; letztes: Herstellung_von_Investitionsg_tern.Produktionspl_ne__lag5, RMSE = 2.3649
#   9500/25920 Features gerankt; letztes: Herstellung_von_Kabeln_und_Elektroinstallationsmaterial.Exporterwartungen__lag7, RMSE = 2.3718
#   9550/25920 Features gerankt; letztes: Herstellung_von_Kabeln_und_Elektroinstallationsmaterial.Gesch_ftslage_Erwartungen__lag9, RMSE = 2.3694
#   9600/25920 Features gerankt; letztes: Herstellung_von_Kabeln_und_Elektroinstallationsmaterial.Produktion_gegen_Vormonat__lag11, RMSE = 2.3741
#   9650/25920 Features gerankt; letztes: Herstellung_von_Karosserien_Aufbauten_und_Anh_ngern.Exporterwartungen__lag1, RMSE = 2.3693
#   9700/25920 Features gerankt; letztes: Herstellung_von_Karosserien_Aufbauten_und_Anh_ngern.Gesch_ftslage_Erwartungen__lag3, RMSE = 2.3635
#   9750/25920 Features gerankt; letztes: Herstellung_von_Karosserien_Aufbauten_und_Anh_ngern.Produktion_gegen_Vormonat__lag5, RMSE = 2.3598
#   9800/25920 Features gerankt; letztes: Herstellung_von_Karton_und_Pappe.Auftragsbestand_gegen_Vormonat__lag7, RMSE = 2.3564
#   9850/25920 Features gerankt; letztes: Herstellung_von_Karton_und_Pappe.Gesch_ftslage_Beurteilung__lag9, RMSE = 2.3716
#   9900/25920 Features gerankt; letztes: Herstellung_von_Karton_und_Pappe.Preiserwartungen__lag11, RMSE = 2.3697
#   9950/25920 Features gerankt; letztes: Herstellung_von_Konsumg_tern__Ge__und_Verbrauchsg_ter_.Auftragsbestand_gegen_Vormonat__lag1, RMSE = 2.3763
#   10000/25920 Features gerankt; letztes: Herstellung_von_Konsumg_tern__Ge__und_Verbrauchsg_ter_.Gesch_ftslage_Beurteilung__lag3, RMSE = 2.3661
#   10050/25920 Features gerankt; letztes: Herstellung_von_Konsumg_tern__Ge__und_Verbrauchsg_ter_.Preiserwartungen__lag5, RMSE = 2.3935
#   10100/25920 Features gerankt; letztes: Herstellung_von_Konsumg_tern__ohne_Ern_hrungsgewerbe_.Auftragsbestand_Beurteilung_Export__lag7, RMSE = 2.3652
#   10150/25920 Features gerankt; letztes: Herstellung_von_Konsumg_tern__ohne_Ern_hrungsgewerbe_.Gesch_ftsklima__lag9, RMSE = 2.3725
#   10200/25920 Features gerankt; letztes: Herstellung_von_Konsumg_tern__ohne_Ern_hrungsgewerbe_.Preise_gegen_Vormonat__lag11, RMSE = 2.3837
#   10250/25920 Features gerankt; letztes: Herstellung_von_Kraftwagen_und__motoren.Auftragsbestand_Beurteilung_Export__lag1, RMSE = 2.3615
#   10300/25920 Features gerankt; letztes: Herstellung_von_Kraftwagen_und__motoren.Gesch_ftsklima__lag3, RMSE = 2.3618
#   10350/25920 Features gerankt; letztes: Herstellung_von_Kraftwagen_und__motoren.Preise_gegen_Vormonat__lag5, RMSE = 2.3659
#   10400/25920 Features gerankt; letztes: Herstellung_von_Kraftwagen_und_Kraftwagenteilen.Auftragsbestand_Beurteilung__lag7, RMSE = 2.3369
#   10450/25920 Features gerankt; letztes: Herstellung_von_Kraftwagen_und_Kraftwagenteilen.Fertigwarenlager_Beurteilung__lag9, RMSE = 2.3751
#   10500/25920 Features gerankt; letztes: Herstellung_von_Kraftwagen_und_Kraftwagenteilen.Nachfrage_gegen_Vormonat__lag11, RMSE = 2.3633
#   10550/25920 Features gerankt; letztes: Herstellung_von_Kunststoffwaren.Auftragsbestand_Beurteilung__lag1, RMSE = 2.3670
#   10600/25920 Features gerankt; letztes: Herstellung_von_Kunststoffwaren.Fertigwarenlager_Beurteilung__lag3, RMSE = 2.3620
#   10650/25920 Features gerankt; letztes: Herstellung_von_Kunststoffwaren.Nachfrage_gegen_Vormonat__lag5, RMSE = 2.3673
#   10700/25920 Features gerankt; letztes: Herstellung_von_Kunststoffwaren.Produktionspl_ne__lag7, RMSE = 2.3661
#   10750/25920 Features gerankt; letztes: Herstellung_von_Lagern.Exporterwartungen__lag9, RMSE = 2.3641
#   10800/25920 Features gerankt; letztes: Herstellung_von_Lagern.Gesch_ftslage_Erwartungen__lag11, RMSE = 2.3597
#   10850/25920 Features gerankt; letztes: Herstellung_von_Lagern.Produktionspl_ne__lag1, RMSE = 2.3806
#   10900/25920 Features gerankt; letztes: Herstellung_von_Lagern_Getrieben_Zahnr_dern.Exporterwartungen__lag3, RMSE = 2.3645
#   10950/25920 Features gerankt; letztes: Herstellung_von_Lagern_Getrieben_Zahnr_dern.Gesch_ftslage_Erwartungen__lag5, RMSE = 2.3657
#   11000/25920 Features gerankt; letztes: Herstellung_von_Lagern_Getrieben_Zahnr_dern.Produktion_gegen_Vormonat__lag7, RMSE = 2.3623
#   11050/25920 Features gerankt; letztes: Herstellung_von_Leder_Lederwaren_und_Schuhen.Auftragsbestand_gegen_Vormonat__lag9, RMSE = 2.3603
#   11100/25920 Features gerankt; letztes: Herstellung_von_Leder_Lederwaren_und_Schuhen.Gesch_ftslage_Beurteilung__lag11, RMSE = 2.3697
#   11150/25920 Features gerankt; letztes: Herstellung_von_Leder_Lederwaren_und_Schuhen.Produktion_gegen_Vormonat__lag1, RMSE = 2.3911
#   11200/25920 Features gerankt; letztes: Herstellung_von_Leder_und_Lederwaren__ohne_Lederbekleidung_.Exporterwartungen__lag3, RMSE = 2.3544
#   11250/25920 Features gerankt; letztes: Herstellung_von_Leder_und_Lederwaren__ohne_Lederbekleidung_.Gesch_ftslage_Erwartungen__lag5, RMSE = 2.3948
#   11300/25920 Features gerankt; letztes: Herstellung_von_Leder_und_Lederwaren__ohne_Lederbekleidung_.Produktion_gegen_Vormonat__lag7, RMSE = 2.3675
#   11350/25920 Features gerankt; letztes: Herstellung_von_Mahl__und_Sch_lm_hlen_St_rkeerzeugnissen.Auftragsbestand_gegen_Vormonat__lag9, RMSE = 2.3400
#   11400/25920 Features gerankt; letztes: Herstellung_von_Mahl__und_Sch_lm_hlen_St_rkeerzeugnissen.Gesch_ftslage_Beurteilung__lag11, RMSE = 2.3704
#   11450/25920 Features gerankt; letztes: Herstellung_von_Mahl__und_Sch_lm_hlen_St_rkeerzeugnissen.Produktion_gegen_Vormonat__lag1, RMSE = 2.3680
#   11500/25920 Features gerankt; letztes: Herstellung_von_Maschinen_f_r_das_Ern_hrungsgewerbe.Auftragsbestand_gegen_Vormonat__lag3, RMSE = 2.3747
#   11550/25920 Features gerankt; letztes: Herstellung_von_Maschinen_f_r_das_Ern_hrungsgewerbe.Gesch_ftslage_Beurteilung__lag5, RMSE = 2.3699
#   11600/25920 Features gerankt; letztes: Herstellung_von_Maschinen_f_r_das_Ern_hrungsgewerbe.Preiserwartungen__lag7, RMSE = 2.3801
#   11650/25920 Features gerankt; letztes: Herstellung_von_Maschinen_f_r_das_Textilgewerbe.Auftragsbestand_Beurteilung_Export__lag9, RMSE = 2.3682
#   11700/25920 Features gerankt; letztes: Herstellung_von_Maschinen_f_r_das_Textilgewerbe.Gesch_ftsklima__lag11, RMSE = 2.3728
#   11750/25920 Features gerankt; letztes: Herstellung_von_Maschinen_f_r_das_Textilgewerbe.Preiserwartungen__lag1, RMSE = 2.3757
#   11800/25920 Features gerankt; letztes: Herstellung_von_Maschinen_f_r_sonstige_bestimmte_Branchen.Auftragsbestand_Beurteilung_Export__lag3, RMSE = 2.3620
#   11850/25920 Features gerankt; letztes: Herstellung_von_Maschinen_f_r_sonstige_bestimmte_Branchen.Gesch_ftsklima__lag5, RMSE = 2.3634
#   11900/25920 Features gerankt; letztes: Herstellung_von_Maschinen_f_r_sonstige_bestimmte_Branchen.Preise_gegen_Vormonat__lag7, RMSE = 2.3705
#   11950/25920 Features gerankt; letztes: Herstellung_von_Maschinen_zur_Bearbeitung_harter_Stoffe.Auftragsbestand_Beurteilung__lag9, RMSE = 2.3646
#   12000/25920 Features gerankt; letztes: Herstellung_von_Maschinen_zur_Bearbeitung_harter_Stoffe.Fertigwarenlager_Beurteilung__lag11, RMSE = 2.3648
#   12050/25920 Features gerankt; letztes: Herstellung_von_Maschinen_zur_Bearbeitung_harter_Stoffe.Preise_gegen_Vormonat__lag1, RMSE = 2.3672
#   12100/25920 Features gerankt; letztes: Herstellung_von_Mess__und_Navigationsinstrumenten.Auftragsbestand_Beurteilung__lag3, RMSE = 2.3640
#   12150/25920 Features gerankt; letztes: Herstellung_von_Mess__und_Navigationsinstrumenten.Fertigwarenlager_Beurteilung__lag5, RMSE = 2.3621
#   12200/25920 Features gerankt; letztes: Herstellung_von_Mess__und_Navigationsinstrumenten.Nachfrage_gegen_Vormonat__lag7, RMSE = 2.3649
#   12250/25920 Features gerankt; letztes: Herstellung_von_Mess__und_Navigationsinstrumenten.Produktionspl_ne__lag9, RMSE = 2.3595
#   12300/25920 Features gerankt; letztes: Herstellung_von_Metallerzeugnissen.Exporterwartungen__lag11, RMSE = 2.3676
#   12350/25920 Features gerankt; letztes: Herstellung_von_Metallerzeugnissen.Nachfrage_gegen_Vormonat__lag1, RMSE = 2.3883
#   12400/25920 Features gerankt; letztes: Herstellung_von_Metallerzeugnissen.Produktionspl_ne__lag3, RMSE = 2.3650
#   12450/25920 Features gerankt; letztes: Herstellung_von_Metallerzeugungsmaschinen.Exporterwartungen__lag5, RMSE = 2.3642
#   12500/25920 Features gerankt; letztes: Herstellung_von_Metallerzeugungsmaschinen.Gesch_ftslage_Erwartungen__lag7, RMSE = 2.3562
#   12550/25920 Features gerankt; letztes: Herstellung_von_Metallerzeugungsmaschinen.Produktion_gegen_Vormonat__lag9, RMSE = 2.3621
#   12600/25920 Features gerankt; letztes: Herstellung_von_Metallkonstruktionen.Auftragsbestand_gegen_Vormonat__lag11, RMSE = 2.3800
#   12650/25920 Features gerankt; letztes: Herstellung_von_Metallkonstruktionen.Gesch_ftslage_Erwartungen__lag1, RMSE = 2.3801
#   12700/25920 Features gerankt; letztes: Herstellung_von_Metallkonstruktionen.Produktion_gegen_Vormonat__lag3, RMSE = 2.3622
#   12750/25920 Features gerankt; letztes: Herstellung_von_Metalltanks_Heizk_rpern_und__kesseln.Auftragsbestand_gegen_Vormonat__lag5, RMSE = 2.3742
#   12800/25920 Features gerankt; letztes: Herstellung_von_Metalltanks_Heizk_rpern_und__kesseln.Gesch_ftslage_Beurteilung__lag7, RMSE = 2.3655
#   12850/25920 Features gerankt; letztes: Herstellung_von_Metalltanks_Heizk_rpern_und__kesseln.Preiserwartungen__lag9, RMSE = 2.3749
#   12900/25920 Features gerankt; letztes: Herstellung_von_M_beln.Auftragsbestand_Beurteilung_Export__lag11, RMSE = 2.3657
#   12950/25920 Features gerankt; letztes: Herstellung_von_M_beln.Gesch_ftslage_Beurteilung__lag1, RMSE = 2.3601
#   13000/25920 Features gerankt; letztes: Herstellung_von_M_beln.Preiserwartungen__lag3, RMSE = 2.3960
#   13050/25920 Features gerankt; letztes: Herstellung_von_Nahrungs__und_Futtermitteln.Auftragsbestand_Beurteilung_Export__lag5, RMSE = 2.3648
#   13100/25920 Features gerankt; letztes: Herstellung_von_Nahrungs__und_Futtermitteln.Gesch_ftsklima__lag7, RMSE = 2.3660
#   13150/25920 Features gerankt; letztes: Herstellung_von_Nahrungs__und_Futtermitteln.Preise_gegen_Vormonat__lag9, RMSE = 2.3782
#   13200/25920 Features gerankt; letztes: Herstellung_von_Nutzkraftwagen.Auftragsbestand_Beurteilung__lag11, RMSE = 2.3564
#   13250/25920 Features gerankt; letztes: Herstellung_von_Nutzkraftwagen.Gesch_ftsklima__lag1, RMSE = 2.3671
#   13300/25920 Features gerankt; letztes: Herstellung_von_Nutzkraftwagen.Preise_gegen_Vormonat__lag3, RMSE = 2.3606
#   13350/25920 Features gerankt; letztes: Herstellung_von_Papier.Auftragsbestand_Beurteilung_Export__lag5, RMSE = 2.3650
#   13400/25920 Features gerankt; letztes: Herstellung_von_Papier.Gesch_ftsklima__lag7, RMSE = 2.3671
#   13450/25920 Features gerankt; letztes: Herstellung_von_Papier.Preise_gegen_Vormonat__lag9, RMSE = 2.3627
#   13500/25920 Features gerankt; letztes: Herstellung_von_Papier_Karton_und_Pappe.Auftragsbestand_Beurteilung__lag11, RMSE = 2.3690
#   13550/25920 Features gerankt; letztes: Herstellung_von_Papier_Karton_und_Pappe.Gesch_ftsklima__lag1, RMSE = 2.3749
#   13600/25920 Features gerankt; letztes: Herstellung_von_Papier_Karton_und_Pappe.Preise_gegen_Vormonat__lag3, RMSE = 2.3661
#   13650/25920 Features gerankt; letztes: Herstellung_von_Personenkraftwagen_einschlie_lich_Kombis.Auftragsbestand_Beurteilung__lag5, RMSE = 2.3554
#   13700/25920 Features gerankt; letztes: Herstellung_von_Personenkraftwagen_einschlie_lich_Kombis.Fertigwarenlager_Beurteilung__lag7, RMSE = 2.3642
#   13750/25920 Features gerankt; letztes: Herstellung_von_Personenkraftwagen_einschlie_lich_Kombis.Nachfrage_gegen_Vormonat__lag9, RMSE = 2.3579
#   13800/25920 Features gerankt; letztes: Herstellung_von_Personenkraftwagen_einschlie_lich_Kombis.Produktionspl_ne__lag11, RMSE = 2.3574
#   13850/25920 Features gerankt; letztes: Herstellung_von_Platten_Folien_Schl_uchen_und_Profilen.Fertigwarenlager_Beurteilung__lag1, RMSE = 2.3671
#   13900/25920 Features gerankt; letztes: Herstellung_von_Platten_Folien_Schl_uchen_und_Profilen.Nachfrage_gegen_Vormonat__lag3, RMSE = 2.3639
#   13950/25920 Features gerankt; letztes: Herstellung_von_Platten_Folien_Schl_uchen_und_Profilen.Produktionspl_ne__lag5, RMSE = 2.3666
#   14000/25920 Features gerankt; letztes: Herstellung_von_Polsterm_beln.Exporterwartungen__lag7, RMSE = 2.3618
#   14050/25920 Features gerankt; letztes: Herstellung_von_Polsterm_beln.Gesch_ftslage_Erwartungen__lag9, RMSE = 2.3654
#   14100/25920 Features gerankt; letztes: Herstellung_von_Polsterm_beln.Produktion_gegen_Vormonat__lag11, RMSE = 2.3670
#   14150/25920 Features gerankt; letztes: Herstellung_von_Pr_zisionswerkzeugen.Exporterwartungen__lag1, RMSE = 2.3916
#   14200/25920 Features gerankt; letztes: Herstellung_von_Pr_zisionswerkzeugen.Gesch_ftslage_Erwartungen__lag3, RMSE = 2.3664
#   14250/25920 Features gerankt; letztes: Herstellung_von_Pr_zisionswerkzeugen.Produktion_gegen_Vormonat__lag5, RMSE = 2.3667
#   14300/25920 Features gerankt; letztes: Herstellung_von_Schleifk_rpern_und_Schleifmitteln.Auftragsbestand_gegen_Vormonat__lag7, RMSE = 2.3655
#   14350/25920 Features gerankt; letztes: Herstellung_von_Schleifk_rpern_und_Schleifmitteln.Gesch_ftslage_Beurteilung__lag9, RMSE = 2.3496
#   14400/25920 Features gerankt; letztes: Herstellung_von_Schleifk_rpern_und_Schleifmitteln.Preiserwartungen__lag11, RMSE = 2.3497
#   14450/25920 Features gerankt; letztes: Herstellung_von_Schl_ssern_und_Beschl_gen.Auftragsbestand_gegen_Vormonat__lag1, RMSE = 2.3737
#   14500/25920 Features gerankt; letztes: Herstellung_von_Schl_ssern_und_Beschl_gen.Gesch_ftslage_Beurteilung__lag3, RMSE = 2.3558
#   14550/25920 Features gerankt; letztes: Herstellung_von_Schl_ssern_und_Beschl_gen.Preiserwartungen__lag5, RMSE = 2.3940
#   14600/25920 Features gerankt; letztes: Herstellung_von_Schmiede__Press__Zieh__und_Stanzteilen.Auftragsbestand_Beurteilung_Export__lag7, RMSE = 2.3646
#   14650/25920 Features gerankt; letztes: Herstellung_von_Schmiede__Press__Zieh__und_Stanzteilen.Gesch_ftsklima__lag9, RMSE = 2.3687
#   14700/25920 Features gerankt; letztes: Herstellung_von_Schmiede__Press__Zieh__und_Stanzteilen.Preise_gegen_Vormonat__lag11, RMSE = 2.3614
#   14750/25920 Features gerankt; letztes: Herstellung_von_Schneidwaren_Werkzeugen_Schl_ssern.Auftragsbestand_Beurteilung_Export__lag1, RMSE = 2.3614
#   14800/25920 Features gerankt; letztes: Herstellung_von_Schneidwaren_Werkzeugen_Schl_ssern.Gesch_ftsklima__lag3, RMSE = 2.3652
#   14850/25920 Features gerankt; letztes: Herstellung_von_Schneidwaren_Werkzeugen_Schl_ssern.Preise_gegen_Vormonat__lag5, RMSE = 2.3780
#   14900/25920 Features gerankt; letztes: Herstellung_von_Schneidwaren_und_Bestecken.Auftragsbestand_Beurteilung__lag7, RMSE = 2.3667
#   14950/25920 Features gerankt; letztes: Herstellung_von_Schneidwaren_und_Bestecken.Fertigwarenlager_Beurteilung__lag9, RMSE = 2.3630
#   15000/25920 Features gerankt; letztes: Herstellung_von_Schneidwaren_und_Bestecken.Nachfrage_gegen_Vormonat__lag11, RMSE = 2.3629
#   15050/25920 Features gerankt; letztes: Herstellung_von_Schrauben_und_Nieten.Auftragsbestand_Beurteilung_Export__lag1, RMSE = 2.3654
#   15100/25920 Features gerankt; letztes: Herstellung_von_Schrauben_und_Nieten.Gesch_ftsklima__lag3, RMSE = 2.3613
#   15150/25920 Features gerankt; letztes: Herstellung_von_Schrauben_und_Nieten.Preise_gegen_Vormonat__lag5, RMSE = 2.3638
#   15200/25920 Features gerankt; letztes: Herstellung_von_Schreibwaren_und_B_robedarf_aus_Papier.Auftragsbestand_Beurteilung__lag7, RMSE = 2.3668
#   15250/25920 Features gerankt; letztes: Herstellung_von_Schreibwaren_und_B_robedarf_aus_Papier.Fertigwarenlager_Beurteilung__lag9, RMSE = 2.3642
#   15300/25920 Features gerankt; letztes: Herstellung_von_Schreibwaren_und_B_robedarf_aus_Papier.Nachfrage_gegen_Vormonat__lag11, RMSE = 2.3577
#   15350/25920 Features gerankt; letztes: Herstellung_von_Schuhen.Auftragsbestand_Beurteilung__lag1, RMSE = 2.3735
#   15400/25920 Features gerankt; letztes: Herstellung_von_Schuhen.Fertigwarenlager_Beurteilung__lag3, RMSE = 2.3672
#   15450/25920 Features gerankt; letztes: Herstellung_von_Schuhen.Nachfrage_gegen_Vormonat__lag5, RMSE = 2.3726
#   15500/25920 Features gerankt; letztes: Herstellung_von_Schuhen.Produktionspl_ne__lag7, RMSE = 2.3662
#   15550/25920 Features gerankt; letztes: Herstellung_von_Spirituosen.Exporterwartungen__lag9, RMSE = 2.3698
#   15600/25920 Features gerankt; letztes: Herstellung_von_Spirituosen.Gesch_ftslage_Erwartungen__lag11, RMSE = 2.3701
#   15650/25920 Features gerankt; letztes: Herstellung_von_Spirituosen.Produktionspl_ne__lag1, RMSE = 2.3285
#   15700/25920 Features gerankt; letztes: Herstellung_von_Strumpfwaren.Gesch_ftsklima__lag3, RMSE = 2.3744
#   15750/25920 Features gerankt; letztes: Herstellung_von_Strumpfwaren.Preiserwartungen__lag5, RMSE = 2.3644
#   15800/25920 Features gerankt; letztes: Herstellung_von_S__waren__einschlie_lich_Dauerbackwaren_.Auftragsbestand_Beurteilung_Export__lag7, RMSE = 2.3739
#   15850/25920 Features gerankt; letztes: Herstellung_von_S__waren__einschlie_lich_Dauerbackwaren_.Gesch_ftsklima__lag9, RMSE = 2.3732
#   15900/25920 Features gerankt; letztes: Herstellung_von_S__waren__einschlie_lich_Dauerbackwaren_.Preise_gegen_Vormonat__lag11, RMSE = 2.3980
#   15950/25920 Features gerankt; letztes: Herstellung_von_Teilen_und_Zubeh_r_f_r_Kraftwagen.Auftragsbestand_Beurteilung_Export__lag1, RMSE = 2.3677
#   16000/25920 Features gerankt; letztes: Herstellung_von_Teilen_und_Zubeh_r_f_r_Kraftwagen.Gesch_ftsklima__lag3, RMSE = 2.3656
#   16050/25920 Features gerankt; letztes: Herstellung_von_Teilen_und_Zubeh_r_f_r_Kraftwagen.Preise_gegen_Vormonat__lag5, RMSE = 2.3671
#   16100/25920 Features gerankt; letztes: Herstellung_von_Textilien.Auftragsbestand_Beurteilung__lag7, RMSE = 2.3682
#   16150/25920 Features gerankt; letztes: Herstellung_von_Textilien.Fertigwarenlager_Beurteilung__lag9, RMSE = 2.3662
#   16200/25920 Features gerankt; letztes: Herstellung_von_Textilien.Nachfrage_gegen_Vormonat__lag11, RMSE = 2.3613
#   16250/25920 Features gerankt; letztes: Herstellung_von_Verbrauchsg_tern.Auftragsbestand_Beurteilung__lag1, RMSE = 2.3639
#   16300/25920 Features gerankt; letztes: Herstellung_von_Verbrauchsg_tern.Fertigwarenlager_Beurteilung__lag3, RMSE = 2.3642
#   16350/25920 Features gerankt; letztes: Herstellung_von_Verbrauchsg_tern.Nachfrage_gegen_Vormonat__lag5, RMSE = 2.3689
#   16400/25920 Features gerankt; letztes: Herstellung_von_Verbrauchsg_tern.Produktionspl_ne__lag7, RMSE = 2.3696
#   16450/25920 Features gerankt; letztes: Herstellung_von_Verbrauchsg_tern__ohne_Ern_hrungsgewerbe_.Exporterwartungen__lag9, RMSE = 2.3759
#   16500/25920 Features gerankt; letztes: Herstellung_von_Verbrauchsg_tern__ohne_Ern_hrungsgewerbe_.Gesch_ftslage_Erwartungen__lag11, RMSE = 2.3769
#   16550/25920 Features gerankt; letztes: Herstellung_von_Verbrauchsg_tern__ohne_Ern_hrungsgewerbe_.Produktionspl_ne__lag1, RMSE = 2.3758
#   16600/25920 Features gerankt; letztes: Herstellung_von_Verpackungen_und_Verschl_ssen_aus_Metall.Exporterwartungen__lag3, RMSE = 2.3650
#   16650/25920 Features gerankt; letztes: Herstellung_von_Verpackungen_und_Verschl_ssen_aus_Metall.Gesch_ftslage_Erwartungen__lag5, RMSE = 2.3654
#   16700/25920 Features gerankt; letztes: Herstellung_von_Verpackungen_und_Verschl_ssen_aus_Metall.Produktion_gegen_Vormonat__lag7, RMSE = 2.3659
#   16750/25920 Features gerankt; letztes: Herstellung_von_Verpackungsmitteln_aus_Holz.Auftragsbestand_gegen_Vormonat__lag9, RMSE = 2.3662
#   16800/25920 Features gerankt; letztes: Herstellung_von_Verpackungsmitteln_aus_Holz.Gesch_ftslage_Beurteilung__lag11, RMSE = 2.3650
#   16850/25920 Features gerankt; letztes: Herstellung_von_Verpackungsmitteln_aus_Holz.Produktion_gegen_Vormonat__lag1, RMSE = 2.3697
#   16900/25920 Features gerankt; letztes: Herstellung_von_Verpackungsmitteln_aus_Kunststoffen.Auftragsbestand_gegen_Vormonat__lag3, RMSE = 2.3673
#   16950/25920 Features gerankt; letztes: Herstellung_von_Verpackungsmitteln_aus_Kunststoffen.Gesch_ftslage_Beurteilung__lag5, RMSE = 2.3662
#   17000/25920 Features gerankt; letztes: Herstellung_von_Verpackungsmitteln_aus_Kunststoffen.Preiserwartungen__lag7, RMSE = 2.3727
#   17050/25920 Features gerankt; letztes: Herstellung_von_Vorleistungsg_tern.Auftragsbestand_Beurteilung_Export__lag9, RMSE = 2.3594
#   17100/25920 Features gerankt; letztes: Herstellung_von_Vorleistungsg_tern.Gesch_ftsklima__lag11, RMSE = 2.3679
#   17150/25920 Features gerankt; letztes: Herstellung_von_Vorleistungsg_tern.Preiserwartungen__lag1, RMSE = 2.3677
#   17200/25920 Features gerankt; letztes: Herstellung_von_Wasch__Reinigungs__u._K_rperpflegemitteln.Auftragsbestand_Beurteilung_Export__lag3, RMSE = 2.3586
#   17250/25920 Features gerankt; letztes: Herstellung_von_Wasch__Reinigungs__u._K_rperpflegemitteln.Gesch_ftsklima__lag5, RMSE = 2.3643
#   17300/25920 Features gerankt; letztes: Herstellung_von_Wasch__Reinigungs__u._K_rperpflegemitteln.Preise_gegen_Vormonat__lag7, RMSE = 2.3696
#   17350/25920 Features gerankt; letztes: Herstellung_von_Wellpapier_und__pappe_Verpackungsmitteln.Auftragsbestand_Beurteilung__lag9, RMSE = 2.3759
#   17400/25920 Features gerankt; letztes: Herstellung_von_Wellpapier_und__pappe_Verpackungsmitteln.Fertigwarenlager_Beurteilung__lag11, RMSE = 2.3686
#   17450/25920 Features gerankt; letztes: Herstellung_von_Wellpapier_und__pappe_Verpackungsmitteln.Preise_gegen_Vormonat__lag1, RMSE = 2.3635
#   17500/25920 Features gerankt; letztes: Herstellung_von_Werkzeugen.Auftragsbestand_Beurteilung__lag3, RMSE = 2.3670
#   17550/25920 Features gerankt; letztes: Herstellung_von_Werkzeugen.Fertigwarenlager_Beurteilung__lag5, RMSE = 2.3556
#   17600/25920 Features gerankt; letztes: Herstellung_von_Werkzeugen.Nachfrage_gegen_Vormonat__lag7, RMSE = 2.3676
#   17650/25920 Features gerankt; letztes: Herstellung_von_Werkzeugen.Produktionspl_ne__lag9, RMSE = 2.3459
#   17700/25920 Features gerankt; letztes: Herstellung_von_Werkzeugen__ohne_Pr_zisionswerkzeuge_.Exporterwartungen__lag11, RMSE = 2.3724
#   17750/25920 Features gerankt; letztes: Herstellung_von_Werkzeugen__ohne_Pr_zisionswerkzeuge_.Nachfrage_gegen_Vormonat__lag1, RMSE = 2.3759
#   17800/25920 Features gerankt; letztes: Herstellung_von_Werkzeugen__ohne_Pr_zisionswerkzeuge_.Produktionspl_ne__lag3, RMSE = 2.3665
#   17850/25920 Features gerankt; letztes: Herstellung_von_Werkzeugmaschinen.Exporterwartungen__lag5, RMSE = 2.3714
#   17900/25920 Features gerankt; letztes: Herstellung_von_Werkzeugmaschinen.Gesch_ftslage_Erwartungen__lag7, RMSE = 2.3711
#   17950/25920 Features gerankt; letztes: Herstellung_von_Werkzeugmaschinen.Produktion_gegen_Vormonat__lag9, RMSE = 2.3621
#   18000/25920 Features gerankt; letztes: Herstellung_von_Werkzeugmaschinen_f_r_die_Metallbearbeitung.Auftragsbestand_gegen_Vormonat__lag11, RMSE = 2.3762
# ...
#   19950/25920 Features gerankt; letztes: Herstellung_von_k_lte__und_lufttechnischen_Erzeugnissen.Preise_gegen_Vormonat__lag5, RMSE = 2.3571
#   20000/25920 Features gerankt; letztes: Herstellung_von_land__und_forstwirtschaftlichen_Maschinen.Auftragsbestand_Beurteilung__lag7, RMSE = 2.3622
#   20050/25920 Features gerankt; letztes: Herstellung_von_land__und_forstwirtschaftlichen_Maschinen.Fertigwarenlager_Beurteilung__lag9, RMSE = 2.3550
#   20100/25920 Features gerankt; letztes: Herstellung_von_land__und_forstwirtschaftlichen_Maschinen.Nachfrage_gegen_Vormonat__lag11, RMSE = 2.3670
#   20150/25920 Features gerankt; letztes: Herstellung_von_medizinischen_Apparaten_und_Materialien.Auftragsbestand_Beurteilung__lag1, RMSE = 2.3492
#   20200/25920 Features gerankt; letztes: Herstellung_von_medizinischen_Apparaten_und_Materialien.Fertigwarenlager_Beurteilung__lag3, RMSE = 2.3652
#   20250/25920 Features gerankt; letztes: Herstellung_von_medizinischen_Apparaten_und_Materialien.Nachfrage_gegen_Vormonat__lag5, RMSE = 2.3521
#   20300/25920 Features gerankt; letztes: Herstellung_von_medizinischen_Apparaten_und_Materialien.Produktionspl_ne__lag7, RMSE = 2.3689
#   20350/25920 Features gerankt; letztes: Herstellung_von_medizinmechanischen_Erzeugnissen.Exporterwartungen__lag9, RMSE = 2.3762
#   20400/25920 Features gerankt; letztes: Herstellung_von_medizinmechanischen_Erzeugnissen.Gesch_ftslage_Erwartungen__lag11, RMSE = 2.3601
#   20450/25920 Features gerankt; letztes: Herstellung_von_medizinmechanischen_Erzeugnissen.Produktionspl_ne__lag1, RMSE = 2.3466
#   20500/25920 Features gerankt; letztes: Herstellung_von_nicht_branchenspezifischen_Maschinen.Exporterwartungen__lag3, RMSE = 2.3659
#   20550/25920 Features gerankt; letztes: Herstellung_von_nicht_branchenspezifischen_Maschinen.Gesch_ftslage_Erwartungen__lag5, RMSE = 2.3743
#   20600/25920 Features gerankt; letztes: Herstellung_von_nicht_branchenspezifischen_Maschinen.Produktion_gegen_Vormonat__lag7, RMSE = 2.3643
#   20650/25920 Features gerankt; letztes: Herstellung_von_optischen_Instrumenten_und_Lasern.Auftragsbestand_gegen_Vormonat__lag9, RMSE = 2.3597
#   20700/25920 Features gerankt; letztes: Herstellung_von_optischen_Instrumenten_und_Lasern.Gesch_ftslage_Beurteilung__lag11, RMSE = 2.3597
#   20750/25920 Features gerankt; letztes: Herstellung_von_optischen_Instrumenten_und_Lasern.Produktion_gegen_Vormonat__lag1, RMSE = 2.3725
#   20800/25920 Features gerankt; letztes: Herstellung_von_optischen_und_fotografischen_Ger_ten.Auftragsbestand_gegen_Vormonat__lag3, RMSE = 2.3670
#   20850/25920 Features gerankt; letztes: Herstellung_von_optischen_und_fotografischen_Ger_ten.Gesch_ftslage_Beurteilung__lag5, RMSE = 2.3600
#   20900/25920 Features gerankt; letztes: Herstellung_von_optischen_und_fotografischen_Ger_ten.Preiserwartungen__lag7, RMSE = 2.3748
#   20950/25920 Features gerankt; letztes: Herstellung_von_pneumatischen_Steuerungen.Auftragsbestand_Beurteilung_Export__lag9, RMSE = 2.3643
#   21000/25920 Features gerankt; letztes: Herstellung_von_pneumatischen_Steuerungen.Gesch_ftsklima__lag11, RMSE = 2.3673
#   21050/25920 Features gerankt; letztes: Herstellung_von_pneumatischen_Steuerungen.Preiserwartungen__lag1, RMSE = 2.3650
#   21100/25920 Features gerankt; letztes: Herstellung_von_sonstigen_Gummiwaren.Auftragsbestand_Beurteilung_Export__lag3, RMSE = 2.3593
#   21150/25920 Features gerankt; letztes: Herstellung_von_sonstigen_Gummiwaren.Gesch_ftsklima__lag5, RMSE = 2.3606
#   21200/25920 Features gerankt; letztes: Herstellung_von_sonstigen_Gummiwaren.Preise_gegen_Vormonat__lag7, RMSE = 2.3624
#   21250/25920 Features gerankt; letztes: Herstellung_von_sonstigen_Kunststoffwaren.Auftragsbestand_Beurteilung__lag9, RMSE = 2.3676
#   21300/25920 Features gerankt; letztes: Herstellung_von_sonstigen_Kunststoffwaren.Fertigwarenlager_Beurteilung__lag11, RMSE = 2.3686
#   21350/25920 Features gerankt; letztes: Herstellung_von_sonstigen_Kunststoffwaren.Preise_gegen_Vormonat__lag1, RMSE = 2.3731
#   21400/25920 Features gerankt; letztes: Herstellung_von_sonstigen_Metallwaren.Auftragsbestand_Beurteilung__lag3, RMSE = 2.3694
#   21450/25920 Features gerankt; letztes: Herstellung_von_sonstigen_Metallwaren.Fertigwarenlager_Beurteilung__lag5, RMSE = 2.3630
#   21500/25920 Features gerankt; letztes: Herstellung_von_sonstigen_Metallwaren.Nachfrage_gegen_Vormonat__lag7, RMSE = 2.3639
#   21550/25920 Features gerankt; letztes: Herstellung_von_sonstigen_Metallwaren.Produktionspl_ne__lag9, RMSE = 2.3774
#   21600/25920 Features gerankt; letztes: Herstellung_von_sonstigen_M_bel.Exporterwartungen__lag11, RMSE = 2.3451
#   21650/25920 Features gerankt; letztes: Herstellung_von_sonstigen_M_bel.Nachfrage_gegen_Vormonat__lag1, RMSE = 2.3766
#   21700/25920 Features gerankt; letztes: Herstellung_von_sonstigen_M_bel.Produktionspl_ne__lag3, RMSE = 2.3601
#   21750/25920 Features gerankt; letztes: Herstellung_von_sonstigen_Nahrungsmitteln.Exporterwartungen__lag5, RMSE = 2.3716
#   21800/25920 Features gerankt; letztes: Herstellung_von_sonstigen_Nahrungsmitteln.Gesch_ftslage_Erwartungen__lag7, RMSE = 2.3514
#   21850/25920 Features gerankt; letztes: Herstellung_von_sonstigen_Nahrungsmitteln.Produktion_gegen_Vormonat__lag9, RMSE = 2.3533
#   21900/25920 Features gerankt; letztes: Herstellung_von_sonstigen_Textilwaren.Auftragsbestand_gegen_Vormonat__lag11, RMSE = 2.3571
#   21950/25920 Features gerankt; letztes: Herstellung_von_sonstigen_Textilwaren.Gesch_ftslage_Erwartungen__lag1, RMSE = 2.3974
#   22000/25920 Features gerankt; letztes: Herstellung_von_sonstigen_Textilwaren.Produktion_gegen_Vormonat__lag3, RMSE = 2.3654
#   22050/25920 Features gerankt; letztes: Herstellung_von_sonstigen_Waren.Auftragsbestand_gegen_Vormonat__lag5, RMSE = 2.3630
#   22100/25920 Features gerankt; letztes: Herstellung_von_sonstigen_Waren.Gesch_ftslage_Beurteilung__lag7, RMSE = 2.3735
#   22150/25920 Features gerankt; letztes: Herstellung_von_sonstigen_Waren.Preiserwartungen__lag9, RMSE = 2.3788
#   22200/25920 Features gerankt; letztes: Herstellung_von_sonstigen_chemischen_Erzeugnissen.Auftragsbestand_Beurteilung_Export__lag11, RMSE = 2.3642
#   22250/25920 Features gerankt; letztes: Herstellung_von_sonstigen_chemischen_Erzeugnissen.Gesch_ftslage_Beurteilung__lag1, RMSE = 2.3637
#   22300/25920 Features gerankt; letztes: Herstellung_von_sonstigen_chemischen_Erzeugnissen.Preiserwartungen__lag3, RMSE = 2.3653
#   22350/25920 Features gerankt; letztes: Herstellung_von_sonstiger_Keramik.Auftragsbestand_Beurteilung_Export__lag5, RMSE = 2.3673
#   22400/25920 Features gerankt; letztes: Herstellung_von_sonstiger_Keramik.Gesch_ftsklima__lag7, RMSE = 2.3704
#   22450/25920 Features gerankt; letztes: Herstellung_von_sonstiger_Keramik.Preise_gegen_Vormonat__lag9, RMSE = 2.3693
#   22500/25920 Features gerankt; letztes: Herstellung_von_sonstiger_Oberbekleidung.Auftragsbestand_Beurteilung__lag11, RMSE = 2.3895
#   22550/25920 Features gerankt; letztes: Herstellung_von_sonstiger_Oberbekleidung.Gesch_ftsklima__lag1, RMSE = 2.3785
#   22600/25920 Features gerankt; letztes: Herstellung_von_sonstiger_Oberbekleidung.Preise_gegen_Vormonat__lag3, RMSE = 2.3710
#   22650/25920 Features gerankt; letztes: Herstellung_von_technischen_Glaswaren.Auftragsbestand_Beurteilung__lag5, RMSE = 2.3646
#   22700/25920 Features gerankt; letztes: Herstellung_von_technischen_Glaswaren.Fertigwarenlager_Beurteilung__lag7, RMSE = 2.3566
#   22750/25920 Features gerankt; letztes: Herstellung_von_technischen_Glaswaren.Nachfrage_gegen_Vormonat__lag9, RMSE = 2.3715
#   22800/25920 Features gerankt; letztes: Herstellung_von_technischen_Glaswaren.Produktionspl_ne__lag11, RMSE = 2.3649
#   22850/25920 Features gerankt; letztes: Herstellung_von__lhydraulik.Fertigwarenlager_Beurteilung__lag1, RMSE = 2.3675
#   22900/25920 Features gerankt; letztes: Herstellung_von__lhydraulik.Nachfrage_gegen_Vormonat__lag3, RMSE = 2.3694
#   22950/25920 Features gerankt; letztes: Herstellung_von__lhydraulik.Produktionspl_ne__lag5, RMSE = 2.3651
#   23000/25920 Features gerankt; letztes: Holz__Flecht__Korb__und_Korkwarenherstellung__ohne_M_bel_.Exporterwartungen__lag7, RMSE = 2.3633
#   23050/25920 Features gerankt; letztes: Holz__Flecht__Korb__und_Korkwarenherstellung__ohne_M_bel_.Gesch_ftslage_Erwartungen__lag9, RMSE = 2.3647
#   23100/25920 Features gerankt; letztes: Holz__Flecht__Korb__und_Korkwarenherstellung__ohne_M_bel_.Produktion_gegen_Vormonat__lag11, RMSE = 2.3643
#   23150/25920 Features gerankt; letztes: Kokerei_und_Mineral_lverarbeitung.Exporterwartungen__lag1, RMSE = 2.3654
#   23200/25920 Features gerankt; letztes: Kokerei_und_Mineral_lverarbeitung.Gesch_ftslage_Erwartungen__lag3, RMSE = 2.3611
#   23250/25920 Features gerankt; letztes: Kokerei_und_Mineral_lverarbeitung.Produktion_gegen_Vormonat__lag5, RMSE = 2.3645
#   23300/25920 Features gerankt; letztes: Maschinenbau.Auftragsbestand_gegen_Vormonat__lag7, RMSE = 2.3648
#   23350/25920 Features gerankt; letztes: Maschinenbau.Gesch_ftslage_Beurteilung__lag9, RMSE = 2.3538
#   23400/25920 Features gerankt; letztes: Maschinenbau.Preiserwartungen__lag11, RMSE = 2.3687
#   23450/25920 Features gerankt; letztes: Mechanik_a.n.g..Auftragsbestand_gegen_Vormonat__lag1, RMSE = 2.3708
#   23500/25920 Features gerankt; letztes: Mechanik_a.n.g..Gesch_ftslage_Beurteilung__lag3, RMSE = 2.3628
#   23550/25920 Features gerankt; letztes: Mechanik_a.n.g..Preiserwartungen__lag5, RMSE = 2.3678
#   23600/25920 Features gerankt; letztes: Metallerzeugung_und__bearbeitung.Auftragsbestand_Beurteilung_Export__lag7, RMSE = 2.3587
#   23650/25920 Features gerankt; letztes: Metallerzeugung_und__bearbeitung.Gesch_ftsklima__lag9, RMSE = 2.3627
#   23700/25920 Features gerankt; letztes: Metallerzeugung_und__bearbeitung.Preise_gegen_Vormonat__lag11, RMSE = 2.3631
#   23750/25920 Features gerankt; letztes: Milchverarbeitung.Auftragsbestand_Beurteilung_Export__lag1, RMSE = 2.3690
#   23800/25920 Features gerankt; letztes: Milchverarbeitung.Gesch_ftsklima__lag3, RMSE = 2.3639
#   23850/25920 Features gerankt; letztes: Milchverarbeitung.Preise_gegen_Vormonat__lag5, RMSE = 2.3693
#   23900/25920 Features gerankt; letztes: NE_Metallguss.Auftragsbestand_Beurteilung__lag7, RMSE = 2.3685
#   23950/25920 Features gerankt; letztes: NE_Metallguss.Fertigwarenlager_Beurteilung__lag9, RMSE = 2.3686
#   24000/25920 Features gerankt; letztes: NE_Metallguss.Nachfrage_gegen_Vormonat__lag11, RMSE = 2.3736
#   24050/25920 Features gerankt; letztes: Oberfl_chenveredlung_W_rmebehandlung_und_Mechanik_a.n.g..Auftragsbestand_Beurteilung__lag1, RMSE = 2.3661
#   24100/25920 Features gerankt; letztes: Oberfl_chenveredlung_W_rmebehandlung_und_Mechanik_a.n.g..Fertigwarenlager_Beurteilung__lag3, RMSE = 2.3561
#   24150/25920 Features gerankt; letztes: Oberfl_chenveredlung_W_rmebehandlung_und_Mechanik_a.n.g..Nachfrage_gegen_Vormonat__lag5, RMSE = 2.3643
#   24200/25920 Features gerankt; letztes: Oberfl_chenveredlung_W_rmebehandlung_und_Mechanik_a.n.g..Produktionspl_ne__lag7, RMSE = 2.3621
#   24250/25920 Features gerankt; letztes: Papier__Karton__und_Pappeverarbeitung.Exporterwartungen__lag9, RMSE = 2.3756
#   24300/25920 Features gerankt; letztes: Papier__Karton__und_Pappeverarbeitung.Gesch_ftslage_Erwartungen__lag11, RMSE = 2.3643
#   24350/25920 Features gerankt; letztes: Papier__Karton__und_Pappeverarbeitung.Produktionspl_ne__lag1, RMSE = 2.3888
#   24400/25920 Features gerankt; letztes: Papiergewerbe.Exporterwartungen__lag3, RMSE = 2.3680
#   24450/25920 Features gerankt; letztes: Papiergewerbe.Gesch_ftslage_Erwartungen__lag5, RMSE = 2.3689
#   24500/25920 Features gerankt; letztes: Papiergewerbe.Produktion_gegen_Vormonat__lag7, RMSE = 2.3628
#   24550/25920 Features gerankt; letztes: Schlachten_und_Fleischverarbeitung.Auftragsbestand_gegen_Vormonat__lag9, RMSE = 2.3766
#   24600/25920 Features gerankt; letztes: Schlachten_und_Fleischverarbeitung.Gesch_ftslage_Beurteilung__lag11, RMSE = 2.3707
#   24650/25920 Features gerankt; letztes: Schlachten_und_Fleischverarbeitung.Produktion_gegen_Vormonat__lag1, RMSE = 2.3558
#   24700/25920 Features gerankt; letztes: Sonstiger_Fahrzeugbau.Auftragsbestand_gegen_Vormonat__lag3, RMSE = 2.3697
#   24750/25920 Features gerankt; letztes: Sonstiger_Fahrzeugbau.Gesch_ftslage_Beurteilung__lag5, RMSE = 2.3537
#   24800/25920 Features gerankt; letztes: Sonstiger_Fahrzeugbau.Preiserwartungen__lag7, RMSE = 2.3675
#   24850/25920 Features gerankt; letztes: Stahl__und_Leichtmetallbau.Auftragsbestand_Beurteilung_Export__lag9, RMSE = 2.3569
#   24900/25920 Features gerankt; letztes: Stahl__und_Leichtmetallbau.Gesch_ftsklima__lag11, RMSE = 2.3754
#   24950/25920 Features gerankt; letztes: Stahl__und_Leichtmetallbau.Preiserwartungen__lag1, RMSE = 2.3595
#   25000/25920 Features gerankt; letztes: S_ge__Hobel__und_Holzimpr_gnierwerke.Auftragsbestand_Beurteilung_Export__lag3, RMSE = 2.3665
#   25050/25920 Features gerankt; letztes: S_ge__Hobel__und_Holzimpr_gnierwerke.Gesch_ftsklima__lag5, RMSE = 2.3666
#   25100/25920 Features gerankt; letztes: S_ge__Hobel__und_Holzimpr_gnierwerke.Preise_gegen_Vormonat__lag7, RMSE = 2.3729
#   25150/25920 Features gerankt; letztes: Verarbeitendes_Gewerbe.Auftragsbestand_Beurteilung__lag9, RMSE = 2.3590
#   25200/25920 Features gerankt; letztes: Verarbeitendes_Gewerbe.Fertigwarenlager_Beurteilung__lag11, RMSE = 2.3673
#   25250/25920 Features gerankt; letztes: Verarbeitendes_Gewerbe.Preise_gegen_Vormonat__lag1, RMSE = 2.3696
#   25300/25920 Features gerankt; letztes: Verarbeitendes_Gewerbe__ohne_Ern_hrungsgewerbe_.Auftragsbestand_Beurteilung__lag3, RMSE = 2.3626
#   25350/25920 Features gerankt; letztes: Verarbeitendes_Gewerbe__ohne_Ern_hrungsgewerbe_.Fertigwarenlager_Beurteilung__lag5, RMSE = 2.3647
#   25400/25920 Features gerankt; letztes: Verarbeitendes_Gewerbe__ohne_Ern_hrungsgewerbe_.Nachfrage_gegen_Vormonat__lag7, RMSE = 2.3645
#   25450/25920 Features gerankt; letztes: Verarbeitendes_Gewerbe__ohne_Ern_hrungsgewerbe_.Produktionspl_ne__lag9, RMSE = 2.3639
#   25500/25920 Features gerankt; letztes: Veredelung_und_Bearbeitung_von_Flachglas.Exporterwartungen__lag11, RMSE = 2.3626
#   25550/25920 Features gerankt; letztes: Veredelung_und_Bearbeitung_von_Flachglas.Nachfrage_gegen_Vormonat__lag1, RMSE = 2.3652
#   25600/25920 Features gerankt; letztes: Veredelung_und_Bearbeitung_von_Flachglas.Produktionspl_ne__lag3, RMSE = 2.3659
#   25650/25920 Features gerankt; letztes: Weberei.Exporterwartungen__lag5, RMSE = 2.3725
#   25700/25920 Features gerankt; letztes: Weberei.Gesch_ftslage_Erwartungen__lag7, RMSE = 2.3635
#   25750/25920 Features gerankt; letztes: Weberei.Produktion_gegen_Vormonat__lag9, RMSE = 2.3668
#   25800/25920 Features gerankt; letztes: Zeitungsdruck.Auftragsbestand_gegen_Vormonat__lag11, RMSE = 2.3677
#   25850/25920 Features gerankt; letztes: Zeitungsdruck.Gesch_ftslage_Erwartungen__lag1, RMSE = 2.3777
#   25900/25920 Features gerankt; letztes: Zeitungsdruck.Produktion_gegen_Vormonat__lag3, RMSE = 2.3545
#   25920/25920 Features gerankt; letztes: Zeitungsdruck.Produktionspl_ne__lag11, RMSE = 2.3612
#
# === Ranking abgeschlossen ===
# Beste 10 Features nach Forward-RMSE (h=1, Ridge, expandierendes Fenster):
#   1. Herstellung_von_sonstiger_Oberbekleidung.Produktion_gegen_Vormonat__lag10  -> RMSE = 2.310379
#   2. Herstellung_von_sonstigen_Waren.Produktion_gegen_Vormonat__lag9  -> RMSE = 2.312487
#   3. Herstellung_von_medizinischen_Apparaten_und_Materialien.Produktion_gegen_Vormonat__lag9  -> RMSE = 2.313011
#   4. Herstellung_von_Heizkesseln_f_r_Zentralheizungen.Preise_gegen_Vormonat__lag0  -> RMSE = 2.314590
#   5. Herstellung_von_Backwaren__ohne_Dauerbackwaren_.Gesch_ftslage_Beurteilung__lag1  -> RMSE = 2.316559
#   6. Herstellung_von_Wasch__Reinigungs__u._K_rperpflegemitteln.Gesch_ftslage_Beurteilung__lag0  -> RMSE = 2.317039
#   7. Herstellung_von_Heizkesseln_und__k_rpern_f_r_Zentralheizungen.Preise_gegen_Vormonat__lag0  -> RMSE = 2.321290
#   8. Getr_nkeherstellung.Fertigwarenlager_Beurteilung__lag0  -> RMSE = 2.321629
#   9. Herstellung_isolierter_Elektrokabel__leitungen_und__dr_hte.Nachfrage_gegen_Vormonat__lag2  -> RMSE = 2.323179
#   10. Herstellung_von_Nutzkraftwagen.Auftragsbestand_Beurteilung_Export__lag7  -> RMSE = 2.324921
