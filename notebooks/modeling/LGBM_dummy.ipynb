# %%
# --- Setup & Imports ---
import os, sys
from pathlib import Path
import pandas as pd
import numpy as np

# --- 1. Pfad-Setup (wie in ET.ipynb) ---
def _locate_repo_root(start: Path) -> Path:
    cur = start.resolve()
    for _ in range(5):
        if (cur / 'src').exists():
            return cur
        if cur.parent == cur:
            break
        cur = cur.parent
    return start.resolve()

NOTEBOOK_DIR = Path.cwd()
PROJECT_ROOT = _locate_repo_root(NOTEBOOK_DIR)
os.environ['PROJECT_ROOT'] = str(PROJECT_ROOT)
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from src.config import GlobalConfig, DEFAULT_CORR_SPEC, EWMA_CORR_SPEC, outputs_for_model
from src.tuning import run_stageA, run_stageB
from src.io_timesplits import (
    load_target, load_ifo_features,
    load_full_lagged_features, load_rolling_importance
)
# --- MODELL-IMPORT (LGBM-Wrapper im ET/EN-API-Stil) ---
from src.models.LGBM import ForecastModel  # LightGBM Regressor-Wrapper

print('PROJECT_ROOT =', PROJECT_ROOT)

# --- 2. Master-Switch & Pfade ---
USE_DYNAMIC_FI_PIPELINE = False  # False => normale FE-Pipeline, True => Dynamic FI
FI_PATH = PROJECT_ROOT / "outputs" / "feature_importance" / "outputs_no_missing"

MODEL_NAME = "lightgbm_dynamic_fi_debug" if USE_DYNAMIC_FI_PIPELINE else "lightgbm_debug"
outputs_for_model(MODEL_NAME)
print(f'Modell {MODEL_NAME} wird getunt (DEBUG).')

# --- 3. Daten laden ---
y = load_target()          # ΔIP (DatetimeIndex)
X_ifo = load_ifo_features()

if USE_DYNAMIC_FI_PIPELINE:
    try:
        X_full_lagged = load_full_lagged_features(base_dir=FI_PATH)
        rolling_imp   = load_rolling_importance(base_dir=FI_PATH)
        idx_fi = y.index.intersection(X_full_lagged.index).intersection(rolling_imp.index)
        y_fi, X_full_lagged, rolling_imp = y.loc[idx_fi], X_full_lagged.loc[idx_fi], rolling_imp.loc[idx_fi]
        print('Dynamic-FI Daten geladen. Shapes:', X_full_lagged.shape, rolling_imp.shape)
    except FileNotFoundError as e:
        print(f"FEHLER: {e}")
        print("Hinweis: Für Dynamic FI müssen die Artefakte aus feature_importance.ipynb vorhanden sein.")
        raise
else:
    X_full_lagged, rolling_imp = None, None
    idx = y.index.intersection(X_ifo.index)
    y, X_ifo = y.loc[idx], X_ifo.loc[idx]
    print('Normale FE-Daten geladen. Shapes:', X_ifo.shape, y.shape)

# --- 4. Base config: DEBUG (mit Fallback) ---
def base_cfg_debug() -> GlobalConfig:
    try:
        cfg = GlobalConfig(preset="debug")  # schneller, weniger Splits
    except Exception:
        cfg = GlobalConfig(preset="thesis")
        # kompaktere Policy als Fallback
        cfg.policy_window   = 12
        cfg.policy_decay    = 0.95
        cfg.policy_gain_min = 0.05
        cfg.policy_cooldown = 2
        return cfg
    # Debug-Policy
    cfg.policy_window   = 12
    cfg.policy_decay    = 0.95
    cfg.policy_gain_min = 0.05
    cfg.policy_cooldown = 2
    return cfg

cfg0 = base_cfg_debug()

# --- 5. Corr-Spezifikation (wie ET) ---
def make_corr_spec(kind: str) -> dict:
    if kind == 'expanding':
        return dict(DEFAULT_CORR_SPEC)
    elif kind == 'ewm':
        return dict(EWMA_CORR_SPEC)
    else:
        raise ValueError("kind must be 'expanding' or 'ewm'")

# --- 6. Mini-Grids ohne tiefe Schachtelung (je Modus genau 1 HP-Set) ---

if USE_DYNAMIC_FI_PIPELINE:
    print("Erstelle MINI-Grid für 'Dynamic FI' (DEBUG)...")
    model_grid = [{
        # Dynamic-FI spezifisch
        'n_features_to_use': 10,
        # LGBM Minimal-HPs (schnell)
        'n_estimators': 300,
        'learning_rate': 0.05,
        'num_leaves': 31,
        'max_depth': -1,
        'min_child_samples': 20,
        'colsample_bytree': 1.0,
        'subsample': 1.0,
        'bagging_freq': 0,
        'reg_alpha': 0.0,
        'reg_lambda': 0.0,
        'min_split_gain': 0.0,
        'min_child_weight': 1e-3,
        'importance_type': 'gain',
        # Early Stopping off (Speed)
        'early_stopping_rounds': None,
        'val_tail': None,
        'seed': 42,
        'n_jobs': 1,
        # Gewichtung
        'sample_weight_decay': None,
    }]
else:
    print("Erstelle MINI-Grid für 'Full FE' (DEBUG)...")
    # nur eine Corr-Variante und eine FE-Kombi, um die ET-Logik zu spiegeln
    corr_tag, corr_spec = ("expanding", make_corr_spec("expanding"))

    model_grid = [{
        # --- FE/DR/Blocks (minimal) ---
        'lag_candidates': (1, 3, 12),
        'top_k_lags_per_feature': 1,
        'use_rm3': True,
        'k1_topk': 100,
        'redundancy_param': 0.90,
        'dr_method': 'none',
        'corr_tag': corr_tag,
        'corr_spec': corr_spec,
        'target_block_set': None,
        'sample_weight_decay': None,
        # --- LGBM Minimal-HPs ---
        'n_estimators': 300,
        'learning_rate': 0.05,
        'num_leaves': 31,
        'max_depth': -1,
        'min_child_samples': 20,
        'colsample_bytree': 1.0,
        'subsample': 1.0,
        'bagging_freq': 0,
        'reg_alpha': 0.0,
        'reg_lambda': 0.0,
        'min_split_gain': 0.0,
        'min_child_weight': 1e-3,
        'importance_type': 'gain',
        'early_stopping_rounds': None,
        'val_tail': None,
        'seed': 42,
        'n_jobs': 1,
    }]

print("HP-Kombinationen (DEBUG):", len(model_grid))
print("Erstes HP-Set:", model_grid[0] if model_grid else "Grid ist leer")

# --- 7. Stage A/B Lauf (minimale Einstellungen) ---
if model_grid:
    if USE_DYNAMIC_FI_PIPELINE:
        shortlist = run_stageA(
            model_name=MODEL_NAME,
            model_ctor=lambda hp: ForecastModel(hp),
            model_grid=model_grid,
            X=X_ifo,           # Platzhalter
            y=y_fi,
            cfg=cfg0,
            keep_top_k_final=1,
            min_survivors_per_block=1,
            X_full_lagged=X_full_lagged,
            rolling_imp=rolling_imp
        )
        run_stageB(
            model_name=MODEL_NAME,
            model_ctor=lambda hp: ForecastModel(hp),
            shortlist=shortlist,
            X=X_ifo,           # Platzhalter
            y=y_fi,
            cfg=cfg0,
            X_full_lagged=X_full_lagged,
            rolling_imp=rolling_imp
        )
    else:
        shortlist = run_stageA(
            model_name=MODEL_NAME,
            model_ctor=lambda hp: ForecastModel(hp),
            model_grid=model_grid,
            X=X_ifo,
            y=y,
            cfg=cfg0,
            keep_top_k_final=1,
            min_survivors_per_block=1,
        )
        run_stageB(
            model_name=MODEL_NAME,
            model_ctor=lambda hp: ForecastModel(hp),
            shortlist=shortlist,
            X=X_ifo,
            y=y,
            cfg=cfg0,
        )
else:
    print("Keine gültigen HP-Kombinationen gefunden, Stages übersprungen.")

print(f"\nDone (DEBUG). Results in outputs/stageA|stageB/{MODEL_NAME}.")
# Out:
# PROJECT_ROOT = /Users/jonasschernich/Documents/Masterarbeit/Code
# Modell lightgbm_debug wird getunt (DEBUG).
# INFO in load_ifo_features: Renaming columns to ensure validity.
# Normale FE-Daten geladen. Shapes: (407, 2160) (407,)
# Erstelle MINI-Grid für 'Full FE' (DEBUG)...
# HP-Kombinationen (DEBUG): 1
# Erstes HP-Set: {'lag_candidates': (1, 3, 12), 'top_k_lags_per_feature': 1, 'use_rm3': True, 'k1_topk': 100, 'redundancy_param': 0.9, 'dr_method': 'none', 'corr_tag': 'expanding', 'corr_spec': {'mode': 'expanding', 'window': None, 'lam': None}, 'target_block_set': None, 'sample_weight_decay': None, 'n_estimators': 300, 'learning_rate': 0.05, 'num_leaves': 31, 'max_depth': -1, 'min_child_samples': 20, 'colsample_bytree': 1.0, 'subsample': 1.0, 'bagging_freq': 0, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'min_split_gain': 0.0, 'min_child_weight': 0.001, 'importance_type': 'gain', 'early_stopping_rounds': None, 'val_tail': None, 'seed': 42, 'n_jobs': 1}
# [Stage A] Using FULL FE pipeline (Gleis 1 & 2).
# [Stage A][Block 1] train_end=48, OOS=49-60 | configs=1
#   - Config 1/1
#     · Month 5/12 processed | running...RMSE=0.8592
#     · Month 10/12 processed | running...RMSE=1.0747
#     · Month 12/12 processed | running...RMSE=1.0796
# [Stage A][Block 1] kept 1 configs (floor=1).
# [Stage A][Block 2] train_end=60, OOS=61-72 | configs=1
#   - Config 1/1
#     · Month 5/12 processed | running...RMSE=1.1637
#     · Month 10/12 processed | running...RMSE=1.2243
#     · Month 12/12 processed | running...RMSE=1.5906
# [Stage A][Block 2] kept 1 configs (floor=1).
# [Stage A] Shortlist saved with 1 configs.
# [Stage B] Using FULL FE pipeline (Gleis 1 & 2).
# [Stage B] Month origin t=73 | evaluating 1 configs | active=1
# [Stage B] Month origin t=74 | evaluating 1 configs | active=1
# [Stage B] Month origin t=75 | evaluating 1 configs | active=1
# [Stage B] Month origin t=76 | evaluating 1 configs | active=1
# [Stage B] Month origin t=77 | evaluating 1 configs | active=1
# [Stage B] Month origin t=78 | evaluating 1 configs | active=1
# [Stage B] Month origin t=79 | evaluating 1 configs | active=1
# [Stage B] Month origin t=80 | evaluating 1 configs | active=1
# [Stage B] Month origin t=81 | evaluating 1 configs | active=1
# [Stage B] Month origin t=82 | evaluating 1 configs | active=1
# [Stage B] Month origin t=83 | evaluating 1 configs | active=1
# [Stage B] Month origin t=84 | evaluating 1 configs | active=1
# [Stage B] Month origin t=85 | evaluating 1 configs | active=1
# [Stage B] Month origin t=86 | evaluating 1 configs | active=1
# [Stage B] Month origin t=87 | evaluating 1 configs | active=1
# [Stage B] Month origin t=88 | evaluating 1 configs | active=1
# [Stage B] Month origin t=89 | evaluating 1 configs | active=1
# [Stage B] Month origin t=90 | evaluating 1 configs | active=1
# [Stage B] Month origin t=91 | evaluating 1 configs | active=1
# [Stage B] Month origin t=92 | evaluating 1 configs | active=1
# [Stage B] Month origin t=93 | evaluating 1 configs | active=1
# [Stage B] Month origin t=94 | evaluating 1 configs | active=1
# [Stage B] Month origin t=95 | evaluating 1 configs | active=1
# [Stage B] Month origin t=96 | evaluating 1 configs | active=1
# [Stage B] Month origin t=97 | evaluating 1 configs | active=1
# [Stage B] Month origin t=98 | evaluating 1 configs | active=1
# [Stage B] Month origin t=99 | evaluating 1 configs | active=1
# [Stage B] Month origin t=100 | evaluating 1 configs | active=1
# [Stage B] Month origin t=101 | evaluating 1 configs | active=1
# [Stage B] Month origin t=102 | evaluating 1 configs | active=1
# [Stage B] Month origin t=103 | evaluating 1 configs | active=1
# [Stage B] Month origin t=104 | evaluating 1 configs | active=1
# [Stage B] Month origin t=105 | evaluating 1 configs | active=1
# [Stage B] Month origin t=106 | evaluating 1 configs | active=1
# [Stage B] Month origin t=107 | evaluating 1 configs | active=1
# [Stage B] Month origin t=108 | evaluating 1 configs | active=1
# [Stage B] Month origin t=109 | evaluating 1 configs | active=1
# [Stage B] Month origin t=110 | evaluating 1 configs | active=1
# [Stage B] Month origin t=111 | evaluating 1 configs | active=1
# [Stage B] Month origin t=112 | evaluating 1 configs | active=1
# [Stage B] Month origin t=113 | evaluating 1 configs | active=1
# [Stage B] Month origin t=114 | evaluating 1 configs | active=1
# [Stage B] Month origin t=115 | evaluating 1 configs | active=1
# [Stage B] Month origin t=116 | evaluating 1 configs | active=1
# [Stage B] Month origin t=117 | evaluating 1 configs | active=1
# [Stage B] Month origin t=118 | evaluating 1 configs | active=1
# [Stage B] Month origin t=119 | evaluating 1 configs | active=1
# [Stage B] Month origin t=120 | evaluating 1 configs | active=1
# [Stage B] Month origin t=121 | evaluating 1 configs | active=1
# [Stage B] Month origin t=122 | evaluating 1 configs | active=1
# [Stage B] Month origin t=123 | evaluating 1 configs | active=1
# [Stage B] Month origin t=124 | evaluating 1 configs | active=1
# [Stage B] Month origin t=125 | evaluating 1 configs | active=1
# [Stage B] Month origin t=126 | evaluating 1 configs | active=1
# [Stage B] Month origin t=127 | evaluating 1 configs | active=1
# [Stage B] Month origin t=128 | evaluating 1 configs | active=1
# [Stage B] Month origin t=129 | evaluating 1 configs | active=1
# [Stage B] Month origin t=130 | evaluating 1 configs | active=1
# [Stage B] Month origin t=131 | evaluating 1 configs | active=1
# [Stage B] Month origin t=132 | evaluating 1 configs | active=1
# [Stage B] Month origin t=133 | evaluating 1 configs | active=1
# [Stage B] Month origin t=134 | evaluating 1 configs | active=1
# [Stage B] Month origin t=135 | evaluating 1 configs | active=1
# [Stage B] Month origin t=136 | evaluating 1 configs | active=1
# [Stage B] Month origin t=137 | evaluating 1 configs | active=1
# [Stage B] Month origin t=138 | evaluating 1 configs | active=1
# [Stage B] Month origin t=139 | evaluating 1 configs | active=1
# [Stage B] Month origin t=140 | evaluating 1 configs | active=1
# [Stage B] Month origin t=141 | evaluating 1 configs | active=1
# [Stage B] Month origin t=142 | evaluating 1 configs | active=1
# [Stage B] Month origin t=143 | evaluating 1 configs | active=1
# [Stage B] Month origin t=144 | evaluating 1 configs | active=1
# [Stage B] Month origin t=145 | evaluating 1 configs | active=1
# [Stage B] Month origin t=146 | evaluating 1 configs | active=1
# [Stage B] Month origin t=147 | evaluating 1 configs | active=1
# [Stage B] Month origin t=148 | evaluating 1 configs | active=1
# [Stage B] Month origin t=149 | evaluating 1 configs | active=1
# [Stage B] Month origin t=150 | evaluating 1 configs | active=1
# [Stage B] Month origin t=151 | evaluating 1 configs | active=1
# [Stage B] Month origin t=152 | evaluating 1 configs | active=1
# [Stage B] Month origin t=153 | evaluating 1 configs | active=1
# [Stage B] Month origin t=154 | evaluating 1 configs | active=1
# [Stage B] Month origin t=155 | evaluating 1 configs | active=1
# [Stage B] Month origin t=156 | evaluating 1 configs | active=1
# [Stage B] Month origin t=157 | evaluating 1 configs | active=1
# [Stage B] Month origin t=158 | evaluating 1 configs | active=1
# [Stage B] Month origin t=159 | evaluating 1 configs | active=1
# [Stage B] Month origin t=160 | evaluating 1 configs | active=1
# [Stage B] Month origin t=161 | evaluating 1 configs | active=1
# [Stage B] Month origin t=162 | evaluating 1 configs | active=1
# [Stage B] Month origin t=163 | evaluating 1 configs | active=1
# [Stage B] Month origin t=164 | evaluating 1 configs | active=1
# [Stage B] Month origin t=165 | evaluating 1 configs | active=1
# [Stage B] Month origin t=166 | evaluating 1 configs | active=1
# [Stage B] Month origin t=167 | evaluating 1 configs | active=1
# [Stage B] Month origin t=168 | evaluating 1 configs | active=1
# [Stage B] Month origin t=169 | evaluating 1 configs | active=1
# [Stage B] Month origin t=170 | evaluating 1 configs | active=1
# [Stage B] Month origin t=171 | evaluating 1 configs | active=1
# [Stage B] Month origin t=172 | evaluating 1 configs | active=1
# [Stage B] Month origin t=173 | evaluating 1 configs | active=1
# [Stage B] Month origin t=174 | evaluating 1 configs | active=1
# [Stage B] Month origin t=175 | evaluating 1 configs | active=1
# [Stage B] Month origin t=176 | evaluating 1 configs | active=1
# [Stage B] Month origin t=177 | evaluating 1 configs | active=1
# [Stage B] Month origin t=178 | evaluating 1 configs | active=1
# [Stage B] Month origin t=179 | evaluating 1 configs | active=1
# [Stage B] Month origin t=180 | evaluating 1 configs | active=1
# [Stage B] Month origin t=181 | evaluating 1 configs | active=1
# [Stage B] Month origin t=182 | evaluating 1 configs | active=1
# [Stage B] Month origin t=183 | evaluating 1 configs | active=1
# [Stage B] Month origin t=184 | evaluating 1 configs | active=1
# [Stage B] Month origin t=185 | evaluating 1 configs | active=1
# [Stage B] Month origin t=186 | evaluating 1 configs | active=1
# [Stage B] Month origin t=187 | evaluating 1 configs | active=1
# [Stage B] Month origin t=188 | evaluating 1 configs | active=1
# [Stage B] Month origin t=189 | evaluating 1 configs | active=1
# [Stage B] Month origin t=190 | evaluating 1 configs | active=1
# [Stage B] Month origin t=191 | evaluating 1 configs | active=1
# [Stage B] Month origin t=192 | evaluating 1 configs | active=1
# [Stage B] Month origin t=193 | evaluating 1 configs | active=1
# [Stage B] Month origin t=194 | evaluating 1 configs | active=1
# [Stage B] Month origin t=195 | evaluating 1 configs | active=1
# [Stage B] Month origin t=196 | evaluating 1 configs | active=1
# [Stage B] Month origin t=197 | evaluating 1 configs | active=1
# [Stage B] Month origin t=198 | evaluating 1 configs | active=1
# [Stage B] Month origin t=199 | evaluating 1 configs | active=1
# [Stage B] Month origin t=200 | evaluating 1 configs | active=1
# [Stage B] Month origin t=201 | evaluating 1 configs | active=1
# [Stage B] Month origin t=202 | evaluating 1 configs | active=1
# [Stage B] Month origin t=203 | evaluating 1 configs | active=1
# [Stage B] Month origin t=204 | evaluating 1 configs | active=1
# [Stage B] Month origin t=205 | evaluating 1 configs | active=1
# [Stage B] Month origin t=206 | evaluating 1 configs | active=1
# [Stage B] Month origin t=207 | evaluating 1 configs | active=1
# [Stage B] Month origin t=208 | evaluating 1 configs | active=1
# [Stage B] Month origin t=209 | evaluating 1 configs | active=1
# [Stage B] Month origin t=210 | evaluating 1 configs | active=1
# [Stage B] Month origin t=211 | evaluating 1 configs | active=1
# [Stage B] Month origin t=212 | evaluating 1 configs | active=1
# [Stage B] Month origin t=213 | evaluating 1 configs | active=1
# [Stage B] Month origin t=214 | evaluating 1 configs | active=1
# [Stage B] Month origin t=215 | evaluating 1 configs | active=1
# [Stage B] Month origin t=216 | evaluating 1 configs | active=1
# [Stage B] Month origin t=217 | evaluating 1 configs | active=1
# [Stage B] Month origin t=218 | evaluating 1 configs | active=1
# [Stage B] Month origin t=219 | evaluating 1 configs | active=1
# [Stage B] Month origin t=220 | evaluating 1 configs | active=1
# [Stage B] Month origin t=221 | evaluating 1 configs | active=1
# [Stage B] Month origin t=222 | evaluating 1 configs | active=1
# [Stage B] Month origin t=223 | evaluating 1 configs | active=1
# [Stage B] Month origin t=224 | evaluating 1 configs | active=1
# [Stage B] Month origin t=225 | evaluating 1 configs | active=1
# [Stage B] Month origin t=226 | evaluating 1 configs | active=1
# [Stage B] Month origin t=227 | evaluating 1 configs | active=1
# [Stage B] Month origin t=228 | evaluating 1 configs | active=1
# [Stage B] Month origin t=229 | evaluating 1 configs | active=1
# [Stage B] Month origin t=230 | evaluating 1 configs | active=1
# [Stage B] Month origin t=231 | evaluating 1 configs | active=1
# [Stage B] Month origin t=232 | evaluating 1 configs | active=1
# [Stage B] Month origin t=233 | evaluating 1 configs | active=1
# [Stage B] Month origin t=234 | evaluating 1 configs | active=1
# [Stage B] Month origin t=235 | evaluating 1 configs | active=1
# [Stage B] Month origin t=236 | evaluating 1 configs | active=1
# [Stage B] Month origin t=237 | evaluating 1 configs | active=1
# [Stage B] Month origin t=238 | evaluating 1 configs | active=1
# [Stage B] Month origin t=239 | evaluating 1 configs | active=1
# [Stage B] Month origin t=240 | evaluating 1 configs | active=1
# [Stage B] Month origin t=241 | evaluating 1 configs | active=1
# [Stage B] Month origin t=242 | evaluating 1 configs | active=1
# [Stage B] Month origin t=243 | evaluating 1 configs | active=1
# [Stage B] Month origin t=244 | evaluating 1 configs | active=1
# [Stage B] Month origin t=245 | evaluating 1 configs | active=1
# [Stage B] Month origin t=246 | evaluating 1 configs | active=1
# [Stage B] Month origin t=247 | evaluating 1 configs | active=1
# [Stage B] Month origin t=248 | evaluating 1 configs | active=1
# [Stage B] Month origin t=249 | evaluating 1 configs | active=1
# [Stage B] Month origin t=250 | evaluating 1 configs | active=1
# [Stage B] Month origin t=251 | evaluating 1 configs | active=1
# [Stage B] Month origin t=252 | evaluating 1 configs | active=1
# [Stage B] Month origin t=253 | evaluating 1 configs | active=1
# [Stage B] Month origin t=254 | evaluating 1 configs | active=1
# [Stage B] Month origin t=255 | evaluating 1 configs | active=1
# [Stage B] Month origin t=256 | evaluating 1 configs | active=1
# [Stage B] Month origin t=257 | evaluating 1 configs | active=1
# [Stage B] Month origin t=258 | evaluating 1 configs | active=1
# [Stage B] Month origin t=259 | evaluating 1 configs | active=1
# [Stage B] Month origin t=260 | evaluating 1 configs | active=1
# [Stage B] Month origin t=261 | evaluating 1 configs | active=1
# [Stage B] Month origin t=262 | evaluating 1 configs | active=1
# [Stage B] Month origin t=263 | evaluating 1 configs | active=1
# [Stage B] Month origin t=264 | evaluating 1 configs | active=1
# [Stage B] Month origin t=265 | evaluating 1 configs | active=1
# [Stage B] Month origin t=266 | evaluating 1 configs | active=1
# [Stage B] Month origin t=267 | evaluating 1 configs | active=1
# [Stage B] Month origin t=268 | evaluating 1 configs | active=1
# [Stage B] Month origin t=269 | evaluating 1 configs | active=1
# [Stage B] Month origin t=270 | evaluating 1 configs | active=1
# [Stage B] Month origin t=271 | evaluating 1 configs | active=1
# [Stage B] Month origin t=272 | evaluating 1 configs | active=1
# [Stage B] Month origin t=273 | evaluating 1 configs | active=1
# [Stage B] Month origin t=274 | evaluating 1 configs | active=1
# [Stage B] Month origin t=275 | evaluating 1 configs | active=1
# [Stage B] Month origin t=276 | evaluating 1 configs | active=1
# [Stage B] Month origin t=277 | evaluating 1 configs | active=1
# [Stage B] Month origin t=278 | evaluating 1 configs | active=1
# [Stage B] Month origin t=279 | evaluating 1 configs | active=1
# [Stage B] Month origin t=280 | evaluating 1 configs | active=1
# [Stage B] Month origin t=281 | evaluating 1 configs | active=1
# [Stage B] Month origin t=282 | evaluating 1 configs | active=1
# [Stage B] Month origin t=283 | evaluating 1 configs | active=1
# [Stage B] Month origin t=284 | evaluating 1 configs | active=1
# [Stage B] Month origin t=285 | evaluating 1 configs | active=1
# [Stage B] Month origin t=286 | evaluating 1 configs | active=1
# [Stage B] Month origin t=287 | evaluating 1 configs | active=1
# [Stage B] Month origin t=288 | evaluating 1 configs | active=1
# [Stage B] Month origin t=289 | evaluating 1 configs | active=1
# [Stage B] Month origin t=290 | evaluating 1 configs | active=1
# [Stage B] Month origin t=291 | evaluating 1 configs | active=1
# [Stage B] Month origin t=292 | evaluating 1 configs | active=1
# [Stage B] Month origin t=293 | evaluating 1 configs | active=1
# [Stage B] Month origin t=294 | evaluating 1 configs | active=1
# [Stage B] Month origin t=295 | evaluating 1 configs | active=1
# [Stage B] Month origin t=296 | evaluating 1 configs | active=1
# [Stage B] Month origin t=297 | evaluating 1 configs | active=1
# [Stage B] Month origin t=298 | evaluating 1 configs | active=1
# [Stage B] Month origin t=299 | evaluating 1 configs | active=1
# [Stage B] Month origin t=300 | evaluating 1 configs | active=1
# [Stage B] Month origin t=301 | evaluating 1 configs | active=1
# [Stage B] Month origin t=302 | evaluating 1 configs | active=1
# [Stage B] Month origin t=303 | evaluating 1 configs | active=1
# [Stage B] Month origin t=304 | evaluating 1 configs | active=1
# [Stage B] Month origin t=305 | evaluating 1 configs | active=1
# [Stage B] Month origin t=306 | evaluating 1 configs | active=1
# [Stage B] Month origin t=307 | evaluating 1 configs | active=1
# [Stage B] Month origin t=308 | evaluating 1 configs | active=1
# [Stage B] Month origin t=309 | evaluating 1 configs | active=1
# [Stage B] Month origin t=310 | evaluating 1 configs | active=1
# [Stage B] Month origin t=311 | evaluating 1 configs | active=1
# [Stage B] Month origin t=312 | evaluating 1 configs | active=1
# [Stage B] Month origin t=313 | evaluating 1 configs | active=1
# [Stage B] Month origin t=314 | evaluating 1 configs | active=1
# [Stage B] Month origin t=315 | evaluating 1 configs | active=1
# [Stage B] Month origin t=316 | evaluating 1 configs | active=1
# [Stage B] Month origin t=317 | evaluating 1 configs | active=1
# [Stage B] Month origin t=318 | evaluating 1 configs | active=1
# [Stage B] Month origin t=319 | evaluating 1 configs | active=1
# [Stage B] Month origin t=320 | evaluating 1 configs | active=1
# [Stage B] Month origin t=321 | evaluating 1 configs | active=1
# [Stage B] Month origin t=322 | evaluating 1 configs | active=1
# [Stage B] Month origin t=323 | evaluating 1 configs | active=1
# [Stage B] Month origin t=324 | evaluating 1 configs | active=1
# [Stage B] Month origin t=325 | evaluating 1 configs | active=1
# [Stage B] Month origin t=326 | evaluating 1 configs | active=1
# [Stage B] Month origin t=327 | evaluating 1 configs | active=1
# [Stage B] Month origin t=328 | evaluating 1 configs | active=1
# [Stage B] Month origin t=329 | evaluating 1 configs | active=1
# [Stage B] Month origin t=330 | evaluating 1 configs | active=1
# [Stage B] Month origin t=331 | evaluating 1 configs | active=1
# [Stage B] Month origin t=332 | evaluating 1 configs | active=1
# [Stage B] Month origin t=333 | evaluating 1 configs | active=1
# [Stage B] Month origin t=334 | evaluating 1 configs | active=1
# [Stage B] Month origin t=335 | evaluating 1 configs | active=1
# [Stage B] Month origin t=336 | evaluating 1 configs | active=1
# [Stage B] Month origin t=337 | evaluating 1 configs | active=1
# [Stage B] Month origin t=338 | evaluating 1 configs | active=1
# [Stage B] Month origin t=339 | evaluating 1 configs | active=1
# [Stage B] Month origin t=340 | evaluating 1 configs | active=1
# [Stage B] Month origin t=341 | evaluating 1 configs | active=1
# [Stage B] Month origin t=342 | evaluating 1 configs | active=1
# [Stage B] Month origin t=343 | evaluating 1 configs | active=1
# [Stage B] Month origin t=344 | evaluating 1 configs | active=1
# [Stage B] Month origin t=345 | evaluating 1 configs | active=1
# [Stage B] Month origin t=346 | evaluating 1 configs | active=1
# [Stage B] Month origin t=347 | evaluating 1 configs | active=1
# [Stage B] Month origin t=348 | evaluating 1 configs | active=1
# [Stage B] Month origin t=349 | evaluating 1 configs | active=1
# [Stage B] Month origin t=350 | evaluating 1 configs | active=1
# [Stage B] Month origin t=351 | evaluating 1 configs | active=1
# [Stage B] Month origin t=352 | evaluating 1 configs | active=1
# [Stage B] Month origin t=353 | evaluating 1 configs | active=1
# [Stage B] Month origin t=354 | evaluating 1 configs | active=1
# [Stage B] Month origin t=355 | evaluating 1 configs | active=1
# [Stage B] Month origin t=356 | evaluating 1 configs | active=1
# [Stage B] Month origin t=357 | evaluating 1 configs | active=1
# [Stage B] Month origin t=358 | evaluating 1 configs | active=1
# [Stage B] Month origin t=359 | evaluating 1 configs | active=1
# [Stage B] Month origin t=360 | evaluating 1 configs | active=1
# [Stage B] Month origin t=361 | evaluating 1 configs | active=1
# [Stage B] Month origin t=362 | evaluating 1 configs | active=1
# [Stage B] Month origin t=363 | evaluating 1 configs | active=1
# [Stage B] Month origin t=364 | evaluating 1 configs | active=1
# [Stage B] Month origin t=365 | evaluating 1 configs | active=1
# [Stage B] Month origin t=366 | evaluating 1 configs | active=1
# [Stage B] Month origin t=367 | evaluating 1 configs | active=1
# [Stage B] Month origin t=368 | evaluating 1 configs | active=1
# [Stage B] Month origin t=369 | evaluating 1 configs | active=1
# [Stage B] Month origin t=370 | evaluating 1 configs | active=1
# [Stage B] Month origin t=371 | evaluating 1 configs | active=1
# [Stage B] Month origin t=372 | evaluating 1 configs | active=1
# [Stage B] Month origin t=373 | evaluating 1 configs | active=1
# [Stage B] Month origin t=374 | evaluating 1 configs | active=1
# [Stage B] Month origin t=375 | evaluating 1 configs | active=1
# [Stage B] Month origin t=376 | evaluating 1 configs | active=1
# [Stage B] Month origin t=377 | evaluating 1 configs | active=1
# [Stage B] Month origin t=378 | evaluating 1 configs | active=1
# [Stage B] Month origin t=379 | evaluating 1 configs | active=1
# [Stage B] Month origin t=380 | evaluating 1 configs | active=1
# [Stage B] Month origin t=381 | evaluating 1 configs | active=1
# [Stage B] Month origin t=382 | evaluating 1 configs | active=1
# [Stage B] Month origin t=383 | evaluating 1 configs | active=1
# [Stage B] Month origin t=384 | evaluating 1 configs | active=1
# [Stage B] Month origin t=385 | evaluating 1 configs | active=1
# [Stage B] Month origin t=386 | evaluating 1 configs | active=1
# [Stage B] Month origin t=387 | evaluating 1 configs | active=1
# [Stage B] Month origin t=388 | evaluating 1 configs | active=1
# [Stage B] Month origin t=389 | evaluating 1 configs | active=1
# [Stage B] Month origin t=390 | evaluating 1 configs | active=1
# [Stage B] Month origin t=391 | evaluating 1 configs | active=1
# [Stage B] Month origin t=392 | evaluating 1 configs | active=1
# [Stage B] Month origin t=393 | evaluating 1 configs | active=1
# [Stage B] Month origin t=394 | evaluating 1 configs | active=1
# [Stage B] Month origin t=395 | evaluating 1 configs | active=1
# [Stage B] Month origin t=396 | evaluating 1 configs | active=1
# [Stage B] Month origin t=397 | evaluating 1 configs | active=1
# [Stage B] Month origin t=398 | evaluating 1 configs | active=1
# [Stage B] Month origin t=399 | evaluating 1 configs | active=1
# [Stage B] Month origin t=400 | evaluating 1 configs | active=1
# [Stage B] Month origin t=401 | evaluating 1 configs | active=1
# [Stage B] Month origin t=402 | evaluating 1 configs | active=1
# [Stage B] Month origin t=403 | evaluating 1 configs | active=1
# [Stage B] Month origin t=404 | evaluating 1 configs | active=1
# [Stage B] Month origin t=405 | evaluating 1 configs | active=1
# [Stage B] done → /Users/jonasschernich/Documents/Masterarbeit/Code/outputs/stageB/lightgbm_debug/monthly
# [Stage B] summary.csv & summary_active.txt geschrieben.
#
# Done (DEBUG). Results in outputs/stageA|stageB/lightgbm_debug.
